# %% [markdown]
# ![4step.png](data:image/png;base64,...)

# %%
dyt1_sy= ['torsina','dyt1', 'tor1a', 'primary dystonias',
'dyt1 dystonia', 'tor1a dystonia',
'early-onset torsion dystonia',
"oppenheim's dystonia",'primary torsion dystonia',
 'idiopathic torsion dystonia', "Dystonia musculorum deformans",
'EOTD',
'Early-onset generalized torsion dystonia',
'Early-onset isolated dystonia',
'Early-onset primary dystonia',
'Early-onset torsion dystonia',
'Idiopathic torsion dystonia',
'Oppenheim dystonia',
'Early-onset generalized limb-onset dystonia',
'DYT1', 'dystonia 1', 'torsion (autosomal dominant; torsin A)', 'torsin family 1', "member A (torsin A)",
'Early onset torsion dystonia',
'EOTD',
'Dystonia musculorum deformans 1',
'Early-onset primary dystonia',
"Oppenheim's dystonia",
'Idiopathic dystonia DYT1',
'Idiopathic torsion dystonia',
'Dystonia 1, torsion, autosomal dominant',
'DYT1 Early-Onset Isolated Dystonia',
'Early-Onset Torsion Dystonia',
'Early-onset generalized dystonia',
'DYT-TOR1A dystonia',
'Dystonia 1',
'DQ2', 'torsin A', 'torsin-1A', 'torsinA'
]

dyt1_sy= list(set(dyt1_sy))
dyt1_sy= [i.lower().strip() for i in dyt1_sy]
print(dyt1_sy)
# Out:
# ['early-onset generalized torsion dystonia', 'tor1a dystonia', 'idiopathic dystonia dyt1', 'primary torsion dystonia', 'early-onset torsion dystonia', "oppenheim's dystonia", 'torsin a', 'early onset torsion dystonia', 'dyt1 dystonia', 'torsina', 'oppenheim dystonia', 'early-onset generalized dystonia', 'torsin-1a', 'tor1a', 'dyt1', 'dystonia 1', 'torsion (autosomal dominant; torsin a)', "oppenheim's dystonia", 'dyt1 early-onset isolated dystonia', 'early-onset torsion dystonia', 'dyt1', 'torsin family 1', 'dystonia musculorum deformans 1', 'dystonia musculorum deformans', 'dystonia 1, torsion, autosomal dominant', 'idiopathic torsion dystonia', 'early-onset generalized limb-onset dystonia', 'idiopathic torsion dystonia', 'dq2', 'early-onset primary dystonia', 'member a (torsin a)', 'dyt-tor1a dystonia', 'torsina', 'primary dystonias', 'early-onset torsion dystonia', 'eotd', 'dystonia 1', 'early-onset isolated dystonia']

# %%
# !pip install chembl-webresource-client
# Out:
# Collecting chembl-webresource-client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 527.6 kB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl-webresource-client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl-webresource-client) (2.31.0)
# Collecting requests-cache~=1.2 (from chembl-webresource-client)
#   Downloading requests_cache-1.2.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl-webresource-client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl-webresource-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl-webresource-client) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl-webresource-client) (2024.2.2)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl-webresource-client) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl-webresource-client)
#   Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl-webresource-client) (4.2.2)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl-webresource-client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl-webresource-client) (1.2.1)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl-webresource-client) (4.11.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl-webresource-client) (1.16.0)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl-webresource-client
# Successfully installed cattrs-23.2.3 chembl-webresource-client-0.10.9 requests-cache-1.2.0 url-normalize-1.4.3

# %% [markdown]
# # Pharos Gene_drug_assocaition
#
# https://pharos.nih.gov/analyze/ligands?facet=Type!Drug

# %%
import pandas as pd
Gen_drug_assocaition= pd.read_csv('/content/query results.csv')
Data[['Ligand Name','Symbol']]
# Out:
#          id     Ligand ID       Ligand Name  Ligand Is Drug Ligand PubChem ID  \
# 0         1  1K8VDFWQQMK8   levobupivacaine               1             92253
# 1         1  1K8VDFWQQMK8   levobupivacaine               1             92253
# 2         1  1K8VDFWQQMK8   levobupivacaine               1             92253
# 3         2  WW6F1T3WP7LC  (S)-nitrendipine               1            157702
# 4         2  WW6F1T3WP7LC  (S)-nitrendipine               1            157702
# ...     ...           ...               ...             ...               ...
# 27280  1780  G7F7Q6ZWA7QY        simeprevir               1          24873435
# 27281  1780  G7F7Q6ZWA7QY        simeprevir               1          24873435
# 27282  1781   tannic acid       tannic acid               1               NaN
# 27283  1781   tannic acid       tannic acid               1               NaN
# 27284  1782  SZLRFDYACUPR         alexidine               1               NaN
#
#       Ligand ChEMBL ID Ligand Guide to Pharmacology ID  Ligand DrugCentral ID  \
# 0        CHEMBL1201193                             NaN                      4
# 1        CHEMBL1201193                             NaN                      4
# 2        CHEMBL1201193                             NaN                      4
# 3         CHEMBL251230                             NaN                      6
# 4         CHEMBL251230                             NaN                      6
# ...                ...                             ...                    ...
# 27280     CHEMBL501849                             NaN                   4812
# 27281     CHEMBL501849                             NaN                   4812
# 27282              NaN                             NaN                   5039
# 27283              NaN                             NaN                   5039
# 27284              NaN                             NaN                    113
#
#        Ligand Activity Count  Ligand Activity Ligand Activity Type  \
# 0                          3             6.71                 IC50
# 1                          3             6.30                 AC50
# 2                          3              NaN                  NaN
# 3                          4             6.50                 AC50
# 4                          4             6.90                 AC50
# ...                      ...              ...                  ...
# 27280                      2             6.10                 IC50
# 27281                      2             6.10                 IC50
# 27282                      2             6.04                 IC50
# 27283                      2             6.49                 IC50
# 27284                      1             7.97                 IC50
#
#       Ligand Action                                  Ligand References  \
# 0               NaN                               None, None:None:None
# 1               NaN                               None, None:None:None
# 2           BLOCKER  https://www.ebi.ac.uk/chembl/compound/inspect/...
# 3               NaN                               None, None:None:None
# 4               NaN                               None, None:None:None
# ...             ...                                                ...
# 27280           NaN    Antimicrob. Agents Chemother., (2009) 53:4:1377
# 27281           NaN  https://www.ebi.ac.uk/chembl/compound/inspect/...
# 27282           NaN  https://www.ebi.ac.uk/chembl/compound/inspect/...
# 27283           NaN  https://www.ebi.ac.uk/chembl/compound/inspect/...
# 27284     INHIBITOR        http://www.ncbi.nlm.nih.gov/pubmed/20167843
#
#       Ligand Reference Source Ligand PubMed IDs   Symbol UniProt
# 0                         NaN               NaN   CYP2D6  P10635
# 1                         NaN               NaN   CYP2D6  P10635
# 2                      CHEMBL               NaN    SCN4A  P35499
# 3                         NaN               NaN   CYP2C9  P11712
# 4                         NaN               NaN  CYP2C19  P33261
# ...                       ...               ...      ...     ...
# 27280                     NaN          19171797     CTSS  P25774
# 27281                  CHEMBL               NaN     CTSS  P25774
# 27282                  CHEMBL               NaN   CYP1A2  P05177
# 27283                  CHEMBL               NaN   TBXAS1  P24557
# 27284   SCIENTIFIC LITERATURE               NaN   PTPMT1  Q8WUK0
#
# [27285 rows x 17 columns]

# %%
grouped_df = Data.groupby(['Ligand Name', 'Symbol']).size().reset_index(name='Frequency')

print(grouped_df)
# Out:
#            Ligand Name   Symbol  Frequency
# 0      (S)-nicardipine  CACNA1C          1
# 1      (S)-nicardipine  CACNA1D          1
# 2      (S)-nicardipine   CYP2C9          1
# 3      (S)-nicardipine   CYP3A4          1
# 4     (S)-nitrendipine  CACNA1C          1
# ...                ...      ...        ...
# 6778          zotepine   SLC6A4          1
# 6779       zucapsaicin   CYP2C9          1
# 6780       zucapsaicin    TRPV1          3
# 6781    zuclopenthixol     DRD1          1
# 6782    zuclopenthixol     DRD2          1
#
# [6783 rows x 3 columns]

# %%
grouped_df[grouped_df['Symbol']== 'levobupivacaine']
# Out:
#           Ligand Name  Symbol  Frequency
# 3460  levobupivacaine  CYP2D6          2
# 3461  levobupivacaine   SCN4A          1

# %%
grouped_df_gene = grouped_df.groupby(['Symbol']).size().reset_index(name='Frequency')
grouped_df_gene
# Out:
#      Symbol  Frequency
# 0     9-Sep          1
# 1     AADAC          1
# 2      AAK1          3
# 3      ABAT          1
# 4     ABCA1          1
# ...     ...        ...
# 1267    XDH          4
# 1268   XPO1          1
# 1269   YES1          4
# 1270   ZACN          1
# 1271  ZAP70          1
#
# [1272 rows x 2 columns]

# %%
grouped_df_gene['Frequency'].min(),grouped_df_gene['Frequency'].mean(), grouped_df_gene['Frequency'].median(),grouped_df_gene['Frequency'].max()
# Out:
# (1, 5.3325471698113205, 2.0, 109)

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Sort the DataFrame by 'Frequency'
df_sorted = grouped_df_gene.sort_values(by='Frequency', ascending=False)
df_sorted=df_sorted[:75]
# Plotting the bar chart
plt.figure(figsize=(10, 10))
plt.barh(df_sorted['Symbol'], df_sorted['Frequency'], color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('Symbol')
plt.title('Frequency of Symbols')
plt.xlim(0, 50)

# Adjust the size of the y-ticks
plt.yticks(fontsize=8)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray', axis='x')

plt.gca().invert_yaxis()  # Invert y-axis to have the highest frequency on top
plt.show()

# %% [markdown]
# ##Step1: finding similiar compunds

# %%
from chembl_webresource_client.new_client import new_client
def perform_similarity_search(smiles, threshold=80):
    similarity = new_client.similarity
    # Perform similarity search using ChEMBL's similarity search API
    res = similarity.filter(smiles=smiles, similarity=threshold).only(['molecule_chembl_id', 'similarity'])
    similar_compounds = [(entry['molecule_chembl_id'],round(float(entry['similarity']),2)) for entry in res]
    similar_compounds_ = [entry['molecule_chembl_id'] for entry in res]
    return similar_compounds_

# Screening compounds with their IDs and SMILES strings
screening_compounds = {
    'NCGC00125704': 'CC1=CC=C(C=C1)N2C(=C3C(=NN(C(=O)C3=N2)CCCC(=O)NCC4=C(C(=CC=C4)OC)OC)C)C'}

#    'NCGC00602080-03': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=C(F)C=CC=C4)N=C2C',
 #   'NCGC00685598-01': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=CC=CC=C4)N=C2C',
  #  'NCGC00685517-01': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=CC=CC(F)=C4)N=C2C',
   # 'NCGC00686269-01': 'CC1=C2C(=NN1C3=CC=C(C)C=C3)C(=O)N(CCCCNCCC4=CC(F)=CC(F)=C4)N=C2C'}

#NCGC00125704.
#Pubchem SID 24401087
#Compound CID: 16022698


# Perform chemical structure similarity search against ChEMBL for each screening compound
similar_compounds_dict = {}
for compound_id, compound_smiles in screening_compounds.items():
    similar_compounds = perform_similarity_search(compound_smiles)
    print(similar_compounds)
    similar_compounds_dict[compound_id] = similar_compounds

similar_compounds_dict
# Out:
# ['CHEMBL1372162', 'CHEMBL1367890', 'CHEMBL1733809']
# {'NCGC00125704': ['CHEMBL1372162', 'CHEMBL1367890', 'CHEMBL1733809']}

# %% [markdown]
# ##Finding Gene for each similiar conpund:

# %%
from chembl_webresource_client.new_client import new_client

# Function to retrieve targets associated with a ChEMBL ID
def get_gene_symbols(entry):
    gene_symbols = []
    for component in entry['target_components']:
        for synonym in component['target_component_synonyms']:
            #if synonym['syn_type'] in ['GENE_SYMBOL', 'GENE_SYMBOL_OTHER']:
                gene_symbols.append(synonym['component_synonym'])
    return tuple(gene_symbols)  # Convert list to tuple

def get_targets(chembl_id):
    target_client = new_client.target
    # Retrieve targets associated with the ChEMBL ID
    res = target_client.filter(target=chembl_id,organism='Homo sapiens').only(['target_chembl_id','organism','pref_name','target_components'])
    res = res[:10]
    print(res)

    # Extract the target ChEMBL IDs
    return {(entry['organism'], entry['target_chembl_id'], entry['pref_name'], get_gene_symbols(entry)) for entry in res}

    #return {(entry['organism'],entry['target_chembl_id'], entry['pref_name']) for entry in res}


import time
def find_shared_targets(chembl_ids):
    shared_targets = []
    for chembl_id in chembl_ids:
        start_time = time.time()  # Start time of the process
        print(chembl_id, 'is processing...')
        targets = get_targets(chembl_id)  # Assuming get_targets function is defined elsewhere
        end_time = time.time()  # End time of the process
        process_time = end_time - start_time  # Calculate the time taken for the process
        print(f"{chembl_id} processing completed in {process_time} seconds.")
        shared_targets.append(targets)
    return shared_targets

# Get targets associated with ChEMBL compounds
chembl_targets = set()
for similar_compounds in similar_compounds_dict.values():
    chembl_targets.update(similar_compounds)

# Find shared targets
shared_targets = find_shared_targets( chembl_targets)
#print("Shared Targets:", list(shared_targets))  # Convert set to list for printing
# Out:
# CHEMBL1372162 is processing...
# [{'organism': 'Homo sapiens', 'pref_name': 'Maltase-glucoamylase', 'target_chembl_id': 'CHEMBL2074', 'target_components': [{'accession': 'O43451', 'component_description': 'Maltase-glucoamylase', 'component_id': 434, 'component_type': 'PROTEIN', 'relationship': 'SINGLE PROTEIN', 'target_component_synonyms': [{'component_synonym': '3.2.1.20', 'syn_type': 'EC_NUMBER'}, {'component_synonym': 'Alpha-1,4-glucosidase', 'syn_type': 'UNIPROT'}, {'component_synonym': 'Maltase-glucoamylase', 'syn_type': 'UNIPROT'}, {'component_synonym': 'MGA', 'syn_type': 'GENE_SYMBOL_OTHER'}, {'component_synonym': 'MGAM', 'syn_type': 'GENE_SYMBOL'}, {'component_synonym': 'MGAML', 'syn_type': 'GENE_SYMBOL_OTHER'}, {'component_synonym': 'Synonyms=MGA', 'syn_type': 'GENE_SYMBOL_OTHER'}], 'target_component_xrefs': [{'xref_id': 'O43451', 'xref_name': None, 'xref_src_db': 'ExpressionAtlas'}, {'xref_id': 'GO:0005886', 'xref_name': 'plasma membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0016020', 'xref_name': 'membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0016324', 'xref_name': 'apical plasma membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0070062', 'xref_name': 'extracellular exosome', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0070821', 'xref_name': 'tertiary granule membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0101003', 'xref_name': 'ficolin-1-rich granule membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0003824', 'xref_name': 'catalytic activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0004339', 'xref_name': 'glucan 1,4-alpha-glucosidase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0004553', 'xref_name': 'hydrolase activity, hydrolyzing O-glycosyl compounds', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0004558', 'xref_name': 'alpha-1,4-glucosidase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0005515', 'xref_name': 'protein binding', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0016160', 'xref_name': 'amylase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0016787', 'xref_name': 'hydrolase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0016798', 'xref_name': 'hydrolase activity, acting on glycosyl bonds', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0030246', 'xref_name': 'carbohydrate binding', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0032450', 'xref_name': 'maltose alpha-glucosidase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0090599', 'xref_name': 'alpha-glucosidase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0000025', 'xref_name': 'maltose catabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': 'GO:0005975', 'xref_name': 'carbohydrate metabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': 'GO:0005983', 'xref_name': 'starch catabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': 'GO:0008152', 'xref_name': 'metabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': 'GO:1901027', 'xref_name': 'dextrin catabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': '2627', 'xref_name': None, 'xref_src_db': 'GuideToPHARMACOLOGY'}, {'xref_id': 'O43451', 'xref_name': None, 'xref_src_db': 'IntAct'}, {'xref_id': 'IPR000322', 'xref_name': 'Glyco_hydro_31_TIM.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR000519', 'xref_name': 'P_trefoil_dom.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR011013', 'xref_name': 'Gal_mutarotase_sf_dom.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR013780', 'xref_name': 'Glyco_hydro_b.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR017853', 'xref_name': 'Glycoside_hydrolase_SF.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR017957', 'xref_name': 'P_trefoil_CS.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR025887', 'xref_name': 'Glyco_hydro_31_N_dom.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR030458', 'xref_name': 'Glyco_hydro_31_AS.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR030459', 'xref_name': 'Glyco_hydro_31_CS.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR044913', 'xref ...
# CHEMBL1372162 processing completed in 4.777828931808472 seconds.
# CHEMBL1733809 is processing...
# [{'organism': 'Homo sapiens', 'pref_name': 'Maltase-glucoamylase', 'target_chembl_id': 'CHEMBL2074', 'target_components': [{'accession': 'O43451', 'component_description': 'Maltase-glucoamylase', 'component_id': 434, 'component_type': 'PROTEIN', 'relationship': 'SINGLE PROTEIN', 'target_component_synonyms': [{'component_synonym': '3.2.1.20', 'syn_type': 'EC_NUMBER'}, {'component_synonym': 'Alpha-1,4-glucosidase', 'syn_type': 'UNIPROT'}, {'component_synonym': 'Maltase-glucoamylase', 'syn_type': 'UNIPROT'}, {'component_synonym': 'MGA', 'syn_type': 'GENE_SYMBOL_OTHER'}, {'component_synonym': 'MGAM', 'syn_type': 'GENE_SYMBOL'}, {'component_synonym': 'MGAML', 'syn_type': 'GENE_SYMBOL_OTHER'}, {'component_synonym': 'Synonyms=MGA', 'syn_type': 'GENE_SYMBOL_OTHER'}], 'target_component_xrefs': [{'xref_id': 'O43451', 'xref_name': None, 'xref_src_db': 'ExpressionAtlas'}, {'xref_id': 'GO:0005886', 'xref_name': 'plasma membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0016020', 'xref_name': 'membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0016324', 'xref_name': 'apical plasma membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0070062', 'xref_name': 'extracellular exosome', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0070821', 'xref_name': 'tertiary granule membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0101003', 'xref_name': 'ficolin-1-rich granule membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0003824', 'xref_name': 'catalytic activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0004339', 'xref_name': 'glucan 1,4-alpha-glucosidase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0004553', 'xref_name': 'hydrolase activity, hydrolyzing O-glycosyl compounds', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0004558', 'xref_name': 'alpha-1,4-glucosidase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0005515', 'xref_name': 'protein binding', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0016160', 'xref_name': 'amylase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0016787', 'xref_name': 'hydrolase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0016798', 'xref_name': 'hydrolase activity, acting on glycosyl bonds', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0030246', 'xref_name': 'carbohydrate binding', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0032450', 'xref_name': 'maltose alpha-glucosidase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0090599', 'xref_name': 'alpha-glucosidase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0000025', 'xref_name': 'maltose catabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': 'GO:0005975', 'xref_name': 'carbohydrate metabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': 'GO:0005983', 'xref_name': 'starch catabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': 'GO:0008152', 'xref_name': 'metabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': 'GO:1901027', 'xref_name': 'dextrin catabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': '2627', 'xref_name': None, 'xref_src_db': 'GuideToPHARMACOLOGY'}, {'xref_id': 'O43451', 'xref_name': None, 'xref_src_db': 'IntAct'}, {'xref_id': 'IPR000322', 'xref_name': 'Glyco_hydro_31_TIM.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR000519', 'xref_name': 'P_trefoil_dom.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR011013', 'xref_name': 'Gal_mutarotase_sf_dom.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR013780', 'xref_name': 'Glyco_hydro_b.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR017853', 'xref_name': 'Glycoside_hydrolase_SF.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR017957', 'xref_name': 'P_trefoil_CS.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR025887', 'xref_name': 'Glyco_hydro_31_N_dom.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR030458', 'xref_name': 'Glyco_hydro_31_AS.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR030459', 'xref_name': 'Glyco_hydro_31_CS.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR044913', 'xref ...
# CHEMBL1733809 processing completed in 4.732393026351929 seconds.
# CHEMBL1367890 is processing...
# [{'organism': 'Homo sapiens', 'pref_name': 'Maltase-glucoamylase', 'target_chembl_id': 'CHEMBL2074', 'target_components': [{'accession': 'O43451', 'component_description': 'Maltase-glucoamylase', 'component_id': 434, 'component_type': 'PROTEIN', 'relationship': 'SINGLE PROTEIN', 'target_component_synonyms': [{'component_synonym': '3.2.1.20', 'syn_type': 'EC_NUMBER'}, {'component_synonym': 'Alpha-1,4-glucosidase', 'syn_type': 'UNIPROT'}, {'component_synonym': 'Maltase-glucoamylase', 'syn_type': 'UNIPROT'}, {'component_synonym': 'MGA', 'syn_type': 'GENE_SYMBOL_OTHER'}, {'component_synonym': 'MGAM', 'syn_type': 'GENE_SYMBOL'}, {'component_synonym': 'MGAML', 'syn_type': 'GENE_SYMBOL_OTHER'}, {'component_synonym': 'Synonyms=MGA', 'syn_type': 'GENE_SYMBOL_OTHER'}], 'target_component_xrefs': [{'xref_id': 'O43451', 'xref_name': None, 'xref_src_db': 'ExpressionAtlas'}, {'xref_id': 'GO:0005886', 'xref_name': 'plasma membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0016020', 'xref_name': 'membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0016324', 'xref_name': 'apical plasma membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0070062', 'xref_name': 'extracellular exosome', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0070821', 'xref_name': 'tertiary granule membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0101003', 'xref_name': 'ficolin-1-rich granule membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0003824', 'xref_name': 'catalytic activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0004339', 'xref_name': 'glucan 1,4-alpha-glucosidase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0004553', 'xref_name': 'hydrolase activity, hydrolyzing O-glycosyl compounds', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0004558', 'xref_name': 'alpha-1,4-glucosidase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0005515', 'xref_name': 'protein binding', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0016160', 'xref_name': 'amylase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0016787', 'xref_name': 'hydrolase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0016798', 'xref_name': 'hydrolase activity, acting on glycosyl bonds', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0030246', 'xref_name': 'carbohydrate binding', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0032450', 'xref_name': 'maltose alpha-glucosidase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0090599', 'xref_name': 'alpha-glucosidase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0000025', 'xref_name': 'maltose catabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': 'GO:0005975', 'xref_name': 'carbohydrate metabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': 'GO:0005983', 'xref_name': 'starch catabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': 'GO:0008152', 'xref_name': 'metabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': 'GO:1901027', 'xref_name': 'dextrin catabolic process', 'xref_src_db': 'GoProcess'}, {'xref_id': '2627', 'xref_name': None, 'xref_src_db': 'GuideToPHARMACOLOGY'}, {'xref_id': 'O43451', 'xref_name': None, 'xref_src_db': 'IntAct'}, {'xref_id': 'IPR000322', 'xref_name': 'Glyco_hydro_31_TIM.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR000519', 'xref_name': 'P_trefoil_dom.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR011013', 'xref_name': 'Gal_mutarotase_sf_dom.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR013780', 'xref_name': 'Glyco_hydro_b.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR017853', 'xref_name': 'Glycoside_hydrolase_SF.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR017957', 'xref_name': 'P_trefoil_CS.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR025887', 'xref_name': 'Glyco_hydro_31_N_dom.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR030458', 'xref_name': 'Glyco_hydro_31_AS.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR030459', 'xref_name': 'Glyco_hydro_31_CS.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR044913', 'xref ...
# CHEMBL1367890 processing completed in 4.430336952209473 seconds.

# %%
def get_targets(chembl_id):
    target_client = new_client.target
    # Retrieve targets associated with the ChEMBL ID
    res = target_client.filter(target=chembl_id,organism='Homo sapiens').only(['target_chembl_id','organism','pref_name','target_components'])
    res = res[:20]
    # Extract the target ChEMBL IDs
    return {(entry['organism'], entry['target_chembl_id'], entry['pref_name'], get_gene_symbols(entry)) for entry in res}

A=get_targets('CHEMBL1367890')
B=get_targets('CHEMBL1829')
A==B
# Out:
# True

# %%
shared_targets[1]
# Out:
# {'CHEMBL1367890', 'CHEMBL1372162', 'CHEMBL1733809'}

# %%
Genes_=[]
for i in shared_targets:
  symbols1=[]
  for j in i:
    symbols1+=list(j[3])
  Genes_.append(list(set(symbols1)))

# %% [markdown]
# https://www.ebi.ac.uk/chembl/g/#search_results/all/query=CHEMBL1372162
#
# https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL2902/
#
# https://www.uniprot.org/uniprotkb/P00381/entry

# %%
['CHEMBL1372162', 'CHEMBL1367890', 'CHEMBL1733809']

#Genes_predicton=[['folA','ampC','F10','THRB','USP7'],[],[]]
Genes_=[['TGR','TARDBP','ampC','NFE2L2','EHMT2','CBX1','TDP1'],['CGA','PTH1R','SMAD3','EHMT2','GMNN','TDP1'],['CGA','EHMT2']]

# %% [markdown]
# 1- Finding smile:  https://www.ebi.ac.uk/chembl/compound_report_card/CHEMBL1733809/
#
# 2- finding genes with probablity:http://www.swisstargetprediction.ch/result.php?job=105216416&organism=Homo_sapiens
#
# 3- Fidning pathways based on genes: http://bioinformatics.sdstate.edu/go/

# %%
import pandas as pd
NCGC00685598=pd.read_csv('/content/1- NCGC00685598-01.csv')
NCGC00602080=pd.read_csv('/content/2- NCGC00602080-03.csv')
NCGC00686269=pd.read_csv('/content/3- NCGC00686269.csv')
NCGC00685517=pd.read_csv('/content/4- NCGC00685517-01.csv')

enrichment_all_NCGC00685598=pd.read_csv('/content/1- enrichment_all.csv')
enrichment_all_NCGC00602080=pd.read_csv('/content/2- enrichment_all (5).csv')
enrichment_all_NCGC00686269=pd.read_csv('/content/3- enrichment_al.csv')
enrichment_all_NCGC00685517=pd.read_csv('/content/4- enrichment_all (7).csv')

# %%
NCGC00685598.columns
# Out:
# Index(['Target', 'Common name', 'Uniprot ID', 'ChEMBL ID', 'Target Class',
#        'Probability*', 'Known actives (3D/2D)'],
#       dtype='object')

# %%
Genes_= [list(NCGC00685598[ 'Common name'].values),list(NCGC00602080[ 'Common name'].values) ,list(NCGC00686269[ 'Common name'].values),list(NCGC00685517[ 'Common name'].values)]

# %% [markdown]
# ##Fidning Disaese/Phenotypes associated to these Genes

# %%
import json
import pandas as pd

# Read the JSON file
file_path = '/content/hp.json'
with open(file_path, 'r') as file:
    data = json.load(file)
# Extract relevant information from the JSON dat
graphs = data['graphs']
nodes = graphs[0]['nodes']  # Assuming there's only one graph in the JSON data
# Initialize lists to store data
ids = []
labels = []
types = []
# Iterate over the nodes and extract the required information
for node in nodes:
    ids.append(node['id'])
    labels.append(node.get('lbl', ''))
    types.append(node.get('type', ''))
# Create a DataFrame from the extracted data
HP = pd.DataFrame({
    'id': ids,
    'label': labels,
    'type': types
})

import pandas as pd
phenotype_to_genes = pd.read_csv('/content/phenotype_to_genes.txt', sep='\t')
genes_to_phenotype = pd.read_csv('/content/genes_to_phenotype.txt', sep='\t')
genes_to_disease = pd.read_csv('/content/genes_to_disease.txt', sep='\t')
phenotype = pd.read_csv('/content/phenotype.hpoa', sep='\t', skiprows=4)
# Out:
# <ipython-input-164-781703eb0002>:31: DtypeWarning: Columns (2,6,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   phenotype = pd.read_csv('/content/phenotype.hpoa', sep='\t', skiprows=4)

# %% [markdown]
# Finiding phenotypes

# %%
max_length = max([len(genes) for genes in Genes_])
shared_gene_phenotype_table = pd.DataFrame(index=range(max_length))
# Populate the DataFrame
for i in range(len(Genes_)):
    col_name = 'shared_gene_' + str(i)
    genes = Genes_[i]
    shared_gene_phenotype_table[col_name] = pd.Series(genes)
shared_gene_phenotype_table = shared_gene_phenotype_table.fillna('None')
print(shared_gene_phenotype_table)
# Out:
#    shared_gene_0 shared_gene_1 shared_gene_2 shared_gene_3
# 0           BCHE          BCHE          ACHE         HTR1F
# 1          AVPR2          ACHE          XIAP          WEE1
# 2         AVPR1A         AVPR2           KDR           EBP
# 3          NR1I3        AVPR1A           EBP          XIAP
# 4           WEE1           SRC         HTR1F           SRC
# ..           ...           ...           ...           ...
# 95          HCN4        MBTPS1    CCNE1 CDK2           ADK
# 96          HCN1          ABL1          CDK5       CACNA1B
# 97         IGF1R          RAF1         CXCR3          PAK4
# 98           ITK           BLK          CCR8           AXL
# 99        PTPN22           LCK         ABCG2          CNR1
#
# [100 rows x 4 columns]

# %%
import pandas as pd
#shared_gene_phenotype_table = pd.read_csv('/content/shared_gene_phenotype_table.csv')
genes_to_phenotype = pd.read_csv('/content/genes_to_phenotype.txt', sep='\t')
# Preprocess genes_to_phenotype DataFrame
gene_to_hpo_dict = genes_to_phenotype.groupby('gene_symbol').agg({'hpo_name': list}).to_dict()['hpo_name']
gene_to_hpo_dict_lower = {key.lower(): value for key, value in gene_to_hpo_dict.items()}
# Modify the function to use the preprocessed dictionary
def finding_hpo(x):
    return list(set(gene_to_hpo_dict_lower.get(x.lower(), [])))

# Apply the function
shared_gene_phenotype_table['phenotype_0'] = shared_gene_phenotype_table['shared_gene_0'].str.lower().apply(finding_hpo)
shared_gene_phenotype_table['phenotype_1'] = shared_gene_phenotype_table['shared_gene_1'].str.lower().apply(finding_hpo)
shared_gene_phenotype_table['phenotype_2'] = shared_gene_phenotype_table['shared_gene_2'].str.lower().apply(finding_hpo)
#shared_gene_phenotype_table['phenotype'] = shared_gene_phenotype_table.apply(lambda x: x['phenotype'] + [x['shared_gene']], axis=1)
#shared_gene_phenotype_table['shared_gene'] = shared_gene_phenotype_table.apply(lambda x:  [x['shared_gene_1']], axis=1)

#shared_gene_phenotype_table=shared_gene_phenotype_table.dropna()
shared_gene_phenotype_table
# Out:
#              shared_gene_0 shared_gene_1 shared_gene_2  \
# 0                    MGAT2        SLC8A1         DGAT1
# 1                    DGAT2          PTK2         PDE4B
# 2                     FASN         SCN9A         MAPK8
# 3                    DGAT1         PTAFR         FGFR3
# 4                      SYK         ABCB1         FGFR1
# ..                     ...           ...           ...
# 95                    BRD2        PLA2G7           TEK
# 96                    BRD3           ITK          IDO1
# 97             CDK5R1 CDK5    CCNA2 CDK2          BRAF
# 98  CCNB3 CDK1 CCNB1 CCNB2          BRAF          RORC
# 99            CALCRL RAMP1            F9         NAMPT
#
#                                           phenotype_0  \
# 0   [Osteopenia, Aggressive behavior, Dental crowd...
# 1                                                  []
# 2                                                  []
# 3   [Neonatal onset, Hyperlipidemia, Diarrhea, Aut...
# 4   [Lymphadenopathy, Hepatitis, Splenomegaly, Ele...
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
#                                           phenotype_1  \
# 0                                                  []
# 1                                                  []
# 2   [Generalized cerebral atrophy/hypoplasia, Inte...
# 3                                                  []
# 4               [Inflammation of the large intestine]
# ..                                                ...
# 95  [Autosomal recessive inheritance, Increased le...
# 96  [Pleural effusion, Lymphadenopathy, Decreased ...
# 97                                                 []
# 98  [Osteopenia, EEG abnormality, Abnormal heart v...
# 99  [X-linked recessive inheritance, Abnormal blee...
#
#                                           phenotype_2
# 0   [Neonatal onset, Hyperlipidemia, Diarrhea, Aut...
# 1                                                  []
# 2                                                  []
# 3   [Hypoplastic ilia, Nail dysplasia, Tibial bowi...
# 4   [Osteopenia, Inguinal hernia, Renal agenesis, ...
# ..                                                ...
# 95  [Increased cup-to-disc ratio, Ocular hypertens...
# 96                                                 []
# 97  [Osteopenia, EEG abnormality, Abnormal heart v...
# 98  [Hypoplasia of the thymus, Autosomal recessive...
# 99                                                 []
#
# [100 rows x 6 columns]

# %%
phenotype_tor1a=list(set(finding_hpo('tor1a')))


Shared_pheno=[]
n=0
for cc in ['shared_gene_0','shared_gene_1','shared_gene_2']:
  shared_gene_phenotype_table[cc+'_phen'] =None
  shared_gene_phenotype_table[cc+'_phen'] = shared_gene_phenotype_table[cc+'_phen'].astype(object)
  for i in shared_gene_phenotype_table.index:
   X=[]
   if type(shared_gene_phenotype_table['phenotype_'+str(n)][i] )==list:
    for j in shared_gene_phenotype_table['phenotype_'+str(n)][i]:
         if j in phenotype_tor1a:
              print(cc,j)
              X.append(j)
    shared_gene_phenotype_table.at[i, cc+'_phen']=X
  n+=1
           #Shared_pheno.append(shared_gene_phenotype_table['shared_gene_0'][i])
           #print(shared_gene_phenotype_table['shared_gene_0'][i])
           #break
shared_gene_phenotype_table
# Out:
# shared_gene_0 Scoliosis
# shared_gene_0 Global developmental delay
# shared_gene_0 Microcephaly
# shared_gene_0 Prominent antihelix
# shared_gene_0 Generalized hypotonia
# shared_gene_0 Short neck
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Long philtrum
# shared_gene_0 Kyphosis
# shared_gene_0 Hypotonia
# shared_gene_0 Macrotia
# shared_gene_0 Gastrostomy tube feeding in infancy
# shared_gene_0 Intellectual disability, severe
# shared_gene_0 Hypertonia
# shared_gene_0 Neonatal onset
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Scoliosis
# shared_gene_0 Babinski sign
# shared_gene_0 Pes valgus
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Dysarthria
# shared_gene_0 Growth delay
# shared_gene_0 Motor delay
# shared_gene_0 Intrauterine growth retardation
# shared_gene_0 Upslanted palpebral fissure
# shared_gene_0 Micrognathia
# shared_gene_0 Delayed speech and language development
# shared_gene_0 Strabismus
# shared_gene_0 Anxiety
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Long philtrum
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Global developmental delay
# shared_gene_0 Wide nasal bridge
# shared_gene_0 Microcephaly
# shared_gene_0 Global developmental delay
# shared_gene_0 Microcephaly
# shared_gene_0 Neonatal respiratory distress
# shared_gene_0 Short neck
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Wide nasal bridge
# shared_gene_0 Anteverted nares
# shared_gene_0 Hyperlordosis
# shared_gene_0 Umbilical hernia
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Hypotonia
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Abnormality of the voice
# shared_gene_0 Anxiety
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Depression
# shared_gene_0 Camptodactyly
# shared_gene_0 Anxiety
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Depression
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Abnormality of the voice
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Global developmental delay
# shared_gene_0 Microcephaly
# shared_gene_0 Micrognathia
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Facial palsy
# shared_gene_0 Death in infancy
# shared_gene_0 Adducted thumb
# shared_gene_0 Hip dislocation
# shared_gene_0 Delayed speech and language development
# shared_gene_0 Global developmental delay
# shared_gene_0 Microcephaly
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Anteverted nares
# shared_gene_0 Intrauterine growth retardation
# shared_gene_0 Macrotia
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Poikilocytosis
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Middle age onset
# shared_gene_0 Dysarthria
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Growth delay
# shared_gene_0 Anxiety
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Depression
# shared_gene_0 Dysphagia
# shared_gene_0 Flexion contracture
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Typified by incomplete penetrance
# shared_gene_0 Myoclonus
# shared_gene_0 Delayed speech and language development
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Global developmental delay
# shared_gene_0 Neonatal onset
# shared_gene_0 Delayed speech and language development
# shared_gene_0 Delayed speech and language development
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Adducted thumb
# shared_gene_0 Ptosis
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Talipes equinovarus
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Polyhydramnios
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Inguinal hernia
# shared_gene_0 Gait disturbance
# shared_gene_0 Scoliosis
# shared_gene_0 Motor delay
# shared_gene_0 Global developmental delay
# shared_gene_0 Microcephaly
# shared_gene_0 Depression
# shared_gene_0 Kyphosis
# shared_gene_0 Kyphoscoliosis
# shared_gene_0 Anteverted nares
# shared_gene_0 Hypotonia
# shared_gene_0 Hypertonia
# shared_gene_0 Delayed speech and language development
# shared_gene_0 Strabismus
# shared_gene_0 Growth delay
# shared_gene_0 Dysphagia
# shared_gene_0 Global developmental delay
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Dysphagia
# shared_gene_0 Flexion contracture
# shared_gene_0 Abnormality of the musculature
# shared_gene_0 Anxiety
# shared_gene_0 Depression
# shared_gene_0 Facial palsy
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Restrictive ventilatory defect
# shared_gene_0 Ptosis
# shared_gene_0 Gait disturbance
# shared_gene_0 Myoclonus
# shared_gene_0 Global developmental delay
# shared_gene_0 Generalized hypotonia
# shared_gene_0 Long philtrum
# shared_gene_0 Umbilical hernia
# shared_gene_0 Hypotonia
# shared_gene_0 Intellectual disability, severe
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Strabismus
# shared_gene_0 Generalized hypotonia
# shared_gene_0 Motor delay
# shared_gene_0 Tremor
# shared_gene_0 Myoclonus
# shared_gene_0 Decreased fetal movement
# shared_gene_0 Delayed speech and language development
# shared_gene_0 Ptosis
# shared_gene_0 Intellectual disability, severe
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Global developmental delay
# shared_gene_0 Microcephaly
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Myoclonus
# shared_gene_0 Neonatal onset
# shared_gene_0 Dysphagia
# shared_gene_0 Polyhydramnios
# shared_gene_0 Long philtrum
# shared_gene_0 Wide nasal bridge
# shared_gene_0 Anteverted nares
# shared_gene_0 Macrotia
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Growth delay
# shared_gene_0 Depression
# shared_gene_0 Kyphoscoliosis
# shared_gene_0 Panic attack
# shared_gene_0 Intrauterine growth retardation
# shared_gene_0 Gastrostomy tube feeding in infancy
# shared_gene_0 Strabismus
# shared_gene_0 Generalized hypotonia
# shared_gene_0 Hypertonia
# shared_gene_0 Scoliosis
# shared_gene_0 Global developmental delay
# shared_gene_0 Micrognathia
# shared_gene_0 Short neck
# shared_gene_0 Hypotonia
# shared_gene_0 Dysarthria
# shared_gene_0 Abnormality of the voice
# shared_gene_0 Ptosis
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Absent speech
# shared_gene_0 Generalized hypotonia
# shared_gene_0 Anteverted nares
# shared_gene_0 Tremor
# shared_gene_0 Myoclonus
# shared_gene_0 Decreased fetal movement
# shared_gene_0 Inability to walk
# shared_gene_0 Dystonia
# shared_gene_0 Delayed speech and language development
# shared_gene_0 Ptosis
# shared_gene_0 Hypotonia
# shared_gene_0 Strabismus
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Global developmental delay
# shared_gene_0 Microcephaly
# shared_gene_0 Typified by incomplete penetrance
# shared_gene_0 Dysphagia
# shared_gene_0 Anxiety
# shared_gene_0 Depression
# shared_gene_0 Middle age onset
# shared_gene_0 Dysarthria
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Babinski sign
# shared_gene_0 Ptosis
# shared_gene_0 Hyperreflexia
# shared_gene_0 Scoliosis
# shared_gene_0 Intrauterine growth retardation
# shared_gene_0 Upslanted palpebral fissure
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Kyphosis
# shared_gene_0 Global developmental delay
# shared_gene_0 Camptodactyly
# shared_gene_0 Growth delay
# shared_gene_0 Myoclonus
# shared_gene_0 Neonatal onset
# shared_gene_0 Typified by incomplete penetrance
# shared_gene_0 Abnormality of movement
# shared_gene_0 Global developmental delay
# shared_gene_0 Microcephaly
# shared_gene_0 Absent speech
# shared_gene_0 Torsion dystonia
# shared_gene_0 Polyhydramnios
# shared_gene_0 Inability to walk
# shared_gene_0 Short neck
# shared_gene_0 Premature skin wrinkling
# shared_gene_0 Anxiety
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Depression
# shared_gene_0 Long philtrum
# shared_gene_0 Wide nasal bridge
# shared_gene_0 Anteverted nares
# shared_gene_0 Hypotonia
# shared_gene_0 Macrotia
# shared_gene_0 Dysarthria
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Hypertonia
# shared_gene_0 Babinski sign
# shared_gene_0 Tremor
# shared_gene_0 Delayed speech and language development
# shared_gene_0 Dystonia
# shared_gene_0 Limb myoclonus
# shared_gene_0 Strabismus
# shared_gene_0 Hyperreflexia
# shared_gene_0 Gait disturbance
# shared_gene_0 Babinski sign
# shared_gene_0 Myoclonus
# shared_gene_0 Inability to walk
# shared_gene_0 Dystonia
# shared_gene_0 Compulsive behaviors
# shared_gene_0 Anxiety
# shared_gene_0 Hyperreflexia
# shared_gene_0 Depression
# shared_gene_0 Growth delay
# shared_gene_0 Neonatal onset
# shared_gene_0 Autosomal recessive inheritance
# shared_gene_0 Autosomal dominant inheritance
# shared_gene_0 Global developmental delay
# shared_gene_0 Microcephaly
# shared_gene_0 Micrognathia
# shared_gene_0 Short neck
# shared_gene_0 Anxiety
# shared_gene_0 Long philtrum
# shared_gene_0 Anteverted nares
# shared_gene_0 Intrauterine growth retardation
# shared_gene_0 Hypotonia
# shared_gene_0 Macrotia
# shared_gene_0 Intellectual disability, severe
# shared_gene_0 Hypertonia
# shared_gene_0 Hip dislocation
# shared_gene_0 Compulsive behaviors
# shared_gene_0 Ptosis
# shared_gene_0 Strabismus
# shared_gene_1 Myoclonus
# shared_gene_1 Neonatal onset
# shared_gene_1 Generalized hypotonia
# shared_gene_1 Pes valgus
# shared_gene_1 Anxiety
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Hyperlordosis
# shared_gene_1 Hypotonia
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Tremor
# shared_gene_1 Inguinal hernia
# shared_gene_1 Growth delay
# shared_gene_1 Scoliosis
# shared_gene_1 Global developmental delay
# shared_gene_1 Microcephaly
# shared_gene_1 Generalized hypotonia
# shared_gene_1 Micrognathia
# shared_gene_1 Short neck
# shared_gene_1 Anxiety
# shared_gene_1 Depression
# shared_gene_1 Long philtrum
# shared_gene_1 Wide nasal bridge
# shared_gene_1 Anteverted nares
# shared_gene_1 Hyperlordosis
# shared_gene_1 Intrauterine growth retardation
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Delayed speech and language development
# shared_gene_1 Compulsive behaviors
# shared_gene_1 Ptosis
# shared_gene_1 Scoliosis
# shared_gene_1 Intrauterine growth retardation
# shared_gene_1 Upslanted palpebral fissure
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Kyphosis
# shared_gene_1 Global developmental delay
# shared_gene_1 Camptodactyly
# shared_gene_1 Global developmental delay
# shared_gene_1 Microcephaly
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Anteverted nares
# shared_gene_1 Intrauterine growth retardation
# shared_gene_1 Macrotia
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Anxiety
# shared_gene_1 Myoclonus
# shared_gene_1 Dystonia
# shared_gene_1 Compulsive behaviors
# shared_gene_1 Depression
# shared_gene_1 Personality disorder
# shared_gene_1 Writer's cramp
# shared_gene_1 Torticollis
# shared_gene_1 Spinal myoclonus
# shared_gene_1 Panic attack
# shared_gene_1 Limb myoclonus
# shared_gene_1 Dysarthria
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Hand tremor
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Hyperreflexia
# shared_gene_1 Optic disc pallor
# shared_gene_1 Death in infancy
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Intrauterine growth retardation
# shared_gene_1 Gait disturbance
# shared_gene_1 Scoliosis
# shared_gene_1 Global developmental delay
# shared_gene_1 Microcephaly
# shared_gene_1 Abnormality of the musculature
# shared_gene_1 Micrognathia
# shared_gene_1 Anxiety
# shared_gene_1 Depression
# shared_gene_1 Wide nasal bridge
# shared_gene_1 Middle age onset
# shared_gene_1 Intrauterine growth retardation
# shared_gene_1 Dysarthria
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Tremor
# shared_gene_1 Dystonia
# shared_gene_1 Ptosis
# shared_gene_1 Hyperreflexia
# shared_gene_1 Inguinal hernia
# shared_gene_1 Gait disturbance
# shared_gene_1 Scoliosis
# shared_gene_1 Motor delay
# shared_gene_1 Global developmental delay
# shared_gene_1 Microcephaly
# shared_gene_1 Depression
# shared_gene_1 Kyphosis
# shared_gene_1 Kyphoscoliosis
# shared_gene_1 Anteverted nares
# shared_gene_1 Hypotonia
# shared_gene_1 Hypertonia
# shared_gene_1 Delayed speech and language development
# shared_gene_1 Strabismus
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Scoliosis
# shared_gene_1 Babinski sign
# shared_gene_1 Pes valgus
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Dysarthria
# shared_gene_1 Motor delay
# shared_gene_1 Dysphagia
# shared_gene_1 Polyhydramnios
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Anteverted nares
# shared_gene_1 Blepharospasm
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Intellectual disability, moderate
# shared_gene_1 Camptodactyly
# shared_gene_1 Hyperlordosis
# shared_gene_1 Death in infancy
# shared_gene_1 Restrictive ventilatory defect
# shared_gene_1 Strabismus
# shared_gene_1 Scoliosis
# shared_gene_1 Decreased fetal movement
# shared_gene_1 Global developmental delay
# shared_gene_1 Microcephaly
# shared_gene_1 Neonatal respiratory distress
# shared_gene_1 Micrognathia
# shared_gene_1 Short neck
# shared_gene_1 Kyphosis
# shared_gene_1 Hypotonia
# shared_gene_1 Intellectual disability, severe
# shared_gene_1 Ptosis
# shared_gene_1 Inguinal hernia
# shared_gene_1 Dysphagia
# shared_gene_1 Long philtrum
# shared_gene_1 Wide nasal bridge
# shared_gene_1 Anteverted nares
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Tremor
# shared_gene_1 Growth delay
# shared_gene_1 Typified by incomplete penetrance
# shared_gene_1 Flexion contracture
# shared_gene_1 Camptodactyly
# shared_gene_1 Absent speech
# shared_gene_1 Anxiety
# shared_gene_1 Depression
# shared_gene_1 Intrauterine growth retardation
# shared_gene_1 Gastrostomy tube feeding in infancy
# shared_gene_1 Strabismus
# shared_gene_1 Gait disturbance
# shared_gene_1 Upslanted palpebral fissure
# shared_gene_1 Hypertonia
# shared_gene_1 Hip dislocation
# shared_gene_1 Scoliosis
# shared_gene_1 Global developmental delay
# shared_gene_1 Microcephaly
# shared_gene_1 Micrognathia
# shared_gene_1 Inability to walk
# shared_gene_1 Short neck
# shared_gene_1 Hypotonia
# shared_gene_1 Dysarthria
# shared_gene_1 Abnormality of the voice
# shared_gene_1 Delayed speech and language development
# shared_gene_1 Ptosis
# shared_gene_1 Scoliosis
# shared_gene_1 Motor delay
# shared_gene_1 Neonatal onset
# shared_gene_1 Global developmental delay
# shared_gene_1 Arthrogryposis multiplex congenita
# shared_gene_1 Wide nasal bridge
# shared_gene_1 Intrauterine growth retardation
# shared_gene_1 Hypotonia
# shared_gene_1 Intellectual disability, severe
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Dysphagia
# shared_gene_1 Long philtrum
# shared_gene_1 Anteverted nares
# shared_gene_1 Blepharospasm
# shared_gene_1 Macrotia
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Intellectual disability, moderate
# shared_gene_1 Flexion contracture
# shared_gene_1 Camptodactyly
# shared_gene_1 Hyperlordosis
# shared_gene_1 Umbilical hernia
# shared_gene_1 Strabismus
# shared_gene_1 Upslanted palpebral fissure
# shared_gene_1 Scoliosis
# shared_gene_1 Global developmental delay
# shared_gene_1 Micrognathia
# shared_gene_1 Rocker bottom foot
# shared_gene_1 Ptosis
# shared_gene_1 Delayed speech and language development
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Prominent occiput
# shared_gene_1 Scoliosis
# shared_gene_1 Hyperlordosis
# shared_gene_1 Intrauterine growth retardation
# shared_gene_1 Micrognathia
# shared_gene_1 Strabismus
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Kyphosis
# shared_gene_1 Intrauterine growth retardation
# shared_gene_1 Anxiety
# shared_gene_1 Depression
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Scoliosis
# shared_gene_1 Decreased fetal movement
# shared_gene_1 Global developmental delay
# shared_gene_1 Generalized hypotonia
# shared_gene_1 Polyhydramnios
# shared_gene_1 Kyphosis
# shared_gene_1 Panic attack
# shared_gene_1 Hyperlordosis
# shared_gene_1 Death in infancy
# shared_gene_1 Hypotonia
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Adducted thumb
# shared_gene_1 Tremor
# shared_gene_1 Strabismus
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Poikilocytosis
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Middle age onset
# shared_gene_1 Dysarthria
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Growth delay
# shared_gene_1 Anxiety
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Depression
# shared_gene_1 Dysphagia
# shared_gene_1 Flexion contracture
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Global developmental delay
# shared_gene_1 Microcephaly
# shared_gene_1 Micrognathia
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Facial palsy
# shared_gene_1 Death in infancy
# shared_gene_1 Adducted thumb
# shared_gene_1 Hip dislocation
# shared_gene_1 Delayed speech and language development
# shared_gene_1 Myoclonus
# shared_gene_1 Personality disorder
# shared_gene_1 Generalized hypotonia
# shared_gene_1 Motor delay
# shared_gene_1 Hypotonia
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Myoclonus
# shared_gene_1 Global developmental delay
# shared_gene_1 Pes valgus
# shared_gene_1 Anxiety
# shared_gene_1 Depression
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Limb myoclonus
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Global developmental delay
# shared_gene_1 Microcephaly
# shared_gene_1 Neonatal respiratory distress
# shared_gene_1 Short neck
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Wide nasal bridge
# shared_gene_1 Anteverted nares
# shared_gene_1 Hyperlordosis
# shared_gene_1 Umbilical hernia
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Hypotonia
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Scoliosis
# shared_gene_1 Global developmental delay
# shared_gene_1 Microcephaly
# shared_gene_1 Prominent antihelix
# shared_gene_1 Generalized hypotonia
# shared_gene_1 Short neck
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Long philtrum
# shared_gene_1 Kyphosis
# shared_gene_1 Hypotonia
# shared_gene_1 Macrotia
# shared_gene_1 Gastrostomy tube feeding in infancy
# shared_gene_1 Intellectual disability, severe
# shared_gene_1 Hypertonia
# shared_gene_1 Growth delay
# shared_gene_1 Scoliosis
# shared_gene_1 Global developmental delay
# shared_gene_1 Polyhydramnios
# shared_gene_1 Micrognathia
# shared_gene_1 Short neck
# shared_gene_1 Wide nasal bridge
# shared_gene_1 Middle age onset
# shared_gene_1 Intrauterine growth retardation
# shared_gene_1 Hypotonia
# shared_gene_1 Dysarthria
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Abnormality of the voice
# shared_gene_1 Ptosis
# shared_gene_1 Strabismus
# shared_gene_1 Adducted thumb
# shared_gene_1 Ptosis
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Talipes equinovarus
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Inguinal hernia
# shared_gene_1 Scoliosis
# shared_gene_1 Microcephaly
# shared_gene_1 Umbilical hernia
# shared_gene_1 Strabismus
# shared_gene_1 Polyhydramnios
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Micrognathia
# shared_gene_1 Macrotia
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Wide nasal bridge
# shared_gene_1 Microcephaly
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Autosomal recessive inheritance
# shared_gene_1 Neonatal onset
# shared_gene_1 Dysphagia
# shared_gene_1 Polyhydramnios
# shared_gene_1 Long philtrum
# shared_gene_1 Wide nasal bridge
# shared_gene_1 Anteverted nares
# shared_gene_1 Macrotia
# shared_gene_1 Autosomal dominant inheritance
# shared_gene_1 Growth delay
# shared_gene_1 Depression
# shared_gene_1 Kyphoscoliosis
# shared_gene_1 Panic attack
# shared_gene_1 Intrauterine growth retardation
# shared_gene_1 Gastrostomy tube feeding in infancy
# shared_gene_1 Strabismus
# shared_gene_1 Generalized hypotonia
# shared_gene_1 Hypertonia
# shared_gene_1 Scoliosis
# shared_gene_1 Global developmental delay
# shared_gene_1 Micrognathia
# shared_gene_1 Short neck
# shared_gene_1 Hypotonia
# shared_gene_1 Dysarthria
# shared_gene_1 Abnormality of the voice
# shared_gene_1 Ptosis
# shared_gene_2 Neonatal onset
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Motor delay
# shared_gene_2 Dysphagia
# shared_gene_2 Polyhydramnios
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Anteverted nares
# shared_gene_2 Blepharospasm
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Intellectual disability, moderate
# shared_gene_2 Camptodactyly
# shared_gene_2 Hyperlordosis
# shared_gene_2 Death in infancy
# shared_gene_2 Restrictive ventilatory defect
# shared_gene_2 Strabismus
# shared_gene_2 Scoliosis
# shared_gene_2 Decreased fetal movement
# shared_gene_2 Global developmental delay
# shared_gene_2 Microcephaly
# shared_gene_2 Neonatal respiratory distress
# shared_gene_2 Micrognathia
# shared_gene_2 Short neck
# shared_gene_2 Kyphosis
# shared_gene_2 Hypotonia
# shared_gene_2 Intellectual disability, severe
# shared_gene_2 Ptosis
# shared_gene_2 Inguinal hernia
# shared_gene_2 Dysphagia
# shared_gene_2 Long philtrum
# shared_gene_2 Wide nasal bridge
# shared_gene_2 Anteverted nares
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Tremor
# shared_gene_2 Growth delay
# shared_gene_2 Typified by incomplete penetrance
# shared_gene_2 Flexion contracture
# shared_gene_2 Camptodactyly
# shared_gene_2 Absent speech
# shared_gene_2 Anxiety
# shared_gene_2 Depression
# shared_gene_2 Intrauterine growth retardation
# shared_gene_2 Gastrostomy tube feeding in infancy
# shared_gene_2 Strabismus
# shared_gene_2 Gait disturbance
# shared_gene_2 Upslanted palpebral fissure
# shared_gene_2 Hypertonia
# shared_gene_2 Hip dislocation
# shared_gene_2 Scoliosis
# shared_gene_2 Global developmental delay
# shared_gene_2 Microcephaly
# shared_gene_2 Micrognathia
# shared_gene_2 Inability to walk
# shared_gene_2 Short neck
# shared_gene_2 Hypotonia
# shared_gene_2 Dysarthria
# shared_gene_2 Abnormality of the voice
# shared_gene_2 Delayed speech and language development
# shared_gene_2 Ptosis
# shared_gene_2 Dysphagia
# shared_gene_2 Long philtrum
# shared_gene_2 Anteverted nares
# shared_gene_2 Blepharospasm
# shared_gene_2 Macrotia
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Intellectual disability, moderate
# shared_gene_2 Flexion contracture
# shared_gene_2 Camptodactyly
# shared_gene_2 Hyperlordosis
# shared_gene_2 Umbilical hernia
# shared_gene_2 Strabismus
# shared_gene_2 Upslanted palpebral fissure
# shared_gene_2 Scoliosis
# shared_gene_2 Global developmental delay
# shared_gene_2 Micrognathia
# shared_gene_2 Rocker bottom foot
# shared_gene_2 Ptosis
# shared_gene_2 Typified by incomplete penetrance
# shared_gene_2 Dysphagia
# shared_gene_2 Anxiety
# shared_gene_2 Depression
# shared_gene_2 Middle age onset
# shared_gene_2 Dysarthria
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Babinski sign
# shared_gene_2 Ptosis
# shared_gene_2 Hyperreflexia
# shared_gene_2 Inguinal hernia
# shared_gene_2 Gait disturbance
# shared_gene_2 Scoliosis
# shared_gene_2 Motor delay
# shared_gene_2 Global developmental delay
# shared_gene_2 Microcephaly
# shared_gene_2 Depression
# shared_gene_2 Kyphosis
# shared_gene_2 Kyphoscoliosis
# shared_gene_2 Anteverted nares
# shared_gene_2 Hypotonia
# shared_gene_2 Hypertonia
# shared_gene_2 Delayed speech and language development
# shared_gene_2 Strabismus
# shared_gene_2 Neonatal onset
# shared_gene_2 Delayed speech and language development
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Intrauterine growth retardation
# shared_gene_2 Gait disturbance
# shared_gene_2 Scoliosis
# shared_gene_2 Global developmental delay
# shared_gene_2 Microcephaly
# shared_gene_2 Abnormality of the musculature
# shared_gene_2 Micrognathia
# shared_gene_2 Anxiety
# shared_gene_2 Depression
# shared_gene_2 Wide nasal bridge
# shared_gene_2 Middle age onset
# shared_gene_2 Intrauterine growth retardation
# shared_gene_2 Dysarthria
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Tremor
# shared_gene_2 Dystonia
# shared_gene_2 Ptosis
# shared_gene_2 Hyperreflexia
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Global developmental delay
# shared_gene_2 Microcephaly
# shared_gene_2 Neonatal respiratory distress
# shared_gene_2 Short neck
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Wide nasal bridge
# shared_gene_2 Anteverted nares
# shared_gene_2 Hyperlordosis
# shared_gene_2 Umbilical hernia
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Hypotonia
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Global developmental delay
# shared_gene_2 Microcephaly
# shared_gene_2 Micrognathia
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Facial palsy
# shared_gene_2 Death in infancy
# shared_gene_2 Adducted thumb
# shared_gene_2 Hip dislocation
# shared_gene_2 Delayed speech and language development
# shared_gene_2 Inguinal hernia
# shared_gene_2 Gait disturbance
# shared_gene_2 Scoliosis
# shared_gene_2 Microcephaly
# shared_gene_2 Micrognathia
# shared_gene_2 Anxiety
# shared_gene_2 Depression
# shared_gene_2 Kyphosis
# shared_gene_2 Long philtrum
# shared_gene_2 Wide nasal bridge
# shared_gene_2 Hyperlordosis
# shared_gene_2 Umbilical hernia
# shared_gene_2 Hypotonia
# shared_gene_2 Macrotia
# shared_gene_2 Dysarthria
# shared_gene_2 Adducted thumb
# shared_gene_2 Tremor
# shared_gene_2 Abnormality of the voice
# shared_gene_2 Compulsive behaviors
# shared_gene_2 Strabismus
# shared_gene_2 Hyperreflexia
# shared_gene_2 Adducted thumb
# shared_gene_2 Ptosis
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Talipes equinovarus
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Scoliosis
# shared_gene_2 Babinski sign
# shared_gene_2 Pes valgus
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Dysarthria
# shared_gene_2 Scoliosis
# shared_gene_2 Motor delay
# shared_gene_2 Neonatal onset
# shared_gene_2 Global developmental delay
# shared_gene_2 Arthrogryposis multiplex congenita
# shared_gene_2 Wide nasal bridge
# shared_gene_2 Intrauterine growth retardation
# shared_gene_2 Hypotonia
# shared_gene_2 Intellectual disability, severe
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Growth delay
# shared_gene_2 Scoliosis
# shared_gene_2 Global developmental delay
# shared_gene_2 Polyhydramnios
# shared_gene_2 Micrognathia
# shared_gene_2 Short neck
# shared_gene_2 Wide nasal bridge
# shared_gene_2 Middle age onset
# shared_gene_2 Intrauterine growth retardation
# shared_gene_2 Hypotonia
# shared_gene_2 Dysarthria
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Abnormality of the voice
# shared_gene_2 Ptosis
# shared_gene_2 Strabismus
# shared_gene_2 Inguinal hernia
# shared_gene_2 Absent speech
# shared_gene_2 Scoliosis
# shared_gene_2 Anteverted nares
# shared_gene_2 Polyhydramnios
# shared_gene_2 Micrognathia
# shared_gene_2 Delayed speech and language development
# shared_gene_2 Umbilical hernia
# shared_gene_2 Ptosis
# shared_gene_2 Hypotonia
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Global developmental delay
# shared_gene_2 Wide nasal bridge
# shared_gene_2 Microcephaly
# shared_gene_2 Prominent occiput
# shared_gene_2 Scoliosis
# shared_gene_2 Hyperlordosis
# shared_gene_2 Intrauterine growth retardation
# shared_gene_2 Micrognathia
# shared_gene_2 Strabismus
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Kyphosis
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Intrauterine growth retardation
# shared_gene_2 Anxiety
# shared_gene_2 Depression
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Growth delay
# shared_gene_2 Anxiety
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Depression
# shared_gene_2 Dysphagia
# shared_gene_2 Flexion contracture
# shared_gene_2 Myoclonus
# shared_gene_2 Polyhydramnios
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Babinski sign
# shared_gene_2 Middle age onset
# shared_gene_2 Anxiety
# shared_gene_2 Hyperreflexia
# shared_gene_2 Dysphagia
# shared_gene_2 Depression
# shared_gene_2 Dysarthria
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Anxiety
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Depression
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Inguinal hernia
# shared_gene_2 Scoliosis
# shared_gene_2 Microcephaly
# shared_gene_2 Umbilical hernia
# shared_gene_2 Strabismus
# shared_gene_2 Poikilocytosis
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Middle age onset
# shared_gene_2 Dysarthria
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Microcephaly
# shared_gene_2 Micrognathia
# shared_gene_2 Short neck
# shared_gene_2 Anxiety
# shared_gene_2 Long philtrum
# shared_gene_2 Anteverted nares
# shared_gene_2 Intrauterine growth retardation
# shared_gene_2 Hypotonia
# shared_gene_2 Macrotia
# shared_gene_2 Intellectual disability, severe
# shared_gene_2 Hypertonia
# shared_gene_2 Hip dislocation
# shared_gene_2 Compulsive behaviors
# shared_gene_2 Ptosis
# shared_gene_2 Strabismus
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Flexion contracture
# shared_gene_2 Inguinal hernia
# shared_gene_2 Growth delay
# shared_gene_2 Scoliosis
# shared_gene_2 Global developmental delay
# shared_gene_2 Flexion contracture
# shared_gene_2 Microcephaly
# shared_gene_2 Absent speech
# shared_gene_2 Polyhydramnios
# shared_gene_2 Upslanted palpebral fissure
# shared_gene_2 Micrognathia
# shared_gene_2 Long philtrum
# shared_gene_2 Talipes equinovarus
# shared_gene_2 Wide nasal bridge
# shared_gene_2 Anteverted nares
# shared_gene_2 Panic attack
# shared_gene_2 Intrauterine growth retardation
# shared_gene_2 Umbilical hernia
# shared_gene_2 Hypotonia
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Adducted thumb
# shared_gene_2 Delayed speech and language development
# shared_gene_2 Compulsive behaviors
# shared_gene_2 Ptosis
# shared_gene_2 Strabismus
# shared_gene_2 Hyperreflexia
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Generalized hypotonia
# shared_gene_2 Motor delay
# shared_gene_2 Ptosis
# shared_gene_2 Strabismus
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Death in infancy
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Middle age onset
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Scoliosis
# shared_gene_2 Global developmental delay
# shared_gene_2 Microcephaly
# shared_gene_2 Prominent antihelix
# shared_gene_2 Generalized hypotonia
# shared_gene_2 Short neck
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Long philtrum
# shared_gene_2 Kyphosis
# shared_gene_2 Hypotonia
# shared_gene_2 Macrotia
# shared_gene_2 Gastrostomy tube feeding in infancy
# shared_gene_2 Intellectual disability, severe
# shared_gene_2 Hypertonia
# shared_gene_2 Motor delay
# shared_gene_2 Global developmental delay
# shared_gene_2 Arthrogryposis multiplex congenita
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Intrauterine growth retardation
# shared_gene_2 Hand tremor
# shared_gene_2 Hypotonia
# shared_gene_2 Intellectual disability, severe
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Delayed speech and language development
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Growth delay
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Depression
# shared_gene_2 Adducted thumb
# shared_gene_2 Intellectual disability, moderate
# shared_gene_2 Neonatal onset
# shared_gene_2 Strabismus
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Depression
# shared_gene_2 Global developmental delay
# shared_gene_2 Micrognathia
# shared_gene_2 Anxiety
# shared_gene_2 Depression
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Wide nasal bridge
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Polyhydramnios
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Autosomal recessive inheritance
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Neonatal onset
# shared_gene_2 Dysphagia
# shared_gene_2 Polyhydramnios
# shared_gene_2 Long philtrum
# shared_gene_2 Wide nasal bridge
# shared_gene_2 Anteverted nares
# shared_gene_2 Macrotia
# shared_gene_2 Autosomal dominant inheritance
# shared_gene_2 Growth delay
# shared_gene_2 Depression
# shared_gene_2 Kyphoscoliosis
# shared_gene_2 Panic attack
# shared_gene_2 Intrauterine growth retardation
# shared_gene_2 Gastrostomy tube feeding in infancy
# shared_gene_2 Strabismus
# shared_gene_2 Generalized hypotonia
# shared_gene_2 Hypertonia
# shared_gene_2 Scoliosis
# shared_gene_2 Global developmental delay
# shared_gene_2 Micrognathia
# shared_gene_2 Short neck
# shared_gene_2 Hypotonia
# shared_gene_2 Dysarthria
# shared_gene_2 Abnormality of the voice
# shared_gene_2 Ptosis
# shared_gene_2 Autosomal recessive inheritance
#              shared_gene_0 shared_gene_1 shared_gene_2  \
# 0                    MGAT2        SLC8A1         DGAT1
# 1                    DGAT2          PTK2         PDE4B
# 2                     FASN         SCN9A         MAPK8
# 3                    DGAT1         PTAFR         FGFR3
# 4                      SYK         ABCB1         FGFR1
# ..                     ...           ...           ...
# 95                    BRD2        PLA2G7           TEK
# 96                    BRD3           ITK          IDO1
# 97             CDK5R1 CDK5    CCNA2 CDK2          BRAF
# 98  CCNB3 CDK1 CCNB1 CCNB2          BRAF          RORC
# 99            CALCRL RAMP1            F9         NAMPT
#
#                                           phenotype_0  \
# 0   [Osteopenia, Aggressive behavior, Dental crowd...
# 1                                                  []
# 2                                                  []
# 3   [Neonatal onset, Hyperlipidemia, Diarrhea, Aut...
# 4   [Lymphadenopathy, Hepatitis, Splenomegaly, Ele...
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
#                                           phenotype_1  \
# 0                                                  []
# 1                                                  []
# 2   [Generalized cerebral atrophy/hypoplasia, Inte...
# 3                                                  []
# 4               [Inflammation of the large intestine]
# ..                                                ...
# 95  [Autosomal recessive inheritance, Increased le...
# 96  [Pleural effusion, Lymphadenopathy, Decreased ...
# 97                                                 []
# 98  [Osteopenia, EEG abnormality, Abnormal heart v...
# 99  [X-linked recessive inheritance, Abnormal blee...
#
#                                           phenotype_2  \
# 0   [Neonatal onset, Hyperlipidemia, Diarrhea, Aut...
# 1                                                  []
# 2                                                  []
# 3   [Hypoplastic ilia, Nail dysplasia, Tibial bowi...
# 4   [Osteopenia, Inguinal hernia, Renal agenesis, ...
# ..                                                ...
# 95  [Increased cup-to-disc ratio, Ocular hypertens...
# 96                                                 []
# 97  [Osteopenia, EEG abnormality, Abnormal heart v...
# 98  [Hypoplasia of the thymus, Autosomal recessive...
# 99                                                 []
#
#                                    shared_gene_0_phen  \
# 0   [Scoliosis, Global developmental delay, Microc...
# 1                                                  []
# 2                                                  []
# 3   [Neonatal onset, Autosomal recessive inheritance]
# 4                    [Autosomal dominant inheritance]
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
#                                    shared_gene_1_phen  \
# 0                                                  []
# 1                                                  []
# 2   [Myoclonus, Neonatal onset, Generalized hypoto...
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 95                  [Autosomal recessive inheritance]
# 96                  [Autosomal recessive inheritance]
# 97                                                 []
# 98  [Neonatal onset, Dysphagia, Polyhydramnios, Lo...
# 99                                                 []
#
#                                    shared_gene_2_phen
# 0   [Neonatal onset, Autosomal recessive inheritance]
# 1                                                  []
# 2                                                  []
# 3   [Motor delay, Dysphagia, Polyhydramnios, Autos...
# 4   [Inguinal hernia, Dysphagia, Long philtrum, Wi...
# ..                                                ...
# 95  [Autosomal recessive inheritance, Autosomal do...
# 96                                                 []
# 97  [Neonatal onset, Dysphagia, Polyhydramnios, Lo...
# 98                  [Autosomal recessive inheritance]
# 99                                                 []
#
# [100 rows x 9 columns]

# %% [markdown]
# Finding disease

# %%
# !pip install requests
# !pip install beautifulsoup4
import requests
from bs4 import BeautifulSoup
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %%
n=0
for cc in ['shared_gene_0','shared_gene_1','shared_gene_2']:
   shared_gene_phenotype_table['dis_'+str(n)] =None
   shared_gene_phenotype_table['dis_'+str(n)] = shared_gene_phenotype_table[cc+'_phen'].astype(object)
   for i in shared_gene_phenotype_table.index:
          gene__=shared_gene_phenotype_table[cc][i]
          shared_gene_phenotype_table.at[i,'dis_'+str(n)] =list(genes_to_disease[genes_to_disease['gene_symbol'].str.lower()==gene__.lower()]['disease_id'])
   n+=1
shared_gene_phenotype_table
# Out:
#              shared_gene_0 shared_gene_1 shared_gene_2  \
# 0                    MGAT2        SLC8A1         DGAT1
# 1                    DGAT2          PTK2         PDE4B
# 2                     FASN         SCN9A         MAPK8
# 3                    DGAT1         PTAFR         FGFR3
# 4                      SYK         ABCB1         FGFR1
# ..                     ...           ...           ...
# 95                    BRD2        PLA2G7           TEK
# 96                    BRD3           ITK          IDO1
# 97             CDK5R1 CDK5    CCNA2 CDK2          BRAF
# 98  CCNB3 CDK1 CCNB1 CCNB2          BRAF          RORC
# 99            CALCRL RAMP1            F9         NAMPT
#
#                                           phenotype_0  \
# 0   [Osteopenia, Aggressive behavior, Dental crowd...
# 1                                                  []
# 2                                                  []
# 3   [Neonatal onset, Hyperlipidemia, Diarrhea, Aut...
# 4   [Lymphadenopathy, Hepatitis, Splenomegaly, Ele...
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
#                                           phenotype_1  \
# 0                                                  []
# 1                                                  []
# 2   [Generalized cerebral atrophy/hypoplasia, Inte...
# 3                                                  []
# 4               [Inflammation of the large intestine]
# ..                                                ...
# 95  [Autosomal recessive inheritance, Increased le...
# 96  [Pleural effusion, Lymphadenopathy, Decreased ...
# 97                                                 []
# 98  [Osteopenia, EEG abnormality, Abnormal heart v...
# 99  [X-linked recessive inheritance, Abnormal blee...
#
#                                           phenotype_2  \
# 0   [Neonatal onset, Hyperlipidemia, Diarrhea, Aut...
# 1                                                  []
# 2                                                  []
# 3   [Hypoplastic ilia, Nail dysplasia, Tibial bowi...
# 4   [Osteopenia, Inguinal hernia, Renal agenesis, ...
# ..                                                ...
# 95  [Increased cup-to-disc ratio, Ocular hypertens...
# 96                                                 []
# 97  [Osteopenia, EEG abnormality, Abnormal heart v...
# 98  [Hypoplasia of the thymus, Autosomal recessive...
# 99                                                 []
#
#                                    shared_gene_0_phen  \
# 0   [Scoliosis, Global developmental delay, Microc...
# 1                                                  []
# 2                                                  []
# 3   [Neonatal onset, Autosomal recessive inheritance]
# 4                    [Autosomal dominant inheritance]
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
#                                    shared_gene_1_phen  \
# 0                                                  []
# 1                                                  []
# 2   [Myoclonus, Neonatal onset, Generalized hypoto...
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 95                  [Autosomal recessive inheritance]
# 96                  [Autosomal recessive inheritance]
# 97                                                 []
# 98  [Neonatal onset, Dysphagia, Polyhydramnios, Lo...
# 99                                                 []
#
#                                    shared_gene_2_phen  \
# 0   [Neonatal onset, Autosomal recessive inheritance]
# 1                                                  []
# 2                                                  []
# 3   [Motor delay, Dysphagia, Polyhydramnios, Autos...
# 4   [Inguinal hernia, Dysphagia, Long philtrum, Wi...
# ..                                                ...
# 95  [Autosomal recessive inheritance, Autosomal do...
# 96                                                 []
# 97  [Neonatal onset, Dysphagia, Polyhydramnios, Lo...
# 98                  [Autosomal recessive inheritance]
# 99                                                 []
#
#                           dis_0  \
# 0    [OMIM:212066, ORPHA:79329]
# 1                [ORPHA:487814]
# 2                            []
# 3   [OMIM:615863, ORPHA:329242]
# 4                 [OMIM:619381]
# ..                          ...
# 95                           []
# 96                           []
# 97                           []
# 98                           []
# 99                           []
#
#                                                 dis_1  \
# 0                                                  []
# 1                                                  []
# 2   [OMIM:201300, OMIM:243000, OMIM:133020, OMIM:1...
# 3                                                  []
# 4               [OMIM:120080, OMIM:612244, ORPHA:771]
# ..                                                ...
# 95                                      [OMIM:614278]
# 96                        [OMIM:613011, ORPHA:538963]
# 97                                                 []
# 98  [OMIM:115150, OMIM:114500, OMIM:211980, OMIM:6...
# 99  [OMIM:301052, OMIM:306900, OMIM:300807, ORPHA:...
#
#                                                 dis_2
# 0                         [OMIM:615863, ORPHA:329242]
# 1                                                  []
# 2                                                  []
# 3   [OMIM:146000, OMIM:162900, OMIM:616482, OMIM:1...
# 4   [OMIM:613001, OMIM:190440, OMIM:147950, OMIM:6...
# ..                                                ...
# 95  [OMIM:600975, OMIM:600195, OMIM:617272, ORPHA:...
# 96                                                 []
# 97  [OMIM:115150, OMIM:114500, OMIM:211980, OMIM:6...
# 98                        [OMIM:616622, ORPHA:477857]
# 99                                                 []
#
# [100 rows x 12 columns]

# %%
All_dis=list(set(sum(shared_gene_phenotype_table['dis_0'], [])
+sum(shared_gene_phenotype_table['dis_1'], [])
+sum(shared_gene_phenotype_table['dis_2'], [])   ))
df=pd.DataFrame()
df['Disease']=All_dis
df
# Out:
#           Disease
# 0    ORPHA:178342
# 1     OMIM:618573
# 2     OMIM:246200
# 3     OMIM:613011
# 4       ORPHA:536
# ..            ...
# 391   OMIM:166250
# 392   OMIM:100800
# 393   ORPHA:33069
# 394   OMIM:619802
# 395     ORPHA:794
#
# [396 rows x 1 columns]

# %% [markdown]
# Orpha: https://www.orpha.net/en/disease/detail/746

# %%
def get_info(num):
  # URL of the page to scrape
  url = "https://www.orpha.net/en/disease/detail/"+str(num)
  # Send a GET request to the URL
  response = requests.get(url)
  # Parse the HTML content
  soup = BeautifulSoup(response.text, 'html.parser')
  # Find the title tag and extract its text
  title_tag = soup.find('title')
  title = title_tag.text if title_tag else None
  ##########################################################
  # Find the <strong> tag with the text "Synonym(s):"
  synonyms=None
  synonym_tag = soup.find('strong', string="Synonym(s): ")
  # If the <strong> tag is found
  if synonym_tag:
        # Find the <ul> tag following the <strong> tag
        ul_tag = synonym_tag.find_next('ul')
        # Find all <li> tags within the <ul> tag
        synonym_tags = ul_tag.find_all('li')
        # Extract and return the synonyms
        synonyms = [tag.get_text(strip=True) for tag in synonym_tags]
        synonyms= ", ".join(synonyms)
  ##########################################################
  # Find the <strong> tag with the class "d-block mb-3 service-color" containing the text "Disease definition"
  Dis_def=None
  definition_strong = soup.find('strong', class_="d-block mb-3 service-color", string="Disease definition")
  # If the <strong> tag is found
  if definition_strong:
        # Get the next <p> tag which contains the disease definition
        definition_p = definition_strong.find_next('p')
        # If <p> tag exists
        if definition_p:
            # Extract and return the disease definition
            Dis_def= definition_p.get_text(strip=True)
    # If disease definition is not found
  ##########################################################
  Clinical_des=None
  # Find the <div> tag with the class "fs-5 orpha-blue" containing the text "Clinical description"
  clinical_div = soup.find('div', class_="fs-5 orpha-blue", string="Clinical description")
  # If the <div> tag is found
  if clinical_div:
        # Get the next <p> tag which contains the clinical description
        clinical_p = clinical_div.find_next('p')
        # If <p> tag exists
        if clinical_p:
            # Extract and return the clinical description
            Clinical_des= clinical_p.get_text(strip=True)
  return title, synonyms, Dis_def, Clinical_des


'''
import requests
from bs4 import BeautifulSoup
def get_name(num):
  # URL of the page to scrape
  url = "https://www.orpha.net/en/disease/detail/"+str(num)
  # Send a GET request to the URL
  response = requests.get(url)
  # Parse the HTML content
  soup = BeautifulSoup(response.text, 'html.parser')
  # Find the title tag and extract its text
  title_tag = soup.find('title')
  title = title_tag.text if title_tag else "Title not found"
  # Print the extracted title
  return title
  #print("Title:", title)
def find_dis(y):
  if y[:6] =='ORPHA:':
      return get_name(y[6:])

df['disease_name']= df.apply(lambda x: find_dis(x['Disease']), axis=1)
df.head()
'''
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor

def get_name(num):
    # URL of the page to scrape
    url = "https://www.orpha.net/en/disease/detail/" + str(num)
    # Send a GET request to the URL
    response = requests.get(url)
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')
    # Find the title tag and extract its text
    title_tag = soup.find('title')
    title = title_tag.text if title_tag else "Title not found"
    # Print the extracted title
    return title

def find_dis(y):
    if y[:6] == 'ORPHA:':
        return get_info(y[6:])
    else:
      return None, None, None, None
# Assuming df is your pandas DataFrame
# Modify df in-place, so we don't need to return a new DataFrame
# We'll use a ThreadPoolExecutor to make asynchronous requests
with ThreadPoolExecutor(max_workers=10) as executor:
    # Apply the find_dis function to each row in parallel
    df['disease_name'], df['Syn'], df['disease_des/def'], df['Clinicalfeatures/Clinical_des']  =zip(*list(executor.map(find_dis, df['Disease'])))
 #list(executor.map(find_dis, df['Disease']))



# Print the modified DataFrame
df2= df.dropna(subset=['disease_name'])
df_unique_1 = df2.drop_duplicates(subset=['disease_name'])
df_unique_1
# Out:
#           Disease                                       disease_name  \
# 0    ORPHA:178342       Orphanet: Inflammatory myofibroblastic tumor
# 4       ORPHA:536             Orphanet: Systemic lupus erythematosus
# 5     ORPHA:64752  Orphanet: Hereditary sensory and autonomic neu...
# 7     ORPHA:99802                       Orphanet: Hemimegalencephaly
# 9     ORPHA:93259                 Orphanet: Pfeiffer syndrome type 2
# ..            ...                                                ...
# 388    ORPHA:1930        Orphanet: Herpes simplex virus encephalitis
# 389   ORPHA:50943              Orphanet: Keratolytic winter erythema
# 390  ORPHA:464293  Orphanet: NON RARE IN EUROPE: Infantile capill...
# 393   ORPHA:33069                          Orphanet: Dravet syndrome
# 395     ORPHA:794                 Orphanet: Saethre-Chotzen syndrome
#
#                                                    Syn  \
# 0                                                 None
# 4                Disseminated lupus erythematosus, SLE
# 5    CIP, Congenital insensitivity to pain and ther...
# 7                            Unilateral megalencephaly
# 9                                                 None
# ..                                                 ...
# 388  HSE, HSV encephalitis, HSVE, Herpes simplex me...
# 389    Erythrokeratolysis hiemalis, Oudtshoorn disease
# 390                                               None
# 393  SMEI, Severe myoclonic epilepsy of infancy, Se...
# 395            ACS3, Acrocephalosyndactyly type 3, SCS
#
#                                        disease_des/def  \
# 0    Inflammatory myofibroblastic tumor is a rare n...
# 4                                                 None
# 5    A disorder that is characterized by loss of pa...
# 7    Hemimegalencephaly is a rare cerebral malforma...
# 9                                                 None
# ..                                                 ...
# 388  A rare disorder caused by infection of the cen...
# 389  Keratolytic winter erythema is a rare epiderma...
# 390                                               None
# 393  A rare, genetic, developmental and epileptic e...
# 395  A syndrome characterized by unilateral or bila...
#
#                          Clinicalfeatures/Clinical_des
# 0                                                 None
# 4                                                 None
# 5    Other findings include ulcers, self-mutilation...
# 7                                                 None
# 9                                                 None
# ..                                                 ...
# 388  HSVE usually peaks in childhood (between 3 mon...
# 389                                               None
# 390                                               None
# 393  Onset of the first seizure is mainly in the fi...
# 395  SCS has a variable spectrum of manifestations....
#
# [215 rows x 5 columns]

# %% [markdown]
# https://www.omim.org/entry/313490

# %%
import pandas as pd
# Read the contents of omim_info.txt into a Pandas DataFrame
omim_info = pd.read_csv('omim_info.txt', sep='\t',  header=3)
# Display the DataFrame
display(omim_info.head())

import requests
from bs4 import BeautifulSoup

def get_description_and_clinical_features(num):
    # URL of the page to scrape
    url = f"https://api.omim.org/api/entry?mimNumber={num}&apiKey=FNQbzW08SSWjNwMbMFBrhw&include=text"
    # Send a GET request to the URL
    response = requests.get(url)
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the description section
    description_section = soup.find('textsectionname', string="description")
    # If description section is found, get the content
    description_content = description_section.find_next_sibling('textsectioncontent').get_text(strip=True) if description_section else None

    # Find the clinical features section
    clinical_features_section = soup.find('textsectionname', string="clinicalFeatures")
    # If clinical features section is found, get the content
    clinical_features_content = clinical_features_section.find_next_sibling('textsectioncontent').get_text(strip=True) if clinical_features_section else None

    return description_content, clinical_features_content

get_description_and_clinical_features(str(620283))


def find_dis_omim(number_to_search):
 result_df = omim_info[omim_info['# Phenotype'].str.contains(number_to_search)]
 result_df.index=range(result_df.shape[0])
 description_, _clinical_features=get_description_and_clinical_features(number_to_search)
 return result_df['# Phenotype'][0] , result_df['Gene/Locus And Other Related Symbols'][0],description_, _clinical_features


number_to_search = "202110"
find_dis_omim(number_to_search)
find_dis_omim('620283')

def find_dis_from_omim(y):
    if y[:5] == 'OMIM:':
      try:
        return find_dis_omim(str(y[5:]))
      except:
        pass
    return None, None, None, None
df['disease_name'], df['Syn'], df['disease_des/def'], df['Clinicalfeatures/Clinical_des'] = zip(*df.apply(lambda x: find_dis_from_omim(x['Disease']), axis=1))
df2= df.dropna(subset=['disease_name'])
df_unique_2 = df2.drop_duplicates(subset=['disease_name'])
df_unique_2
# Out:
#                                          # Phenotype  \
# 0       17,20-lyase deficiency, isolated, 202110 (3)
# 1  17-alpha-hydroxylase/17,20-lyase deficiency, 2...
# 2   2,4-dienoyl-CoA reductase deficiency, 616034 (3)
# 3              2-methylbutyrylglycinuria, 610006 (3)
# 4                         3-M syndrome 1, 273750 (3)
#
#   Gene/Locus And Other Related Symbols  MIM Number Cyto Location
# 0              CYP17A1, CYP17, P450C17    609300.0      10q24.32
# 1              CYP17A1, CYP17, P450C17    609300.0      10q24.32
# 2                NADK2, C5orf33, DECRD    615787.0        5p13.2
# 3                        ACADSB, SBCAD    600301.0      10q26.13
# 4                            CUL7, 3M1    609577.0        6p21.1
# /usr/lib/python3.10/html/parser.py:170: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   k = self.parse_starttag(i)
#          Disease                                       disease_name  \
# 1    OMIM:618573  Hypothyroidism, congenital, nongoitrous, 7, 61...
# 2    OMIM:246200                       Donohue syndrome, 246200 (3)
# 3    OMIM:613011         Lymphoproliferative syndrome 1, 613011 (3)
# 6    OMIM:617062  Okur-Chung neurodevelopmental syndrome, 617062...
# 8    OMIM:602849                        Muenke syndrome, 602849 (3)
# ..           ...                                                ...
# 384  OMIM:606777  GLUT1 deficiency syndrome 1, infantile onset, ...
# 386  OMIM:180849            Rubinstein-Taybi syndrome 1, 180849 (3)
# 391  OMIM:166250               Osteoglophonic dysplasia, 166250 (3)
# 392  OMIM:100800                         Achondroplasia, 100800 (3)
# 394  OMIM:619802  Immunodeficiency 97 with autoinflammation, 619...
#
#                                                    Syn  \
# 1                                          TRHR, CHNG7
# 2                                           INSR, HHF5
# 3                                      ITK, EMT, LPFS1
# 6                                CSNK2A1, CK2A1, OCNDS
# 8                                           FGFR3, ACH
# ..                                                 ...
# 384  SLC2A1, GLUT1, HTLVR, DYT18, PED, GLUT1DS, EIG...
# 386                          CREBBP, CBP, RSTS1, MKHK1
# 391          FGFR1, FLT2, OGD, KAL2, HH2, HRTFDS, ECCL
# 392                                         FGFR3, ACH
# 394                                      PIK3CG, IMD97
#
#                                        disease_des/def  \
# 1    Nongoitrous congenital hypothyroidism-7 (CHNG7...
# 2                                                 None
# 3    Lymphoproliferative syndrome-1 is an autosomal...
# 6    Okur-Chung neurodevelopmental syndrome (OCNDS)...
# 8    Muenke syndrome is an autosomal dominant disor...
# ..                                                 ...
# 384  GLUT1 deficiency syndrome-1 is a neurologic di...
# 386  Rubinstein-Taybi syndrome is a multiple congen...
# 391  Osteoglophonic dysplasia (OGD) is characterize...
# 392  Achondroplasia is the most frequent form of sh...
# 394  Immunodeficiency-97 with autoinflammation (IMD...
#
#                          Clinicalfeatures/Clinical_des
# 1    {2:Collu et al. (1997)} studied a 12.5-year-ol...
# 2    Among the children of second cousins once remo...
# 3    {1:Huck et al. (2009)} reported 2 sisters, bor...
# 6    {3:Okur et al. (2016)} reported 5 unrelated gi...
# 8    On the basis of 61 individuals from 20 unrelat...
# ..                                                 ...
# 384  {3:De Vivo et al. (1991)} described 2 patients...
# 386  {57:Rubinstein and Taybi (1963)} reported a sy...
# 391  {1:Beighton et al. (1980)} described a seeming...
# 392  Whereas many conditions that cause short statu...
# 394  {1:Takeda et al. (2019)} reported a 9-year-old...
#
# [180 rows x 5 columns]

# %%
concatenated_df = pd.concat([df_unique_2, df_unique_1], ignore_index=True)
concatenated_df
# Out:
#           Disease                                       disease_name  \
# 0     OMIM:618573  Hypothyroidism, congenital, nongoitrous, 7, 61...
# 1     OMIM:246200                       Donohue syndrome, 246200 (3)
# 2     OMIM:613011         Lymphoproliferative syndrome 1, 613011 (3)
# 3     OMIM:617062  Okur-Chung neurodevelopmental syndrome, 617062...
# 4     OMIM:602849                        Muenke syndrome, 602849 (3)
# ..            ...                                                ...
# 390    ORPHA:1930        Orphanet: Herpes simplex virus encephalitis
# 391   ORPHA:50943              Orphanet: Keratolytic winter erythema
# 392  ORPHA:464293  Orphanet: NON RARE IN EUROPE: Infantile capill...
# 393   ORPHA:33069                          Orphanet: Dravet syndrome
# 394     ORPHA:794                 Orphanet: Saethre-Chotzen syndrome
#
#                                                    Syn  \
# 0                                          TRHR, CHNG7
# 1                                           INSR, HHF5
# 2                                      ITK, EMT, LPFS1
# 3                                CSNK2A1, CK2A1, OCNDS
# 4                                           FGFR3, ACH
# ..                                                 ...
# 390  HSE, HSV encephalitis, HSVE, Herpes simplex me...
# 391    Erythrokeratolysis hiemalis, Oudtshoorn disease
# 392                                               None
# 393  SMEI, Severe myoclonic epilepsy of infancy, Se...
# 394            ACS3, Acrocephalosyndactyly type 3, SCS
#
#                                        disease_des/def  \
# 0    Nongoitrous congenital hypothyroidism-7 (CHNG7...
# 1                                                 None
# 2    Lymphoproliferative syndrome-1 is an autosomal...
# 3    Okur-Chung neurodevelopmental syndrome (OCNDS)...
# 4    Muenke syndrome is an autosomal dominant disor...
# ..                                                 ...
# 390  A rare disorder caused by infection of the cen...
# 391  Keratolytic winter erythema is a rare epiderma...
# 392                                               None
# 393  A rare, genetic, developmental and epileptic e...
# 394  A syndrome characterized by unilateral or bila...
#
#                          Clinicalfeatures/Clinical_des
# 0    {2:Collu et al. (1997)} studied a 12.5-year-ol...
# 1    Among the children of second cousins once remo...
# 2    {1:Huck et al. (2009)} reported 2 sisters, bor...
# 3    {3:Okur et al. (2016)} reported 5 unrelated gi...
# 4    On the basis of 61 individuals from 20 unrelat...
# ..                                                 ...
# 390  HSVE usually peaks in childhood (between 3 mon...
# 391                                               None
# 392                                               None
# 393  Onset of the first seizure is mainly in the fi...
# 394  SCS has a variable spectrum of manifestations....
#
# [395 rows x 5 columns]

# %% [markdown]
# gene to diease name

# %%
shared_gene_phenotype_table

n=0
for cc in ['shared_gene_0','shared_gene_1','shared_gene_2']:

  if cc== 'shared_gene_0': col='dis_0'
  if cc== 'shared_gene_1': col='dis_1'
  if cc== 'shared_gene_2': col='dis_2'
  for i in shared_gene_phenotype_table.index:
    XX=  shared_gene_phenotype_table[col][i]
    if XX !=[]:
      print(shared_gene_phenotype_table[cc][i],':')
      print('...........................................................')
      for k in XX:
          print(k,'.....:........,' ,concatenated_df  [concatenated_df['Disease']==k]['disease_name'].values[0])
# Out:
# MGAT2 :
# ...........................................................
# OMIM:212066 .....:........, Congenital disorder of glycosylation, type IIa, 212066 (3)
# ORPHA:79329 .....:........, Orphanet: MGAT2-CDG
# DGAT2 :
# ...........................................................
# ORPHA:487814 .....:........, Orphanet: Autosomal dominant Charcot-Marie-Tooth disease type 2 due to DGAT2 mutation
# DGAT1 :
# ...........................................................
# OMIM:615863 .....:........, Diarrhea 7, protein-losing enteropathy type, 615863 (3)
# ORPHA:329242 .....:........, Orphanet: Congenital chronic diarrhea with protein-losing enteropathy
# SYK :
# ...........................................................
# OMIM:619381 .....:........, Immunodeficiency 82 with systemic inflammation, 619381 (3)
# FAAH :
# ...........................................................
# OMIM:606581 .....:........, {Drug addiction, susceptibility to}, 606581 (3)
# CTSB :
# ...........................................................
# OMIM:148370 .....:........, Keratolytic winter erythema, 148370 (4)
# ORPHA:50943 .....:........, Orphanet: Keratolytic winter erythema
# CAPN1 :
# ...........................................................
# OMIM:616907 .....:........, Spastic paraplegia 76, autosomal recessive, 616907 (3)
# ORPHA:488594 .....:........, Orphanet: Autosomal recessive spastic paraplegia type 76
# IGF1R :
# ...........................................................
# OMIM:270450 .....:........, Insulin-like growth factor I, resistance to, 270450 (3)
# ORPHA:73273 .....:........, Orphanet: Growth delay due to insulin-like growth factor I resistance
# PIK3CD :
# ...........................................................
# OMIM:615513 .....:........, Immunodeficiency 14A, autosomal dominant, 615513 (3)
# OMIM:613328 .....:........, ?Roifman-Chitayat syndrome, digenic, 613328 (3)
# OMIM:619281 .....:........, Immunodeficiency 14B, autosomal recessive, 619281 (3)
# ORPHA:397596 .....:........, Orphanet: Activated PI3K-delta syndrome
# ORPHA:221139 .....:........, Orphanet: Combined immunodeficiency with facio-oculo-skeletal anomalies
# PIK3CG :
# ...........................................................
# OMIM:619802 .....:........, Immunodeficiency 97 with autoinflammation, 619802 (3)
# MMP3 :
# ...........................................................
# OMIM:614466 .....:........, {Coronary heart disease, susceptibility to, 6}, 614466 (3)
# MMP9 :
# ...........................................................
# OMIM:613073 .....:........, Metaphyseal anadysplasia 2, 613073 (3)
# ORPHA:1040 .....:........, Orphanet: Metaphyseal anadysplasia
# GNRHR :
# ...........................................................
# OMIM:146110 .....:........, Hypogonadotropic hypogonadism 7 without anosmia, 146110 (3)
# ORPHA:432 .....:........, Orphanet: Normosmic congenital hypogonadotropic hypogonadism
# CFTR :
# ...........................................................
# OMIM:167800 .....:........, Pancreatitis, hereditary, 167800 (3)
# OMIM:219700 .....:........, Cystic fibrosis, 219700 (3)
# OMIM:277180 .....:........, Congenital bilateral absence of vas deferens, 277180 (3)
# OMIM:211400 .....:........, Bronchiectasis with or without elevated sweat chloride 1, 211400 (3)
# ORPHA:48 .....:........, Orphanet: Congenital bilateral absence of vas deferens
# ORPHA:399805 .....:........, Orphanet: Male infertility with azoospermia or oligozoospermia due to single gene mutation
# ORPHA:60033 .....:........, Orphanet: Idiopathic bronchiectasis
# ORPHA:676 .....:........, Orphanet: Hereditary chronic pancreatitis
# ORPHA:498359 .....:........, Orphanet: Aquagenic palmoplantar keratoderma
# ORPHA:586 .....:........, Orphanet: Cystic fibrosis
# LCK :
# ...........................................................
# OMIM:615758 .....:........, Immunodeficiency 22, 615758 (3)
# ORPHA:280142 .....:........, Orphanet: Severe combined immunodeficiency due to LCK deficiency
# TEK :
# ...........................................................
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-173-349f7c47637f> in <cell line: 4>()
#      13       print('...........................................................')
#      14       for k in XX:
# ---> 15           print(k,'.....:........,' ,concatenated_df  [concatenated_df['Disease']==k]['disease_name'].values[0])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# #Pathways synonyms
# https://www.ebi.ac.uk/QuickGO/GTerm?id=GO:0019430
#
# https://amigo.geneontology.org/amigo/term/GO:0019430
#
# https://ncithesaurus.nci.nih.gov/ncitbrowser/ConceptReport.jsp?dictionary=NCI_Thesaurus&code=C21566&ns=ncit

# %%
#!pip install requests beautifulsoup4
import requests
from bs4 import BeautifulSoup

def find_syns_path(url):
  #url = "https://amigo.geneontology.org/amigo/term/GO:0019430"
  # Send a GET request to the website
  try:
      response = requests.get(url)
      # Check if the request was successful
      if response.status_code == 200:
          # Parse the webpage content
          soup = BeautifulSoup(response.content, 'html.parser')
          # Find the section containing synonyms
          synonyms_label = soup.find(string="Synonyms")
          if synonyms_label:
              synonyms_section = synonyms_label.find_next("dd")
              if synonyms_section:
                  synonyms_text = synonyms_section.get_text(strip=True)
                  synonyms_list = synonyms_text.split(',')
                  return synonyms_list
      return []
  except:
    return []

# %%
enrichment_all_NCGC00685598['synon']=enrichment_all_NCGC00685598.apply(lambda x: [x['Pathway'][11:].strip().lower()] ,axis=1)
#enrichment_all_NCGC00685598['synon']=enrichment_all_NCGC00685598.apply(lambda x:   find_syns_path(x['URL'])    +x['synon'],axis=1)
enrichment_all_NCGC00685598['synon']=  enrichment_all_NCGC00685598.apply(lambda x:  [i.lower().strip()  for i in x['synon'] if i != 'None'],axis=1)

enrichment_all_NCGC00602080['synon']=enrichment_all_NCGC00602080.apply(lambda x: [x['Pathway'][11:].strip().lower()] ,axis=1)
#enrichment_all_NCGC00602080['synon']=enrichment_all_NCGC00602080.apply(lambda x:   find_syns_path(x['URL'])    +x['synon'],axis=1)
enrichment_all_NCGC00602080['synon']=  enrichment_all_NCGC00602080.apply(lambda x:  [i.lower().strip()  for i in x['synon'] if i != 'None'],axis=1)

enrichment_all_NCGC00686269['synon']=enrichment_all_NCGC00686269.apply(lambda x: [x['Pathway'][11:].strip().lower()] ,axis=1)
#enrichment_all_NCGC00686269['synon']=enrichment_all_NCGC00686269.apply(lambda x:   find_syns_path(x['URL'])    +x['synon'],axis=1)
enrichment_all_NCGC00686269['synon']=  enrichment_all_NCGC00686269.apply(lambda x:  [i.lower().strip()  for i in x['synon'] if i != 'None'],axis=1)

enrichment_all_NCGC00685517['synon']=enrichment_all_NCGC00685517.apply(lambda x: [x['Pathway'][11:].strip().lower()] ,axis=1)
#enrichment_all_NCGC00685517['synon']=enrichment_all_NCGC00685517.apply(lambda x:   find_syns_path(x['URL'])    +x['synon'],axis=1)
enrichment_all_NCGC00685517['synon']=  enrichment_all_NCGC00685517.apply(lambda x:  [i.lower().strip()  for i in x['synon'] if i != 'None'],axis=1)

# %%
# Finding pathways synonyms
import pandas as pd
pathwys=pd.read_csv('/content/enrichment_all_CHEMBL1367890.csv')
pathwys['synon']=pathwys.apply(lambda x: [x['Pathway'][11:].strip().lower()] ,axis=1)
pathwys['synon']=pathwys.apply(lambda x:   find_syns_path(x['URL'])    +x['synon'],axis=1)
pathwys['synon']=  pathwys.apply(lambda x:  [i.lower().strip()  for i in x['synon'] if i != 'None'],axis=1)

# %%
find_gene_from_pathways=dict()
for i in pathwys.index:
       for j in pathwys['synon'][i]:
            if j not in find_gene_from_pathways:
               find_gene_from_pathways[j]=[pathwys['Genes'][i].strip()]
            else:
              if pathwys['Genes'][i].strip() not in find_gene_from_pathways[j]:
                  find_gene_from_pathways[j].append(pathwys['Genes'][i].strip())
#for i in find_gene_from_pathways.

for i in find_gene_from_pathways:
    find_gene_from_pathways[i] =[ i.replace("'",'')  for i in ''.join(find_gene_from_pathways[i]).split()]

# %% [markdown]
# # Semantic similairty

# %%
# !pip install transformers sentence-transformers datasets
from datasets import load_dataset
from sentence_transformers import SentenceTransformer, models
from transformers import BertTokenizer
from transformers import get_linear_schedule_with_warmup
import torch
from torch.optim import AdamW
from torch.utils.data import DataLoader
from tqdm import tqdm
import time
import datetime
import random
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModel
from transformers import BertTokenizer, RobertaTokenizer, RobertaModel
tokenizer = AutoTokenizer.from_pretrained('microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext')
class BertForSTS(torch.nn.Module):
    def __init__(self):
        super(BertForSTS, self).__init__()
        #self.bert = models.Transformer("bert-base-uncased", max_seq_length=512)
        self.bert = models.Transformer('microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext', max_seq_length=1000)
        #model = AutoModel.from_pretrained(model_name)
        self.pooling_layer = models.Pooling(self.bert.get_word_embedding_dimension())
        self.sts_bert = SentenceTransformer(modules=[self.bert, self.pooling_layer])
    def forward(self, input_data):
        output = self.sts_bert(input_data)['sentence_embedding']
        return output
# Instantiate the model and move it to GPU
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f'There are {torch.cuda.device_count()} GPU(s) available.')
    print('We will use the GPU:', torch.cuda.get_device_name(0))
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")

model = BertForSTS()
model.to(device)
model.eval()
def predict_similarity(sentence_pair):
  test_input = tokenizer(sentence_pair, padding=True, truncation=True, return_tensors="pt").to(device) # max_length = 512,
  test_input['input_ids'] = test_input['input_ids']
  test_input['attention_mask'] = test_input['attention_mask']
  del test_input['token_type_ids']
  output = model(test_input)
  sim = torch.nn.functional.cosine_similarity(output[0], output[1], dim=0).item()
  return sim

from google.colab import drive
drive.mount('/content/drive')
PATH = '/content/drive/My Drive/Finetunned_Bert_2.pt'
model = BertForSTS()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.load_state_dict(torch.load(PATH, map_location=device))
model.eval()

print("##########################################################################################")
example_1=[ 'A cat is walking around a house.', 'A woman is peeling potato']
print(f"Sentence 1: {example_1[0]}")
print(f"Sentence 2: {example_1[1]}")
print(f"Predicted similarity score: {round(predict_similarity(example_1), 2)}")

print("##########################################################################################")
example_1=[  'arterial thoracic outlet syndrome',
 '''
 The objective of this project is to study the contribution of hemorrheology to arterial and venous thrombosis using the arterio-venous (A-V)
   ''']
print(f"Sentence 1: {example_1[0]}")
print(f"Sentence 2: {example_1[1]}")
print(f"Predicted similarity score: {round(predict_similarity(example_1), 2)}")


print("##########################################################################################")
example_1=['antisynthetase syndrome',
 '''
  A rare idiopathic inflammatory myopathy (IIM) historically characterized by symmetric proximal muscle weakness, elevated muscle enzymes (creatine kinase), myopathic findings on electromyography, and muscle biopsy showing endomyial infiltration composed mainly of macrophages and lymphocytes. The features are non-specific, thus the disease should be distinguished from similar entities with specific clinical, immunological, histological features, notably dermatomyositis, immune-mediated necrotizing myopathy, anti-synthetase syndrome, inclusion body myositis, and myositis associated with other connective tissue disorder.
''']
print(f"Sentence 1: {example_1[0]}")
print(f"Sentence 2: {example_1[1]}")
print(f"Predicted similarity score: {round(predict_similarity(example_1), 2)}")

print("##########################################################################################")
##(one of its synonym is childhood cancer)
example_1=['mismatch repair cancer syndrome 1 '
,
'''
childhood cancer''']

print(f"Sentence 1: {example_1[0]}")
print(f"Sentence 2: {example_1[1]}")
print(f"Predicted similarity score: {round(predict_similarity(example_1), 2)}")

print("##########################################################################################")
example_1=[  'polymyositis',
 '''
 A rare idiopathic inflammatory myopathy (IIM) historically characterized by symmetric proximal muscle weakness, elevated muscle enzymes (creatine kinase), myopathic findings on electromyography, and muscle biopsy showing endomyial infiltration composed mainly of macrophages and lymphocytes. The features are non-specific, thus the disease should be distinguished from similar entities with specific clinical, immunological, histological features, notably dermatomyositis, immune-mediated necrotizing myopathy, anti-synthetase syndrome, inclusion body myositis, and myositis associated with other connective tissue disorder.
   '''
]
print(f"Sentence 1: {example_1[0]}")
print(f"Sentence 2: {example_1[1]}")
print(f"Predicted similarity score: {round(predict_similarity(example_1), 2)}")

def is_about_term(input_text, target_term):
  sentence_pair=[input_text, target_term]
  test_input = tokenizer(sentence_pair, padding=True, truncation=True, return_tensors="pt").to(device) # max_length = 512,
  test_input['input_ids'] = test_input['input_ids']
  test_input['attention_mask'] = test_input['attention_mask']
  del test_input['token_type_ids']
  output = model(test_input)
  sim = torch.nn.functional.cosine_similarity(output[0], output[1], dim=0).item()
  return  round(sim,2)
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.0)
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 1.5 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.3.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 38.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: xxhash, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, sentence-transformers
# Successfully installed datasets-2.19.1 dill-0.3.8 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 sentence-transformers-2.7.0 xxhash-3.4.1
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]
# No GPU available, using the CPU instead.
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Mounted at /content/drive
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ##########################################################################################
# Sentence 1: A cat is walking around a house.
# Sentence 2: A woman is peeling potato
# Predicted similarity score: -0.09
# ##########################################################################################
# Sentence 1: arterial thoracic outlet syndrome
# Sentence 2:
#  The objective of this project is to study the contribution of hemorrheology to arterial and venous thrombosis using the arterio-venous (A-V)
#
# Predicted similarity score: 0.35
# ##########################################################################################
# Sentence 1: antisynthetase syndrome
# Sentence 2:
#   A rare idiopathic inflammatory myopathy (IIM) historically characterized by symmetric proximal muscle weakness, elevated muscle enzymes (creatine kinase), myopathic findings on electromyography, and muscle biopsy showing endomyial infiltration composed mainly of macrophages and lymphocytes. The features are non-specific, thus the disease should be distinguished from similar entities with specific clinical, immunological, histological features, notably dermatomyositis, immune-mediated necrotizing myopathy, anti-synthetase syndrome, inclusion body myositis, and myositis associated with other connective tissue disorder.
#
# Predicted similarity score: 0.45
# ##########################################################################################
# Sentence 1: mismatch repair cancer syndrome 1
# Sentence 2:
# childhood cancer
# Predicted similarity score: 0.84
# ##########################################################################################
# Sentence 1: polymyositis
# Sentence 2:
#  A rare idiopathic inflammatory myopathy (IIM) historically characterized by symmetric proximal muscle weakness, elevated muscle enzymes (creatine kinase), myopathic findings on electromyography, and muscle biopsy showing endomyial infiltration composed mainly of macrophages and lymphocytes. The features are non-specific, thus the disease should be distinguished from similar entities with specific clinical, immunological, histological features, notably dermatomyositis, immune-mediated necrotizing myopathy, anti-synthetase syndrome, inclusion body myositis, and myositis associated with other connective tissue disorder.
#
# Predicted similarity score: 0.84

# %%
Dis_desc_DYT1='''
'Dystonia' describes a neurologic condition characterized by involuntary, sustained muscle contractions affecting one or more sites of the body; 'torsion' refers to the twisting nature of body movements observed in dystonia. Dystonia has been classified as primary (dystonia as the sole or major symptom) or secondary (a symptom of another disorder), and by age of onset, muscle groups affected, and mode of inheritance (Muller and Kupke, 1990; Nemeth, 2002).
'''
Dis_Clincial_DYT1='''
Primary torsion dystonia (also known as 'idiopathic' torsion dystonia; ITD) usually begins in childhood or adolescence with involuntary posturing of the trunk, neck, or limbs (Marsden et al., 1976; Nemeth, 2002). Some patients have a myostatic picture, such as was described by Wechsler and Brock (1922). Johnson et al. (1962) described an extensively affected French-Canadian family. Age of onset of affected family members ranged from 6 to 42 years and severity of the disease varied considerably, with early-onset cases being severely affected. Minor manifestations interpreted as 'formes frustes' were found in some family members. In a large North American family of non-Jewish ancestry, Brin et al. (1989) found that age of onset ranged from 4 to 43 years (mean 14.4, median 10.0). Generalization occurred within a median time of 3 years and occurred earlier in cases with onset in the leg. One 6.5-year-old was unable to walk within 3 months of onset. Batshaw et al. (1985) described a patient with severe simulated torsion dystonia as the main feature of Munchausen syndrome.

Bressman et al. (1994) analyzed the haplotype of 174 Ashkenazi Jewish individuals affected with torsion dystonia. In this group, there were 90 carriers of the haplotype and 70 noncarriers. The authors found very striking differences in the phenotype between carriers and noncarriers. The age of onset in carriers was 12.5 years versus 36.5 years in the noncarriers. In 94% of carriers, symptoms began in a limb but only rarely in the neck and larynx. In contrast, the neck, larynx, or other cranial muscles were the site of onset in 79% of noncarriers. Discriminant analysis of limb onset, leg involvement, and age at onset distinguished haplotype carriers from noncarriers with 90% accuracy. In 23 of the 70 noncarriers, the disease was familial and included brachial, cervical, laryngeal, and facial dystonia.

Cheng et al. (1996) studied 49 probands with cervical or cranial dystonia with age of onset greater than 12 years and with a positive family history. They found that age of onset of clinical symptoms was earlier by an average of 21.25 years in the second generation than in the first, and suggested that an unstable trinucleotide repeat may be involved in adult-onset primary cranial or cervical dystonia.

Grundmann et al. (2003) stated that most cases of early-onset generalized dystonia are caused by a 3-bp deletion in the DYT1 gene (delE302/303; 605204.0001). They reported 6 patients with dystonia caused by the 3-bp deletion who exhibited wide phenotypic variability: 2 had classic early-onset primary generalized dystonia, 2 had multifocal dystonia (1 with cranial and cervical muscle involvement), and 2 had only writer's cramp with mild progression.

Kostic et al. (2006) reported a large Serbian family in which 7 members carried the delE302/303 DYT1 mutation (605204.0001). However, only 2 were affected by dystonia, indicating a penetrance of 29%. One of the affected individuals had late-onset mild torticollis, and the other had generalized jerky dystonia. In addition, 3 family members with dystonia did not carry the DYT1 mutation, indicating genetic heterogeneity or possibly a psychogenic origin. Kostic et al. (2006) commented on the phenotypic variability in this family.

Zirn et al. (2008) reported an 18-year-old girl with a severe form of early-onset dystonia. She had mildly delayed early motor development with stalling of further development during the second year of life. She never learned to walk independently and became wheelchair-bound at age 5 years. At age 13, she could no longer eat or drink without assistance. At age 18, she had dysphagia, severe dysarthria, facial palsy with reduced tongue mobility, dystonic movements, multiple joint contractures, increased muscle tone, hyperreflexia, and extensor plantar responses. Cognition was normal.
'''

# %%
def cal_sem_def(x):
  if x!=None:
     try:
      return is_about_term(x, Dis_desc_DYT1)
     except:
      return is_about_term(x[:1000], Dis_desc_DYT1)
  else:
    return None
def cal_sem_clinical(x):
   if x!= None:
      try:
         return  is_about_term(x, Dis_Clincial_DYT1)
      except:
         return  is_about_term(x[:1000], Dis_Clincial_DYT1)
   else:
     return None

concatenated_df['sem_def']=concatenated_df.apply(lambda x:  cal_sem_def(x[ 'disease_des/def'])  ,axis=1)
concatenated_df['sem_clinical']=concatenated_df.apply( lambda x:  cal_sem_def(x['Clinicalfeatures/Clinical_des'])  ,axis=1)

# %%
concatenated_df
# Out:
#          Disease                                       disease_name  \
# 0    OMIM:125350     Failure of tooth eruption, primary, 125350 (3)
# 1    OMIM:156400  Metaphyseal chondrodysplasia, Murk Jansen type...
# 2    OMIM:607250  ?Spinocerebellar ataxia, autosomal recessive, ...
# 3    OMIM:612069  Amyotrophic lateral sclerosis 10, with or with...
# 4    OMIM:215045      Chondrodysplasia, Blomstrand type, 215045 (3)
# 5    OMIM:616835                Meier-Gorlin syndrome 6, 616835 (3)
# 6    OMIM:613795                 Loeys-Dietz syndrome 3, 613795 (3)
# 7    OMIM:600002                         Eiken syndrome, 600002 (3)
# 8    OMIM:617744  Immunodeficiency, developmental delay, and hyp...
# 9   ORPHA:275872  Orphanet: Frontotemporal dementia with motor n...
# 10     ORPHA:296                           Orphanet: Ollier disease
# 11  ORPHA:619979  Orphanet: Developmental delay-immunodeficiency...
# 12    ORPHA:2554       Orphanet: Ear-patella-short stature syndrome
# 13   ORPHA:79106                           Orphanet: Eiken syndrome
# 14   ORPHA:91387  Orphanet: Familial thoracic aortic aneurysm an...
# 15   ORPHA:94124  Orphanet: Spinocerebellar ataxia with axonal n...
# 16   ORPHA:50945       Orphanet: Blomstrand lethal chondrodysplasia
# 17  ORPHA:284984         Orphanet: Aneurysm-osteoarthritis syndrome
# 18     ORPHA:803            Orphanet: Amyotrophic lateral sclerosis
# 19   ORPHA:60030                     Orphanet: Loeys-Dietz syndrome
# 20  ORPHA:412206        Orphanet: Primary failure of tooth eruption
# 21   ORPHA:33067  Orphanet: Metaphyseal chondrodysplasia, Jansen...
#
#                                                   Syn  \
# 0                       PTH1R, PTHR1, PTHR, PFE, EKNS
# 1                       PTH1R, PTHR1, PTHR, PFE, EKNS
# 2                                         TDP1, SCAN1
# 3                                TARDBP, TDP43, ALS10
# 4                       PTH1R, PTHR1, PTHR, PFE, EKNS
# 5                                        GMNN, MGORS6
# 6                                  SMAD3, MADH3, LDS3
# 7                       PTH1R, PTHR1, PTHR, PFE, EKNS
# 8                                NFE2L2, NRF2, IMDDHH
# 9   FTD-ALS, FTD-MND, Frontotemporal dementia with...
# 10  Enchondromatosis Spranger type I, Multiple Enc...
# 11                                               None
# 12                              Meier-Gorlin syndrome
# 13                                               None
# 14  Familial TAAD, Familial non-syndromic thoracic...
# 15                                              SCAN1
# 16  BLC, BOCD, Blomstrand chondrodysplasia, Blomst...
# 17                                               None
# 18           ALS, Charcot disease, Lou Gehrig disease
# 19  Aortic aneurysm syndrome due to TGF-beta recep...
# 20                    PFE, Primary retention of teeth
# 21                                               None
#
#                                       disease_des/def  \
# 0   Primary failure of tooth eruption (PFE) is an ...
# 1   The Murk Jansen type of metaphyseal chondrodys...
# 2   Spinocerebellar ataxia with axonal neuropathy-...
# 3                                                None
# 4   Blomstrand chondrodysplasia is an autosomal re...
# 5                                                None
# 6   Loeys-Dietz syndrome-3 (LDS3) is an autosomal ...
# 7   Eiken syndrome (EKNS) is an autosomal recessiv...
# 8   IMDDHH is a multisystem disorder characterized...
# 9   Frontotemporal dementia with motor neuron dise...
# 10  A rare primary bone dysplasia characterized by...
# 11  A rare syndrome with combined immunodeficiency...
# 12  A rare microcephalic primordial dwarfism chara...
# 13  A rare, genetic, primary bone dysplasia syndro...
# 14  Familial thoracic aortic aneurysm and aortic d...
# 15  Spinocerebellar ataxia with axonal neuropathy ...
# 16  Blomstrand lethal chondrodysplasia (BLC) is a ...
# 17  A rare, genetic, systemic disease characterize...
# 18  A neurodegenerative disease characterized by p...
# 19  Loeys-Dietz syndrome is a rare genetic connect...
# 20  A rare genetic odontologic disease characteriz...
# 21  A rare autosomal dominant skeletal dysplasia c...
#
#                         Clinicalfeatures/Clinical_des  sem_def  sem_clinical
# 0   {10:Shokeir (1974)} described autosomal domina...     0.65          0.50
# 1   {17:Stoeckenius (1966)} described affected mot...     0.66          0.67
# 2   {2:Takashima et al. (2002)} investigated a lar...     0.95          0.95
# 3   {14:Tagawa et al. (2007)} described a Japanese...      NaN          0.92
# 4   {1:Blomstrand et al. (1985)} presented the cli...     0.71          0.64
# 5   {2:Burrage et al. (2015)} described 3 unrelate...      NaN          0.64
# 6   {3:Van de Laar et al. (2011)} studied 3 unrela...     0.62          0.43
# 7   In a consanguineous Turkish family living in D...     0.70          0.70
# 8   {1:Huppke et al. (2017)} reported 4 unrelated ...     0.62          0.68
# 9                                                None     0.92           NaN
# 10  Clinical expression of the disease is variable...     0.44          0.50
# 11                                               None     0.26           NaN
# 12                                               None     0.59           NaN
# 13                                               None     0.46           NaN
# 14                                               None     0.13           NaN
# 15                                               None     0.94           NaN
# 16  BLC is a congenital disorder characterized by ...     0.55          0.76
# 17                                               None     0.11           NaN
# 18  Approximately two thirds of patients with typi...     0.94          0.87
# 19                                               None     0.78           NaN
# 20                                               None     0.07           NaN
# 21                                               None     0.46           NaN

# %% [markdown]
# # literature mining (Paper to DYT1)

# %%
concatenated_df['disease_name']
concatenated_df['Syn'] =  concatenated_df.apply(lambda x: x['Syn'].split(',')	if type(x['Syn'])==str else []  , axis=1)
concatenated_df['disease_name'] =  concatenated_df.apply(lambda x: x['disease_name'].replace('?','').replace('{','').replace('}','').replace('[','').replace(']','') , axis=1)
concatenated_df['disease_name'] =  concatenated_df.apply(lambda x: ','.join(x['disease_name'].split(',')[:-1]) if len(x['disease_name'].split(','))>1 else	x['disease_name'] , axis=1)
concatenated_df['disease_name+syn']= concatenated_df.apply(lambda x: [x['disease_name']]+ x['Syn'] , axis=1)

concatenated_df
# Out:
#           Disease                                       disease_name  \
# 0     OMIM:618573         Hypothyroidism, congenital, nongoitrous, 7
# 1     OMIM:246200                                   Donohue syndrome
# 2     OMIM:613011                     Lymphoproliferative syndrome 1
# 3     OMIM:617062             Okur-Chung neurodevelopmental syndrome
# 4     OMIM:602849                                    Muenke syndrome
# ..            ...                                                ...
# 390    ORPHA:1930        Orphanet: Herpes simplex virus encephalitis
# 391   ORPHA:50943              Orphanet: Keratolytic winter erythema
# 392  ORPHA:464293  Orphanet: NON RARE IN EUROPE: Infantile capill...
# 393   ORPHA:33069                          Orphanet: Dravet syndrome
# 394     ORPHA:794                 Orphanet: Saethre-Chotzen syndrome
#
#                                                    Syn  \
# 0                                       [TRHR,  CHNG7]
# 1                                        [INSR,  HHF5]
# 2                                  [ITK,  EMT,  LPFS1]
# 3                            [CSNK2A1,  CK2A1,  OCNDS]
# 4                                        [FGFR3,  ACH]
# ..                                                 ...
# 390  [HSE,  HSV encephalitis,  HSVE,  Herpes simple...
# 391  [Erythrokeratolysis hiemalis,  Oudtshoorn dise...
# 392                                                 []
# 393  [SMEI,  Severe myoclonic epilepsy of infancy, ...
# 394        [ACS3,  Acrocephalosyndactyly type 3,  SCS]
#
#                                        disease_des/def  \
# 0    Nongoitrous congenital hypothyroidism-7 (CHNG7...
# 1                                                 None
# 2    Lymphoproliferative syndrome-1 is an autosomal...
# 3    Okur-Chung neurodevelopmental syndrome (OCNDS)...
# 4    Muenke syndrome is an autosomal dominant disor...
# ..                                                 ...
# 390  A rare disorder caused by infection of the cen...
# 391  Keratolytic winter erythema is a rare epiderma...
# 392                                               None
# 393  A rare, genetic, developmental and epileptic e...
# 394  A syndrome characterized by unilateral or bila...
#
#                          Clinicalfeatures/Clinical_des  \
# 0    {2:Collu et al. (1997)} studied a 12.5-year-ol...
# 1    Among the children of second cousins once remo...
# 2    {1:Huck et al. (2009)} reported 2 sisters, bor...
# 3    {3:Okur et al. (2016)} reported 5 unrelated gi...
# 4    On the basis of 61 individuals from 20 unrelat...
# ..                                                 ...
# 390  HSVE usually peaks in childhood (between 3 mon...
# 391                                               None
# 392                                               None
# 393  Onset of the first seizure is mainly in the fi...
# 394  SCS has a variable spectrum of manifestations....
#
#                                       disease_name+syn
# 0    [Hypothyroidism, congenital, nongoitrous, 7, T...
# 1                      [Donohue syndrome, INSR,  HHF5]
# 2    [Lymphoproliferative syndrome 1, ITK,  EMT,  L...
# 3    [Okur-Chung neurodevelopmental syndrome, CSNK2...
# 4                       [Muenke syndrome, FGFR3,  ACH]
# ..                                                 ...
# 390  [Orphanet: Herpes simplex virus encephalitis, ...
# 391  [Orphanet: Keratolytic winter erythema, Erythr...
# 392  [Orphanet: NON RARE IN EUROPE: Infantile capil...
# 393  [Orphanet: Dravet syndrome, SMEI,  Severe myoc...
# 394  [Orphanet: Saethre-Chotzen syndrome, ACS3,  Ac...
#
# [395 rows x 6 columns]

# %%
Find_dis_dict={}
for i in concatenated_df.index:
    for j in concatenated_df['disease_name+syn'][i]:
      Find_dis_dict[ j[9:].strip().lower()  if j[:9]=='Orphanet:' else j.strip().lower()   ]  =   concatenated_df['Disease'][i]

Find_dis_dict
# Out:
# {'hypothyroidism, congenital, nongoitrous, 7': 'OMIM:618573',
#  'trhr': 'OMIM:618573',
#  'chng7': 'OMIM:618573',
#  'donohue syndrome': 'ORPHA:508',
#  'insr': 'OMIM:262190',
#  'hhf5': 'OMIM:262190',
#  'lymphoproliferative syndrome 1': 'OMIM:613011',
#  'itk': 'OMIM:613011',
#  'emt': 'OMIM:613011',
#  'lpfs1': 'OMIM:613011',
#  'okur-chung neurodevelopmental syndrome': 'OMIM:617062',
#  'csnk2a1': 'OMIM:617062',
#  'ck2a1': 'OMIM:617062',
#  'ocnds': 'OMIM:617062',
#  'muenke syndrome': 'ORPHA:53271',
#  'fgfr3': 'OMIM:100800',
#  'ach': 'OMIM:100800',
#  'immunodeficiency 15a': 'OMIM:618204',
#  'ikbkb': 'OMIM:615592',
#  'nfkbikb': 'OMIM:615592',
#  'imd15b': 'OMIM:615592',
#  'imd15a': 'OMIM:615592',
#  'crouzon syndrome': 'ORPHA:207',
#  'fgfr2': 'OMIM:609579',
#  'bek': 'OMIM:609579',
#  'cfd1': 'OMIM:609579',
#  'jws': 'ORPHA:1540',
#  'tk14': 'OMIM:609579',
#  'bbds': 'OMIM:609579',
#  'immunodeficiency 82 with systemic inflammation': 'OMIM:619381',
#  'syk': 'OMIM:619381',
#  'imd82': 'OMIM:619381',
#  'hyperinsulinemic hypoglycemia, familial, 3': 'OMIM:602485',
#  'gck': 'OMIM:606176',
#  'hhf3': 'OMIM:606176',
#  'pndm1': 'OMIM:606176',
#  'pallister-hall-like syndrome': 'OMIM:241800',
#  'smo': 'OMIM:601707',
#  'smoh': 'OMIM:601707',
#  'crjs': 'OMIM:601707',
#  'phls': 'OMIM:601707',
#  'noonan syndrome 1': 'OMIM:163950',
#  'ptpn11': 'OMIM:163950',
#  'ptp2c': 'OMIM:163950',
#  'shp2': 'OMIM:163950',
#  'ns1': 'OMIM:163950',
#  'jmml': 'OMIM:163950',
#  'metcds': 'OMIM:163950',
#  'leopard syndrome 2': 'OMIM:611554',
#  'raf1': 'OMIM:611553',
#  'craf': 'OMIM:611553',
#  'ns5': 'OMIM:611553',
#  'cmd1nn': 'OMIM:611553',
#  'epilepsy, childhood absence, susceptibility to, 4': 'OMIM:611136',
#  'gabra1': 'OMIM:615744',
#  'ejm5': 'OMIM:615744',
#  'eca4': 'OMIM:615744',
#  'dee19': 'OMIM:615744',
#  'congenital heart defects, multiple types, 7': 'OMIM:618780',
#  'flt4': 'OMIM:602089',
#  'vegfr3': 'OMIM:602089',
#  'pcl': 'OMIM:602089',
#  'lmphm1': 'OMIM:602089',
#  'chtd7': 'OMIM:602089',
#  'intellectual developmental disorder, x-linked 19': 'OMIM:300844',
#  'rps6ka3': 'OMIM:303600',
#  'rsk2': 'OMIM:303600',
#  'xlid19': 'OMIM:303600',
#  'mody, type ii': 'OMIM:125851',
#  'basal ganglia calcification, idiopathic, 1': 'OMIM:213600',
#  'slc20a2': 'OMIM:213600',
#  'mlvar': 'OMIM:213600',
#  'glvr2': 'OMIM:213600',
#  'ibgc1': 'OMIM:213600',
#  'ibgc2': 'OMIM:213600',
#  'focal cortical dysplasia, type ii, somatic': 'OMIM:607341',
#  'tsc2': 'OMIM:607341',
#  'lam': 'OMIM:607341',
#  'ovarian cancer, somatic': 'OMIM:167000',
#  'akt1': 'OMIM:167000',
#  'cws6': 'OMIM:167000',
#  'ghosal hematodiaphyseal syndrome': 'OMIM:231095',
#  'tbxas1': 'OMIM:231095',
#  'ghosal': 'OMIM:231095',
#  'cyp5': 'OMIM:231095',
#  'myelofibrosis with myeloid metaplasia, somatic': 'OMIM:254450',
#  'mpl': 'OMIM:254450',
#  'tpor': 'OMIM:254450',
#  'mplv': 'OMIM:254450',
#  'thcyt2': 'OMIM:254450',
#  'germ cell tumors, somatic': 'OMIM:273300',
#  'kit': 'OMIM:273300',
#  'pbt': 'OMIM:273300',
#  'mastc': 'OMIM:273300',
#  'ladd syndrome 1': 'OMIM:149730',
#  'immunodeficiency 22': 'OMIM:615758',
#  'lck': 'OMIM:615758',
#  'imd22': 'OMIM:615758',
#  'ladd syndrome 2': 'OMIM:620192',
#  'thrombophilia 8, x-linked, due to factor ix defect': 'OMIM:300807',
#  'f9': 'OMIM:301052',
#  'hemb': 'OMIM:301052',
#  'thph8': 'OMIM:301052',
#  'saddan': 'ORPHA:85165',
#  'immunodeficiency 14a, autosomal dominant': 'OMIM:615513',
#  'pik3cd': 'OMIM:619281',
#  'apds': 'ORPHA:397596',
#  'imd14a': 'OMIM:619281',
#  'imd14b': 'OMIM:619281',
#  'rochis': 'OMIM:613328',
#  'platelet-activating factor acetylhydrolase deficiency': 'OMIM:614278',
#  'pla2g7': 'OMIM:614278',
#  'pafah': 'OMIM:614278',
#  'pafad': 'OMIM:614278',
#  'diabetes mellitus, insulin-resistant, with acanthosis nigricans': 'OMIM:610549',
#  'coffin-lowry syndrome': 'ORPHA:192',
#  'erythermalgia, primary': 'OMIM:133020',
#  'scn9a': 'OMIM:167400',
#  'nena': 'OMIM:167400',
#  'pn1': 'OMIM:167400',
#  'sfnp': 'OMIM:167400',
#  'hsan2d': 'OMIM:167400',
#  'developmental and epileptic encephalopathy 19': 'OMIM:615744',
#  'pycnodysostosis': 'ORPHA:763',
#  'ctsk': 'OMIM:265800',
#  'factor x deficiency': 'OMIM:227600',
#  'f10': 'OMIM:227600',
#  'advanced sleep-phase syndrome, familial, 2': 'OMIM:615224',
#  'csnk1d': 'OMIM:615224',
#  'asps': 'OMIM:615224',
#  'fasps2': 'OMIM:615224',
#  'kosaki overgrowth syndrome': 'ORPHA:477831',
#  'pdgfrb': 'OMIM:615007',
#  'pdgfr': 'OMIM:615007',
#  'ibgc4': 'OMIM:615007',
#  'imf1': 'OMIM:615007',
#  'pentt': 'OMIM:615007',
#  'kogs': 'OMIM:615007',
#  'fanconi-bickel syndrome': 'ORPHA:2088',
#  'slc2a2': 'OMIM:227810',
#  'glut2': 'OMIM:227810',
#  'gastric cancer, somatic': 'OMIM:613659',
#  'apc': 'OMIM:613659',
#  'gs': 'OMIM:613659',
#  'fpc': 'OMIM:613659',
#  'btps2': 'OMIM:613659',
#  'desmd': 'OMIM:613659',
#  'colchicine resistance': 'OMIM:120080',
#  'abcb1': 'OMIM:612244',
#  'pgy1': 'OMIM:612244',
#  'mdr1': 'OMIM:612244',
#  'ibd13': 'OMIM:612244',
#  'clcs': 'OMIM:612244',
#  'inflammatory bowel disease 13': 'OMIM:612244',
#  'agammaglobulinemia, x-linked 1': 'OMIM:300755',
#  'btk': 'OMIM:307200',
#  'agmx1': 'OMIM:307200',
#  'imd1': 'OMIM:307200',
#  'xla': 'OMIM:307200',
#  'at': 'OMIM:307200',
#  'ighd3': 'OMIM:307200',
#  'butyrylcholinesterase deficiency': 'OMIM:617936',
#  'bche': 'OMIM:617936',
#  'che1': 'OMIM:617936',
#  'bched': 'OMIM:617936',
#  'prostate cancer/brain cancer susceptibility, somatic': 'OMIM:603688',
#  'ephb2': 'OMIM:618462',
#  'epht3': 'OMIM:618462',
#  'drt': 'OMIM:618462',
#  'erk': 'OMIM:618462',
#  'pcbc': 'OMIM:618462',
#  'capb': 'OMIM:618462',
#  'bdplt22': 'OMIM:618462',
#  'noonan syndrome 7': 'OMIM:613706',
#  'braf': 'OMIM:155600',
#  'ns7': 'OMIM:155600',
#  'thyroid hormone resistance, selective pituitary': 'OMIM:145650',
#  'thrb': 'OMIM:188570',
#  'erba2': 'OMIM:188570',
#  'thr1': 'OMIM:188570',
#  'prth': 'OMIM:188570',
#  'lymphatic malformation 1': 'OMIM:153100',
#  'craniofacial-skeletal-dermatologic dysplasia': 'OMIM:101600',
#  'hyperinsulinemic hypoglycemia, familial, 5': 'OMIM:609968',
#  'metaphyseal anadysplasia 2': 'OMIM:613073',
#  'mmp9': 'OMIM:613073',
#  'clg4b': 'OMIM:613073',
#  'mandp2': 'OMIM:613073',
#  'beare-stevenson cutis gyrata syndrome': 'ORPHA:1555',
#  'glaucoma 3, primary congenital, e': 'OMIM:617272',
#  'tek': 'OMIM:600195',
#  'tie2': 'OMIM:600195',
#  'vmcm': 'ORPHA:2451',
#  'glc3e': 'OMIM:600195',
#  'medullary thyroid carcinoma': 'OMIM:155240',
#  'ret': 'OMIM:142623',
#  'men2a': 'ORPHA:247698',
#  'hscr1': 'OMIM:142623',
#  'stomatin-deficient cryohydrocytosis with neurologic defects': 'OMIM:608885',
#  'slc2a1': 'OMIM:606777',
#  'glut1': 'OMIM:606777',
#  'htlvr': 'OMIM:606777',
#  'dyt18': 'ORPHA:98811',
#  'ped': 'ORPHA:98811',
#  'glut1ds': 'OMIM:606777',
#  'eig12': 'OMIM:606777',
#  'dyt9': 'ORPHA:53583',
#  'sdchcn': 'OMIM:606777',
#  'congenital heart defects and skeletal malformations syndrome': 'OMIM:617602',
#  'abl1': 'OMIM:608232',
#  'chdskm': 'OMIM:608232',
#  'pseudovaginal perineoscrotal hypospadias': 'ORPHA:753',
#  'srd5a2': 'OMIM:264600',
#  'leukemia, philadelphia chromosome-positive, resistant to imatinib': 'OMIM:608232',
#  'keratolytic winter erythema': 'ORPHA:50943',
#  'ctsb': 'OMIM:148370',
#  'cpsb': 'OMIM:148370',
#  'receup': 'OMIM:148370',
#  'cardiofaciocutaneous syndrome': 'ORPHA:1340',
#  'erythrocytosis, somatic': 'OMIM:133100',
#  'jak2': 'OMIM:600880',
#  'thcyt3': 'OMIM:600880',
#  'lymphatic malformation 8': 'OMIM:618773',
#  'calcrl': 'OMIM:618773',
#  'cgrpr': 'OMIM:618773',
#  'crlr': 'OMIM:618773',
#  'lmphm8': 'OMIM:618773',
#  'thrombocythemia 3': 'OMIM:614521',
#  'bent bone dysplasia syndrome': 'OMIM:614592',
#  'deafness, autosomal dominant 77': 'OMIM:618915',
#  'abcc1': 'OMIM:618915',
#  'mrp1': 'OMIM:618915',
#  'mrp': 'OMIM:618915',
#  'dfna77': 'OMIM:618915',
#  'visceral neuropathy, familial, 2, autosomal recessive': 'OMIM:619465',
#  'erbb2': 'OMIM:137800',
#  'ngl': 'OMIM:137800',
#  'neu': 'OMIM:137800',
#  'her2': 'OMIM:137800',
#  'vscn2': 'OMIM:137800',
#  'immunodeficiency 14b, autosomal recessive': 'OMIM:619281',
#  'epilepsy, idiopathic generalized, susceptibility to, 15': 'OMIM:618357',
#  'rorb': 'OMIM:618357',
#  'rzrb': 'OMIM:618357',
#  'eig15': 'OMIM:618357',
#  'inflammatory skin and bowel disease, neonatal, 2': 'OMIM:616069',
#  'egfr': 'OMIM:211980',
#  'nisbd2': 'OMIM:211980',
#  'basal cell carcinoma, somatic': 'OMIM:605462',
#  'ptch1': 'OMIM:605462',
#  'nbccs': 'OMIM:605462',
#  'bcns1': 'OMIM:605462',
#  'hpe7': 'OMIM:605462',
#  'congenital disorder of glycosylation, type iia': 'OMIM:212066',
#  'mgat2': 'OMIM:212066',
#  'cdgs2': 'OMIM:212066',
#  'cdg2a': 'ORPHA:79329',
#  'epilepsy, idiopathic generalized, susceptibility to, 12': 'OMIM:614847',
#  'neuropathy, hereditary sensory and autonomic, type ii': 'OMIM:201300',
#  'wnk1': 'OMIM:201300',
#  'prkwnk1': 'OMIM:201300',
#  'kdp': 'OMIM:201300',
#  'pha2c': 'OMIM:201300',
#  'hsan2': 'ORPHA:970',
#  'hsn2': 'OMIM:201300',
#  'noonan syndrome 13': 'OMIM:619087',
#  'mapk1': 'OMIM:619087',
#  'prkm1': 'OMIM:619087',
#  'erk2': 'OMIM:619087',
#  'ns13': 'OMIM:619087',
#  'hemangioma, capillary infantile, somatic': 'OMIM:602089',
#  'cardiomyopathy, dilated, 1nn': 'OMIM:615916',
#  'leopard syndrome 3': 'OMIM:613707',
#  'sarcoidosis, susceptibility to, 1': 'OMIM:181000',
#  'hla-drb1': 'OMIM:181000',
#  'ss1': 'OMIM:181000',
#  'venous malformations, multiple cutaneous and mucosal': 'OMIM:600195',
#  'immunodeficiency 15b': 'OMIM:615592',
#  'uric acid concentration, serum, qtl1': 'OMIM:138900',
#  'abcg2': 'OMIM:614490',
#  'bcrp': 'OMIM:614490',
#  'abcp': 'OMIM:614490',
#  'uaqtl1': 'OMIM:614490',
#  'gout1': 'OMIM:614490',
#  'menke-hennekam syndrome 1': 'OMIM:618332',
#  'crebbp': 'OMIM:180849',
#  'cbp': 'OMIM:180849',
#  'rsts1': 'OMIM:180849',
#  'mkhk1': 'OMIM:180849',
#  'autoinflammation, immune dysregulation, and eosinophilia': 'OMIM:618999',
#  'jak1': 'OMIM:618999',
#  'aiide': 'OMIM:618999',
#  'hypertryptophanemia': 'ORPHA:2224',
#  'tdo2': 'OMIM:600627',
#  'tph2': 'OMIM:600627',
#  'trpo': 'OMIM:600627',
#  'hyptrp': 'OMIM:600627',
#  'antley-bixler syndrome without genital anomalies or disordered steroidogenesis': 'OMIM:207410',
#  'smith-kingsmore syndrome': 'ORPHA:457485',
#  'mtor': 'OMIM:616638',
#  'frap1': 'OMIM:616638',
#  'sks': 'OMIM:616638',
#  'drug addiction, susceptibility to': 'OMIM:606581',
#  'faah': 'OMIM:606581',
#  'melanoma, malignant, somatic': 'OMIM:155600',
#  'neurodevelopmental disorder with seizures and nonepileptic hyperkinetic movements': 'OMIM:618497',
#  'cacna1b': 'OMIM:618497',
#  'cacnl1a5': 'OMIM:618497',
#  'nedneh': 'OMIM:618497',
#  'pancreatitis, hereditary': 'OMIM:167800',
#  'prss1': 'OMIM:167800',
#  'try1': 'OMIM:167800',
#  'immunodeficiency 42': 'OMIM:616622',
#  'rorc': 'OMIM:616622',
#  'rorg': 'OMIM:616622',
#  'rzrg': 'OMIM:616622',
#  'imd42': 'OMIM:616622',
#  'bronchiectasis with or without elevated sweat chloride 1': 'OMIM:211400',
#  'scnn1b': 'OMIM:211400',
#  'besc1': 'OMIM:211400',
#  'lidls1': 'OMIM:211400',
#  'pha1b2': 'OMIM:211400',
#  'bladder cancer, somatic': 'OMIM:109800',
#  'multiple sclerosis, disease progression, modifier of': 'OMIM:126200',
#  'pdcd1': 'OMIM:126200',
#  'sleb2': 'OMIM:126200',
#  'mandibulofacial dysostosis with alopecia': 'ORPHA:443995',
#  'ednra': 'OMIM:616367',
#  'mfda': 'ORPHA:443995',
#  'multiple endocrine neoplasia iib': 'OMIM:162300',
#  'cervical cancer, somatic': 'OMIM:603956',
#  'migraine without aura, susceptibility to': 'OMIM:157300',
#  'tnf': 'OMIM:157300',
#  'tnfa': 'OMIM:157300',
#  'hemophilia b': 'OMIM:306900',
#  'myeloproliferative disorder with eosinophilia': 'OMIM:131440',
#  'insensitivity to pain, congenital': 'OMIM:243000',
#  'factor xi deficiency, autosomal dominant': 'OMIM:612416',
#  'f11': 'OMIM:612416',
#  'catshl syndrome': 'ORPHA:85164',
#  'thyroid hormone resistance, autosomal recessive': 'OMIM:274300',
#  'pheochromocytoma': 'OMIM:171300',
#  'autoimmune disease, multisystem, infantile-onset, 1': 'OMIM:615952',
#  'stat3': 'OMIM:147060',
#  'aprf': 'OMIM:147060',
#  'hies': 'OMIM:147060',
#  'admio1': 'OMIM:147060',
#  'hypogonadotropic hypogonadism 7 without anosmia': 'OMIM:146110',
#  'gnrhr': 'OMIM:146110',
#  'lhrhr': 'OMIM:146110',
#  'hh7': 'OMIM:146110',
#  'cystic fibrosis': 'ORPHA:586',
#  'cftr': 'OMIM:277180',
#  'abcc7': 'OMIM:277180',
#  'cf': 'ORPHA:586',
#  'mrp7': 'OMIM:277180',
#  'scid, autosomal recessive, t-negative/b-positive type': 'OMIM:600802',
#  'jak3': 'OMIM:600802',
#  'jakl': 'OMIM:600802',
#  'epidermal nevus, somatic': 'OMIM:162900',
#  'nras': 'OMIM:162900',
#  'alps4': 'OMIM:162900',
#  'ns6': 'OMIM:162900',
#  'cmns': 'OMIM:162900',
#  'ncms': 'OMIM:162900',
#  'saethre-chotzen syndrome with or without eyelid anomalies': 'OMIM:101400',
#  'twist1': 'OMIM:101400',
#  'acs3': 'ORPHA:794',
#  'scs': 'ORPHA:794',
#  'crs1': 'OMIM:101400',
#  'swcos': 'OMIM:101400',
#  'copd, rate of decline of lung function in': 'OMIM:606963',
#  'mmp1': 'OMIM:606963',
#  'clg': 'OMIM:606963',
#  'polycythemia vera, somatic': 'OMIM:263300',
#  'adenocarcinoma of lung, response to tyrosine kinase inhibitor in': 'OMIM:211980',
#  'junior blood group system': 'OMIM:614490',
#  'epidermolysis bullosa dystrophica inversa': 'OMIM:226600',
#  'col7a1': 'OMIM:226600',
#  'ndnc8': 'OMIM:226600',
#  'curry-jones syndrome, somatic mosaic': 'OMIM:601707',
#  'apert syndrome': 'ORPHA:87',
#  'intellectual developmental disorder, autosomal recessive 54': 'OMIM:617028',
#  'tnik': 'OMIM:617028',
#  'kiaa0551': 'OMIM:617028',
#  'mrt54': 'OMIM:617028',
#  'glioblastoma, somatic': 'OMIM:137800',
#  'coronary heart disease, susceptibility to, 6': 'OMIM:614466',
#  'mmp3': 'OMIM:614466',
#  'stmy1': 'OMIM:614466',
#  'chds6': 'OMIM:614466',
#  'hypogonadotropic hypogonadism 2 with or without anosmia': 'OMIM:147950',
#  'fgfr1': 'OMIM:166250',
#  'flt2': 'OMIM:166250',
#  'ogd': 'OMIM:166250',
#  'kal2': 'OMIM:166250',
#  'hh2': 'OMIM:166250',
#  'hrtfds': 'OMIM:166250',
#  'eccl': 'OMIM:166250',
#  'high density lipoprotein cholesterol level qtl6': 'OMIM:610762',
#  'scarb1': 'OMIM:610762',
#  'cd36l1': 'OMIM:610762',
#  'cla1': 'OMIM:610762',
#  'hdlqtl6': 'OMIM:610762',
#  'acrofacial dysostosis, cincinnati type': 'OMIM:616462',
#  'polr1a': 'OMIM:620675',
#  'rpa194': 'OMIM:620675',
#  'afdcin': 'OMIM:620675',
#  'hld27': 'OMIM:620675',
#  'premature aging syndrome, penttinen type': 'OMIM:601812',
#  'colon cancer, advanced, somatic': 'OMIM:114500',
#  'src': 'OMIM:616937',
#  'asv': 'OMIM:616937',
#  'src1': 'OMIM:616937',
#  'thc6': 'OMIM:616937',
#  'dystonia 9': 'OMIM:601042',
#  'jackson-weiss syndrome': 'ORPHA:1540',
#  'blood group, yt system': 'OMIM:112100',
#  'ache': 'OMIM:112100',
#  'yt': 'OMIM:112100',
#  'isolated growth hormone deficiency, type iii, with agammaglobulinemia': 'OMIM:307200',
#  'hyper-ige syndrome 1, autosomal dominant, with recurrent infections': 'OMIM:147060',
#  'thrombocytopenia 6': 'OMIM:616937',
#  'myofibromatosis, infantile, 1': 'OMIM:228550',
#  'thanatophoric dysplasia, type i': 'OMIM:187600',
#  'thanatophoric dysplasia, type ii': 'OMIM:187601',
#  'insensitivity to pain, congenital, with anhidrosis': 'OMIM:256800',
#  'ntrk1': 'OMIM:256800',
#  'trka': 'OMIM:256800',
#  'glut1 deficiency syndrome 2, childhood onset': 'OMIM:612126',
#  'diabetes mellitus, permanent neonatal 1': 'OMIM:606176',
#  'asthma, diminished response to antileukotriene treatment in': 'OMIM:600807',
#  'alox5': 'OMIM:600807',
#  'schizophrenia': 'OMIM:181500',
#  'disc2': 'OMIM:181500',
#  'leukemia, acute myeloid': 'OMIM:601626',
#  'cebpa': 'OMIM:601626',
#  'cebp': 'OMIM:601626',
#  'warfarin sensitivity': 'OMIM:301052',
#  'scaphocephaly, maxillary retrusion, and impaired intellectual development': 'OMIM:609579',
#  'encephalopathy, acute, infection-induced (herpes-specific), susceptibility to, 8': 'OMIM:617900',
#  'tbk1': 'OMIM:616439',
#  'nak': 'OMIM:616439',
#  'ftdals4': 'OMIM:616439',
#  'iiae8': 'OMIM:616439',
#  'roifman-chitayat syndrome, digenic': 'OMIM:613328',
#  'knstrn': 'OMIM:613328',
#  'c15orf23': 'OMIM:613328',
#  'skap': 'OMIM:613328',
#  'multiple endocrine neoplasia iia': 'OMIM:171400',
#  'diabetes mellitus, noninsulin-dependent': 'OMIM:125853',
#  'abcc8': 'OMIM:125853',
#  'sur': 'OMIM:125853',
#  'phhi': 'OMIM:125853',
#  'sur1': 'OMIM:125853',
#  'hhf1': 'OMIM:125853',
#  'tndm2': 'OMIM:125853',
#  'pndm3': 'OMIM:125853',
#  'focal dermal hypoplasia': 'ORPHA:2092',
#  'porcn': 'OMIM:305600',
#  'porc': 'OMIM:305600',
#  'dhof': 'OMIM:305600',
#  'fodh': 'OMIM:305600',
#  'diarrhea 7, protein-losing enteropathy type': 'OMIM:615863',
#  'dgat1': 'OMIM:615863',
#  'argp1': 'OMIM:615863',
#  'diar7': 'OMIM:615863',
#  'budd-chiari syndrome, somatic': 'OMIM:600880',
#  'developmental and epileptic encephalopathy 79': 'OMIM:618559',
#  'gabra5': 'OMIM:618559',
#  'dee79': 'OMIM:618559',
#  'crouzon syndrome with acanthosis nigricans': 'OMIM:612247',
#  'hirschsprung disease, protection against': 'OMIM:142623',
#  'encephalocraniocutaneous lipomatosis, somatic mosaic': 'OMIM:613001',
#  'noonan syndrome 5': 'OMIM:611553',
#  'spastic paraplegia 76, autosomal recessive': 'OMIM:616907',
#  'capn1': 'OMIM:616907',
#  'spg76': 'ORPHA:488594',
#  'amyotrophic lateral sclerosis 19': 'OMIM:615515',
#  'erbb4': 'OMIM:615515',
#  'her4': 'OMIM:615515',
#  'als19': 'OMIM:615515',
#  'bleeding disorder, platelet-type, 22': 'OMIM:618462',
#  'retinitis pigmentosa 38': 'OMIM:613862',
#  'mertk': 'OMIM:613862',
#  'rp38': 'OMIM:613862',
#  'intellectual developmental disorder with hypotonia and behavioral abnormalities': 'OMIM:618748',
#  'cdk8': 'OMIM:618748',
#  'iddhba': 'OMIM:618748',
#  'insulin-like growth factor i, resistance to': 'OMIM:270450',
#  'igf1r': 'OMIM:270450',
#  'congenital bilateral absence of vas deferens': 'ORPHA:48',
#  'essential tremor, hereditary, 1': 'OMIM:190300',
#  'drd3': 'OMIM:190300',
#  'etm1': 'OMIM:190300',
#  'fet1': 'OMIM:190300',
#  'frontotemporal dementia and/or amyotrophic lateral sclerosis 4': 'OMIM:616439',
#  'hypochondroplasia': 'ORPHA:429',
#  'leukodystrophy, hypomyelinating, 27': 'OMIM:620675',
#  'hartsfield syndrome': 'ORPHA:2117',
#  'paroxysmal extreme pain disorder': 'ORPHA:46348',
#  'cpt deficiency, hepatic, type ia': 'OMIM:255120',
#  'cpt1a': 'OMIM:255120',
#  'neuroblastoma, susceptibility to, 3': 'OMIM:613014',
#  'alk': 'OMIM:613014',
#  'nblst3': 'OMIM:613014',
#  'rabson-mendenhall syndrome': 'ORPHA:769',
#  'abdominal obesity-metabolic syndrome 3': 'OMIM:615812',
#  'dyrk1b': 'OMIM:615812',
#  'mirk': 'OMIM:615812',
#  'aoms3': 'OMIM:615812',
#  'thyroid hormone resistance': 'OMIM:188570',
#  'cornelia de lange syndrome 6': 'OMIM:620568',
#  'brd4': 'OMIM:620568',
#  'cap': 'OMIM:620568',
#  'hunk1': 'OMIM:620568',
#  'cdls6': 'OMIM:620568',
#  'basal ganglia calcification, idiopathic, 4': 'OMIM:615007',
#  'trigonocephaly 1': 'OMIM:190440',
#  'glut1 deficiency syndrome 1, infantile onset, severe': 'OMIM:606777',
#  'rubinstein-taybi syndrome 1': 'OMIM:180849',
#  'osteoglophonic dysplasia': 'OMIM:166250',
#  'achondroplasia': 'ORPHA:15',
#  'immunodeficiency 97 with autoinflammation': 'OMIM:619802',
#  'pik3cg': 'OMIM:619802',
#  'imd97': 'OMIM:619802',
#  'inflammatory myofibroblastic tumor': 'ORPHA:178342',
#  'systemic lupus erythematosus': 'ORPHA:536',
#  'disseminated lupus erythematosus': 'ORPHA:536',
#  'sle': 'ORPHA:536',
#  'hereditary sensory and autonomic neuropathy type 5': 'ORPHA:64752',
#  'cip': 'ORPHA:64752',
#  'congenital insensitivity to pain and thermal analgesia': 'ORPHA:64752',
#  'hsan5': 'ORPHA:64752',
#  'hereditary sensory and autonomic neuropathy type v': 'ORPHA:64752',
#  'hemimegalencephaly': 'ORPHA:99802',
#  'unilateral megalencephaly': 'ORPHA:99802',
#  'pfeiffer syndrome type 2': 'ORPHA:93259',
#  'alk-positive anaplastic large cell lymphoma': 'ORPHA:300895',
#  'alk+ alcl': 'ORPHA:300895',
#  'alk+ anaplastic large cell lymphoma': 'ORPHA:300895',
#  'hereditary butyrylcholinesterase deficiency': 'ORPHA:132',
#  'hereditary pseudocholinesterase deficiency': 'ORPHA:132',
#  'mild hemophilia b': 'ORPHA:169799',
#  'mild congenital f9 deficiency': 'ORPHA:169799',
#  'mild congenital factor ix deficiency': 'ORPHA:169799',
#  'symptomatic form of coffin-lowry syndrome in female carriers': 'ORPHA:276630',
#  'autoimmune pulmonary alveolar proteinosis': 'ORPHA:747',
#  'autoimmune pap': 'ORPHA:747',
#  'apap': 'ORPHA:747',
#  'follicular lymphoma': 'ORPHA:545',
#  'myoclonus-dystonia syndrome': 'ORPHA:36899',
#  'alcohol-responsive dystonia': 'ORPHA:36899',
#  'hereditary essential myoclonus': 'ORPHA:36899',
#  'myoclonic dystonia': 'ORPHA:36899',
#  'narcolepsy type 1': 'ORPHA:2073',
#  'gélineau disease': 'ORPHA:2073',
#  'narcolepsy-cataplexy': 'ORPHA:2073',
#  'neonatal inflammatory skin and bowel disease': 'ORPHA:294023',
#  'goltz syndrome': 'ORPHA:2092',
#  'goltz-gorlin syndrome': 'ORPHA:2092',
#  'preeclampsia': 'ORPHA:275555',
#  'semilobar holoprosencephaly': 'ORPHA:220386',
#  'activated pi3k-delta syndrome': 'ORPHA:397596',
#  'senescent t-cells-lymphadenopathy-immunodeficiency syndrome due to p110delta-activating mutation': 'ORPHA:397596',
#  'hereditary sensory and autonomic neuropathy type 2': 'ORPHA:970',
#  'autosomal recessive sensory radicular neuropathy': 'ORPHA:970',
#  'hereditary sensory and autonomic neuropathy type ii': 'ORPHA:970',
#  'neurogenic acroosteolysis': 'ORPHA:970',
#  'rubinstein-taybi syndrome due to crebbp mutations': 'ORPHA:353277',
#  'congenital insensitivity to pain-anosmia-neuropathic arthropathy': 'ORPHA:88642',
#  'scn9a-related congenital insensitivity to pain': 'ORPHA:88642',
#  'colobomatous microphthalmia': 'ORPHA:98938',
#  'mac': 'ORPHA:98938',
#  'microphthalmia with colobomatous cyst': 'ORPHA:98938',
#  'microphthalmia-anophthalmia-coloboma syndrome': 'ORPHA:98938',
#  'systemic-onset juvenile idiopathic arthritis': 'ORPHA:85414',
#  'still disease': 'ORPHA:85414',
#  'systemic-onset jia': 'ORPHA:85414',
#  'non rare in europe: celiac disease': 'ORPHA:555',
#  'celiac sprue': 'ORPHA:555',
#  'coeliac disease': 'ORPHA:555',
#  'coeliac sprue': 'ORPHA:555',
#  'gluten intolerance': 'ORPHA:555',
#  'gluten-induced enteropathy': 'ORPHA:555',
#  'gluten-sensitive enteropathy': 'ORPHA:555',
#  'idiopathic steatorrhea': 'ORPHA:555',
#  'nontropical sprue': 'ORPHA:555',
#  'blue rubber bleb nevus': 'ORPHA:1059',
#  'brbn': 'ORPHA:1059',
#  'bean syndrome': 'ORPHA:1059',
#  'differentiated thyroid carcinoma': 'ORPHA:146',
#  'papillary or follicular thyroid carcinoma': 'ORPHA:146',
#  'well-differentiated thyroid carcinoma': 'ORPHA:146',
#  'congenital glaucoma': 'ORPHA:98976',
#  'buphthalmia': 'ORPHA:98976',
#  'buphthalmos': 'ORPHA:98976',
#  'buphthalmus': 'ORPHA:98976',
#  'primary congenital glaucoma': 'ORPHA:98976',
#  'pfeiffer syndrome type 3': 'ORPHA:93260',
#  'oligoarticular juvenile idiopathic arthritis': 'ORPHA:85410',
#  'oligoarticular jia': 'ORPHA:85410',
#  'pauciarticular chronic arthritis': 'ORPHA:85410',
#  'familial advanced sleep-phase syndrome': 'ORPHA:164736',
#  'fasps': 'ORPHA:164736',
#  'congenital factor x deficiency': 'ORPHA:328',
#  'congenital stuart factor deficiency': 'ORPHA:328',
#  'stuart-prower factor deficiency': 'ORPHA:328',
#  'short stature due to isolated growth hormone deficiency with x-linked hypogammaglobulinemia': 'ORPHA:632',
#  'b-lymphoblastic leukemia/lymphoma with t(9;22)(q34.1;q11.2)': 'ORPHA:585909',
#  'b-all with t(9;22)(q34.1;q11.2)': 'ORPHA:585909',
#  'bcr-abl1-like b-all': 'ORPHA:585909',
#  'philadelphia chromosome-like b-all': 'ORPHA:585909',
#  'narcolepsy type 2': 'ORPHA:83465',
#  'narcolepsy without cataplexy': 'ORPHA:83465',
#  'alk-positive large b-cell lymphoma': 'ORPHA:364043',
#  'alk+ lbcl': 'ORPHA:364043',
#  'alk+ large b-cell lymphoma': 'ORPHA:364043',
#  'aquagenic palmoplantar keratoderma': 'ORPHA:498359',
#  'aquagenic keratoderma': 'ORPHA:498359',
#  'aquagenic syringeal acrokeratoderma': 'ORPHA:498359',
#  'aquagenic wrinkling of the palms': 'ORPHA:498359',
#  'transient reactive papulotranslucent acrokeratoderma': 'ORPHA:498359',
#  'autosomal recessive non-syndromic intellectual disability': 'ORPHA:88616',
#  'ar-nsid': 'ORPHA:88616',
#  'ns-arid': 'ORPHA:88616',
#  'non rare in europe: hypodontia': 'ORPHA:2227',
#  'tooth agenesis': 'ORPHA:2227',
#  'menke-hennekam syndrome': 'ORPHA:592574',
#  'huntington disease': 'ORPHA:399',
#  'huntington chorea': 'ORPHA:399',
#  'cfc syndrome': 'ORPHA:1340',
#  'severe achondroplasia-developmental delay-acanthosis nigricans syndrome': 'ORPHA:85165',
#  'myoclonic-astatic epilepsy': 'ORPHA:1942',
#  'doose syndrome': 'ORPHA:1942',
#  'emas': 'ORPHA:1942',
#  'epilepsy with myoclonic-astatic seizures': 'ORPHA:1942',
#  'epilepsy with myoclonic-atonic seizures': 'ORPHA:1942',
#  'mae': 'ORPHA:1942',
#  'myoclonic atonic epilepsy': 'ORPHA:1942',
#  'myoclonic-astatic epilepsy in early childhood': 'ORPHA:1942',
#  'combined immunodeficiency with facio-oculo-skeletal anomalies': 'ORPHA:221139',
#  'roifman-chitayat syndrome': 'ORPHA:221139',
#  'familial isolated dilated cardiomyopathy': 'ORPHA:154',
#  'familial or idiopathic dilated cardiomyopathy': 'ORPHA:154',
#  'williams syndrome': 'ORPHA:904',
#  'deletion 7q11.23': 'ORPHA:904',
#  'monosomy 7q11.23': 'ORPHA:904',
#  'williams-beuren syndrome': 'ORPHA:904',
#  'large congenital melanocytic nevus': 'ORPHA:626',
#  'congenital pigmented nevus': 'ORPHA:626',
#  'gmn': 'ORPHA:626',
#  'giant congenital melanocytic nevus': 'ORPHA:626',
#  'giant pigmented hairy nevus': 'ORPHA:626',
#  'lcmn': 'ORPHA:626',
#  'non-syndromic metopic craniosynostosis': 'ORPHA:3366',
#  'isolated metopic craniosynostosis': 'ORPHA:3366',
#  'isolated trigonocephaly': 'ORPHA:3366',
#  'non-syndromic metopic suture synostosis': 'ORPHA:3366',
#  'familial medullary thyroid carcinoma': 'ORPHA:99361',
#  'familial mtc': 'ORPHA:99361',
#  'acute promyelocytic leukemia': 'ORPHA:520',
#  'aml m3': 'ORPHA:520',
#  'aml with t(15;17)(q22;q12);(pml/raralpha) and variants': 'ORPHA:520',
#  'apml': 'ORPHA:520',
#  'acute myeloblastic leukemia 3': 'ORPHA:520',
#  'acute myeloid leukemia with t(15;17)(q22;q12);(pml/raralpha) and variants': 'ORPHA:520',
#  'polycythemia vera': 'ORPHA:729',
#  'acquired primary erythrocytosis': 'ORPHA:729',
#  'osler-vaquez disease': 'ORPHA:729',
#  'pv': 'ORPHA:729',
#  'polycythemia rubra vera': 'ORPHA:729',
#  'vaquez disease': 'ORPHA:729',
#  'non rare in europe: multiple sclerosis': 'ORPHA:802',
#  '46': 'ORPHA:753',
#  'xy dsd due to 5-alpha-reductase 2 deficiency': 'ORPHA:753',
#  'xy disorder of sex development due to 5-alpha-reductase 2 deficiency': 'ORPHA:753',
#  'steroid 5-alpha-reductase 2 deficiency': 'ORPHA:753',
#  'non-syndromic bicoronal craniosynostosis': 'ORPHA:35099',
#  'isolated bicoronal craniosynostosis': 'ORPHA:35099',
#  'isolated brachycephaly': 'ORPHA:35099',
#  'non-syndromic bilateral coronal suture synostosis': 'ORPHA:35099',
#  'autosomal dominant non-syndromic intellectual disability': 'ORPHA:178469',
#  'leprechaunism': 'ORPHA:508',
#  'multiple endocrine neoplasia type 2b': 'ORPHA:247709',
#  'men2b': 'ORPHA:247709',
#  'multiple endocrine neoplasia type 3': 'ORPHA:247709',
#  'wagenmann-froboese syndrome': 'ORPHA:247709',
#  'limited cutaneous systemic sclerosis': 'ORPHA:220402',
#  'limited cutaneous systemic scleroderma': 'ORPHA:220402',
#  'giant cell glioblastoma': 'ORPHA:251579',
#  'fgfr2-related bent bone dysplasia': 'ORPHA:313855',
#  'perinatal lethal bent bone dysplasia': 'ORPHA:313855',
#  'congenital factor xi deficiency': 'ORPHA:329',
#  'hemophilia c': 'ORPHA:329',
#  'pta deficiency': 'ORPHA:329',
#  'plasma thromboplastin antecedent deficiency': 'ORPHA:329',
#  'rosenthal factor deficiency': 'ORPHA:329',
#  'rosenthal syndrome': 'ORPHA:329',
#  'non-immune hydrops fetalis': 'ORPHA:363999',
#  'nihf': 'ORPHA:363999',
#  'non-immune hf': 'ORPHA:363999',
#  'non-immune fetal edema': 'ORPHA:363999',
#  'non-immune fetal hydrops': 'ORPHA:363999',
#  'myeloid/lymphoid neoplasm associated with pdgfrb rearrangement': 'ORPHA:168950',
#  'hyperinsulinism due to insr deficiency': 'ORPHA:263458',
#  'hyperinsulinemic hypoglycemia due to insr deficiency': 'ORPHA:263458',
#  'hyperinsulinemic hypoglycemia due to insulin receptor deficiency': 'ORPHA:263458',
#  'hereditary chronic pancreatitis': 'ORPHA:676',
#  'classic hairy cell leukemia': 'ORPHA:58017',
#  'hcl-c': 'ORPHA:58017',
#  'leukemic reticuloendotheliosis': 'ORPHA:58017',
#  'isolated permanent neonatal diabetes mellitus': 'ORPHA:99885',
#  'isolated pndm': 'ORPHA:99885',
#  'monogenic diabetes of infancy': 'ORPHA:99885',
#  'non rare in europe: rheumatoid arthritis': 'ORPHA:284130',
#  'distal 22q11.2 microdeletion syndrome': 'ORPHA:261330',
#  'distal del(22)(q11.2)': 'ORPHA:261330',
#  'distal monosomy 22q11.2': 'ORPHA:261330',
#  'isolated focal cortical dysplasia type iia': 'ORPHA:269001',
#  'fcd type iia': 'ORPHA:269001',
#  'non rare in europe: melanoma': 'ORPHA:411533',
#  'mucoviscidosis': 'ORPHA:586',
#  'chronic lymphoproliferative disorder of natural killer cells': 'ORPHA:512017',
#  'clpd-nk': 'ORPHA:512017',
#  'cnkl': 'ORPHA:512017',
#  'chronic nk lymphocytosis': 'ORPHA:512017',
#  'chronic nk-cell lymphocytosis': 'ORPHA:512017',
#  'chronic lymphoproliferative disorder of nk-cells': 'ORPHA:512017',
#  'nk-cell lineage granular lymphocyte proliferative disorder': 'ORPHA:512017',
#  'normosmic congenital hypogonadotropic hypogonadism': 'ORPHA:432',
#  'normosmic idiopathic hypogonadotropic hypogonadism': 'ORPHA:432',
#  'nihh': 'ORPHA:432',
#  'diffuse cutaneous systemic sclerosis': 'ORPHA:220393',
#  'diffuse cutaneous systemic scleroderma': 'ORPHA:220393',
#  'progressive cutaneous systemic scleroderma': 'ORPHA:220393',
#  'progressive cutaneous systemic sclerosis': 'ORPHA:220393',
#  'hereditary thrombocytopenia with early-onset myelofibrosis': 'ORPHA:480851',
#  'amyotrophic lateral sclerosis': 'ORPHA:803',
#  'als': 'ORPHA:803',
#  'charcot disease': 'ORPHA:803',
#  'lou gehrig disease': 'ORPHA:803',
#  'tetralogy of fallot': 'ORPHA:3303',
#  'frontotemporal dementia with motor neuron disease': 'ORPHA:275872',
#  'ftd-als': 'ORPHA:275872',
#  'ftd-mnd': 'ORPHA:275872',
#  'frontotemporal dementia with amyotrophic lateral sclerosis': 'ORPHA:275872',
#  'precursor t-cell acute lymphoblastic leukemia': 'ORPHA:99861',
#  'precursor t-cell acute lymphoblastic leukemia/lymphoma': 'ORPHA:99861',
#  'precursor t-cell acute lymphocytic leukemia': 'ORPHA:99861',
#  'precursor t-cell acute lymphocytic leukemia/lymphoma': 'ORPHA:99861',
#  't-all': 'ORPHA:99861',
#  'lennox-gastaut syndrome': 'ORPHA:2382',
#  'ghosal hematodiaphyseal dysplasia': 'ORPHA:1802',
#  'diaphyseal dysplasia-anemia syndrome': 'ORPHA:1802',
#  'ghosal syndrome': 'ORPHA:1802',
#  'non-specific early-onset epileptic encephalopathy': 'ORPHA:442835',
#  'non-specific eoee': 'ORPHA:442835',
#  'undetermined eoee': 'ORPHA:442835',
#  'undetermined early-onset epileptic encephalopathy': 'ORPHA:442835',
#  'generalized epilepsy with febrile seizures-plus': 'ORPHA:36387',
#  'gefs+': 'ORPHA:36387',
#  'genetic epilepsy with febrile seizures-plus': 'ORPHA:36387',
#  'rare autosomal dominant non-syndromic sensorineural deafness type dfna': 'ORPHA:90635',
#  'autosomal dominant isolated neurosensory deafness type dfna': 'ORPHA:90635',
#  'autosomal dominant isolated neurosensory hearing loss type dfna': 'ORPHA:90635',
#  'autosomal dominant isolated sensorineural deafness type dfna': 'ORPHA:90635',
#  'autosomal dominant isolated sensorineural hearing loss type dfna': 'ORPHA:90635',
#  'autosomal dominant non-syndromic neurosensory deafness type dfna': 'ORPHA:90635',
#  'autosomal dominant non-syndromic neurosensory hearing loss type dfna': 'ORPHA:90635',
#  'autosomal dominant non-syndromic sensorineural hearing loss type dfna': 'ORPHA:90635',
#  'insulin-resistance syndrome type a': 'ORPHA:2297',
#  'epilepsy with myoclonic absences': 'ORPHA:86911',
#  'congenital chronic diarrhea with protein-losing enteropathy': 'ORPHA:329242',
#  'congenital chronic diarrhea with exudative enteropathy': 'ORPHA:329242',
#  'hereditary sodium channelopathy-related small fibers neuropathy': 'ORPHA:306577',
#  'bleeding disorder in hemophilia b carriers': 'ORPHA:177929',
#  'severe hemophilia b': 'ORPHA:169793',
#  'severe congenital f9 deficiency': 'ORPHA:169793',
#  'severe congenital factor ix deficiency': 'ORPHA:169793',
#  'lobar holoprosencephaly': 'ORPHA:93924',
#  'childhood absence epilepsy': 'ORPHA:64280',
#  'pyknolepsy': 'ORPHA:64280',
#  'hereditary pheochromocytoma-paraganglioma': 'ORPHA:29072',
#  'familial pheochromocytoma-paraganglioma': 'ORPHA:29072',
#  'idiopathic bronchiectasis': 'ORPHA:60033',
#  'sporadic pheochromocytoma/secreting paraganglioma': 'ORPHA:276621',
#  'marfanoid habitus-facial dysmorphism-skeletal abnormality-heart defect syndrome': 'ORPHA:643503',
#  'moderate hemophilia b': 'ORPHA:169796',
#  'moderate congenital f9 deficiency': 'ORPHA:169796',
#  'moderate congenital factor ix deficiency': 'ORPHA:169796',
#  'giant cell arteritis': 'ORPHA:397',
#  'horton disease': 'ORPHA:397',
#  'temporal arteritis': 'ORPHA:397',
#  'mucocutaneous venous malformations': 'ORPHA:2451',
#  'cutaneous and mucosal venous malformation': 'ORPHA:2451',
#  'chronic myeloid leukemia': 'ORPHA:521',
#  'cml': 'ORPHA:521',
#  'chronic granulocytic leukemia': 'ORPHA:521',
#  'chronic myelogenous leukemia': 'ORPHA:521',
#  'bullous pemphigoid': 'ORPHA:703',
#  'non rare in europe: metabolic syndrome': 'ORPHA:411969',
#  'cornelia de lange syndrome': 'ORPHA:199',
#  'brachmann-de lange syndrome': 'ORPHA:199',
#  'stat3-related early-onset multisystem autoimmune disease': 'ORPHA:438159',
#  'non-specific syndromic intellectual disability': 'ORPHA:528084',
#  'complex neurodevelopmental disorder': 'ORPHA:528084',
#  'pfeiffer syndrome type 1': 'ORPHA:93258',
#  'classic pfeiffer syndrome': 'ORPHA:93258',
#  'non rare in europe: hereditary essential tremor': 'ORPHA:862',
#  'curry-jones syndrome': 'ORPHA:1553',
#  'corpus callosum agenesis-polysyndactyly syndrome': 'ORPHA:1553',
#  'paroxysmal exertion-induced dyskinesia': 'ORPHA:98811',
#  'dystonia 18': 'ORPHA:98811',
#  't-b+ severe combined immunodeficiency due to jak3 deficiency': 'ORPHA:35078',
#  't-b+ scid due to jak3 deficiency': 'ORPHA:35078',
#  'familial rectal pain': 'ORPHA:46348',
#  'crouzon craniofacial dysostosis': 'ORPHA:207',
#  'mody': 'ORPHA:552',
#  'maturity-onset diabetes of the young': 'ORPHA:552',
#  'hereditary sensory and autonomic neuropathy type 4': 'ORPHA:642',
#  'cipa': 'ORPHA:642',
#  'congenital insensitivity to pain with anhidrosis': 'ORPHA:642',
#  'hsan4': 'ORPHA:642',
#  'hereditary sensory and autonomic neuropathy type iv': 'ORPHA:642',
#  'primary myelofibrosis': 'ORPHA:824',
#  'agnogenic myeloid metaplasia': 'ORPHA:824',
#  'idiopathic myelofibrosis': 'ORPHA:824',
#  'myelofibrosis with myeloid metaplasia': 'ORPHA:824',
#  'osteomyelofibrosis': 'ORPHA:824',
#  'cls': 'ORPHA:192',
#  'severe combined immunodeficiency due to ikk2 deficiency': 'ORPHA:397787',
#  'scid due to ikk2 deficiency': 'ORPHA:397787',
#  'juvenile myoclonic epilepsy': 'ORPHA:307',
#  'jme': 'ORPHA:307',
#  'juvenile myoclonus epilepsy': 'ORPHA:307',
#  'budd-chiari syndrome': 'ORPHA:131',
#  'x-linked agammaglobulinemia': 'ORPHA:47',
#  'btk-deficiency': 'ORPHA:47',
#  'bruton type agammaglobulinemia': 'ORPHA:47',
#  'congenital bilateral agenesis of vas deferens': 'ORPHA:48',
#  'congenital bilateral aplasia of vas deferens': 'ORPHA:48',
#  'multiple endocrine neoplasia type 2a': 'ORPHA:247698',
#  'ptc syndrome': 'ORPHA:247698',
#  'sipple syndrome': 'ORPHA:247698',
#  'familial thrombocytosis': 'ORPHA:71493',
#  'familial thrombocythemia': 'ORPHA:71493',
#  'hereditary thrombocythemia': 'ORPHA:71493',
#  'severe combined immunodeficiency due to lck deficiency': 'ORPHA:280142',
#  'scid due to lck deficiency': 'ORPHA:280142',
#  'scid due to lymphocyte-specific protein tyrosine kinase deficiency': 'ORPHA:280142',
#  'severe combined immunodeficiency due to lymphocyte-specific protein tyrosine kinase deficiency': 'ORPHA:280142',
#  'infantile myofibromatosis': 'ORPHA:2591',
#  'congenital glucokinase-related hyperinsulinism': 'ORPHA:79299',
#  'glucokinase-related hyperinsulinemic hypoglycemia': 'ORPHA:79299',
#  'noonan syndrome with multiple lentigines': 'ORPHA:500',
#  'cardiomyopathic lentiginosis': 'ORPHA:500',
#  'familial multiple lentigines syndrome': 'ORPHA:500',
#  'leopard syndrome': 'ORPHA:500',
#  'limited systemic sclerosis': 'ORPHA:220407',
#  'systemic sclerosis sine scleroderma': 'ORPHA:220407',
#  'oligodontia': 'ORPHA:99798',
#  'selective tooth agenesis': 'ORPHA:99798',
#  'septo-optic dysplasia spectrum': 'ORPHA:3157',
#  'de morsier syndrome': 'ORPHA:3157',
#  'sod': 'ORPHA:3157',
#  'septo-optic dysplasia': 'ORPHA:3157',
#  'growth delay due to insulin-like growth factor i resistance': 'ORPHA:73273',
#  'resistance to igf-1': 'ORPHA:73273',
#  'kallmann syndrome': 'ORPHA:478',
#  'congenital hypogonadotropic hypogonadism with anosmia': 'ORPHA:478',
#  'olfacto-genital pathological sequence': 'ORPHA:478',
#  'primary hypereosinophilic syndrome': 'ORPHA:314950',
#  'clonal hypereosinophilic syndrome': 'ORPHA:314950',
#  'hes-m': 'ORPHA:314950',
#  'hes-n': 'ORPHA:314950',
#  'neoplastic hypereosinophilic syndrome': 'ORPHA:314950',
#  'primary hes': 'ORPHA:314950',
#  'familial scaphocephaly syndrome': 'ORPHA:168624',
#  'scaphocephaly-macrocephaly-maxillary retrusion-intellectual disability syndrome': 'ORPHA:168624',
#  'langerhans cell histiocytosis': 'ORPHA:389',
#  'histiocytosis x': 'ORPHA:389',
#  'langerhans cell granulomatosis': 'ORPHA:389',
#  'sarcoidosis': 'ORPHA:797',
#  'besnier-boeck-schaumann disease': 'ORPHA:797',
#  'boeck sarcoid': 'ORPHA:797',
#  'x-linked non-syndromic intellectual disability': 'ORPHA:777',
#  'nut midline carcinoma': 'ORPHA:443167',
#  'nmc': 'ORPHA:443167',
#  'pyknodysostosis': 'ORPHA:763',
#  'syringocystadenoma papilliferum': 'ORPHA:840',
#  'fistulous vegetative verrucous hydradenoma': 'ORPHA:840',
#  'naevus syringocystadenomatosus papilliferus': 'ORPHA:840',
#  'papillary syringocystadenoma': 'ORPHA:840',
#  'scap': 'ORPHA:840',
#  'syringadenoma papilliferum': 'ORPHA:840',
#  'haddad syndrome': 'ORPHA:99803',
#  'congenital central alveolar hypoventilation-hirschsprung disease syndrome': 'ORPHA:99803',
#  'ondine-hirschsprung disease': 'ORPHA:99803',
#  'ondine-hirschsprung syndrome': 'ORPHA:99803',
#  'cutis gyrata-acanthosis nigricans-craniosynostosis syndrome': 'ORPHA:1555',
#  'chronic myelomonocytic leukemia': 'ORPHA:98823',
#  'cmml': 'ORPHA:98823',
#  'hirschsprung disease': 'ORPHA:388',
#  'aganglionic megacolon': 'ORPHA:388',
#  'colonic aganglionosis': 'ORPHA:388',
#  'congenital intestinal aganglionosis': 'ORPHA:388',
#  'hscr': 'ORPHA:388',
#  'neuroblastoma': 'ORPHA:635',
#  'crouzon syndrome-acanthosis nigricans syndrome': 'ORPHA:93262',
#  'crouzon-dermoskeletal syndrome': 'ORPHA:93262',
#  'acroosteolysis-keloid-like lesions-premature aging syndrome': 'ORPHA:363665',
#  'premature aging syndrome': 'ORPHA:363665',
#  'penttinen type': 'ORPHA:363665',
#  'microform holoprosencephaly': 'ORPHA:280200',
#  'hpe': 'ORPHA:280200',
#  'minor form': 'ORPHA:280200',
#  'hpe-l': 'ORPHA:280200',
#  'holoprosencephaly': 'ORPHA:280200',
#  'holoprosencephaly-like': 'ORPHA:280200',
#  'microform hpe': 'ORPHA:280200',
#  'male infertility with azoospermia or oligozoospermia due to single gene mutation': 'ORPHA:399805',
#  'carnitine palmitoyl transferase 1a deficiency': 'ORPHA:156',
#  'cpt1a deficiency': 'ORPHA:156',
#  'carnitine palmitoyl transferase ia deficiency': 'ORPHA:156',
#  'hepatic carnitine palmitoyl transferase 1 deficiency': 'ORPHA:156',
#  'hepatic carnitine palmitoyl transferase i deficiency': 'ORPHA:156',
#  'l-cpt1 deficiency': 'ORPHA:156',
#  'l-cpti deficiency': 'ORPHA:156',
#  'retinitis pigmentosa': 'ORPHA:791',
#  'autosomal recessive spastic paraplegia type 76': 'ORPHA:488594',
#  'metaphyseal anadysplasia': 'ORPHA:1040',
#  'maroteaux-verloes-stanescu syndrome': 'ORPHA:1040',
#  'regressive metaphyseal dysplasia': 'ORPHA:1040',
#  'milroy disease': 'ORPHA:79452',
#  'hereditary lymphedema type i': 'ORPHA:79452',
#  'nonne-milroy lymphedema': 'ORPHA:79452',
#  'familial prostate cancer': 'ORPHA:1331',
#  'combined immunodeficiency due to itk deficiency': 'ORPHA:538963',
#  'autosomal recessive lymphoproliferative disease due to itk deficiency': 'ORPHA:538963',
#  'itk deficiency': 'ORPHA:538963',
#  'mgat2-cdg': 'ORPHA:79329',
#  'cdg syndrome type iia': 'ORPHA:79329',
#  'cdg-iia': 'ORPHA:79329',
#  'carbohydrate deficient glycoprotein syndrome type iia': 'ORPHA:79329',
#  'congenital disorder of glycosylation type 2a': 'ORPHA:79329',
#  'congenital disorder of glycosylation type iia': 'ORPHA:79329',
#  'n-acetylglucosaminyltransferase 2 deficiency': 'ORPHA:79329',
#  'resistance to thyrotropin-releasing hormone syndrome': 'ORPHA:99832',
#  'central hypothyroidism due to trh receptor deficiency': 'ORPHA:99832',
#  'trh resistance syndrome': 'ORPHA:99832',
#  'paroxysmal dystonic choreathetosis with episodic ataxia and spasticity': 'ORPHA:53583',
#  'episodic choreoathetosis/spasticity': 'ORPHA:53583',
#  'primary erythromelalgia': 'ORPHA:90026',
#  'primary erythermalgia': 'ORPHA:90026',
#  't-cell large granular lymphocyte leukemia': 'ORPHA:86872',
#  'proliferation of large granular lymphocytes': 'ORPHA:86872',
#  't-lgl': 'ORPHA:86872',
#  't-cell lgl leukemia': 'ORPHA:86872',
#  'bilateral striopallidodentate calcinosis': 'ORPHA:1980',
#  'bspdc': 'ORPHA:1980',
#  'cerebrovascular ferrocalcinosis': 'ORPHA:1980',
#  'idiopathic basal ganglia calcification': 'ORPHA:1980',
#  'pfbc': 'ORPHA:1980',
#  'primary familial brain calcification': 'ORPHA:1980',
#  'autosomal recessive generalized dystrophic epidermolysis bullosa': 'ORPHA:79408',
#  'autosomal recessive dystrophic epidermolysis bullosa generalisata gravis': 'ORPHA:79408',
#  'autosomal recessive dystrophic epidermolysis bullosa': 'ORPHA:79408',
#  'hallopeau-siemens type': 'ORPHA:79408',
#  'generalized rdeb': 'ORPHA:79408',
#  'severe form': 'ORPHA:79408',
#  'rdeb generalisata gravis': 'ORPHA:79408',
#  'rdeb': 'ORPHA:79408',
#  'severe generalized rdeb': 'ORPHA:79408',
#  'antley-bixler syndrome without genital anomaly or disorder of steroidogenesis': 'ORPHA:596008',
#  'autosomal recessive mendelian susceptibility to mycobacterial diseases due to complete rorgamma receptor deficiency': 'ORPHA:477857',
#  'autosomal recessive msmd due to complete rorgamma receptor defiency': 'ORPHA:477857',
#  'autosomal recessive primary immunodeficiency due to rorc mutation': 'ORPHA:477857',
#  'craniopharyngioma': 'ORPHA:54595',
#  'gliosarcoma': 'ORPHA:251576',
#  'non rare in europe: diabetes mellitus type 1': 'ORPHA:243377',
#  'insulin-dependent diabetes mellitus': 'ORPHA:243377',
#  'acute myeloid leukemia with t(8;16)(p11;p13) translocation': 'ORPHA:370026',
#  'aml with t(8;16)(p11;p13) translocation': 'ORPHA:370026',
#  'hereditary cryohydrocytosis with reduced stomatin': 'ORPHA:168577',
#  'chc type 2': 'ORPHA:168577',
#  'hereditary cryohydrocytosis type 2': 'ORPHA:168577',
#  'stomatin-deficient cryohydrocytosis': 'ORPHA:168577',
#  'sdchc': 'ORPHA:168577',
#  'gsd due to glut2 deficiency': 'ORPHA:2088',
#  'glycogen storage disease due to glut2 deficiency': 'ORPHA:2088',
#  'glycogenosis due to glut2 deficiency': 'ORPHA:2088',
#  'autosomal recessive mendelian susceptibility to mycobacterial diseases due to partial jak1 deficiency': 'ORPHA:574957',
#  'autosomal recessive msmd due to partial jak1 deficiency': 'ORPHA:574957',
#  'isolated focal cortical dysplasia type iib': 'ORPHA:269008',
#  'fcd type iib': 'ORPHA:269008',
#  'autosomal dominant charcot-marie-tooth disease type 2 due to dgat2 mutation': 'ORPHA:487814',
#  'cmt2 due to dgat2 mutation': 'ORPHA:487814',
#  'cushing disease': 'ORPHA:96253',
#  'corticotroph pituitary adenoma': 'ORPHA:96253',
#  ...}

# %% [markdown]
# Literature checking

# %%
import pandas as pd
import ast
def convert_string_to_list(string):
    try:
        # Use ast.literal_eval to safely evaluate the string to a Python object
        result = ast.literal_eval(string)
        # Ensure the result is a list
        if isinstance(result, list):
            return result
        else:
            raise ValueError("The provided string does not evaluate to a list.")
    except (ValueError, SyntaxError) as e:
        raise ValueError(f"Error converting string to list: {e}")


dyt1 = pd.read_csv('/content/dyt1_update2.csv')
dyt1
dyt1['related_gene']=dyt1.apply(lambda x:  convert_string_to_list(x['unique_texts'].lower()) , axis=1)
dyt1.head()
# Out:
#   p.pubmed_id                                            p.title  \
# 0   "8432555"  "Evidence for locus heterogeneity in autosomal...
# 1   "2317008"  "Dystonia gene in Ashkenazi Jewish population ...
# 2   "1867195"  "Torsion dystonia genes in two populations con...
# 3   "6694180"  "Inheritance of idiopathic torsion dystonia am...
# 4  "13297089"  "[Family incidence of idiopathic torsion dysto...
#
#                                       p.abstractText p.publicationYear  \
# 0  "Idiopathic torsion dystonia (ITD) is most com...            "1993"
# 1  "Idiopathic torsion dystonia (ITD) is a neurol...            "1990"
# 2  "Idiopathic torsion dystonia (ITD) is characte...            "1991"
# 3  "Idiopathic torsion dystonia (ITD) has long be...            "1984"
# 4                                                 ""            "1956"
#
#                                         unique_texts  \
# 0  ["autosomal dominant torsion dystonia", "idiop...
# 1  ["dystonia", "ass", "argininosuccinate synthet...
# 2  ["ak1", "itd", "dystonia", "torsion dystonia",...
# 3  ["afro", "human", "patients", "patient", "infa...
# 4                    ["idiopathic torsion dystonia"]
#
#                                         related_gene
# 0  [autosomal dominant torsion dystonia, idiopath...
# 1  [dystonia, ass, argininosuccinate synthetase, ...
# 2  [ak1, itd, dystonia, torsion dystonia, idiopat...
# 3  [afro, human, patients, patient, infant, mamma...
# 4                      [idiopathic torsion dystonia]

# %% [markdown]
# Annotation checking: genes

# %%
import requests
import re
Genes_=['TGR','TARDBP','ampC','NFE2L2','EHMT2','CBX1','TDP1','CGA','PTH1R','SMAD3','EHMT2','GMNN','TDP1','CGA','EHMT2']

def get_info(gene):
    # URL of the page to scrape
    url = f"https://www.orpha.net/en/disease/gene/{gene}?name={gene}&mode=gene"
    # Send a GET request to the URL
    response = requests.get(url)
    # Get the text content of the response
    text = response.text
    # Use regular expression to find the desired text
    match = re.search(r'Synonym\(s\): </span><span>(.*?)</span></p>', text)
    if match:
        # Extract the matched text
        synonyms = match.group(1)
        return synonyms.split(',')
    return []
# Call the function with the gene name
#print(get_info('NFE2L2'))

additional_list=[]
for i in Genes_:
      additional_list+=get_info(i)
additional_list
# Out:
# ['ALS10',
#  ' TDP-43',
#  'NF-E2-related factor 2',
#  ' NRF-2',
#  ' NRF2',
#  'FLJ11090',
#  ' SCAN1',
#  '',
#  'HsT17436',
#  ' JV15-2',
#  'Gem',
#  'FLJ11090',
#  ' SCAN1']

# %%
Genes_=['TGR','TARDBP','ampC','NFE2L2','EHMT2','CBX1','TDP1','CGA','PTH1R','SMAD3','EHMT2','GMNN','TDP1','CGA','EHMT2']
additional_list=   [i.strip()   for i in additional_list  if i !='']
Genes_+= additional_list
Genes_=list(set(Genes_))
Genes_annotation= dict()
for i in Genes_:
     for j in dyt1.index:
         if i.lower() in  dyt1['related_gene'][j]:
              if i in Genes_annotation:  Genes_annotation[i].append(dyt1['p.pubmed_id'][j])
              else:                      Genes_annotation[i]=[dyt1['p.pubmed_id'][j]]
Genes_annotation
# Out:
# {}

# %%
#genes_2= list(CHEMBL1367890[ 'Common name'].values) +list(CHEMBL1733809[ 'Common name'].values) +list(CHEMBL1372162[ 'Common name'].values)
genes_2= list(NCGC00685598[ 'Common name'].values)+list(NCGC00602080[ 'Common name'].values) +list(NCGC00686269[ 'Common name'].values)+list(NCGC00685517[ 'Common name'].values)
Genes_= genes_2
Genes_=list(set(Genes_))
Genes_annotation= dict()

pathways_for_concurency=set()
papers_pathways=set()
for i in Genes_:
     for j in dyt1.index:
         if i.lower() in  dyt1['related_gene'][j]:
              if i in Genes_annotation:  Genes_annotation[i].append(dyt1['p.pubmed_id'][j])
              else:                      Genes_annotation[i]=[dyt1['p.pubmed_id'][j]]
              pathways_for_concurency.add(i)
              papers_pathways.add(dyt1['p.pubmed_id'][j])

Genes_annotation
# Out:
# {'PDGFRB': ['"20301334"'],
#  'ACHE': ['"34173686"'],
#  'ABL1': ['"1427899"', '"22639460"'],
#  'CACNA1B': ['"35041927"'],
#  'GCK': ['"28387648"']}

# %%
for i in ['PDGFRB','ACHE','ABL1','CACNA1B','GCK']:
   if i in list(NCGC00685598[ 'Common name'].values):
      print(i,'NCGC00685598')
for i in ['PDGFRB','ACHE','ABL1','CACNA1B','GCK']:
   if i in list(NCGC00602080[ 'Common name'].values):
         print(i,'NCGC00602080')

for i in ['PDGFRB','ACHE','ABL1','CACNA1B','GCK']:
   if i in list(NCGC00686269[ 'Common name'].values):
          print(i,'NCGC00686269')

for i in ['PDGFRB','ACHE','ABL1','CACNA1B','GCK']:
   if i in list(NCGC00685517[ 'Common name'].values):
        print(i,'NCGC00685517')
# Out:
# PDGFRB NCGC00685598
# ABL1 NCGC00685598
# CACNA1B NCGC00685598
# PDGFRB NCGC00602080
# ACHE NCGC00602080
# ABL1 NCGC00602080
# CACNA1B NCGC00602080
# PDGFRB NCGC00686269
# ACHE NCGC00686269
# ABL1 NCGC00686269
# GCK NCGC00686269
# PDGFRB NCGC00685517
# ABL1 NCGC00685517
# CACNA1B NCGC00685517
# GCK NCGC00685517

# %%
def chcek_in_one_sen(word, text):
   dyt1_words=['early-onset generalized torsion dystonia', 'tor1a dystonia', 'idiopathic dystonia dyt1', 'primary torsion dystonia', 'early-onset torsion dystonia', "oppenheim's dystonia", 'torsin a', 'early onset torsion dystonia', 'dyt1 dystonia', 'torsina', 'oppenheim dystonia', 'early-onset generalized dystonia', 'torsin-1a', 'tor1a', 'dyt1', 'dystonia 1', 'torsion (autosomal dominant; torsin a)', "oppenheim's dystonia", 'dyt1 early-onset isolated dystonia', 'early-onset torsion dystonia', 'dyt1', 'torsin family 1', 'dystonia musculorum deformans 1', 'dystonia musculorum deformans', 'dystonia 1, torsion, autosomal dominant', 'idiopathic torsion dystonia', 'early-onset generalized limb-onset dystonia', 'idiopathic torsion dystonia', 'dq2', 'early-onset primary dystonia', 'member a (torsin a)', 'dyt-tor1a dystonia', 'torsina', 'primary dystonias', 'early-onset torsion dystonia', 'eotd', 'dystonia 1', 'early-onset isolated dystonia']
   #['torsina','dyt1', 'tor1a', 'primary dystonias', 'dyt1 dystonia', 'tor1a dystonia', 'early-onset torsion dystonia', "oppenheim's dystonia", 'primary torsion dystonia', 'idiopathic torsion dystonia']
   num=0
   for i in dyt1_words:
       num+=  check_in_one_sen_help(i,word, text)
   return num

pheno_count_smae_Sen=dict()
for i in list(pathways_for_concurency):
    pheno_count_smae_Sen[i.lower()]=[]

dyt1['title_abstract'] = dyt1['p.title'].astype(str) + '. ' + dyt1['p.abstractText'].astype(str)


for i in  dyt1.index:
  pubid=dyt1['p.pubmed_id'][i]
  if pubid in papers_pathways:
        tetx=dyt1['title_abstract'][i]
        words_to_chcek=   pathways_for_concurency
        for j in words_to_chcek:
            num=chcek_in_one_sen(j,tetx)
            if num >0:
                pheno_count_smae_Sen[j.lower()].append((pubid,num))
pheno_count_smae_Sen
# Out:
# {'abl1': [('"22639460"', 3)],
#  'cacna1b': [],
#  'gck': [],
#  'ache': [('"34173686"', 1)],
#  'pdgfrb': []}

# %%
CHEMBL1367890=pd.read_csv('/content/CHEMBL1367890.csv')
CHEMBL1372162=pd.read_csv('/content/CHEMBL1372162.csv')
CHEMBL1733809=pd.read_csv('/content/CHEMBL1733809.csv')
enrichment_all_CHEMBL1367890=pd.read_csv('/content/enrichment_all_CHEMBL1367890.csv')
enrichment_all_CHEMBL1367890=pd.read_csv('/content/enrichment_all_CHEMBL1367890.csv')
enrichment_all_CHEMBL1733809=pd.read_csv('/content/enrichment_all_CHEMBL1733809.csv')

# %% [markdown]
# Annotation checking: pathways

# %%
pathwys=pd.concat([enrichment_all_NCGC00685598, enrichment_all_NCGC00602080, enrichment_all_NCGC00686269, enrichment_all_NCGC00685517])

# %%
enrichment_all_NCGC00685598[680:682]
# Out:
#      Enrichment FDR  nGenes  Pathway Genes  Fold Enrichment  \
# 680    1.038691e-07      13            293         9.952921
# 681    1.048415e-07      14            356         8.821712
#
#                                  Pathway  \
# 680  ENSP00000417273 interacting protein
# 681                      SIDER Agitation
#
#                                                    URL  \
# 680  HTTPS://STRINGDB-STATIC.ORG/DOWNLOAD/PROTEIN.L...
# 681                   HTTPS://GENESETDB.AUCKLAND.AC.NZ
#
#                                                  Genes  \
# 680   LYN  RET  PAK4  FGFR1  AKT1  YES1  SRC  ITK  ...
# 681   CDK4  CTSK  ADRB2  AKT1  ABL1  XIAP  HTR1F  T...
#
#                           synon
# 680  [7273 interacting protein]
# 681                      [tion]

# %%
pathways= list(set(sum(enrichment_all_NCGC00685598['synon'], [])))
'tion' in pathways
filtered_df = enrichment_all_NCGC00685598[enrichment_all_NCGC00685598['synon'].apply(lambda x: 'tion' in x)]
print(filtered_df)
# Out:
#      Enrichment FDR  nGenes  Pathway Genes  Fold Enrichment          Pathway  \
# 681    1.048415e-07      14            356         8.821712  SIDER Agitation
#
#                                   URL  \
# 681  HTTPS://GENESETDB.AUCKLAND.AC.NZ
#
#                                                  Genes   synon
# 681   CDK4  CTSK  ADRB2  AKT1  ABL1  XIAP  HTR1F  T...  [tion]

# %%
pathwys.index=range(pathwys.shape[0])

# %%
pathways=  pathwys# pd.read_csv('/content/enrichment_all.csv')
pathways= list(set(sum(pathwys['synon'], [])))
pathways=[i for i in pathways if len(i)>3 and i !=''  ]
#[ i[11:].strip().lower()  for i in  list(pathways['Pathway'])]
dyt1['title_abstract'] = dyt1['p.title'].astype(str) + '. ' + dyt1['p.abstractText'].astype(str)

pathways_for_concurency=set()
papers_pathways=set()
for i in pathways:
  if i != '':
     for j in dyt1.index:
         if i in dyt1['related_gene'][j] or i in dyt1['title_abstract'][j]:
              print((dyt1['p.pubmed_id'][j],i))
              pathways_for_concurency.add(i)
              papers_pathways.add(dyt1['p.pubmed_id'][j])
# Out:
# Streaming output truncated to the last 5000 lines.
# ('"21995941"', 'duced')
# ('"20584926"', 'duced')
# ('"20223934"', 'duced')
# ('"20132487"', 'duced')
# ('"17956903"', 'duced')
# ('"17428918"', 'duced')
# ('"15930383"', 'duced')
# ('"35955710"', 'duced')
# ('"36546658"', 'duced')
# ('"31320448"', 'duced')
# ('"26183317"', 'duced')
# ('"24951854"', 'duced')
# ('"32516804"', 'duced')
# ('"33753289"', 'duced')
# ('"32239467"', 'duced')
# ('"17200151"', 'duced')
# ('"36329866"', 'duced')
# ('"33458877"', 'duced')
# ('"33445430"', 'duced')
# ('"33799994"', 'duced')
# ('"33894367"', 'duced')
# ('"34173686"', 'duced')
# ('"34398825"', 'duced')
# ('"22040906"', 'duced')
# ('"22080833"', 'duced')
# ('"30981209"', 'duced')
# ('"9635626"', 'duced')
# ('"35665810"', 'duced')
# ('"11495087"', 'duced')
# ('"16981842"', 'duced')
# ('"20178968"', 'duced')
# ('"27171035"', 'duced')
# ('"21656045"', 'duced')
# ('"36757831"', 'duced')
# ('"19038309"', 'duced')
# ('"19157930"', 'duced')
# ('"20301665"', 'duced')
# ('"23893446"', 'duced')
# ('"26004199"', 'duced')
# ('"29396398"', 'duced')
# ('"7629534"', 'duced')
# ('"37267819"', 'duced')
# ('"37165749"', 'duced')
# ('"20350935"', 'duced')
# ('"19039992"', 'duced')
# ('"18571468"', 'duced')
# ('"18552369"', 'duced')
# ('"18258738"', 'duced')
# ('"18176524"', 'duced')
# ('"36288966"', 'duced')
# ('"36263189"', 'duced')
# ('"10714658"', 'duced')
# ('"11261511"', 'duced')
# ('"12360559"', 'duced')
# ('"12821514"', 'duced')
# ('"12859412"', 'duced')
# ('"16361107"', 'duced')
# ('"16537570"', 'duced')
# ('"16924015"', 'duced')
# ('"17097111"', 'duced')
# ('"12671990"', 'duced')
# ('"25674472"', 'duced')
# ('"20169475"', 'duced')
# ('"15829632"', 'duced')
# ('"25425325"', 'duced')
# ('"28768697"', 'duced')
# ('"3746330"', 'duced')
# ('"1940944"', 'duced')
# ('"9221523"', 'duced')
# ('"12876228"', 'duced')
# ('"690631"', 'duced')
# ('"7556545"', 'duced')
# ('"7858177"', 'duced')
# ('"8221055"', 'duced')
# ('"2966619"', 'duced')
# ('"7856369"', 'duced')
# ('"6622883"', 'duced')
# ('"6612149"', 'duced')
# ('"482013"', 'duced')
# ('"2840407"', 'duced')
# ('"2164296"', 'duced')
# ('"9399227"', 'duced')
# ('"8894706"', 'duced')
# ('"21840890"', 'duced')
# ('"19353218"', 'duced')
# ('"18688663"', 'duced')
# ('"12074905"', 'duced')
# ('"20301665"', 'duced')
# ('"36029989"', 'duced')
# ('"33468570"', 'duced')
# ('"33753289"', 'duced')
# ('"32239467"', 'duced')
# ('"32516804"', 'duced')
# ('"28768697"', 'duced')
# ('"36329866"', 'duced')
# ('"35955710"', 'duced')
# ('"33757902"', 'duced')
# ('"33894367"', 'duced')
# ('"34119482"', 'duced')
# ('"26183317"', 'duced')
# ('"36263189"', 'duced')
# ('"34398825"', 'duced')
# ('"36757831"', 'duced')
# ('"27716431"', 'duced')
# ('"37165749"', 'duced')
# ('"33445430"', 'duced')
# ('"33799994"', 'duced')
# ('"11714689"', 'localization of cell')
# ('"22391119"', 'naling pathway')
# ('"33991565"', 'naling pathway')
# ('"37627888"', 'naling pathway')
# ('"32289333"', 'naling pathway')
# ('"25379658"', 'naling pathway')
# ('"33425096"', 'naling pathway')
# ('"32289333"', 'naling pathway')
# ('"33991565"', 'naling pathway')
# ('"22132914"', 'esthesia')
# ('"22151759"', 'esthesia')
# ('"20687193"', 'esthesia')
# ('"18176524"', 'esthesia')
# ('"10448655"', 'esthesia')
# ('"16024174"', 'esthesia')
# ('"12151848"', 'oxin')
# ('"20301587"', 'oxin')
# ('"30237473"', 'oxin')
# ('"21496605"', 'oxin')
# ('"15159681"', 'oxin')
# ('"12822816"', 'oxin')
# ('"20301665"', 'oxin')
# ('"24092288"', 'oxin')
# ('"24588501"', 'oxin')
# ('"21750546"', 'oxin')
# ('"20482602"', 'oxin')
# ('"18685824"', 'oxin')
# ('"10714658"', 'oxin')
# ('"17097111"', 'oxin')
# ('"17129379"', 'oxin')
# ('"15829632"', 'oxin')
# ('"9153120"', 'oxin')
# ('"10809944"', 'oxin')
# ('"1623256"', 'oxin')
# ('"11598522"', 'oxin')
# ('"17960812"', 'oxin')
# ('"19765051"', 'oxin')
# ('"7791942"', 'oxin')
# ('"20301665"', 'oxin')
# ('"32037012"', 'oxin')
# ('"31867614"', 'transport')
# ('"34323950"', 'transport')
# ('"15455404"', 'transport')
# ('"33638639"', 'transport')
# ('"34189496"', 'transport')
# ('"33468570"', 'transport')
# ('"27716431"', 'transport')
# ('"20132487"', 'transport')
# ('"17550429"', 'transport')
# ('"34173686"', 'transport')
# ('"34358617"', 'transport')
# ('"36355183"', 'transport')
# ('"30444426"', 'transport')
# ('"23893446"', 'transport')
# ('"15593317"', 'transport')
# ('"17129379"', 'transport')
# ('"15505207"', 'transport')
# ('"15829632"', 'transport')
# ('"33468570"', 'transport')
# ('"34189496"', 'transport')
# ('"34358617"', 'transport')
# ('"27716431"', 'transport')
# ('"33638639"', 'transport')
# ('"8513401"', 't gene')
# ('"10435508"', 't gene')
# ('"12575458"', 't gene')
# ('"10523017"', 't gene')
# ('"30779476"', 't gene')
# ('"32152690"', 't gene')
# ('"25402387"', 't gene')
# ('"33725967"', 't gene')
# ('"21956287"', 't gene')
# ('"19345148"', 't gene')
# ('"11973627"', 't gene')
# ('"17503336"', 't gene')
# ('"34092466"', 't gene')
# ('"10994500"', 't gene')
# ('"11984483"', 't gene')
# ('"15390042"', 't gene')
# ('"19685389"', 't gene')
# ('"12194383"', 't gene')
# ('"11528394"', 't gene')
# ('"34189496"', 't gene')
# ('"33488508"', 't gene')
# ('"12821512"', 't gene')
# ('"25894231"', 't gene')
# ('"22375360"', 't gene')
# ('"20627944"', 't gene')
# ('"18267263"', 't gene')
# ('"31618684"', 't gene')
# ('"27716431"', 't gene')
# ('"23967309"', 't gene')
# ('"23018676"', 't gene')
# ('"22391119"', 't gene')
# ('"21995941"', 't gene')
# ('"21136869"', 't gene')
# ('"20584926"', 't gene')
# ('"15930383"', 't gene')
# ('"36417958"', 't gene')
# ('"31805123"', 't gene')
# ('"33247415"', 't gene')
# ('"34264428"', 't gene')
# ('"27666935"', 't gene')
# ('"25779878"', 't gene')
# ('"33175450"', 't gene')
# ('"37134150"', 't gene')
# ('"8813214"', 't gene')
# ('"9186828"', 't gene')
# ('"3458307"', 't gene')
# ('"34248079"', 't gene')
# ('"15011460"', 't gene')
# ('"19052350"', 't gene')
# ('"20590811"', 't gene')
# ('"945867"', 't gene')
# ('"10979329"', 't gene')
# ('"36648081"', 't gene')
# ('"12609485"', 't gene')
# ('"19157930"', 't gene')
# ('"19284587"', 't gene')
# ('"24588501"', 't gene')
# ('"25203860"', 't gene')
# ('"27477622"', 't gene')
# ('"28432771"', 't gene')
# ('"28756192"', 't gene')
# ('"34949287"', 't gene')
# ('"17713116"', 't gene')
# ('"9874484"', 't gene')
# ('"9667600"', 't gene')
# ('"9585364"', 't gene')
# ('"8232931"', 't gene')
# ('"7654519"', 't gene')
# ('"37352388"', 't gene')
# ('"35022352"', 't gene')
# ('"29483592"', 't gene')
# ('"29396174"', 't gene')
# ('"20687193"', 't gene')
# ('"18685824"', 't gene')
# ('"18224570"', 't gene')
# ('"10448655"', 't gene')
# ('"10477437"', 't gene')
# ('"10627938"', 't gene')
# ('"12360559"', 't gene')
# ('"12760408"', 't gene')
# ('"15895426"', 't gene')
# ('"16631205"', 't gene')
# ('"16924015"', 't gene')
# ('"15283994"', 't gene')
# ('"28768697"', 't gene')
# ('"2183913"', 't gene')
# ('"1940944"', 't gene')
# ('"7858177"', 't gene')
# ('"27477622"', 't gene')
# ('"37352388"', 't gene')
# ('"28432771"', 't gene')
# ('"31618684"', 't gene')
# ('"36417958"', 't gene')
# ('"34092466"', 't gene')
# ('"33247415"', 't gene')
# ('"33175450"', 't gene')
# ('"34189496"', 't gene')
# ('"28768697"', 't gene')
# ('"27716431"', 't gene')
# ('"28756192"', 't gene')
# ('"34728955"', 't gene')
# ('"20471632"', 'immune response')
# ('"16639700"', 'immune response')
# ('"22572887"', 'immune response')
# ('"9039166"', 'immune response')
# ('"33472447"', 'immune response')
# ('"32118025"', 'immune response')
# ('"19355902"', 'immune response')
# ('"30981209"', 'immune response')
# ('"3458307"', 'immune response')
# ('"36045526"', 'immune response')
# ('"10198739"', 'immune response')
# ('"18519462"', 'immune response')
# ('"24265781"', 'immune response')
# ('"20301587"', 'ty disorder')
# ('"23365103"', 'ty disorder')
# ('"33724724"', 'ty disorder')
# ('"796956"', 's nos')
# ('"10814722"', 'ulfide')
# ('"12671990"', 'ulfide')
# ('"28768697"', 'ulfide')
# ('"34062155"', 'ulfide')
# ('"28768697"', 'ulfide')
# ('"34062155"', 'ulfide')
# ('"16934985"', 'membrane depolarization')
# ('"18267263"', 'response to stress')
# ('"19555827"', 'response to stress')
# ('"12671990"', 'response to stress')
# ('"1347197"', 'osis')
# ('"7911621"', 'osis')
# ('"10674821"', 'osis')
# ('"10737119"', 'osis')
# ('"9778264"', 'osis')
# ('"9779659"', 'osis')
# ('"1639411"', 'osis')
# ('"6683367"', 'osis')
# ('"9146024"', 'osis')
# ('"12785748"', 'osis')
# ('"11912106"', 'osis')
# ('"28943611"', 'osis')
# ('"10583169"', 'osis')
# ('"20471632"', 'osis')
# ('"29418012"', 'osis')
# ('"17190764"', 'osis')
# ('"19593686"', 'osis')
# ('"31244841"', 'osis')
# ('"30779476"', 'osis')
# ('"26060104"', 'osis')
# ('"24444577"', 'osis')
# ('"22572887"', 'osis')
# ('"21397152"', 'osis')
# ('"15137480"', 'osis')
# ('"19244266"', 'osis')
# ('"19688081"', 'osis')
# ('"31867614"', 'osis')
# ('"16967287"', 'osis')
# ('"30561390"', 'osis')
# ('"25925917"', 'osis')
# ('"25402387"', 'osis')
# ('"24198965"', 'osis')
# ('"33239013"', 'osis')
# ('"20499382"', 'osis')
# ('"26001889"', 'osis')
# ('"33725967"', 'osis')
# ('"30528262"', 'osis')
# ('"16706073"', 'osis')
# ('"30302434"', 'osis')
# ('"11232488"', 'osis')
# ('"32044834"', 'osis')
# ('"19345148"', 'osis')
# ('"18823044"', 'osis')
# ('"16415980"', 'osis')
# ('"11984483"', 'osis')
# ('"23420606"', 'osis')
# ('"24311730"', 'osis')
# ('"30244176"', 'osis')
# ('"33488508"', 'osis')
# ('"1427899"', 'osis')
# ('"14989804"', 'osis')
# ('"12691403"', 'osis')
# ('"19349605"', 'osis')
# ('"24949445"', 'osis')
# ('"12652041"', 'osis')
# ('"20301587"', 'osis')
# ('"24978640"', 'osis')
# ('"22375360"', 'osis')
# ('"14628853"', 'osis')
# ('"23967309"', 'osis')
# ('"21136869"', 'osis')
# ('"30237473"', 'osis')
# ('"34298581"', 'osis')
# ('"25347348"', 'osis')
# ('"27666935"', 'osis')
# ('"25779878"', 'osis')
# ('"25449075"', 'osis')
# ('"28516161"', 'osis')
# ('"29053766"', 'osis')
# ('"11940688"', 'osis')
# ('"30981209"', 'osis')
# ('"8525475"', 'osis')
# ('"37627888"', 'osis')
# ('"37554750"', 'osis')
# ('"35182386"', 'osis')
# ('"34655204"', 'osis')
# ('"34476293"', 'osis')
# ('"34248079"', 'osis')
# ('"36355183"', 'osis')
# ('"36415137"', 'osis')
# ('"36468571"', 'osis')
# ('"36096955"', 'osis')
# ('"35839368"', 'osis')
# ('"35611878"', 'osis')
# ('"10198739"', 'osis')
# ('"10611103"', 'osis')
# ('"12092455"', 'osis')
# ('"12169991"', 'osis')
# ('"17706474"', 'osis')
# ('"18519462"', 'osis')
# ('"18689116"', 'osis')
# ('"19041429"', 'osis')
# ('"20178968"', 'osis')
# ('"20359791"', 'osis')
# ('"21412422"', 'osis')
# ('"21621928"', 'osis')
# ('"23066327"', 'osis')
# ('"24265781"', 'osis')
# ('"28708086"', 'osis')
# ('"30444426"', 'osis')
# ('"20590811"', 'osis')
# ('"10437291"', 'osis')
# ('"945867"', 'osis')
# ('"3362365"', 'osis')
# ('"17385355"', 'osis')
# ('"37607452"', 'osis')
# ('"36757831"', 'osis')
# ('"36648081"', 'osis')
# ('"36445406"', 'osis')
# ('"20301665"', 'osis')
# ('"22639460"', 'osis')
# ('"22897341"', 'osis')
# ('"24757586"', 'osis')
# ('"35041927"', 'osis')
# ('"35303767"', 'osis')
# ('"17713116"', 'osis')
# ('"8244374"', 'osis')
# ('"29396174"', 'osis')
# ('"23724359"', 'osis')
# ('"21750546"', 'osis')
# ('"21496603"', 'osis')
# ('"20482602"', 'osis')
# ('"19844939"', 'osis')
# ('"19555827"', 'osis')
# ('"19039992"', 'osis')
# ('"10714658"', 'osis')
# ('"11014135"', 'osis')
# ('"12883919"', 'osis')
# ('"15342362"', 'osis')
# ('"15593317"', 'osis')
# ('"16924015"', 'osis')
# ('"33425096"', 'osis')
# ('"36409706"', 'osis')
# ('"28768697"', 'osis')
# ('"7205314"', 'osis')
# ('"12030016"', 'osis')
# ('"9221523"', 'osis')
# ('"8703227"', 'osis')
# ('"11701630"', 'osis')
# ('"17125732"', 'osis')
# ('"1992364"', 'osis')
# ('"7133334"', 'osis')
# ('"2245082"', 'osis')
# ('"11598522"', 'osis')
# ('"941769"', 'osis')
# ('"482013"', 'osis')
# ('"3178457"', 'osis')
# ('"2977281"', 'osis')
# ('"9399227"', 'osis')
# ('"484133"', 'osis')
# ('"22166421"', 'osis')
# ('"20301665"', 'osis')
# ('"35303767"', 'osis')
# ('"20301334"', 'osis')
# ('"29053766"', 'osis')
# ('"30244176"', 'osis')
# ('"28768697"', 'osis')
# ('"24311730"', 'osis')
# ('"36757831"', 'osis')
# ('"24757586"', 'osis')
# ('"32102149"', 'osis')
# ('"8432555"', 'gene')
# ('"2317008"', 'gene')
# ('"1867195"', 'gene')
# ('"6694180"', 'gene')
# ('"2203908"', 'gene')
# ('"8079990"', 'gene')
# ('"941766"', 'gene')
# ('"1121020"', 'gene')
# ('"2817837"', 'gene')
# ('"2309703"', 'gene')
# ('"1347197"', 'gene')
# ('"8513401"', 'gene')
# ('"7719342"', 'gene')
# ('"7979224"', 'gene')
# ('"10435508"', 'gene')
# ('"10674821"', 'gene')
# ('"17142829"', 'gene')
# ('"1985454"', 'gene')
# ('"1449240"', 'gene')
# ('"10737119"', 'gene')
# ('"9120448"', 'gene')
# ('"9778264"', 'gene')
# ('"9779659"', 'gene')
# ('"15897512"', 'gene')
# ('"12575458"', 'gene')
# ('"1639411"', 'gene')
# ('"2666583"', 'gene')
# ('"1677923"', 'gene')
# ('"9266460"', 'gene')
# ('"12785748"', 'gene')
# ('"11912106"', 'gene')
# ('"8277574"', 'gene')
# ('"28943611"', 'gene')
# ('"10523017"', 'gene')
# ('"34167694"', 'gene')
# ('"33885207"', 'gene')
# ('"16639700"', 'gene')
# ('"26234084"', 'gene')
# ('"12566288"', 'gene')
# ('"29418012"', 'gene')
# ('"16456406"', 'gene')
# ('"18279642"', 'gene')
# ('"19593686"', 'gene')
# ('"19834793"', 'gene')
# ('"23032422"', 'gene')
# ('"28387648"', 'gene')
# ('"31244841"', 'gene')
# ('"30779476"', 'gene')
# ('"24444577"', 'gene')
# ('"22572887"', 'gene')
# ('"21929335"', 'gene')
# ('"15137480"', 'gene')
# ('"12477369"', 'gene')
# ('"11302971"', 'gene')
# ('"11121131"', 'gene')
# ('"19244266"', 'gene')
# ('"31867614"', 'gene')
# ('"32152690"', 'gene')
# ('"30561390"', 'gene')
# ('"25925917"', 'gene')
# ('"25402387"', 'gene')
# ('"33239013"', 'gene')
# ('"32370566"', 'gene')
# ('"20499382"', 'gene')
# ('"9039166"', 'gene')
# ('"33725967"', 'gene')
# ('"33472447"', 'gene')
# ('"33335872"', 'gene')
# ('"32118025"', 'gene')
# ('"30528262"', 'gene')
# ('"29561984"', 'gene')
# ('"23609110"', 'gene')
# ('"19355902"', 'gene')
# ('"16706073"', 'gene')
# ('"32359820"', 'gene')
# ('"8365724"', 'gene')
# ('"11232488"', 'gene')
# ('"32044834"', 'gene')
# ('"32186581"', 'gene')
# ('"30141790"', 'gene')
# ('"12402271"', 'gene')
# ('"34380890"', 'gene')
# ('"10541594"', 'gene')
# ('"16682692"', 'gene')
# ('"10449567"', 'gene')
# ('"21956287"', 'gene')
# ('"19345148"', 'gene')
# ('"19345147"', 'gene')
# ('"20211909"', 'gene')
# ('"8004804"', 'gene')
# ('"8684386"', 'gene')
# ('"9288096"', 'gene')
# ('"9149944"', 'gene')
# ('"10738516"', 'gene')
# ('"11523564"', 'gene')
# ('"11973627"', 'gene')
# ('"12473770"', 'gene')
# ('"12838525"', 'gene')
# ('"15111678"', 'gene')
# ('"12975293"', 'gene')
# ('"15293281"', 'gene')
# ('"15326234"', 'gene')
# ('"15455404"', 'gene')
# ('"15548549"', 'gene')
# ('"17027035"', 'gene')
# ('"17503336"', 'gene')
# ('"18477710"', 'gene')
# ('"18823044"', 'gene')
# ('"19528516"', 'gene')
# ('"19955557"', 'gene')
# ('"16415980"', 'gene')
# ('"22132914"', 'gene')
# ('"27939583"', 'gene')
# ('"27919237"', 'gene')
# ('"30879706"', 'gene')
# ('"33476878"', 'gene')
# ('"33757902"', 'gene')
# ('"33706202"', 'gene')
# ('"34038798"', 'gene')
# ('"34092466"', 'gene')
# ('"34119482"', 'gene')
# ('"34438319"', 'gene')
# ('"12325076"', 'gene')
# ('"10073176"', 'gene')
# ('"10994500"', 'gene')
# ('"11984483"', 'gene')
# ('"24262166"', 'gene')
# ('"25192508"', 'gene')
# ('"8255463"', 'gene')
# ('"15390042"', 'gene')
# ('"19685389"', 'gene')
# ('"21847143"', 'gene')
# ('"24311730"', 'gene')
# ('"22266882"', 'gene')
# ('"16541453"', 'gene')
# ('"33395620"', 'gene')
# ('"12194383"', 'gene')
# ('"10919137"', 'gene')
# ('"11528394"', 'gene')
# ('"12391355"', 'gene')
# ('"12151848"', 'gene')
# ('"30244176"', 'gene')
# ('"34189496"', 'gene')
# ('"33476687"', 'gene')
# ('"33488508"', 'gene')
# ('"1427899"', 'gene')
# ('"16275837"', 'gene')
# ('"14989804"', 'gene')
# ('"12691403"', 'gene')
# ('"12821512"', 'gene')
# ('"33468570"', 'gene')
# ('"17702041"', 'gene')
# ('"19349605"', 'gene')
# ('"26087139"', 'gene')
# ('"17061185"', 'gene')
# ('"22151759"', 'gene')
# ('"14502672"', 'gene')
# ('"24949445"', 'gene')
# ('"21839475"', 'gene')
# ('"15505159"', 'gene')
# ('"12652041"', 'gene')
# ('"9837831"', 'gene')
# ('"20301587"', 'gene')
# ('"28102337"', 'gene')
# ('"26790671"', 'gene')
# ('"25894231"', 'gene')
# ('"24978640"', 'gene')
# ('"25209853"', 'gene')
# ('"23622412"', 'gene')
# ('"23284065"', 'gene')
# ('"22166420"', 'gene')
# ('"22345219"', 'gene')
# ('"22375360"', 'gene')
# ('"21496608"', 'gene')
# ('"20627944"', 'gene')
# ('"20841370"', 'gene')
# ('"19117362"', 'gene')
# ('"18265016"', 'gene')
# ('"19066193"', 'gene')
# ('"18267263"', 'gene')
# ('"16227522"', 'gene')
# ('"15390016"', 'gene')
# ('"14872019"', 'gene')
# ('"15258227"', 'gene')
# ('"14628853"', 'gene')
# ('"12761637"', 'gene')
# ('"31618684"', 'gene')
# ('"27716431"', 'gene')
# ('"24508913"', 'gene')
# ('"23967309"', 'gene')
# ('"23018676"', 'gene')
# ('"22391119"', 'gene')
# ('"21995941"', 'gene')
# ('"21136869"', 'gene')
# ('"21078339"', 'gene')
# ('"20584926"', 'gene')
# ('"20223934"', 'gene')
# ('"20132487"', 'gene')
# ('"18299128"', 'gene')
# ('"17956903"', 'gene')
# ('"17550429"', 'gene')
# ('"16934985"', 'gene')
# ('"16458269"', 'gene')
# ('"15930383"', 'gene')
# ('"11730696"', 'gene')
# ('"10814722"', 'gene')
# ('"36417958"', 'gene')
# ('"35955710"', 'gene')
# ('"36546658"', 'gene')
# ('"31805123"', 'gene')
# ('"31320448"', 'gene')
# ('"26183317"', 'gene')
# ('"24951854"', 'gene')
# ('"23840813"', 'gene')
# ('"20460154"', 'gene')
# ('"30237473"', 'gene')
# ('"33247415"', 'gene')
# ('"32516804"', 'gene')
# ('"29739751"', 'gene')
# ('"31580306"', 'gene')
# ('"34298581"', 'gene')
# ('"32079672"', 'gene')
# ('"24938147"', 'gene')
# ('"34264428"', 'gene')
# ('"25347348"', 'gene')
# ('"33753289"', 'gene')
# ('"27666935"', 'gene')
# ('"33502045"', 'gene')
# ('"25779878"', 'gene')
# ('"23365103"', 'gene')
# ('"33740122"', 'gene')
# ('"30643666"', 'gene')
# ('"25449075"', 'gene')
# ('"18322712"', 'gene')
# ('"21322026"', 'gene')
# ('"22722545"', 'gene')
# ('"32239467"', 'gene')
# ('"33175450"', 'gene')
# ('"33832800"', 'gene')
# ('"33134321"', 'gene')
# ('"17200151"', 'gene')
# ('"11940688"', 'gene')
# ('"25461922"', 'gene')
# ('"37134150"', 'gene')
# ('"36329866"', 'gene')
# ('"15489956"', 'gene')
# ('"33991565"', 'gene')
# ('"34398157"', 'gene')
# ('"33458877"', 'gene')
# ('"33529159"', 'gene')
# ('"33894367"', 'gene')
# ('"27911022"', 'gene')
# ('"8813214"', 'gene')
# ('"22040906"', 'gene')
# ('"22080833"', 'gene')
# ('"29325615"', 'gene')
# ('"34358617"', 'gene')
# ('"30981209"', 'gene')
# ('"9186828"', 'gene')
# ('"8858285"', 'gene')
# ('"8525475"', 'gene')
# ('"8245782"', 'gene')
# ('"7875491"', 'gene')
# ('"7783076"', 'gene')
# ('"7490916"', 'gene')
# ('"37627888"', 'gene')
# ('"37554750"', 'gene')
# ('"35182386"', 'gene')
# ('"3458307"', 'gene')
# ('"34248079"', 'gene')
# ('"32777581"', 'gene')
# ('"3262691"', 'gene')
# ('"31057009"', 'gene')
# ('"36355183"', 'gene')
# ('"35694992"', 'gene')
# ('"36045526"', 'gene')
# ('"36468571"', 'gene')
# ('"36096955"', 'gene')
# ('"35839368"', 'gene')
# ('"35611878"', 'gene')
# ('"10028024"', 'gene')
# ('"10611103"', 'gene')
# ('"10644435"', 'gene')
# ('"11495087"', 'gene')
# ('"12092455"', 'gene')
# ('"12169991"', 'gene')
# ('"14517787"', 'gene')
# ('"15011460"', 'gene')
# ('"15793882"', 'gene')
# ('"1626073"', 'gene')
# ('"16981842"', 'gene')
# ('"18689116"', 'gene')
# ('"19052350"', 'gene')
# ('"19208776"', 'gene')
# ('"19251712"', 'gene')
# ('"20178968"', 'gene')
# ('"20359791"', 'gene')
# ('"20661732"', 'gene')
# ('"21412422"', 'gene')
# ('"21621928"', 'gene')
# ('"22465228"', 'gene')
# ('"23066327"', 'gene')
# ('"28182308"', 'gene')
# ('"28708086"', 'gene')
# ('"29516402"', 'gene')
# ('"21496605"', 'gene')
# ('"20590811"', 'gene')
# ('"19182804"', 'gene')
# ('"21656045"', 'gene')
# ('"17702011"', 'gene')
# ('"2368812"', 'gene')
# ('"2404852"', 'gene')
# ('"21907099"', 'gene')
# ('"6050693"', 'gene')
# ('"10437291"', 'gene')
# ('"945867"', 'gene')
# ('"2426591"', 'gene')
# ('"9146025"', 'gene')
# ('"26417535"', 'gene')
# ('"17385355"', 'gene')
# ('"12822816"', 'gene')
# ('"10979329"', 'gene')
# ('"37607452"', 'gene')
# ('"36757831"', 'gene')
# ('"36648081"', 'gene')
# ('"36445406"', 'gene')
# ('"35533513"', 'gene')
# ('"12609485"', 'gene')
# ('"15939081"', 'gene')
# ('"16938275"', 'gene')
# ('"17290457"', 'gene')
# ('"19038309"', 'gene')
# ('"19157930"', 'gene')
# ('"19284587"', 'gene')
# ('"19578124"', 'gene')
# ('"20301665"', 'gene')
# ('"22639460"', 'gene')
# ('"22897341"', 'gene')
# ('"23180184"', 'gene')
# ('"23196519"', 'gene')
# ('"23222958"', 'gene')
# ('"23893446"', 'gene')
# ('"24092288"', 'gene')
# ('"24588501"', 'gene')
# ('"24757586"', 'gene')
# ('"24931141"', 'gene')
# ('"24976531"', 'gene')
# ('"25155315"', 'gene')
# ('"25203860"', 'gene')
# ('"25403864"', 'gene')
# ('"26004199"', 'gene')
# ('"26297380"', 'gene')
# ('"26940431"', 'gene')
# ('"27143436"', 'gene')
# ('"27477622"', 'gene')
# ('"28283962"', 'gene')
# ('"28432771"', 'gene')
# ('"28756192"', 'gene')
# ('"29396398"', 'gene')
# ('"30100364"', 'gene')
# ('"30838317"', 'gene')
# ('"32502938"', 'gene')
# ('"32662044"', 'gene')
# ('"34949287"', 'gene')
# ('"35041927"', 'gene')
# ('"35044558"', 'gene')
# ('"35303767"', 'gene')
# ('"17713116"', 'gene')
# ('"9874484"', 'gene')
# ('"9749609"', 'gene')
# ('"9749595"', 'gene')
# ('"9667600"', 'gene')
# ('"9618171"', 'gene')
# ('"9585364"', 'gene')
# ('"9191768"', 'gene')
# ('"8871591"', 'gene')
# ('"8309575"', 'gene')
# ('"8244374"', 'gene')
# ('"8232931"', 'gene')
# ('"7845403"', 'gene')
# ('"7654519"', 'gene')
# ('"7629534"', 'gene')
# ('"37352388"', 'gene')
# ('"37165749"', 'gene')
# ('"35022352"', 'gene')
# ('"32289333"', 'gene')
# ('"29483592"', 'gene')
# ('"29396174"', 'gene')
# ('"27093447"', 'gene')
# ('"26596547"', 'gene')
# ('"26592310"', 'gene')
# ('"25653290"', 'gene')
# ('"25337725"', 'gene')
# ('"23814535"', 'gene')
# ('"23724359"', 'gene')
# ('"23436503"', 'gene')
# ('"22770546"', 'gene')
# ('"22622408"', 'gene')
# ('"21800139"', 'gene')
# ('"21496603"', 'gene')
# ('"21301909"', 'gene')
# ('"20687193"', 'gene')
# ('"20482602"', 'gene')
# ('"20350935"', 'gene')
# ('"20066431"', 'gene')
# ('"19890997"', 'gene')
# ('"19844939"', 'gene')
# ('"19555827"', 'gene')
# ('"19457118"', 'gene')
# ('"19403250"', 'gene')
# ('"19260107"', 'gene')
# ('"19039992"', 'gene')
# ('"18685824"', 'gene')
# ('"18571468"', 'gene')
# ('"18552369"', 'gene')
# ('"18437909"', 'gene')
# ('"18299520"', 'gene')
# ('"18224570"', 'gene')
# ('"18176524"', 'gene')
# ('"36288966"', 'gene')
# ('"36302970"', 'gene')
# ('"36263189"', 'gene')
# ('"35563018"', 'gene')
# ('"10050893"', 'gene')
# ('"10225357"', 'gene')
# ('"10448655"', 'gene')
# ('"10477437"', 'gene')
# ('"10627938"', 'gene')
# ('"10714658"', 'gene')
# ('"10871631"', 'gene')
# ('"10881900"', 'gene')
# ('"10984667"', 'gene')
# ('"11009204"', 'gene')
# ('"11014135"', 'gene')
# ('"11104212"', 'gene')
# ('"11261511"', 'gene')
# ('"11921134"', 'gene')
# ('"11980065"', 'gene')
# ('"12360559"', 'gene')
# ('"12760408"', 'gene')
# ('"12821514"', 'gene')
# ('"12859412"', 'gene')
# ('"12883919"', 'gene')
# ('"12900733"', 'gene')
# ('"14581671"', 'gene')
# ('"15342362"', 'gene')
# ('"15555920"', 'gene')
# ('"15593317"', 'gene')
# ('"15726581"', 'gene')
# ('"15895426"', 'gene')
# ('"16361107"', 'gene')
# ('"16537570"', 'gene')
# ('"16631205"', 'gene')
# ('"16773641"', 'gene')
# ('"16924015"', 'gene')
# ('"17129379"', 'gene')
# ('"22472189"', 'gene')
# ('"15283994"', 'gene')
# ('"12671990"', 'gene')
# ('"12007841"', 'gene')
# ('"33425096"', 'gene')
# ('"11405807"', 'gene')
# ('"35796490"', 'gene')
# ('"36409706"', 'gene')
# ('"25674472"', 'gene')
# ('"15136718"', 'gene')
# ('"9750906"', 'gene')
# ('"11584049"', 'gene')
# ('"15989773"', 'gene')
# ('"15099679"', 'gene')
# ('"15147511"', 'gene')
# ('"15829632"', 'gene')
# ('"19761814"', 'gene')
# ('"20639502"', 'gene')
# ('"24627482"', 'gene')
# ('"28768697"', 'gene')
# ('"35643882"', 'gene')
# ('"32248052"', 'gene')
# ('"34062155"', 'gene')
# ('"9539346"', 'gene')
# ('"9380054"', 'gene')
# ('"8723633"', 'gene')
# ('"8413963"', 'gene')
# ('"8341297"', 'gene')
# ('"7969702"', 'gene')
# ('"7753056"', 'gene')
# ('"3574676"', 'gene')
# ('"2322135"', 'gene')
# ('"2215959"', 'gene')
# ('"2183913"', 'gene')
# ('"1940944"', 'gene')
# ('"1758449"', 'gene')
# ('"1756758"', 'gene')
# ('"9440801"', 'gene')
# ('"9335011"', 'gene')
# ('"9221523"', 'gene')
# ('"8723145"', 'gene')
# ('"10349117"', 'gene')
# ('"10526391"', 'gene')
# ('"10877155"', 'gene')
# ('"10980732"', 'gene')
# ('"11701630"', 'gene')
# ('"12876228"', 'gene')
# ('"16024174"', 'gene')
# ('"1623256"', 'gene')
# ('"17125732"', 'gene')
# ('"18591071"', 'gene')
# ('"2073302"', 'gene')
# ('"2356013"', 'gene')
# ('"3948889"', 'gene')
# ('"626228"', 'gene')
# ('"7325607"', 'gene')
# ('"7507398"', 'gene')
# ('"7858177"', 'gene')
# ('"8221055"', 'gene')
# ('"2245082"', 'gene')
# ('"941769"', 'gene')
# ('"8416347"', 'gene')
# ('"6443743"', 'gene')
# ('"556814"', 'gene')
# ('"3724992"', 'gene')
# ('"2868026"', 'gene')
# ('"2840407"', 'gene')
# ('"10527098"', 'gene')
# ('"9399227"', 'gene')
# ('"8894706"', 'gene')
# ('"24486689"', 'gene')
# ('"21840890"', 'gene')
# ('"19353218"', 'gene')
# ('"10833562"', 'gene')
# ('"27448549"', 'gene')
# ('"18688663"', 'gene')
# ('"11714689"', 'gene')
# ('"31332180"', 'gene')
# ('"19765051"', 'gene')
# ('"12074905"', 'gene')
# ('"6240313"', 'gene')
# ('"7791942"', 'gene')
# ('"38214203"', 'gene')
# ('"24976531"', 'gene')
# ('"27477622"', 'gene')
# ('"32662044"', 'gene')
# ('"37352388"', 'gene')
# ('"26297380"', 'gene')
# ('"32502938"', 'gene')
# ('"24931141"', 'gene')
# ('"20301665"', 'gene')
# ('"28432771"', 'gene')
# ('"35303767"', 'gene')
# ('"31618684"', 'gene')
# ('"36417958"', 'gene')
# ('"33476878"', 'gene')
# ('"34092466"', 'gene')
# ('"33468570"', 'gene')
# ('"33753289"', 'gene')
# ('"29325615"', 'gene')
# ('"32239467"', 'gene')
# ('"32516804"', 'gene')
# ('"33247415"', 'gene')
# ('"33175450"', 'gene')
# ('"33502045"', 'gene')
# ('"34189496"', 'gene')
# ('"20301334"', 'gene')
# ('"30244176"', 'gene')
# ('"24627482"', 'gene')
# ('"26592310"', 'gene')
# ('"28768697"', 'gene')
# ('"35563018"', 'gene')
# ('"36329866"', 'gene')
# ('"36426380"', 'gene')
# ('"35955710"', 'gene')
# ('"33134321"', 'gene')
# ('"33757902"', 'gene')
# ('"33894367"', 'gene')
# ('"34062155"', 'gene')
# ('"34119482"', 'gene')
# ('"24311730"', 'gene')
# ('"27911022"', 'gene')
# ('"33229589"', 'gene')
# ('"29739751"', 'gene')
# ('"34358617"', 'gene')
# ('"27567612"', 'gene')
# ('"26183317"', 'gene')
# ('"36263189"', 'gene')
# ('"36757831"', 'gene')
# ('"24757586"', 'gene')
# ('"27716431"', 'gene')
# ('"30838317"', 'gene')
# ('"32289333"', 'gene')
# ('"37165749"', 'gene')
# ('"28756192"', 'gene')
# ('"33991565"', 'gene')
# ('"33395620"', 'gene')
# ('"26790671"', 'gene')
# ('"32102149"', 'gene')
# ('"32037012"', 'gene')
# ('"26596547"', 'gene')
# ('"34728955"', 'gene')
# ('"20661732"', 'inflammatory response')
# ('"8353711"', 'burn')
# ('"8432555"', 'onia')
# ('"2317008"', 'onia')
# ('"1867195"', 'onia')
# ('"6694180"', 'onia')
# ('"13297089"', 'onia')
# ('"941771"', 'onia')
# ('"2203908"', 'onia')
# ('"8079990"', 'onia')
# ('"9382482"', 'onia')
# ('"941766"', 'onia')
# ('"7436383"', 'onia')
# ('"8916165"', 'onia')
# ('"1121020"', 'onia')
# ('"2817837"', 'onia')
# ('"2309703"', 'onia')
# ('"1347197"', 'onia')
# ('"8513401"', 'onia')
# ('"7719342"', 'onia')
# ('"7979224"', 'onia')
# ('"10435508"', 'onia')
# ('"15668438"', 'onia')
# ('"7911621"', 'onia')
# ('"10674821"', 'onia')
# ('"17142829"', 'onia')
# ('"1985454"', 'onia')
# ('"1449240"', 'onia')
# ('"10737119"', 'onia')
# ('"9120448"', 'onia')
# ('"9778264"', 'onia')
# ('"9779659"', 'onia')
# ('"15897512"', 'onia')
# ('"12575458"', 'onia')
# ('"1639411"', 'onia')
# ('"6683367"', 'onia')
# ('"2666583"', 'onia')
# ('"1677923"', 'onia')
# ('"9266460"', 'onia')
# ('"15954126"', 'onia')
# ('"20672922"', 'onia')
# ('"9146024"', 'onia')
# ('"12785748"', 'onia')
# ('"11912106"', 'onia')
# ('"8277574"', 'onia')
# ('"12402271"', 'onia')
# ('"34380890"', 'onia')
# ('"10541594"', 'onia')
# ('"27672781"', 'onia')
# ('"34323950"', 'onia')
# ('"18519876"', 'onia')
# ('"10449567"', 'onia')
# ('"21956287"', 'onia')
# ('"19345148"', 'onia')
# ('"19345147"', 'onia')
# ('"20211909"', 'onia')
# ('"8004804"', 'onia')
# ('"8684386"', 'onia')
# ('"9288096"', 'onia')
# ('"9149944"', 'onia')
# ('"10738516"', 'onia')
# ('"11523564"', 'onia')
# ('"11973627"', 'onia')
# ('"12473770"', 'onia')
# ('"12838525"', 'onia')
# ('"15111678"', 'onia')
# ('"12975293"', 'onia')
# ('"15293281"', 'onia')
# ('"15326234"', 'onia')
# ('"15455404"', 'onia')
# ('"15548549"', 'onia')
# ('"17027035"', 'onia')
# ('"17503336"', 'onia')
# ('"18477710"', 'onia')
# ('"18823044"', 'onia')
# ('"19528516"', 'onia')
# ('"19955557"', 'onia')
# ('"16415980"', 'onia')
# ('"22132914"', 'onia')
# ('"27939583"', 'onia')
# ('"27919237"', 'onia')
# ('"30879706"', 'onia')
# ('"31604331"', 'onia')
# ('"33476878"', 'onia')
# ('"33757902"', 'onia')
# ('"33616084"', 'onia')
# ('"33706202"', 'onia')
# ('"33638639"', 'onia')
# ('"34038798"', 'onia')
# ('"34092466"', 'onia')
# ('"34119482"', 'onia')
# ('"34438319"', 'onia')
# ('"12325076"', 'onia')
# ('"10073176"', 'onia')
# ('"10994500"', 'onia')
# ('"11984483"', 'onia')
# ('"23420606"', 'onia')
# ('"24262166"', 'onia')
# ('"25192508"', 'onia')
# ('"8255463"', 'onia')
# ('"15390042"', 'onia')
# ('"19685389"', 'onia')
# ('"21847143"', 'onia')
# ('"28843013"', 'onia')
# ('"24311730"', 'onia')
# ('"22266882"', 'onia')
# ('"16541453"', 'onia')
# ('"33395620"', 'onia')
# ('"12194383"', 'onia')
# ('"10919137"', 'onia')
# ('"11528394"', 'onia')
# ('"12391355"', 'onia')
# ('"12151848"', 'onia')
# ('"30244176"', 'onia')
# ('"34408078"', 'onia')
# ('"34189496"', 'onia')
# ('"33476687"', 'onia')
# ('"33488508"', 'onia')
# ('"1427899"', 'onia')
# ('"16275837"', 'onia')
# ('"14989804"', 'onia')
# ('"12691403"', 'onia')
# ('"12821512"', 'onia')
# ('"33468570"', 'onia')
# ('"17702041"', 'onia')
# ('"19349605"', 'onia')
# ('"15954129"', 'onia')
# ('"26087139"', 'onia')
# ('"17061185"', 'onia')
# ('"22151759"', 'onia')
# ('"14502672"', 'onia')
# ('"24949445"', 'onia')
# ('"21839475"', 'onia')
# ('"15505159"', 'onia')
# ('"12652041"', 'onia')
# ('"9837831"', 'onia')
# ('"20301587"', 'onia')
# ('"30028274"', 'onia')
# ('"28102337"', 'onia')
# ('"26790671"', 'onia')
# ('"25894231"', 'onia')
# ('"24978640"', 'onia')
# ('"25209853"', 'onia')
# ('"23622412"', 'onia')
# ('"23284065"', 'onia')
# ('"22166420"', 'onia')
# ('"22345219"', 'onia')
# ('"22375360"', 'onia')
# ('"21496608"', 'onia')
# ('"20627944"', 'onia')
# ('"20841370"', 'onia')
# ('"19117362"', 'onia')
# ('"18265016"', 'onia')
# ('"19066193"', 'onia')
# ('"18267263"', 'onia')
# ('"16227522"', 'onia')
# ('"15390016"', 'onia')
# ('"14872019"', 'onia')
# ('"15258227"', 'onia')
# ('"14628853"', 'onia')
# ('"12761637"', 'onia')
# ('"12781594"', 'onia')
# ('"31618684"', 'onia')
# ('"27716431"', 'onia')
# ('"23967309"', 'onia')
# ('"23018676"', 'onia')
# ('"22391119"', 'onia')
# ('"21995941"', 'onia')
# ('"21136869"', 'onia')
# ('"21078339"', 'onia')
# ('"20584926"', 'onia')
# ('"20223934"', 'onia')
# ('"20132487"', 'onia')
# ('"18827015"', 'onia')
# ('"18299128"', 'onia')
# ('"17956903"', 'onia')
# ('"17550429"', 'onia')
# ('"17428918"', 'onia')
# ('"16934985"', 'onia')
# ('"16458269"', 'onia')
# ('"16364891"', 'onia')
# ('"15930383"', 'onia')
# ('"11730696"', 'onia')
# ('"10814722"', 'onia')
# ('"36417958"', 'onia')
# ('"35955710"', 'onia')
# ('"36546658"', 'onia')
# ('"31805123"', 'onia')
# ('"31320448"', 'onia')
# ('"26183317"', 'onia')
# ('"24951854"', 'onia')
# ('"23840813"', 'onia')
# ('"20460154"', 'onia')
# ('"30237473"', 'onia')
# ('"33247415"', 'onia')
# ('"32516804"', 'onia')
# ('"29739751"', 'onia')
# ('"31580306"', 'onia')
# ('"32079672"', 'onia')
# ('"24938147"', 'onia')
# ('"34264428"', 'onia')
# ('"25347348"', 'onia')
# ('"33753289"', 'onia')
# ('"27666935"', 'onia')
# ('"33502045"', 'onia')
# ('"23365103"', 'onia')
# ('"33740122"', 'onia')
# ('"30643666"', 'onia')
# ('"25449075"', 'onia')
# ('"18322712"', 'onia')
# ('"21322026"', 'onia')
# ('"22722545"', 'onia')
# ('"31321303"', 'onia')
# ('"31517057"', 'onia')
# ('"32239467"', 'onia')
# ('"33175450"', 'onia')
# ('"33832800"', 'onia')
# ('"29053766"', 'onia')
# ('"33134321"', 'onia')
# ('"17200151"', 'onia')
# ('"25461922"', 'onia')
# ('"37134150"', 'onia')
# ('"36329866"', 'onia')
# ('"33991565"', 'onia')
# ('"34398157"', 'onia')
# ('"33458877"', 'onia')
# ('"33529159"', 'onia')
# ('"33445430"', 'onia')
# ('"33799994"', 'onia')
# ('"33894367"', 'onia')
# ('"34173686"', 'onia')
# ('"34398825"', 'onia')
# ('"27911022"', 'onia')
# ('"8813214"', 'onia')
# ('"22040906"', 'onia')
# ('"22080833"', 'onia')
# ('"29325615"', 'onia')
# ('"34358617"', 'onia')
# ('"10644435"', 'onia')
# ('"12092455"', 'onia')
# ('"33724724"', 'onia')
# ('"21496605"', 'onia')
# ('"20590811"', 'onia')
# ('"27171035"', 'onia')
# ('"15477576"', 'onia')
# ('"15786454"', 'onia')
# ('"15159681"', 'onia')
# ('"19182804"', 'onia')
# ('"21656045"', 'onia')
# ('"17702011"', 'onia')
# ('"2368812"', 'onia')
# ('"2404852"', 'onia')
# ('"21907099"', 'onia')
# ('"14957878"', 'onia')
# ('"6050693"', 'onia')
# ('"12978961"', 'onia')
# ('"14022841"', 'onia')
# ('"13605317"', 'onia')
# ('"13739435"', 'onia')
# ('"20344681"', 'onia')
# ('"13697597"', 'onia')
# ('"14779577"', 'onia')
# ('"14450922"', 'onia')
# ('"10437291"', 'onia')
# ('"5529477"', 'onia')
# ('"13957880"', 'onia')
# ('"13385097"', 'onia')
# ('"2315224"', 'onia')
# ('"13597141"', 'onia')
# ('"13097210"', 'onia')
# ('"945867"', 'onia')
# ('"6470761"', 'onia')
# ('"2426591"', 'onia')
# ('"7231447"', 'onia')
# ('"3362365"', 'onia')
# ('"9146025"', 'onia')
# ('"26417535"', 'onia')
# ('"17385355"', 'onia')
# ('"12822816"', 'onia')
# ('"12518301"', 'onia')
# ('"10979329"', 'onia')
# ('"35312111"', 'onia')
# ('"37607452"', 'onia')
# ('"36757831"', 'onia')
# ('"36648081"', 'onia')
# ('"36445406"', 'onia')
# ('"35533513"', 'onia')
# ('"12609485"', 'onia')
# ('"15939081"', 'onia')
# ('"16938275"', 'onia')
# ('"17290457"', 'onia')
# ('"19038309"', 'onia')
# ('"19157930"', 'onia')
# ('"19284587"', 'onia')
# ('"19578124"', 'onia')
# ('"20301665"', 'onia')
# ('"22897341"', 'onia')
# ('"23180184"', 'onia')
# ('"23196519"', 'onia')
# ('"23222958"', 'onia')
# ('"23893446"', 'onia')
# ('"24092288"', 'onia')
# ('"24588501"', 'onia')
# ('"24757586"', 'onia')
# ('"24931141"', 'onia')
# ('"24976531"', 'onia')
# ('"25155315"', 'onia')
# ('"25203860"', 'onia')
# ('"25403864"', 'onia')
# ('"26004199"', 'onia')
# ('"26297380"', 'onia')
# ('"26810727"', 'onia')
# ('"26940431"', 'onia')
# ('"27477622"', 'onia')
# ('"28283962"', 'onia')
# ('"28432771"', 'onia')
# ('"28756192"', 'onia')
# ('"29396398"', 'onia')
# ('"30100364"', 'onia')
# ('"30838317"', 'onia')
# ('"32243914"', 'onia')
# ('"32502938"', 'onia')
# ('"32662044"', 'onia')
# ('"34949287"', 'onia')
# ('"35041927"', 'onia')
# ('"35044558"', 'onia')
# ('"35303767"', 'onia')
# ('"17713116"', 'onia')
# ('"9874484"', 'onia')
# ('"9749609"', 'onia')
# ('"9749595"', 'onia')
# ('"9667600"', 'onia')
# ('"9618171"', 'onia')
# ('"9585364"', 'onia')
# ('"9191768"', 'onia')
# ('"8871591"', 'onia')
# ('"8309575"', 'onia')
# ('"8244374"', 'onia')
# ('"8232931"', 'onia')
# ('"7845403"', 'onia')
# ('"7654519"', 'onia')
# ('"7629534"', 'onia')
# ('"37352388"', 'onia')
# ('"37267819"', 'onia')
# ('"37165749"', 'onia')
# ('"35022352"', 'onia')
# ('"34645254"', 'onia')
# ('"32289333"', 'onia')
# ('"29483592"', 'onia')
# ('"29396174"', 'onia')
# ('"28461905"', 'onia')
# ('"27093447"', 'onia')
# ('"26596547"', 'onia')
# ('"26592310"', 'onia')
# ('"26125045"', 'onia')
# ('"25653290"', 'onia')
# ('"25379658"', 'onia')
# ('"25337725"', 'onia')
# ('"25149450"', 'onia')
# ('"23814535"', 'onia')
# ('"23724359"', 'onia')
# ('"23436503"', 'onia')
# ('"22770546"', 'onia')
# ('"22622408"', 'onia')
# ('"21800139"', 'onia')
# ('"21750546"', 'onia')
# ('"21496603"', 'onia')
# ('"21301909"', 'onia')
# ('"20687193"', 'onia')
# ('"20482602"', 'onia')
# ('"20350935"', 'onia')
# ('"20066431"', 'onia')
# ('"19890997"', 'onia')
# ('"19844939"', 'onia')
# ('"19651773"', 'onia')
# ('"19555827"', 'onia')
# ('"19457118"', 'onia')
# ('"19403250"', 'onia')
# ('"19260107"', 'onia')
# ('"19039992"', 'onia')
# ('"18685824"', 'onia')
# ('"18571468"', 'onia')
# ('"18552369"', 'onia')
# ('"18437909"', 'onia')
# ('"18299520"', 'onia')
# ('"18258738"', 'onia')
# ('"18224570"', 'onia')
# ('"18176524"', 'onia')
# ('"17894340"', 'onia')
# ('"36288966"', 'onia')
# ('"36302970"', 'onia')
# ('"36263189"', 'onia')
# ('"35563018"', 'onia')
# ('"10050893"', 'onia')
# ('"10225357"', 'onia')
# ('"10448655"', 'onia')
# ('"10477437"', 'onia')
# ('"10627938"', 'onia')
# ('"10714658"', 'onia')
# ('"10720299"', 'onia')
# ('"10871631"', 'onia')
# ('"10881900"', 'onia')
# ('"10984667"', 'onia')
# ('"11009204"', 'onia')
# ('"11014135"', 'onia')
# ('"11104212"', 'onia')
# ('"11261511"', 'onia')
# ('"11835464"', 'onia')
# ('"11921134"', 'onia')
# ('"11980065"', 'onia')
# ('"12360559"', 'onia')
# ('"12760408"', 'onia')
# ('"12821514"', 'onia')
# ('"12859412"', 'onia')
# ('"12883919"', 'onia')
# ('"12900733"', 'onia')
# ('"14581671"', 'onia')
# ('"15342362"', 'onia')
# ('"15555920"', 'onia')
# ('"15593317"', 'onia')
# ('"15726581"', 'onia')
# ('"15895426"', 'onia')
# ('"16361107"', 'onia')
# ('"16537570"', 'onia')
# ('"16631205"', 'onia')
# ('"16773641"', 'onia')
# ('"16924015"', 'onia')
# ('"17097111"', 'onia')
# ('"17129379"', 'onia')
# ('"22472189"', 'onia')
# ('"15283994"', 'onia')
# ('"12671990"', 'onia')
# ('"12007841"', 'onia')
# ('"33425096"', 'onia')
# ('"19214438"', 'onia')
# ('"11405807"', 'onia')
# ('"25674472"', 'onia')
# ('"21818381"', 'onia')
# ('"20169475"', 'onia')
# ('"15136718"', 'onia')
# ('"9750906"', 'onia')
# ('"10434613"', 'onia')
# ('"11244697"', 'onia')
# ('"11584049"', 'onia')
# ('"15989773"', 'onia')
# ('"11438481"', 'onia')
# ('"14690443"', 'onia')
# ('"15099679"', 'onia')
# ('"15147511"', 'onia')
# ('"15269177"', 'onia')
# ('"15505207"', 'onia')
# ('"15829632"', 'onia')
# ('"19761814"', 'onia')
# ('"20639502"', 'onia')
# ('"24627482"', 'onia')
# ('"25425325"', 'onia')
# ('"28768697"', 'onia')
# ('"35643882"', 'onia')
# ('"32248052"', 'onia')
# ('"26506956"', 'onia')
# ('"23107556"', 'onia')
# ('"34062155"', 'onia')
# ('"9539346"', 'onia')
# ('"941774"', 'onia')
# ('"9380054"', 'onia')
# ('"8723633"', 'onia')
# ('"8595478"', 'onia')
# ('"8552116"', 'onia')
# ('"8413963"', 'onia')
# ('"8341297"', 'onia')
# ('"7969702"', 'onia')
# ('"7897412"', 'onia')
# ('"7753056"', 'onia')
# ('"7205314"', 'onia')
# ('"7057205"', 'onia')
# ('"3746330"', 'onia')
# ('"3574676"', 'onia')
# ('"3400519"', 'onia')
# ('"3400502"', 'onia')
# ('"2840805"', 'onia')
# ('"2456673"', 'onia')
# ('"2322135"', 'onia')
# ('"2239458"', 'onia')
# ('"2215959"', 'onia')
# ('"2183913"', 'onia')
# ('"2005929"', 'onia')
# ('"1940944"', 'onia')
# ('"1758449"', 'onia')
# ('"1758448"', 'onia')
# ('"1756758"', 'onia')
# ('"131183"', 'onia')
# ('"12030016"', 'onia')
# ('"11432664"', 'onia')
# ('"10463238"', 'onia')
# ('"9918350"', 'onia')
# ('"9819835"', 'onia')
# ('"9440801"', 'onia')
# ('"9335011"', 'onia')
# ('"9225692"', 'onia')
# ('"9221523"', 'onia')
# ('"918463"', 'onia')
# ('"9176783"', 'onia')
# ('"9153120"', 'onia')
# ('"8723145"', 'onia')
# ('"8703227"', 'onia')
# ('"8353711"', 'onia')
# ('"10349117"', 'onia')
# ('"10526391"', 'onia')
# ('"10809944"', 'onia')
# ('"10877155"', 'onia')
# ('"10980732"', 'onia')
# ('"11685399"', 'onia')
# ('"11701630"', 'onia')
# ('"12876228"', 'onia')
# ('"16024174"', 'onia')
# ('"1623256"', 'onia')
# ('"17125732"', 'onia')
# ('"18591071"', 'onia')
# ('"1992364"', 'onia')
# ('"2073302"', 'onia')
# ('"21048241"', 'onia')
# ('"2356013"', 'onia')
# ('"2614440"', 'onia')
# ('"3941936"', 'onia')
# ('"3948889"', 'onia')
# ('"3984684"', 'onia')
# ('"4065158"', 'onia')
# ('"626228"', 'onia')
# ('"650244"', 'onia')
# ('"6697632"', 'onia')
# ('"690631"', 'onia')
# ('"7325607"', 'onia')
# ('"7469847"', 'onia')
# ('"7507398"', 'onia')
# ('"7556545"', 'onia')
# ('"7695236"', 'onia')
# ('"7858177"', 'onia')
# ('"8221055"', 'onia')
# ('"7133334"', 'onia')
# ('"2966619"', 'onia')
# ('"2245082"', 'onia')
# ('"11598522"', 'onia')
# ('"941769"', 'onia')
# ('"8511436"', 'onia')
# ('"8416347"', 'onia')
# ('"8277565"', 'onia')
# ('"796956"', 'onia')
# ('"7856369"', 'onia')
# ('"7299845"', 'onia')
# ('"7191439"', 'onia')
# ('"7164771"', 'onia')
# ('"7092616"', 'onia')
# ('"6822602"', 'onia')
# ('"6622883"', 'onia')
# ('"6612149"', 'onia')
# ('"6497558"', 'onia')
# ('"6477216"', 'onia')
# ('"6443743"', 'onia')
# ('"6282513"', 'onia')
# ('"6234055"', 'onia')
# ('"556814"', 'onia')
# ('"482013"', 'onia')
# ('"4072505"', 'onia')
# ('"3724992"', 'onia')
# ('"3178457"', 'onia')
# ('"310282"', 'onia')
# ('"2977281"', 'onia')
# ('"2868026"', 'onia')
# ('"2840407"', 'onia')
# ('"22604515"', 'onia')
# ('"2179685"', 'onia')
# ('"2164296"', 'onia')
# ('"16602679"', 'onia')
# ('"15568498"', 'onia')
# ('"10527098"', 'onia')
# ('"9399227"', 'onia')
# ('"8894706"', 'onia')
# ('"24486689"', 'onia')
# ('"21840890"', 'onia')
# ('"20113647"', 'onia')
# ('"21900627"', 'onia')
# ('"19353218"', 'onia')
# ('"17960812"', 'onia')
# ('"10833562"', 'onia')
# ('"27448549"', 'onia')
# ('"18688663"', 'onia')
# ('"941783"', 'onia')
# ('"941772"', 'onia')
# ('"7908772"', 'onia')
# ('"7245665"', 'onia')
# ('"7052665"', 'onia')
# ('"6731882"', 'onia')
# ('"6694320"', 'onia')
# ('"484133"', 'onia')
# ('"4474046"', 'onia')
# ('"4448193"', 'onia')
# ('"227178"', 'onia')
# ('"22183"', 'onia')
# ('"207060"', 'onia')
# ('"1614793"', 'onia')
# ('"1130730"', 'onia')
# ('"11714689"', 'onia')
# ('"31332180"', 'onia')
# ('"27490483"', 'onia')
# ('"19765051"', 'onia')
# ('"12074905"', 'onia')
# ('"14509659"', 'onia')
# ('"3041765"', 'onia')
# ('"21965893"', 'onia')
# ('"19685597"', 'onia')
# ('"1484541"', 'onia')
# ('"993556"', 'onia')
# ('"895957"', 'onia')
# ('"3848614"', 'onia')
# ('"3468383"', 'onia')
# ('"22166421"', 'onia')
# ('"6240313"', 'onia')
# ('"7791942"', 'onia')
# ('"38214203"', 'onia')
# ('"24976531"', 'onia')
# ('"27477622"', 'onia')
# ('"32662044"', 'onia')
# ('"37352388"', 'onia')
# ('"26297380"', 'onia')
# ('"32502938"', 'onia')
# ('"24931141"', 'onia')
# ('"29641419"', 'onia')
# ('"20301665"', 'onia')
# ('"28432771"', 'onia')
# ('"32243914"', 'onia')
# ('"35303767"', 'onia')
# ('"31618684"', 'onia')
# ('"36417958"', 'onia')
# ('"33476878"', 'onia')
# ('"34092466"', 'onia')
# ('"33468570"', 'onia')
# ('"33753289"', 'onia')
# ('"29325615"', 'onia')
# ('"32239467"', 'onia')
# ('"32516804"', 'onia')
# ('"33247415"', 'onia')
# ('"33175450"', 'onia')
# ('"33502045"', 'onia')
# ('"34189496"', 'onia')
# ('"20301334"', 'onia')
# ('"29053766"', 'onia')
# ('"30244176"', 'onia')
# ('"24627482"', 'onia')
# ('"26592310"', 'onia')
# ('"28768697"', 'onia')
# ('"35563018"', 'onia')
# ('"36329866"', 'onia')
# ('"36426380"', 'onia')
# ('"35955710"', 'onia')
# ('"33134321"', 'onia')
# ('"33757902"', 'onia')
# ('"33894367"', 'onia')
# ('"34062155"', 'onia')
# ('"34119482"', 'onia')
# ('"24311730"', 'onia')
# ('"27911022"', 'onia')
# ('"33229589"', 'onia')
# ('"29739751"', 'onia')
# ('"34358617"', 'onia')
# ('"27567612"', 'onia')
# ('"26183317"', 'onia')
# ('"36263189"', 'onia')
# ('"34398825"', 'onia')
# ('"36757831"', 'onia')
# ('"24757586"', 'onia')
# ('"27716431"', 'onia')
# ('"30838317"', 'onia')
# ('"32289333"', 'onia')
# ('"37165749"', 'onia')
# ('"28756192"', 'onia')
# ('"33445430"', 'onia')
# ('"33799994"', 'onia')
# ('"33638639"', 'onia')
# ('"33991565"', 'onia')
# ('"28843013"', 'onia')
# ('"28941827"', 'onia')
# ('"33395620"', 'onia')
# ('"26790671"', 'onia')
# ('"14814694"', 'onia')
# ('"14822914"', 'onia')
# ('"14957878"', 'onia')
# ('"14779577"', 'onia')
# ('"14921156"', 'onia')
# ('"13735560"', 'onia')
# ('"14022841"', 'onia')
# ('"32102149"', 'onia')
# ('"14824970"', 'onia')
# ('"32037012"', 'onia')
# ('"26596547"', 'onia')
# ('"34728955"', 'onia')
# ('"6683367"', 'kinesia')
# ('"2666583"', 'kinesia')
# ('"9146024"', 'kinesia')
# ('"11912106"', 'kinesia')
# ('"15548549"', 'kinesia')
# ('"27919237"', 'kinesia')
# ('"24262166"', 'kinesia')
# ('"22266882"', 'kinesia')
# ('"17061185"', 'kinesia')
# ('"22151759"', 'kinesia')
# ('"22375360"', 'kinesia')
# ('"25449075"', 'kinesia')
# ('"33458877"', 'kinesia')
# ('"21907099"', 'kinesia')
# ('"10979329"', 'kinesia')
# ('"36757831"', 'kinesia')
# ('"19578124"', 'kinesia')
# ('"23893446"', 'kinesia')
# ('"12883919"', 'kinesia')
# ('"17097111"', 'kinesia')
# ('"941774"', 'kinesia')
# ('"8703227"', 'kinesia')
# ('"17125732"', 'kinesia')
# ('"650244"', 'kinesia')
# ('"7695236"', 'kinesia')
# ('"8277565"', 'kinesia')
# ('"7164771"', 'kinesia')
# ('"36757831"', 'kinesia')
# ('"7299845"', 'transferase activity')
# ('"12671990"', 'response to oxidative stress')
# ('"22391119"', 'gnaling pathway')
# ('"33991565"', 'gnaling pathway')
# ('"37627888"', 'gnaling pathway')
# ('"32289333"', 'gnaling pathway')
# ('"25379658"', 'gnaling pathway')
# ('"33425096"', 'gnaling pathway')
# ('"32289333"', 'gnaling pathway')
# ('"33991565"', 'gnaling pathway')
# ('"1867195"', 'core')
# ('"8513401"', 'core')
# ('"10674821"', 'core')
# ('"9779659"', 'core')
# ('"12575458"', 'core')
# ('"20672922"', 'core')
# ('"31641352"', 'core')
# ('"8004804"', 'core')
# ('"18823044"', 'core')
# ('"22132914"', 'core')
# ('"31604331"', 'core')
# ('"33395620"', 'core')
# ('"12691403"', 'core')
# ('"22151759"', 'core')
# ('"30028274"', 'core')
# ('"22375360"', 'core')
# ('"21496608"', 'core')
# ('"20841370"', 'core')
# ('"32079672"', 'core')
# ('"25449075"', 'core')
# ('"32239467"', 'core')
# ('"36355183"', 'core')
# ('"14517787"', 'core')
# ('"24265781"', 'core')
# ('"28182308"', 'core')
# ('"33724724"', 'core')
# ('"7231447"', 'core')
# ('"12822816"', 'core')
# ('"35312111"', 'core')
# ('"23893446"', 'core')
# ('"34949287"', 'core')
# ('"9749595"', 'core')
# ('"34645254"', 'core')
# ('"25653290"', 'core')
# ('"21301909"', 'core')
# ('"19890997"', 'core')
# ('"19403250"', 'core')
# ('"18552369"', 'core')
# ('"18176524"', 'core')
# ('"36263189"', 'core')
# ('"11261511"', 'core')
# ('"12900733"', 'core')
# ('"8595478"', 'core')
# ('"9918350"', 'core')
# ('"9819835"', 'core')
# ('"10349117"', 'core')
# ('"6622883"', 'core')
# ('"6477216"', 'core')
# ('"482013"', 'core')
# ('"8894706"', 'core')
# ('"21840890"', 'core')
# ('"941772"', 'core')
# ('"32239467"', 'core')
# ('"27567612"', 'core')
# ('"36263189"', 'core')
# ('"33395620"', 'core')
# ('"8277574"', 'trophy')
# ('"12566288"', 'trophy')
# ('"16456406"', 'trophy')
# ('"31244841"', 'trophy')
# ('"26060104"', 'trophy')
# ('"24444577"', 'trophy')
# ('"21397152"', 'trophy')
# ('"15137480"', 'trophy')
# ('"12477369"', 'trophy')
# ('"19244266"', 'trophy')
# ('"32118025"', 'trophy')
# ('"30528262"', 'trophy')
# ('"19355902"', 'trophy')
# ('"32044834"', 'trophy')
# ('"33757902"', 'trophy')
# ('"34038798"', 'trophy')
# ('"22345219"', 'trophy')
# ('"31320448"', 'trophy')
# ('"24951854"', 'trophy')
# ('"25461922"', 'trophy')
# ('"36329866"', 'trophy')
# ('"34173686"', 'trophy')
# ('"34398825"', 'trophy')
# ('"37554750"', 'trophy')
# ('"34248079"', 'trophy')
# ('"31057009"', 'trophy')
# ('"36468571"', 'trophy')
# ('"18689116"', 'trophy')
# ('"20359791"', 'trophy')
# ('"21621928"', 'trophy')
# ('"22465228"', 'trophy')
# ('"7231447"', 'trophy')
# ('"22639460"', 'trophy')
# ('"23196519"', 'trophy')
# ('"26004199"', 'trophy')
# ('"17713116"', 'trophy')
# ('"37352388"', 'trophy')
# ('"26596547"', 'trophy')
# ('"20687193"', 'trophy')
# ('"12821514"', 'trophy')
# ('"22472189"', 'trophy')
# ('"25425325"', 'trophy')
# ('"9335011"', 'trophy')
# ('"11685399"', 'trophy')
# ('"7858177"', 'trophy')
# ('"15568498"', 'trophy')
# ('"227178"', 'trophy')
# ('"37352388"', 'trophy')
# ('"36329866"', 'trophy')
# ('"33757902"', 'trophy')
# ('"34398825"', 'trophy')
# ('"26596547"', 'trophy')
# ('"25461922"', 'protein phosphorylation')
# ('"8277574"', 'behavior')
# ('"12838525"', 'behavior')
# ('"15548549"', 'behavior')
# ('"33757902"', 'behavior')
# ('"24311730"', 'behavior')
# ('"11528394"', 'behavior')
# ('"20223934"', 'behavior')
# ('"20132487"', 'behavior')
# ('"18299128"', 'behavior')
# ('"15930383"', 'behavior')
# ('"36417958"', 'behavior')
# ('"36546658"', 'behavior')
# ('"29739751"', 'behavior')
# ('"34398157"', 'behavior')
# ('"33529159"', 'behavior')
# ('"21496605"', 'behavior')
# ('"6470761"', 'behavior')
# ('"35312111"', 'behavior')
# ('"27143436"', 'behavior')
# ('"17894340"', 'behavior')
# ('"22472189"', 'behavior')
# ('"19214438"', 'behavior')
# ('"14690443"', 'behavior')
# ('"15269177"', 'behavior')
# ('"7507398"', 'behavior')
# ('"2868026"', 'behavior')
# ('"36417958"', 'behavior')
# ('"36029989"', 'behavior')
# ('"33757902"', 'behavior')
# ('"24311730"', 'behavior')
# ('"29739751"', 'behavior')
# ('"2317008"', 'tations')
# ('"6694180"', 'tations')
# ('"8079990"', 'tations')
# ('"1121020"', 'tations')
# ('"2309703"', 'tations')
# ('"17142829"', 'tations')
# ('"10737119"', 'tations')
# ('"9778264"', 'tations')
# ('"15897512"', 'tations')
# ('"9266460"', 'tations')
# ('"28943611"', 'tations')
# ('"31244841"', 'tations')
# ('"26060104"', 'tations')
# ('"24444577"', 'tations')
# ('"21397152"', 'tations')
# ('"15137480"', 'tations')
# ('"12477369"', 'tations')
# ('"11302971"', 'tations')
# ('"30561390"', 'tations')
# ('"32370566"', 'tations')
# ('"9039166"', 'tations')
# ('"2785717"', 'tations')
# ('"30528262"', 'tations')
# ('"24210306"', 'tations')
# ('"23609110"', 'tations')
# ('"32359820"', 'tations')
# ('"8365724"', 'tations')
# ('"32186581"', 'tations')
# ('"12402271"', 'tations')
# ('"21956287"', 'tations')
# ('"19345148"', 'tations')
# ('"19345147"', 'tations')
# ('"20211909"', 'tations')
# ('"10738516"', 'tations')
# ('"11523564"', 'tations')
# ('"11973627"', 'tations')
# ('"15111678"', 'tations')
# ('"15293281"', 'tations')
# ('"15326234"', 'tations')
# ('"18823044"', 'tations')
# ('"19528516"', 'tations')
# ('"19955557"', 'tations')
# ('"16415980"', 'tations')
# ('"22132914"', 'tations')
# ('"33476878"', 'tations')
# ('"33757902"', 'tations')
# ('"34092466"', 'tations')
# ('"10994500"', 'tations')
# ('"24262166"', 'tations')
# ('"25192508"', 'tations')
# ('"19685389"', 'tations')
# ('"21847143"', 'tations')
# ('"24311730"', 'tations')
# ('"12194383"', 'tations')
# ('"10919137"', 'tations')
# ('"11528394"', 'tations')
# ('"12391355"', 'tations')
# ('"30244176"', 'tations')
# ('"17702041"', 'tations')
# ('"26087139"', 'tations')
# ('"24949445"', 'tations')
# ('"21839475"', 'tations')
# ('"20301587"', 'tations')
# ('"30028274"', 'tations')
# ('"28102337"', 'tations')
# ('"26790671"', 'tations')
# ('"24978640"', 'tations')
# ('"25209853"', 'tations')
# ('"23622412"', 'tations')
# ('"23284065"', 'tations')
# ('"22166420"', 'tations')
# ('"22345219"', 'tations')
# ('"21496608"', 'tations')
# ('"20627944"', 'tations')
# ('"19117362"', 'tations')
# ('"18265016"', 'tations')
# ('"19066193"', 'tations')
# ('"16227522"', 'tations')
# ('"15390016"', 'tations')
# ('"14872019"', 'tations')
# ('"15258227"', 'tations')
# ('"14628853"', 'tations')
# ('"24508913"', 'tations')
# ('"23967309"', 'tations')
# ('"22391119"', 'tations')
# ('"21995941"', 'tations')
# ('"20584926"', 'tations')
# ('"17956903"', 'tations')
# ('"16364891"', 'tations')
# ('"31320448"', 'tations')
# ('"30237473"', 'tations')
# ('"32516804"', 'tations')
# ('"24938147"', 'tations')
# ('"25347348"', 'tations')
# ('"27666935"', 'tations')
# ('"33502045"', 'tations')
# ('"23365103"', 'tations')
# ('"31321303"', 'tations')
# ('"31517057"', 'tations')
# ('"33175450"', 'tations')
# ('"33832800"', 'tations')
# ('"29053766"', 'tations')
# ('"17200151"', 'tations')
# ('"33991565"', 'tations')
# ('"22040906"', 'tations')
# ...
# ('"27477622"', 'tion')
# ('"28283962"', 'tion')
# ('"28432771"', 'tion')
# ('"28756192"', 'tion')
# ('"29396398"', 'tion')
# ('"30100364"', 'tion')
# ('"30838317"', 'tion')
# ('"32243914"', 'tion')
# ('"32502938"', 'tion')
# ('"32662044"', 'tion')
# ('"34949287"', 'tion')
# ('"35041927"', 'tion')
# ('"35044558"', 'tion')
# ('"35303767"', 'tion')
# ('"17713116"', 'tion')
# ('"9874484"', 'tion')
# ('"9749609"', 'tion')
# ('"9749595"', 'tion')
# ('"9667600"', 'tion')
# ('"9618171"', 'tion')
# ('"9585364"', 'tion')
# ('"9191768"', 'tion')
# ('"8309575"', 'tion')
# ('"8244374"', 'tion')
# ('"8232931"', 'tion')
# ('"7654519"', 'tion')
# ('"7629534"', 'tion')
# ('"37352388"', 'tion')
# ('"37267819"', 'tion')
# ('"37165749"', 'tion')
# ('"35022352"', 'tion')
# ('"34645254"', 'tion')
# ('"32289333"', 'tion')
# ('"29483592"', 'tion')
# ('"29396174"', 'tion')
# ('"28461905"', 'tion')
# ('"27093447"', 'tion')
# ('"26596547"', 'tion')
# ('"26592310"', 'tion')
# ('"26125045"', 'tion')
# ('"25653290"', 'tion')
# ('"25379658"', 'tion')
# ('"25337725"', 'tion')
# ('"25149450"', 'tion')
# ('"23814535"', 'tion')
# ('"23724359"', 'tion')
# ('"23436503"', 'tion')
# ('"22770546"', 'tion')
# ('"22622408"', 'tion')
# ('"21800139"', 'tion')
# ('"21750546"', 'tion')
# ('"21496603"', 'tion')
# ('"21301909"', 'tion')
# ('"20687193"', 'tion')
# ('"20482602"', 'tion')
# ('"20350935"', 'tion')
# ('"20066431"', 'tion')
# ('"19890997"', 'tion')
# ('"19844939"', 'tion')
# ('"19651773"', 'tion')
# ('"19555827"', 'tion')
# ('"19457118"', 'tion')
# ('"19403250"', 'tion')
# ('"19260107"', 'tion')
# ('"19039992"', 'tion')
# ('"18685824"', 'tion')
# ('"18571468"', 'tion')
# ('"18552369"', 'tion')
# ('"18437909"', 'tion')
# ('"18299520"', 'tion')
# ('"18258738"', 'tion')
# ('"18224570"', 'tion')
# ('"18176524"', 'tion')
# ('"17894340"', 'tion')
# ('"36288966"', 'tion')
# ('"36302970"', 'tion')
# ('"36263189"', 'tion')
# ('"35563018"', 'tion')
# ('"10050893"', 'tion')
# ('"10225357"', 'tion')
# ('"10448655"', 'tion')
# ('"10477437"', 'tion')
# ('"10627938"', 'tion')
# ('"10714658"', 'tion')
# ('"10720299"', 'tion')
# ('"10871631"', 'tion')
# ('"10881900"', 'tion')
# ('"10984667"', 'tion')
# ('"11009204"', 'tion')
# ('"11014135"', 'tion')
# ('"11104212"', 'tion')
# ('"11261511"', 'tion')
# ('"11835464"', 'tion')
# ('"11921134"', 'tion')
# ('"11980065"', 'tion')
# ('"12360559"', 'tion')
# ('"12760408"', 'tion')
# ('"12821514"', 'tion')
# ('"12859412"', 'tion')
# ('"12883919"', 'tion')
# ('"12900733"', 'tion')
# ('"14581671"', 'tion')
# ('"15342362"', 'tion')
# ('"15555920"', 'tion')
# ('"15593317"', 'tion')
# ('"15726581"', 'tion')
# ('"15895426"', 'tion')
# ('"16361107"', 'tion')
# ('"16537570"', 'tion')
# ('"16631205"', 'tion')
# ('"16773641"', 'tion')
# ('"16924015"', 'tion')
# ('"17097111"', 'tion')
# ('"17129379"', 'tion')
# ('"22472189"', 'tion')
# ('"15283994"', 'tion')
# ('"12671990"', 'tion')
# ('"12007841"', 'tion')
# ('"33425096"', 'tion')
# ('"19214438"', 'tion')
# ('"11405807"', 'tion')
# ('"35796490"', 'tion')
# ('"36409706"', 'tion')
# ('"25674472"', 'tion')
# ('"21818381"', 'tion')
# ('"20169475"', 'tion')
# ('"15136718"', 'tion')
# ('"15989773"', 'tion')
# ('"11438481"', 'tion')
# ('"14690443"', 'tion')
# ('"15099679"', 'tion')
# ('"15147511"', 'tion')
# ('"15269177"', 'tion')
# ('"15505207"', 'tion')
# ('"15829632"', 'tion')
# ('"19761814"', 'tion')
# ('"20639502"', 'tion')
# ('"24627482"', 'tion')
# ('"25425325"', 'tion')
# ('"28768697"', 'tion')
# ('"35643882"', 'tion')
# ('"26506956"', 'tion')
# ('"23107556"', 'tion')
# ('"34062155"', 'tion')
# ('"9539346"', 'tion')
# ('"9380054"', 'tion')
# ('"8723633"', 'tion')
# ('"8595478"', 'tion')
# ('"8413963"', 'tion')
# ('"8341297"', 'tion')
# ('"7969702"', 'tion')
# ('"7897412"', 'tion')
# ('"3746330"', 'tion')
# ('"3400502"', 'tion')
# ('"2840805"', 'tion')
# ('"2322135"', 'tion')
# ('"2215959"', 'tion')
# ('"2183913"', 'tion')
# ('"2005929"', 'tion')
# ('"1940944"', 'tion')
# ('"1758449"', 'tion')
# ('"12030016"', 'tion')
# ('"11432664"', 'tion')
# ('"10463238"', 'tion')
# ('"9918350"', 'tion')
# ('"9819835"', 'tion')
# ('"9440801"', 'tion')
# ('"9335011"', 'tion')
# ('"9225692"', 'tion')
# ('"9221523"', 'tion')
# ('"918463"', 'tion')
# ('"9176783"', 'tion')
# ('"9153120"', 'tion')
# ('"8723145"', 'tion')
# ('"8703227"', 'tion')
# ('"8353711"', 'tion')
# ('"10349117"', 'tion')
# ('"10526391"', 'tion')
# ('"10809944"', 'tion')
# ('"10877155"', 'tion')
# ('"10980732"', 'tion')
# ('"11685399"', 'tion')
# ('"11701630"', 'tion')
# ('"12876228"', 'tion')
# ('"16024174"', 'tion')
# ('"17125732"', 'tion')
# ('"18591071"', 'tion')
# ('"2073302"', 'tion')
# ('"21048241"', 'tion')
# ('"2356013"', 'tion')
# ('"2614440"', 'tion')
# ('"3948889"', 'tion')
# ('"3984684"', 'tion')
# ('"4065158"', 'tion')
# ('"626228"', 'tion')
# ('"690631"', 'tion')
# ('"7325607"', 'tion')
# ('"7469847"', 'tion')
# ('"7507398"', 'tion')
# ('"7556545"', 'tion')
# ('"7695236"', 'tion')
# ('"7858177"', 'tion')
# ('"8221055"', 'tion')
# ('"7133334"', 'tion')
# ('"2966619"', 'tion')
# ('"2245082"', 'tion')
# ('"11598522"', 'tion')
# ('"941769"', 'tion')
# ('"8416347"', 'tion')
# ('"8277565"', 'tion')
# ('"796956"', 'tion')
# ('"7856369"', 'tion')
# ('"7299845"', 'tion')
# ('"7191439"', 'tion')
# ('"7164771"', 'tion')
# ('"7092616"', 'tion')
# ('"6822602"', 'tion')
# ('"6622883"', 'tion')
# ('"6612149"', 'tion')
# ('"6497558"', 'tion')
# ('"6477216"', 'tion')
# ('"6443743"', 'tion')
# ('"6282513"', 'tion')
# ('"6234055"', 'tion')
# ('"482013"', 'tion')
# ('"3724992"', 'tion')
# ('"3178457"', 'tion')
# ('"310282"', 'tion')
# ('"2977281"', 'tion')
# ('"2868026"', 'tion')
# ('"2840407"', 'tion')
# ('"22604515"', 'tion')
# ('"2179685"', 'tion')
# ('"2164296"', 'tion')
# ('"16602679"', 'tion')
# ('"15568498"', 'tion')
# ('"10527098"', 'tion')
# ('"9399227"', 'tion')
# ('"8894706"', 'tion')
# ('"21840890"', 'tion')
# ('"21900627"', 'tion')
# ('"19353218"', 'tion')
# ('"17960812"', 'tion')
# ('"10833562"', 'tion')
# ('"27448549"', 'tion')
# ('"18688663"', 'tion')
# ('"941772"', 'tion')
# ('"7908772"', 'tion')
# ('"7052665"', 'tion')
# ('"484133"', 'tion')
# ('"4448193"', 'tion')
# ('"227178"', 'tion')
# ('"207060"', 'tion')
# ('"11714689"', 'tion')
# ('"31332180"', 'tion')
# ('"27490483"', 'tion')
# ('"19765051"', 'tion')
# ('"12074905"', 'tion')
# ('"21965893"', 'tion')
# ('"22166421"', 'tion')
# ('"6240313"', 'tion')
# ('"7791942"', 'tion')
# ('"38214203"', 'tion')
# ('"24976531"', 'tion')
# ('"27477622"', 'tion')
# ('"32662044"', 'tion')
# ('"37352388"', 'tion')
# ('"26297380"', 'tion')
# ('"32502938"', 'tion')
# ('"24931141"', 'tion')
# ('"29641419"', 'tion')
# ('"20301665"', 'tion')
# ('"28432771"', 'tion')
# ('"32243914"', 'tion')
# ('"35303767"', 'tion')
# ('"31618684"', 'tion')
# ('"36417958"', 'tion')
# ('"36029989"', 'tion')
# ('"33476878"', 'tion')
# ('"34092466"', 'tion')
# ('"33468570"', 'tion')
# ('"33753289"', 'tion')
# ('"29325615"', 'tion')
# ('"32239467"', 'tion')
# ('"32516804"', 'tion')
# ('"33247415"', 'tion')
# ('"33175450"', 'tion')
# ('"33502045"', 'tion')
# ('"34189496"', 'tion')
# ('"20301334"', 'tion')
# ('"29053766"', 'tion')
# ('"30244176"', 'tion')
# ('"24627482"', 'tion')
# ('"26592310"', 'tion')
# ('"28768697"', 'tion')
# ('"35563018"', 'tion')
# ('"36329866"', 'tion')
# ('"36426380"', 'tion')
# ('"35955710"', 'tion')
# ('"33134321"', 'tion')
# ('"33757902"', 'tion')
# ('"33894367"', 'tion')
# ('"34062155"', 'tion')
# ('"34119482"', 'tion')
# ('"24311730"', 'tion')
# ('"27911022"', 'tion')
# ('"33229589"', 'tion')
# ('"29739751"', 'tion')
# ('"34358617"', 'tion')
# ('"27567612"', 'tion')
# ('"26183317"', 'tion')
# ('"36263189"', 'tion')
# ('"34398825"', 'tion')
# ('"36757831"', 'tion')
# ('"24757586"', 'tion')
# ('"27716431"', 'tion')
# ('"30838317"', 'tion')
# ('"32289333"', 'tion')
# ('"37165749"', 'tion')
# ('"28756192"', 'tion')
# ('"33445430"', 'tion')
# ('"33799994"', 'tion')
# ('"33638639"', 'tion')
# ('"33991565"', 'tion')
# ('"28843013"', 'tion')
# ('"28941827"', 'tion')
# ('"33395620"', 'tion')
# ('"26790671"', 'tion')
# ('"14022841"', 'tion')
# ('"14022909"', 'tion')
# ('"32102149"', 'tion')
# ('"32037012"', 'tion')
# ('"26596547"', 'tion')
# ('"34728955"', 'tion')
# ('"10814722"', 'sylate')
# ('"15147511"', 'sylate')
# ('"2317008"', 'other')
# ('"8079990"', 'other')
# ('"7436383"', 'other')
# ('"8916165"', 'other')
# ('"1121020"', 'other')
# ('"2817837"', 'other')
# ('"1347197"', 'other')
# ('"8513401"', 'other')
# ('"7979224"', 'other')
# ('"10435508"', 'other')
# ('"7911621"', 'other')
# ('"1985454"', 'other')
# ('"9120448"', 'other')
# ('"9778264"', 'other')
# ('"12575458"', 'other')
# ('"6683367"', 'other')
# ('"2666583"', 'other')
# ('"9266460"', 'other')
# ('"20672922"', 'other')
# ('"8277574"', 'other')
# ('"16639700"', 'other')
# ('"12566288"', 'other')
# ('"29418012"', 'other')
# ('"16456406"', 'other')
# ('"18279642"', 'other')
# ('"19593686"', 'other')
# ('"22572887"', 'other')
# ('"21397152"', 'other')
# ('"15137480"', 'other')
# ('"11121131"', 'other')
# ('"19244266"', 'other')
# ('"32152690"', 'other')
# ('"25925917"', 'other')
# ('"25402387"', 'other')
# ('"16552828"', 'other')
# ('"33239013"', 'other')
# ('"20499382"', 'other')
# ('"9039166"', 'other')
# ('"2785717"', 'other')
# ('"33472447"', 'other')
# ('"33335872"', 'other')
# ('"32118025"', 'other')
# ('"24210306"', 'other')
# ('"23609110"', 'other')
# ('"16706073"', 'other')
# ('"8365724"', 'other')
# ('"11232488"', 'other')
# ('"31641352"', 'other')
# ('"12402271"', 'other')
# ('"10449567"', 'other')
# ('"19345148"', 'other')
# ('"19345147"', 'other')
# ('"11523564"', 'other')
# ('"11973627"', 'other')
# ('"12473770"', 'other')
# ('"15326234"', 'other')
# ('"15455404"', 'other')
# ('"15548549"', 'other')
# ('"17027035"', 'other')
# ('"18823044"', 'other')
# ('"19955557"', 'other')
# ('"27939583"', 'other')
# ('"27919237"', 'other')
# ('"31604331"', 'other')
# ('"33476878"', 'other')
# ('"33616084"', 'other')
# ('"34092466"', 'other')
# ('"34438319"', 'other')
# ('"10073176"', 'other')
# ('"10994500"', 'other')
# ('"23420606"', 'other')
# ('"24262166"', 'other')
# ('"8255463"', 'other')
# ('"15390042"', 'other')
# ('"19685389"', 'other')
# ('"28843013"', 'other')
# ('"22266882"', 'other')
# ('"16541453"', 'other')
# ('"12194383"', 'other')
# ('"10919137"', 'other')
# ('"34189496"', 'other')
# ('"33488508"', 'other')
# ('"16275837"', 'other')
# ('"14989804"', 'other')
# ('"12821512"', 'other')
# ('"19349605"', 'other')
# ('"15954129"', 'other')
# ('"22151759"', 'other')
# ('"24949445"', 'other')
# ('"21839475"', 'other')
# ('"15505159"', 'other')
# ('"12652041"', 'other')
# ('"9837831"', 'other')
# ('"20301587"', 'other')
# ('"30028274"', 'other')
# ('"26790671"', 'other')
# ('"25894231"', 'other')
# ('"23622412"', 'other')
# ('"23284065"', 'other')
# ('"22345219"', 'other')
# ('"21496608"', 'other')
# ('"20627944"', 'other')
# ('"20841370"', 'other')
# ('"18265016"', 'other')
# ('"16227522"', 'other')
# ('"15390016"', 'other')
# ('"14872019"', 'other')
# ('"15258227"', 'other')
# ('"14628853"', 'other')
# ('"23967309"', 'other')
# ('"20223934"', 'other')
# ('"18299128"', 'other')
# ('"36417958"', 'other')
# ('"31320448"', 'other')
# ('"24951854"', 'other')
# ('"32079672"', 'other')
# ('"24938147"', 'other')
# ('"27666935"', 'other')
# ('"33740122"', 'other')
# ('"30643666"', 'other')
# ('"25449075"', 'other')
# ('"22722545"', 'other')
# ('"33832800"', 'other')
# ('"33134321"', 'other')
# ('"36329866"', 'other')
# ('"34398157"', 'other')
# ('"33458877"', 'other')
# ('"33894367"', 'other')
# ('"22040906"', 'other')
# ('"34358617"', 'other')
# ('"30981209"', 'other')
# ('"9486405"', 'other')
# ('"7783076"', 'other')
# ('"37554750"', 'other')
# ('"36355183"', 'other')
# ('"35694992"', 'other')
# ('"36045526"', 'other')
# ('"36468571"', 'other')
# ('"35611878"', 'other')
# ('"10028024"', 'other')
# ('"10644435"', 'other')
# ('"12169991"', 'other')
# ('"16227563"', 'other')
# ('"1626073"', 'other')
# ('"19041429"', 'other')
# ('"26017084"', 'other')
# ('"33724724"', 'other')
# ('"21496605"', 'other')
# ('"15786454"', 'other')
# ('"15159681"', 'other')
# ('"19182804"', 'other')
# ('"21656045"', 'other')
# ('"17702011"', 'other')
# ('"2368812"', 'other')
# ('"21907099"', 'other')
# ('"20344681"', 'other')
# ('"10437291"', 'other')
# ('"13597141"', 'other')
# ('"945867"', 'other')
# ('"6470761"', 'other')
# ('"3362365"', 'other')
# ('"26417535"', 'other')
# ('"17385355"', 'other')
# ('"12518301"', 'other')
# ('"35312111"', 'other')
# ('"37607452"', 'other')
# ('"36648081"', 'other')
# ('"19157930"', 'other')
# ('"19284587"', 'other')
# ('"19578124"', 'other')
# ('"20301665"', 'other')
# ('"22897341"', 'other')
# ('"23180184"', 'other')
# ('"23196519"', 'other')
# ('"23222958"', 'other')
# ('"24588501"', 'other')
# ('"24757586"', 'other')
# ('"24931141"', 'other')
# ('"24976531"', 'other')
# ('"25203860"', 'other')
# ('"26004199"', 'other')
# ('"26297380"', 'other')
# ('"29396398"', 'other')
# ('"30838317"', 'other')
# ('"32243914"', 'other')
# ('"32662044"', 'other')
# ('"35303767"', 'other')
# ('"17713116"', 'other')
# ('"9874484"', 'other')
# ('"9191768"', 'other')
# ('"8871591"', 'other')
# ('"8309575"', 'other')
# ('"7845403"', 'other')
# ('"7654519"', 'other')
# ('"7629534"', 'other')
# ('"37352388"', 'other')
# ('"37267819"', 'other')
# ('"37165749"', 'other')
# ('"29396174"', 'other')
# ('"28461905"', 'other')
# ('"25653290"', 'other')
# ('"22770546"', 'other')
# ('"22622408"', 'other')
# ('"20350935"', 'other')
# ('"20066431"', 'other')
# ('"19260107"', 'other')
# ('"18437909"', 'other')
# ('"18224570"', 'other')
# ('"36263189"', 'other')
# ('"10050893"', 'other')
# ('"10477437"', 'other')
# ('"10714658"', 'other')
# ('"10984667"', 'other')
# ('"11009204"', 'other')
# ('"11261511"', 'other')
# ('"11921134"', 'other')
# ('"12360559"', 'other')
# ('"12760408"', 'other')
# ('"12859412"', 'other')
# ('"12883919"', 'other')
# ('"14581671"', 'other')
# ('"15342362"', 'other')
# ('"16361107"', 'other')
# ('"16537570"', 'other')
# ('"17097111"', 'other')
# ('"17129379"', 'other')
# ('"12671990"', 'other')
# ('"36409706"', 'other')
# ('"21818381"', 'other')
# ('"20169475"', 'other')
# ('"11244697"', 'other')
# ('"15099679"', 'other')
# ('"15147511"', 'other')
# ('"15505207"', 'other')
# ('"15829632"', 'other')
# ('"35643882"', 'other')
# ('"34062155"', 'other')
# ('"941774"', 'other')
# ('"9380054"', 'other')
# ('"8552116"', 'other')
# ('"8413963"', 'other')
# ('"7753056"', 'other')
# ('"2322135"', 'other')
# ('"2005929"', 'other')
# ('"11432664"', 'other')
# ('"9918350"', 'other')
# ('"9440801"', 'other')
# ('"9335011"', 'other')
# ('"9221523"', 'other')
# ('"8703227"', 'other')
# ('"8353711"', 'other')
# ('"18591071"', 'other')
# ('"2073302"', 'other')
# ('"2356013"', 'other')
# ('"2614440"', 'other')
# ('"3948889"', 'other')
# ('"650244"', 'other')
# ('"6697632"', 'other')
# ('"7325607"', 'other')
# ('"7469847"', 'other')
# ('"7858177"', 'other')
# ('"7133334"', 'other')
# ('"2966619"', 'other')
# ('"2245082"', 'other')
# ('"11598522"', 'other')
# ('"941769"', 'other')
# ('"8277565"', 'other')
# ('"7164771"', 'other')
# ('"6622883"', 'other')
# ('"6234055"', 'other')
# ('"2868026"', 'other')
# ('"2840407"', 'other')
# ('"2179685"', 'other')
# ('"9399227"', 'other')
# ('"24486689"', 'other')
# ('"10833562"', 'other')
# ('"27448549"', 'other')
# ('"18688663"', 'other')
# ('"941772"', 'other')
# ('"19765051"', 'other')
# ('"21965893"', 'other')
# ('"22166421"', 'other')
# ('"6240313"', 'other')
# ('"38214203"', 'other')
# ('"24976531"', 'other')
# ('"32662044"', 'other')
# ('"37352388"', 'other')
# ('"26297380"', 'other')
# ('"24931141"', 'other')
# ('"20301665"', 'other')
# ('"32243914"', 'other')
# ('"35303767"', 'other')
# ('"36417958"', 'other')
# ('"33476878"', 'other')
# ('"34092466"', 'other')
# ('"34189496"', 'other')
# ('"36329866"', 'other')
# ('"33134321"', 'other')
# ('"33894367"', 'other')
# ('"34062155"', 'other')
# ('"34358617"', 'other')
# ('"27567612"', 'other')
# ('"36263189"', 'other')
# ('"24757586"', 'other')
# ('"30838317"', 'other')
# ('"37165749"', 'other')
# ('"28843013"', 'other')
# ('"26790671"', 'other')
# ('"17142829"', 'agia')
# ('"28461905"', 'agia')
# ('"20639502"', 'cell cycle')
# ('"19688081"', 'cancer')
# ('"19251712"', 'cancer')
# ('"33425096"', 'cancer')
# ('"14690443"', 'oride')
# ('"10349117"', 'oride')
# ('"7556545"', 'oride')
# ('"21397152"', 'lymphoma')
# ('"15137480"', 'lymphoma')
# ('"30528262"', 'lymphoma')
# ('"16706073"', 'lymphoma')
# ('"30302434"', 'lymphoma')
# ('"11232488"', 'lymphoma')
# ('"37627888"', 'lymphoma')
# ('"35694992"', 'lymphoma')
# ('"18689116"', 'lymphoma')
# ('"20359791"', 'lymphoma')
# ('"20661732"', 'lymphoma')
# ('"21621928"', 'lymphoma')
# ('"22897341"', "eimer's disease")
# ('"27143436"', "eimer's disease")
# ('"11523564"', 'phosphorylation')
# ('"25461922"', 'phosphorylation')
# ('"33458877"', 'phosphorylation')
# ('"27448549"', 'phosphorylation')
# ('"33616084"', 'system development')
# ('"33991565"', 'gents')
# ('"21496605"', 'gents')
# ('"20301665"', 'gents')
# ('"29396398"', 'gents')
# ('"29396174"', 'gents')
# ('"25379658"', 'gents')
# ('"10871631"', 'gents')
# ('"14690443"', 'gents')
# ('"20301665"', 'gents')
# ('"33991565"', 'gents')
# ('"16541453"', 'cell death')

# %%
# check from which data base: 'naling pathway', sive-compulsive disorder

L_list=['localization of cell','naling pathway','immune response','membrane depolarization', 'response to stress',
        'inflammatory response','transferase activity','response to oxidative stress','gnaling pathway',
       'protein phosphorylation','nervous system development','virus infection' ,
        'synaptic signaling','sive-compulsive disorder','autosomal dominant inheritance',
        'synaptic membrane','dilated cardiomyopathy','stiffness',
        'headache','cellular phenotype', 'hypertension','protein processing','muscle contraction',
'cell migration','phosphorylation', 'system development','cell death'
        ]



for i in L_list:
   pathways= list(set(sum(enrichment_all_NCGC00685598['synon'], [])))
   pathways= list(set(sum(pathwys['synon'], [])))
   pathways=[i for i in pathways if len(i)>3 and i !=''  ]
   if i in pathways:
      print(i,'NCGC00685598')
for i in L_list:
   pathways= list(set(sum(enrichment_all_NCGC00602080['synon'], [])))
   pathways= list(set(sum(pathwys['synon'], [])))
   pathways=[i for i in pathways if len(i)>3 and i !=''  ]
   if i in pathways:
         print(i,'NCGC00602080')

for i in L_list:
   pathways= list(set(sum(enrichment_all_NCGC00686269['synon'], [])))
   pathways= list(set(sum(pathwys['synon'], [])))
   pathways=[i for i in pathways if len(i)>3 and i !=''  ]
   if i in pathways:
          print(i,'NCGC00686269')

for i in L_list:
   pathways= list(set(sum(enrichment_all_NCGC00685517['synon'], [])))
   pathways= list(set(sum(pathwys['synon'], [])))
   pathways=[i for i in pathways if len(i)>3 and i !=''  ]
   if i in pathways:
        print(i,'NCGC00685517')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'synon'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-61568dbb890d> in <cell line: 14>()
#      13
#      14 for i in L_list:
# ---> 15    pathways= list(set(sum(enrichment_all_NCGC00685598['synon'], [])))
#      16    pathways= list(set(sum(pathwys['synon'], [])))
#      17    pathways=[i for i in pathways if len(i)>3 and i !=''  ]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'synon'

# %%
pathways=  pathwys# pd.read_csv('/content/enrichment_all.csv')
pathways= list(set(sum(pathwys['synon'], [])))
#[ i[11:].strip().lower()  for i in  list(pathways['Pathway'])]
dyt1['title_abstract'] = dyt1['p.title'].astype(str) + '. ' + dyt1['p.abstractText'].astype(str)

pathways_for_concurency=set()
papers_pathways=set()
for i in pathways:
     for j in dyt1.index:
         if i in dyt1['related_gene'][j]:
              print((dyt1['p.pubmed_id'][j],i))
              pathways_for_concurency.add(i)
              papers_pathways.add(dyt1['p.pubmed_id'][j])
# Out:
# ('"33468570"', 'nucleocytoplasmic transport')
# ('"24931141"', 'protein degradation')
# ('"24627482"', 'protein degradation')
# ('"37627888"', 'viral infection')
# ('"941769"', 'viral infection')
# ('"32516804"', 'brain development')
# ('"24311730"', 'neurotransmission')
# ('"11232488"', 'rcd')
# ('"28182308"', 'rcd')
# ('"24444577"', 'inflammation')
# ('"32118025"', 'inflammation')
# ('"30981209"', 'inflammation')
# ('"33796112"', 'inflammation')
# ('"36045526"', 'inflammation')
# ('"10201480"', 'inflammation')
# ('"26017084"', 'inflammation')
# ('"12609485"', 'inflammation')

# %% [markdown]
# Pathways: concurrency

# %%
# !pip install nltk

import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def check_in_one_sen_help(word0, word1, text):
    sentences = sent_tokenize(text)
    count = 0
    for sentence in sentences:
        sentence=sentence.lower()
        if word0.lower() in sentence and word1.lower() in sentence:
            count += 1
    return count

# Example usage
text = """
This is a sample text. It contains several sentences.
Some sentences contain the word apple and some sentences contain the word banana.
This sentence contains both apple and banana. This one does not?
Another apple and banana sentence is here.
"""
word0 = "apple"
word1 = "banana"
result = check_in_one_sen_help(word0, word1, text)
print(result)
# Out:
# 3

# %%
def chcek_in_one_sen(word, text):
   dyt1_words=['early-onset generalized torsion dystonia', 'tor1a dystonia', 'idiopathic dystonia dyt1', 'primary torsion dystonia', 'early-onset torsion dystonia', "oppenheim's dystonia", 'torsin a', 'early onset torsion dystonia', 'dyt1 dystonia', 'torsina', 'oppenheim dystonia', 'early-onset generalized dystonia', 'torsin-1a', 'tor1a', 'dyt1', 'dystonia 1', 'torsion (autosomal dominant; torsin a)', "oppenheim's dystonia", 'dyt1 early-onset isolated dystonia', 'early-onset torsion dystonia', 'dyt1', 'torsin family 1', 'dystonia musculorum deformans 1', 'dystonia musculorum deformans', 'dystonia 1, torsion, autosomal dominant', 'idiopathic torsion dystonia', 'early-onset generalized limb-onset dystonia', 'idiopathic torsion dystonia', 'dq2', 'early-onset primary dystonia', 'member a (torsin a)', 'dyt-tor1a dystonia', 'torsina', 'primary dystonias', 'early-onset torsion dystonia', 'eotd', 'dystonia 1', 'early-onset isolated dystonia']
   #['torsina','dyt1', 'tor1a', 'primary dystonias', 'dyt1 dystonia', 'tor1a dystonia', 'early-onset torsion dystonia', "oppenheim's dystonia", 'primary torsion dystonia', 'idiopathic torsion dystonia']
   num=0
   for i in dyt1_words:
       num+=  check_in_one_sen_help(i,word, text)
   return num

pheno_count_smae_Sen=dict()
for i in list(pathways_for_concurency):
    pheno_count_smae_Sen[i.lower()]=[]

dyt1['title_abstract'] = dyt1['p.title'].astype(str) + '. ' + dyt1['p.abstractText'].astype(str)


for i in  dyt1.index:
  pubid=dyt1['p.pubmed_id'][i]
  if pubid in papers_pathways:
        tetx=dyt1['title_abstract'][i]
        words_to_chcek=   pathways_for_concurency
        for j in words_to_chcek:
            num=chcek_in_one_sen(j,tetx)
            if num >0:
                pheno_count_smae_Sen[j.lower()].append((pubid,num))
pheno_count_smae_Sen
# Out:
# {'localization of cell': [],
#  'tion': [('"2317008"', 2),
#   ('"1867195"', 2),
#   ('"8079990"', 4),
#   ('"2309703"', 6),
#   ('"1347197"', 10),
#   ('"8513401"', 2),
#   ('"7719342"', 2),
#   ('"7979224"', 12),
#   ('"10435508"', 9),
#   ('"15668438"', 9),
#   ('"7911621"', 2),
#   ('"1985454"', 2),
#   ('"10737119"', 4),
#   ('"9120448"', 2),
#   ('"9778264"', 4),
#   ('"9779659"', 2),
#   ('"15897512"', 8),
#   ('"12575458"', 2),
#   ('"6683367"', 2),
#   ('"1677923"', 2),
#   ('"9266460"', 4),
#   ('"15954126"', 2),
#   ('"9146024"', 2),
#   ('"12785748"', 3),
#   ('"11912106"', 4),
#   ('"28943611"', 1),
#   ('"34167694"', 2),
#   ('"10583169"', 1),
#   ('"20471632"', 2),
#   ('"16639700"', 3),
#   ('"26234084"', 1),
#   ('"18279642"', 1),
#   ('"19593686"', 2),
#   ('"19834793"', 1),
#   ('"31244841"', 1),
#   ('"26060104"', 1),
#   ('"21397152"', 1),
#   ('"15137480"', 1),
#   ('"12477369"', 1),
#   ('"11302971"', 1),
#   ('"19244266"', 1),
#   ('"16967287"', 1),
#   ('"30561390"', 1),
#   ('"25925917"', 1),
#   ('"24198965"', 1),
#   ('"33239013"', 1),
#   ('"32370566"', 1),
#   ('"9039166"', 1),
#   ('"26001889"', 1),
#   ('"33725967"', 1),
#   ('"32118025"', 1),
#   ('"30528262"', 2),
#   ('"29561984"', 3),
#   ('"24210306"', 1),
#   ('"8365724"', 1),
#   ('"30141790"', 1),
#   ('"12402271"', 2),
#   ('"10541594"', 3),
#   ('"16682692"', 2),
#   ('"10449567"', 5),
#   ('"19345148"', 2),
#   ('"19345147"', 5),
#   ('"20211909"', 2),
#   ('"8684386"', 6),
#   ('"9288096"', 2),
#   ('"9149944"', 8),
#   ('"10738516"', 10),
#   ('"11523564"', 10),
#   ('"11973627"', 8),
#   ('"12473770"', 3),
#   ('"12838525"', 10),
#   ('"15111678"', 2),
#   ('"12975293"', 8),
#   ('"15293281"', 6),
#   ('"15326234"', 9),
#   ('"15455404"', 13),
#   ('"15548549"', 2),
#   ('"17027035"', 3),
#   ('"17503336"', 8),
#   ('"18477710"', 14),
#   ('"18823044"', 2),
#   ('"19528516"', 4),
#   ('"19955557"', 6),
#   ('"16415980"', 5),
#   ('"22132914"', 6),
#   ('"27919237"', 2),
#   ('"30879706"', 2),
#   ('"33476878"', 5),
#   ('"33757902"', 16),
#   ('"33616084"', 2),
#   ('"33706202"', 8),
#   ('"34038798"', 18),
#   ('"34092466"', 11),
#   ('"34119482"', 20),
#   ('"34438319"', 3),
#   ('"10073176"', 2),
#   ('"10994500"', 4),
#   ('"11984483"', 3),
#   ('"24262166"', 4),
#   ('"25192508"', 3),
#   ('"8255463"', 2),
#   ('"19685389"', 8),
#   ('"21847143"', 2),
#   ('"28843013"', 3),
#   ('"24311730"', 14),
#   ('"22266882"', 3),
#   ('"33395620"', 9),
#   ('"12194383"', 5),
#   ('"10919137"', 2),
#   ('"12391355"', 2),
#   ('"12151848"', 2),
#   ('"30244176"', 6),
#   ('"34408078"', 7),
#   ('"34189496"', 17),
#   ('"33476687"', 15),
#   ('"33488508"', 3),
#   ('"1427899"', 2),
#   ('"16275837"', 8),
#   ('"14989804"', 14),
#   ('"12691403"', 4),
#   ('"12821512"', 9),
#   ('"33468570"', 21),
#   ('"17702041"', 4),
#   ('"19349605"', 2),
#   ('"17061185"', 10),
#   ('"22151759"', 3),
#   ('"14502672"', 8),
#   ('"24949445"', 2),
#   ('"21839475"', 2),
#   ('"15505159"', 3),
#   ('"9837831"', 11),
#   ('"30028274"', 2),
#   ('"28102337"', 6),
#   ('"26790671"', 4),
#   ('"25894231"', 2),
#   ('"25209853"', 2),
#   ('"23622412"', 2),
#   ('"23284065"', 6),
#   ('"22166420"', 5),
#   ('"22345219"', 4),
#   ('"21496608"', 6),
#   ('"20627944"', 21),
#   ('"20841370"', 2),
#   ('"19117362"', 2),
#   ('"18265016"', 4),
#   ('"19066193"', 4),
#   ('"18267263"', 9),
#   ('"16227522"', 2),
#   ('"15390016"', 3),
#   ('"14872019"', 15),
#   ('"15258227"', 4),
#   ('"12761637"', 2),
#   ('"12781594"', 4),
#   ('"31618684"', 25),
#   ('"27716431"', 11),
#   ('"24508913"', 2),
#   ('"23967309"', 22),
#   ('"23018676"', 15),
#   ('"22391119"', 14),
#   ('"21995941"', 8),
#   ('"21136869"', 12),
#   ('"21078339"', 11),
#   ('"20584926"', 16),
#   ('"20223934"', 26),
#   ('"20132487"', 18),
#   ('"18827015"', 19),
#   ('"18299128"', 12),
#   ('"17956903"', 18),
#   ('"17550429"', 14),
#   ('"17428918"', 12),
#   ('"16934985"', 10),
#   ('"16458269"', 10),
#   ('"16364891"', 7),
#   ('"15930383"', 12),
#   ('"11730696"', 11),
#   ('"10814722"', 5),
#   ('"36417958"', 12),
#   ('"35955710"', 5),
#   ('"36546658"', 8),
#   ('"31805123"', 4),
#   ('"31320448"', 7),
#   ('"26183317"', 13),
#   ('"24951854"', 14),
#   ('"23840813"', 5),
#   ('"20460154"', 12),
#   ('"30237473"', 1),
#   ('"33247415"', 2),
#   ('"32516804"', 7),
#   ('"29739751"', 4),
#   ('"31580306"', 2),
#   ('"32079672"', 2),
#   ('"24938147"', 1),
#   ('"25347348"', 1),
#   ('"33753289"', 2),
#   ('"27666935"', 2),
#   ('"33502045"', 4),
#   ('"25779878"', 1),
#   ('"23365103"', 1),
#   ('"30643666"', 1),
#   ('"25449075"', 1),
#   ('"18322712"', 2),
#   ('"22722545"', 5),
#   ('"31321303"', 3),
#   ('"31517057"', 3),
#   ('"32239467"', 6),
#   ('"33175450"', 7),
#   ('"33832800"', 3),
#   ('"29053766"', 7),
#   ('"33134321"', 8),
#   ('"17200151"', 9),
#   ('"11940688"', 2),
#   ('"37134150"', 8),
#   ('"36329866"', 16),
#   ('"33991565"', 3),
#   ('"34398157"', 1),
#   ('"33458877"', 6),
#   ('"33529159"', 21),
#   ('"33445430"', 4),
#   ('"33799994"', 3),
#   ('"33894367"', 9),
#   ('"34173686"', 8),
#   ('"34398825"', 15),
#   ('"27911022"', 8),
#   ('"22040906"', 4),
#   ('"22080833"', 6),
#   ('"29325615"', 1),
#   ('"34358617"', 10),
#   ('"9486405"', 1),
#   ('"9186828"', 1),
#   ('"8605706"', 1),
#   ('"7875491"', 1),
#   ('"7490916"', 1),
#   ('"37627888"', 1),
#   ('"3458307"', 3),
#   ('"34476293"', 1),
#   ('"32777581"', 2),
#   ('"32195978"', 1),
#   ('"35694992"', 2),
#   ('"36045526"', 1),
#   ('"35665810"', 1),
#   ('"36415137"', 3),
#   ('"36468571"', 1),
#   ('"36096955"', 3),
#   ('"10028024"', 1),
#   ('"10201480"', 1),
#   ('"10611103"', 2),
#   ('"10644435"', 7),
#   ('"11495087"', 2),
#   ('"14517787"', 1),
#   ('"15011460"', 1),
#   ('"15793882"', 1),
#   ('"16227563"', 1),
#   ('"1626073"', 1),
#   ('"16981842"', 1),
#   ('"18519462"', 1),
#   ('"19041429"', 1),
#   ('"19052350"', 1),
#   ('"19208776"', 1),
#   ('"19251712"', 2),
#   ('"20178968"', 1),
#   ('"20661732"', 2),
#   ('"26017084"', 1),
#   ('"28708086"', 1),
#   ('"29516402"', 1),
#   ('"29858799"', 1),
#   ('"30444426"', 1),
#   ('"33724724"', 1),
#   ('"21496605"', 1),
#   ('"20590811"', 1),
#   ('"15786454"', 1),
#   ('"19182804"', 3),
#   ('"21656045"', 2),
#   ('"2404852"', 1),
#   ('"21907099"', 4),
#   ('"14022841"', 1),
#   ('"13597141"', 1),
#   ('"945867"', 1),
#   ('"6470761"', 1),
#   ('"26417535"', 1),
#   ('"17385355"', 1),
#   ('"12822816"', 6),
#   ('"35312111"', 1),
#   ('"36757831"', 3),
#   ('"36648081"', 3),
#   ('"35533513"', 7),
#   ('"12609485"', 10),
#   ('"15939081"', 7),
#   ('"16938275"', 5),
#   ('"17290457"', 5),
#   ('"19038309"', 18),
#   ('"19157930"', 3),
#   ('"19284587"', 14),
#   ('"19578124"', 4),
#   ('"20301665"', 9),
#   ('"22639460"', 3),
#   ('"22897341"', 7),
#   ('"23180184"', 4),
#   ('"23196519"', 8),
#   ('"23222958"', 1),
#   ('"23893446"', 3),
#   ('"24092288"', 3),
#   ('"24588501"', 4),
#   ('"24757586"', 3),
#   ('"24931141"', 16),
#   ('"25155315"', 3),
#   ('"25203860"', 5),
#   ('"25403864"', 3),
#   ('"26004199"', 2),
#   ('"26297380"', 13),
#   ('"26810727"', 2),
#   ('"26940431"', 11),
#   ('"27143436"', 1),
#   ('"27477622"', 10),
#   ('"28283962"', 1),
#   ('"28756192"', 3),
#   ('"29396398"', 10),
#   ('"30100364"', 1),
#   ('"30838317"', 7),
#   ('"32243914"', 6),
#   ('"32502938"', 23),
#   ('"32662044"', 3),
#   ('"34949287"', 4),
#   ('"35044558"', 1),
#   ('"35303767"', 5),
#   ('"17713116"', 4),
#   ('"9874484"', 8),
#   ('"9749609"', 2),
#   ('"9749595"', 15),
#   ('"9667600"', 7),
#   ('"9618171"', 19),
#   ('"9585364"', 11),
#   ('"9191768"', 8),
#   ('"7629534"', 4),
#   ('"37352388"', 6),
#   ('"37267819"', 3),
#   ('"37165749"', 11),
#   ('"32289333"', 5),
#   ('"29483592"', 6),
#   ('"27093447"', 3),
#   ('"26596547"', 9),
#   ('"26592310"', 3),
#   ('"25653290"', 6),
#   ('"25379658"', 12),
#   ('"25337725"', 2),
#   ('"25149450"', 6),
#   ('"23724359"', 3),
#   ('"23436503"', 2),
#   ('"22770546"', 2),
#   ('"22622408"', 8),
#   ('"21800139"', 7),
#   ('"21750546"', 10),
#   ('"20687193"', 2),
#   ('"20482602"', 5),
#   ('"20066431"', 2),
#   ('"19844939"', 2),
#   ('"19651773"', 18),
#   ('"19555827"', 10),
#   ('"19457118"', 13),
#   ('"19403250"', 2),
#   ('"19260107"', 8),
#   ('"19039992"', 7),
#   ('"18571468"', 9),
#   ('"18552369"', 17),
#   ('"18437909"', 10),
#   ('"18299520"', 4),
#   ('"18258738"', 19),
#   ('"18224570"', 14),
#   ('"18176524"', 2),
#   ('"17894340"', 2),
#   ('"36288966"', 2),
#   ('"36302970"', 5),
#   ('"36263189"', 4),
#   ('"35563018"', 6),
#   ('"10050893"', 12),
#   ('"10225357"', 9),
#   ('"10448655"', 4),
#   ('"10477437"', 6),
#   ('"10627938"', 9),
#   ('"10714658"', 11),
#   ('"10720299"', 10),
#   ('"10871631"', 12),
#   ('"10881900"', 5),
#   ('"10984667"', 9),
#   ('"11009204"', 2),
#   ('"11104212"', 6),
#   ('"11261511"', 2),
#   ('"11835464"', 4),
#   ('"11921134"', 7),
#   ('"11980065"', 2),
#   ('"12360559"', 4),
#   ('"12760408"', 8),
#   ('"12821514"', 15),
#   ('"12859412"', 6),
#   ('"12883919"', 2),
#   ('"14581671"', 2),
#   ('"15342362"', 2),
#   ('"15555920"', 15),
#   ('"15593317"', 4),
#   ('"15726581"', 2),
#   ('"16361107"', 6),
#   ('"16537570"', 18),
#   ('"16631205"', 12),
#   ('"16773641"', 4),
#   ('"17129379"', 4),
#   ('"22472189"', 9),
#   ('"15283994"', 14),
#   ('"12671990"', 21),
#   ('"12007841"', 5),
#   ('"19214438"', 5),
#   ('"11405807"', 9),
#   ('"35796490"', 3),
#   ('"36409706"', 2),
#   ('"25674472"', 13),
#   ('"21818381"', 13),
#   ('"20169475"', 14),
#   ('"15136718"', 11),
#   ('"15989773"', 2),
#   ('"11438481"', 7),
#   ('"14690443"', 23),
#   ('"15099679"', 13),
#   ('"15147511"', 11),
#   ('"15505207"', 20),
#   ('"15829632"', 7),
#   ('"19761814"', 11),
#   ('"20639502"', 4),
#   ('"24627482"', 15),
#   ('"25425325"', 6),
#   ('"28768697"', 9),
#   ('"35643882"', 3),
#   ('"26506956"', 1),
#   ('"23107556"', 2),
#   ('"34062155"', 11),
#   ('"9539346"', 4),
#   ('"9380054"', 4),
#   ('"8595478"', 2),
#   ('"8413963"', 2),
#   ('"7969702"', 2),
#   ('"3746330"', 2),
#   ('"2840805"', 2),
#   ('"2215959"', 2),
#   ('"2005929"', 2),
#   ('"1940944"', 2),
#   ('"1758449"', 2),
#   ('"11432664"', 2),
#   ('"9819835"', 2),
#   ('"9225692"', 2),
#   ('"9221523"', 2),
#   ('"9153120"', 2),
#   ('"8723145"', 2),
#   ('"8703227"', 2),
#   ('"10526391"', 2),
#   ('"10877155"', 2),
#   ('"10980732"', 2),
#   ('"11685399"', 2),
#   ('"11701630"', 2),
#   ('"12876228"', 2),
#   ('"17125732"', 2),
#   ('"21048241"', 2),
#   ('"2356013"', 2),
#   ('"4065158"', 2),
#   ('"7556545"', 2),
#   ('"7695236"', 2),
#   ('"2966619"', 1),
#   ('"11598522"', 2),
#   ('"8416347"', 1),
#   ('"8277565"', 1),
#   ('"796956"', 1),
#   ('"7856369"', 1),
#   ('"7164771"', 1),
#   ('"7092616"', 1),
#   ('"6822602"', 1),
#   ('"6234055"', 2),
#   ('"482013"', 1),
#   ('"3178457"', 1),
#   ('"310282"', 1),
#   ('"2977281"', 2),
#   ('"2868026"', 1),
#   ('"2840407"', 1),
#   ('"22604515"', 1),
#   ('"2164296"', 1),
#   ('"8894706"', 2),
#   ('"21840890"', 6),
#   ('"17960812"', 1),
#   ('"10833562"', 1),
#   ('"27448549"', 1),
#   ('"18688663"', 4),
#   ('"7052665"', 1),
#   ('"4448193"', 1),
#   ('"207060"', 1),
#   ('"31332180"', 8),
#   ('"27490483"', 10),
#   ('"6240313"', 1),
#   ('"38214203"', 1),
#   ('"27477622"', 10),
#   ('"32662044"', 3),
#   ('"37352388"', 6),
#   ('"26297380"', 13),
#   ('"32502938"', 23),
#   ('"24931141"', 16),
#   ('"29641419"', 1),
#   ('"20301665"', 9),
#   ('"32243914"', 6),
#   ('"35303767"', 5),
#   ('"31618684"', 25),
#   ('"36417958"', 12),
#   ('"33476878"', 5),
#   ('"34092466"', 11),
#   ('"33468570"', 21),
#   ('"33753289"', 2),
#   ('"29325615"', 1),
#   ('"32239467"', 6),
#   ('"32516804"', 7),
#   ('"33247415"', 2),
#   ('"33175450"', 7),
#   ('"33502045"', 4),
#   ('"34189496"', 17),
#   ('"29053766"', 7),
#   ('"30244176"', 6),
#   ('"24627482"', 15),
#   ('"26592310"', 3),
#   ('"28768697"', 9),
#   ('"35563018"', 6),
#   ('"36329866"', 16),
#   ('"35955710"', 5),
#   ('"33134321"', 8),
#   ('"33757902"', 16),
#   ('"33894367"', 9),
#   ('"34062155"', 11),
#   ('"34119482"', 20),
#   ('"24311730"', 14),
#   ('"27911022"', 8),
#   ('"33229589"', 6),
#   ('"29739751"', 4),
#   ('"34358617"', 10),
#   ('"26183317"', 13),
#   ('"36263189"', 4),
#   ('"34398825"', 15),
#   ('"36757831"', 3),
#   ('"24757586"', 3),
#   ('"27716431"', 11),
#   ('"30838317"', 7),
#   ('"32289333"', 5),
#   ('"37165749"', 11),
#   ('"28756192"', 3),
#   ('"33445430"', 4),
#   ('"33799994"', 3),
#   ('"33991565"', 3),
#   ('"28843013"', 3),
#   ('"28941827"', 2),
#   ('"33395620"', 9),
#   ('"26790671"', 4),
#   ('"14022841"', 1),
#   ('"32037012"', 3),
#   ('"26596547"', 9)],
#  'regulation': [('"33468570"', 11),
#   ('"27716431"', 1),
#   ('"30237473"', 1),
#   ('"33753289"', 1),
#   ('"33799994"', 2),
#   ('"21750546"', 4),
#   ('"33468570"', 11),
#   ('"33753289"', 1),
#   ('"27716431"', 1),
#   ('"33799994"', 2)],
#  'ness': [('"11912106"', 4),
#   ('"15137480"', 1),
#   ('"34038798"', 2),
#   ('"16275837"', 2),
#   ('"33832800"', 1),
#   ('"23724359"', 3),
#   ('"18571468"', 2),
#   ('"36263189"', 3),
#   ('"8277565"', 1),
#   ('"2840407"', 1),
#   ('"36263189"', 3)],
#  'transferase activity': [('"7299845"', 1)],
#  'naling pathway': [('"22391119"', 4),
#   ('"32289333"', 5),
#   ('"25379658"', 2),
#   ('"32289333"', 5)],
#  'sylate': [('"15147511"', 2)],
#  'response to oxidative stress': [('"12671990"', 2)],
#  'muscle contraction': [('"2317008"', 2),
#   ('"1867195"', 2),
#   ('"34189496"', 4),
#   ('"33468570"', 3),
#   ('"23018676"', 4),
#   ('"20223934"', 4),
#   ('"26183317"', 5),
#   ('"23840813"', 2),
#   ('"36329866"', 3),
#   ('"19457118"', 3),
#   ('"17129379"', 2),
#   ('"21818381"', 3),
#   ('"24627482"', 4),
#   ('"27448549"', 1),
#   ('"33468570"', 3),
#   ('"34189496"', 4),
#   ('"24627482"', 4),
#   ('"36329866"', 3),
#   ('"26183317"', 5)],
#  'tension': [('"14872019"', 2),
#   ('"16361107"', 4),
#   ('"7856369"', 1),
#   ('"6234055"', 1)],
#  'virus infection': [],
#  'phosphorylation': [('"11523564"', 2), ('"33458877"', 6)],
#  's nos': [('"796956"', 1)],
#  'aling pathway': [('"22391119"', 4),
#   ('"32289333"', 5),
#   ('"25379658"', 2),
#   ('"32289333"', 5)],
#  'secretion': [('"17428918"', 4), ('"18258738"', 12), ('"21818381"', 2)],
#  'ydrochloride': [('"7556545"', 2)],
#  'other': [('"8079990"', 2),
#   ('"1347197"', 2),
#   ('"10435508"', 1),
#   ('"1985454"', 2),
#   ('"9120448"', 6),
#   ('"2666583"', 2),
#   ('"8277574"', 2),
#   ('"16456406"', 1),
#   ('"15137480"', 1),
#   ('"20499382"', 1),
#   ('"9039166"', 1),
#   ('"2785717"', 1),
#   ('"33472447"', 1),
#   ('"24210306"', 1),
#   ('"8365724"', 1),
#   ('"10449567"', 2),
#   ('"11973627"', 2),
#   ('"15326234"', 2),
#   ('"15455404"', 2),
#   ('"15548549"', 2),
#   ('"19955557"', 1),
#   ('"27939583"', 2),
#   ('"31604331"', 2),
#   ('"33476878"', 2),
#   ('"34092466"', 3),
#   ('"34438319"', 3),
#   ('"10994500"', 2),
#   ('"23420606"', 2),
#   ('"19685389"', 4),
#   ('"22266882"', 3),
#   ('"12194383"', 2),
#   ('"10919137"', 2),
#   ('"34189496"', 3),
#   ('"33488508"', 5),
#   ('"16275837"', 2),
#   ('"9837831"', 2),
#   ('"26790671"', 2),
#   ('"23622412"', 2),
#   ('"23284065"', 2),
#   ('"22166420"', 2),
#   ('"22345219"', 1),
#   ('"21496608"', 2),
#   ('"20627944"', 4),
#   ('"14872019"', 4),
#   ('"15258227"', 2),
#   ('"23967309"', 7),
#   ('"20223934"', 3),
#   ('"18299128"', 5),
#   ('"36417958"', 2),
#   ('"32079672"', 1),
#   ('"25449075"', 1),
#   ('"33832800"', 1),
#   ('"33134321"', 2),
#   ('"36329866"', 2),
#   ('"33458877"', 2),
#   ('"33894367"', 5),
#   ('"34358617"', 1),
#   ('"9486405"', 1),
#   ('"7783076"', 1),
#   ('"36045526"', 1),
#   ('"10644435"', 7),
#   ('"33724724"', 1),
#   ('"19182804"', 1),
#   ('"20344681"', 1),
#   ('"13597141"', 1),
#   ('"945867"', 1),
#   ('"17385355"', 1),
#   ('"19284587"', 2),
#   ('"20301665"', 1),
#   ('"22897341"', 5),
#   ('"24757586"', 3),
#   ('"24931141"', 1),
#   ('"25203860"', 1),
#   ('"25403864"', 3),
#   ('"26297380"', 4),
#   ('"30838317"', 3),
#   ('"32243914"', 2),
#   ('"9874484"', 2),
#   ('"9191768"', 2),
#   ('"8871591"', 2),
#   ('"8309575"', 2),
#   ('"7845403"', 6),
#   ('"7629534"', 4),
#   ('"37352388"', 2),
#   ('"37267819"', 5),
#   ('"19260107"', 2),
#   ('"18437909"', 3),
#   ('"18224570"', 5),
#   ('"17894340"', 2),
#   ('"12360559"', 2),
#   ('"12760408"', 2),
#   ('"16361107"', 2),
#   ('"16537570"', 2),
#   ('"17097111"', 3),
#   ('"17129379"', 1),
#   ('"12671990"', 2),
#   ('"36409706"', 1),
#   ('"21818381"', 2),
#   ('"20169475"', 2),
#   ('"11244697"', 4),
#   ('"15147511"', 4),
#   ('"15505207"', 2),
#   ('"15829632"', 5),
#   ('"34062155"', 2),
#   ('"941774"', 2),
#   ('"11432664"', 2),
#   ('"650244"', 2),
#   ('"6697632"', 2),
#   ('"2868026"', 1),
#   ('"2179685"', 1),
#   ('"27448549"', 4),
#   ('"18688663"', 2),
#   ('"19765051"', 1),
#   ('"6240313"', 1),
#   ('"37352388"', 2),
#   ('"26297380"', 4),
#   ('"24931141"', 1),
#   ('"20301665"', 1),
#   ('"32243914"', 2),
#   ('"36417958"', 2),
#   ('"33476878"', 2),
#   ('"34092466"', 3),
#   ('"34189496"', 3),
#   ('"36329866"', 2),
#   ('"33134321"', 2),
#   ('"33894367"', 5),
#   ('"34062155"', 2),
#   ('"34358617"', 1),
#   ('"24757586"', 3),
#   ('"30838317"', 3),
#   ('"26790671"', 2)],
#  'y impairment': [('"34398825"', 4), ('"34398825"', 4)],
#  'ulfide': [('"12671990"', 2), ('"34062155"', 4), ('"34062155"', 4)],
#  'egulation': [('"33468570"', 11),
#   ('"27716431"', 1),
#   ('"30237473"', 1),
#   ('"33753289"', 1),
#   ('"33799994"', 2),
#   ('"21750546"', 4),
#   ('"33468570"', 11),
#   ('"33753289"', 1),
#   ('"27716431"', 1),
#   ('"33799994"', 2)],
#  'e spasms': [('"25449075"', 1), ('"8353711"', 2)],
#  'mmation': [('"32118025"', 1), ('"30528262"', 1), ('"12609485"', 1)],
#  'agia': [],
#  'depression': [('"15326234"', 7),
#   ('"36417958"', 2),
#   ('"33991565"', 3),
#   ('"34398825"', 4),
#   ('"36417958"', 2),
#   ('"34398825"', 4),
#   ('"33991565"', 3)],
#  'tility': [],
#  'rome': [('"8916165"', 2),
#   ('"1347197"', 2),
#   ('"1639411"', 4),
#   ('"15954126"', 2),
#   ('"12785748"', 3),
#   ('"11912106"', 5),
#   ('"16639700"', 1),
#   ('"16967287"', 1),
#   ('"16682692"', 2),
#   ('"19955557"', 1),
#   ('"11984483"', 3),
#   ('"11528394"', 2),
#   ('"30244176"', 1),
#   ('"1427899"', 2),
#   ('"16275837"', 4),
#   ('"17702041"', 2),
#   ('"17061185"', 8),
#   ('"30028274"', 2),
#   ('"28102337"', 2),
#   ('"26790671"', 2),
#   ('"23622412"', 2),
#   ('"23284065"', 2),
#   ('"22166420"', 5),
#   ('"14872019"', 2),
#   ('"14628853"', 1),
#   ('"12781594"', 2),
#   ('"32516804"', 3),
#   ('"17200151"', 2),
#   ('"3458307"', 1),
#   ('"10201480"', 1),
#   ('"20590811"', 1),
#   ('"2315224"', 1),
#   ('"9146025"', 1),
#   ('"17385355"', 1),
#   ('"19578124"', 1),
#   ('"21301909"', 1),
#   ('"20482602"', 1),
#   ('"19651773"', 2),
#   ('"16361107"', 1),
#   ('"16924015"', 2),
#   ('"2005929"', 2),
#   ('"11432664"', 2),
#   ('"17125732"', 2),
#   ('"4065158"', 2),
#   ('"6697632"', 5),
#   ('"7507398"', 2),
#   ('"796956"', 1),
#   ('"7856369"', 1),
#   ('"22604515"', 1),
#   ('"21840890"', 1),
#   ('"32516804"', 3),
#   ('"30244176"', 1),
#   ('"26790671"', 2)],
#  'gnaling pathway': [('"22391119"', 4),
#   ('"32289333"', 5),
#   ('"25379658"', 2),
#   ('"32289333"', 5)],
#  'sive-compulsive disorder': [],
#  'core': [('"10674821"', 2),
#   ('"9779659"', 2),
#   ('"22132914"', 3),
#   ('"33395620"', 3),
#   ('"20841370"', 2),
#   ('"32239467"', 1),
#   ('"36355183"', 1),
#   ('"7231447"', 1),
#   ('"9749595"', 2),
#   ('"34645254"', 2),
#   ('"25653290"', 2),
#   ('"19403250"', 2),
#   ('"18552369"', 2),
#   ('"11261511"', 2),
#   ('"482013"', 1),
#   ('"32239467"', 1),
#   ('"33395620"', 3)],
#  'trophy': [('"32118025"', 1),
#   ('"32044834"', 1),
#   ('"33757902"', 2),
#   ('"34038798"', 4),
#   ('"31320448"', 2),
#   ('"24951854"', 3),
#   ('"25461922"', 5),
#   ('"36329866"', 2),
#   ('"34173686"', 4),
#   ('"37554750"', 1),
#   ('"7231447"', 1),
#   ('"37352388"', 2),
#   ('"26596547"', 6),
#   ('"12821514"', 6),
#   ('"25425325"', 1),
#   ('"15568498"', 1),
#   ('"37352388"', 2),
#   ('"36329866"', 2),
#   ('"33757902"', 2),
#   ('"26596547"', 6)],
#  'idine': [('"16537570"', 2)],
#  'membrane depolarization': [],
#  'esthesia': [('"20687193"', 2), ('"16024174"', 2)],
#  'protein phosphorylation': [],
#  'itis': [('"8513401"', 6),
#   ('"16779462"', 1),
#   ('"20211909"', 2),
#   ('"10738516"', 4),
#   ('"20223934"', 6),
#   ('"8244257"', 2),
#   ('"7875491"', 1),
#   ('"7490916"', 1),
#   ('"36468571"', 1),
#   ('"11495087"', 1),
#   ('"15793882"', 1),
#   ('"18519462"', 2),
#   ('"19041429"', 1),
#   ('"22465228"', 1),
#   ('"29516402"', 1),
#   ('"29858799"', 1),
#   ('"17385355"', 1),
#   ('"8450297"', 1),
#   ('"15829632"', 2),
#   ('"2183913"', 2),
#   ('"1758449"', 2)],
#  'nervous system development': [('"33616084"', 3)],
#  'response to stress': [('"18267263"', 2),
#   ('"19555827"', 2),
#   ('"12671990"', 2)],
#  'cell cycle': [],
#  "alzheimer's disease": [],
#  'titis': [('"8244257"', 2),
#   ('"7490916"', 1),
#   ('"15793882"', 1),
#   ('"18519462"', 2),
#   ('"19041429"', 1)],
#  'ompounds': [('"34408078"', 7)],
#  'behavior': [('"12838525"', 4),
#   ('"33757902"', 2),
#   ('"24311730"', 2),
#   ('"20223934"', 7),
#   ('"20132487"', 2),
#   ('"18299128"', 5),
#   ('"15930383"', 2),
#   ('"36417958"', 2),
#   ('"36546658"', 3),
#   ('"33529159"', 2),
#   ('"22472189"', 2),
#   ('"14690443"', 2),
#   ('"2868026"', 1),
#   ('"36417958"', 2),
#   ('"33757902"', 2),
#   ('"24311730"', 2)],
#  'autosomal dominant inheritance': [('"2309703"', 2),
#   ('"1347197"', 2),
#   ('"25402387"', 1),
#   ('"17956903"', 8),
#   ('"11940688"', 2),
#   ('"29396174"', 2),
#   ('"12821514"', 3),
#   ('"8894706"', 2)],
#  'tations': [('"8079990"', 2),
#   ('"10737119"', 4),
#   ('"15897512"', 2),
#   ('"11302971"', 1),
#   ('"30561390"', 1),
#   ('"12402271"', 2),
#   ('"19345147"', 5),
#   ('"20211909"', 2),
#   ('"10738516"', 2),
#   ('"11523564"', 3),
#   ('"11973627"', 4),
#   ('"15293281"', 2),
#   ('"15326234"', 2),
#   ('"18823044"', 2),
#   ('"19528516"', 4),
#   ('"19955557"', 3),
#   ('"33476878"', 5),
#   ('"33757902"', 5),
#   ('"34092466"', 2),
#   ('"10994500"', 2),
#   ('"24262166"', 2),
#   ('"25192508"', 3),
#   ('"24311730"', 4),
#   ('"12194383"', 3),
#   ('"10919137"', 2),
#   ('"30244176"', 5),
#   ('"17702041"', 2),
#   ('"21839475"', 2),
#   ('"30028274"', 2),
#   ('"28102337"', 4),
#   ('"26790671"', 4),
#   ('"23284065"', 2),
#   ('"22166420"', 2),
#   ('"22345219"', 4),
#   ('"21496608"', 2),
#   ('"20627944"', 15),
#   ('"19117362"', 2),
#   ('"18265016"', 2),
#   ('"16227522"', 2),
#   ('"15390016"', 3),
#   ('"14872019"', 4),
#   ('"15258227"', 4),
#   ('"23967309"', 7),
#   ('"22391119"', 8),
#   ('"21995941"', 5),
#   ('"20584926"', 6),
#   ('"17956903"', 8),
#   ('"16364891"', 5),
#   ('"31320448"', 3),
#   ('"30237473"', 1),
#   ('"32516804"', 4),
#   ('"33502045"', 2),
#   ('"31321303"', 3),
#   ('"31517057"', 3),
#   ('"33175450"', 1),
#   ('"33832800"', 1),
#   ('"29053766"', 1),
#   ('"17200151"', 4),
#   ('"33991565"', 3),
#   ('"22040906"', 2),
#   ('"22080833"', 2),
#   ('"32195978"', 1),
#   ('"10644435"', 1),
#   ('"19182804"', 2),
#   ('"36648081"', 1),
#   ('"19038309"', 13),
#   ('"19157930"', 2),
#   ('"19284587"', 3),
#   ('"20301665"', 1),
#   ('"22639460"', 3),
#   ('"23180184"', 1),
#   ('"23222958"', 1),
#   ('"23893446"', 3),
#   ('"24092288"', 3),
#   ('"24588501"', 4),
#   ('"24757586"', 3),
#   ('"24931141"', 5),
#   ('"26004199"', 2),
#   ('"26297380"', 8),
#   ('"26810727"', 2),
#   ('"26940431"', 4),
#   ('"27143436"', 1),
#   ('"28283962"', 1),
#   ('"28756192"', 1),
#   ('"34949287"', 3),
#   ('"35303767"', 4),
#   ('"9749595"', 3),
#   ('"9618171"', 2),
#   ('"27093447"', 3),
#   ('"26596547"', 3),
#   ('"26592310"', 2),
#   ('"22622408"', 2),
#   ('"21800139"', 3),
#   ('"20687193"', 2),
#   ('"20482602"', 4),
#   ('"20066431"', 2),
#   ('"18552369"', 6),
#   ('"18437909"', 5),
#   ('"10050893"', 2),
#   ('"12859412"', 4),
#   ('"14581671"', 2),
#   ('"16631205"', 6),
#   ('"15283994"', 1),
#   ('"15099679"', 3),
#   ('"15147511"', 3),
#   ('"15829632"', 5),
#   ('"24627482"', 2),
#   ('"26297380"', 8),
#   ('"24931141"', 5),
#   ('"20301665"', 1),
#   ('"35303767"', 4),
#   ('"33476878"', 5),
#   ('"34092466"', 2),
#   ('"32516804"', 4),
#   ('"33175450"', 1),
#   ('"33502045"', 2),
#   ('"29053766"', 1),
#   ('"30244176"', 5),
#   ('"24627482"', 2),
#   ('"26592310"', 2),
#   ('"33757902"', 5),
#   ('"24311730"', 4),
#   ('"24757586"', 3),
#   ('"28756192"', 1),
#   ('"33991565"', 3),
#   ('"26790671"', 4),
#   ('"32037012"', 1),
#   ('"26596547"', 3)],
#  'ration': [('"12785748"', 2),
#   ('"31244841"', 1),
#   ('"15455404"', 3),
#   ('"22132914"', 3),
#   ('"33757902"', 2),
#   ('"33706202"', 1),
#   ('"34038798"', 2),
#   ('"34092466"', 2),
#   ('"11984483"', 3),
#   ('"24262166"', 2),
#   ('"33395620"', 3),
#   ('"34189496"', 3),
#   ('"17061185"', 3),
#   ('"22151759"', 3),
#   ('"23284065"', 2),
#   ('"20841370"', 2),
#   ('"19117362"', 2),
#   ('"31618684"', 2),
#   ('"27716431"', 5),
#   ('"23018676"', 7),
#   ('"22391119"', 2),
#   ('"20223934"', 1),
#   ('"18827015"', 2),
#   ('"16458269"', 2),
#   ('"10814722"', 3),
#   ('"26183317"', 4),
#   ('"20460154"', 6),
#   ('"32516804"', 1),
#   ('"32079672"', 2),
#   ('"32239467"', 1),
#   ('"36329866"', 2),
#   ('"33529159"', 5),
#   ('"34173686"', 7),
#   ('"34398825"', 4),
#   ('"22040906"', 2),
#   ('"3458307"', 1),
#   ('"35694992"', 1),
#   ('"36415137"', 1),
#   ('"36096955"', 1),
#   ('"21907099"', 4),
#   ('"945867"', 1),
#   ('"35533513"', 4),
#   ('"19578124"', 1),
#   ('"23196519"', 2),
#   ('"35044558"', 1),
#   ('"7629534"', 4),
#   ('"37352388"', 2),
#   ('"25653290"', 2),
#   ('"21750546"', 2),
#   ('"19844939"', 2),
#   ('"19457118"', 4),
#   ('"10871631"', 1),
#   ('"10984667"', 3),
#   ('"15593317"', 2),
#   ('"16361107"', 2),
#   ('"22472189"', 3),
#   ('"15283994"', 2),
#   ('"15989773"', 2),
#   ('"14690443"', 2),
#   ('"10526391"', 2),
#   ('"10877155"', 2),
#   ('"11685399"', 2),
#   ('"12876228"', 2),
#   ('"4065158"', 2),
#   ('"6234055"', 1),
#   ('"2868026"', 1),
#   ('"22604515"', 1),
#   ('"2164296"', 1),
#   ('"37352388"', 2),
#   ('"31618684"', 2),
#   ('"34092466"', 2),
#   ('"32239467"', 1),
#   ('"32516804"', 1),
#   ('"34189496"', 3),
#   ('"36329866"', 2),
#   ('"33757902"', 2),
#   ('"26183317"', 4),
#   ('"34398825"', 4),
#   ('"27716431"', 5),
#   ('"33395620"', 3)],
#  'oxin': [('"12822816"', 2), ('"21750546"', 2), ('"10714658"', 4)],
#  'cancer': [],
#  'pathy': [('"11834848"', 1),
#   ('"19688081"', 1),
#   ('"30561390"', 1),
#   ('"32118025"', 1),
#   ('"16706073"', 1),
#   ('"30302434"', 1),
#   ('"11232488"', 1),
#   ('"31580306"', 2),
#   ('"25449075"', 1),
#   ('"18689116"', 1),
#   ('"20359791"', 1),
#   ('"21621928"', 1),
#   ('"22465228"', 2),
#   ('"25425325"', 2),
#   ('"2614440"', 2),
#   ('"6443743"', 1)],
#  'rine': [('"33757902"', 2),
#   ('"36329866"', 2),
#   ('"33458877"', 2),
#   ('"37352388"', 2),
#   ('"690631"', 2),
#   ('"37352388"', 2),
#   ('"36329866"', 2),
#   ('"33757902"', 2)],
#  'nucleotide binding': [],
#  'ncer': [('"11973627"', 2),
#   ('"27716431"', 5),
#   ('"15159681"', 1),
#   ('"18224570"', 2),
#   ('"796956"', 1),
#   ('"27716431"', 5)],
#  'aling': [('"27939583"', 5),
#   ('"1427899"', 2),
#   ('"22391119"', 4),
#   ('"18827015"', 2),
#   ('"16934985"', 3),
#   ('"22722545"', 2),
#   ('"33894367"', 1),
#   ('"34398825"', 4),
#   ('"32289333"', 5),
#   ('"25379658"', 4),
#   ('"15269177"', 2),
#   ('"33894367"', 1),
#   ('"34398825"', 4),
#   ('"32289333"', 5)],
#  'locomotion': [('"31618684"', 2), ('"20132487"', 2), ('"31618684"', 2)],
#  'oride': [('"14690443"', 2), ('"7556545"', 2)],
#  'transition': [('"18477710"', 1)],
#  'reaction': [('"20471632"', 1),
#   ('"21397152"', 1),
#   ('"9039166"', 1),
#   ('"12975293"', 2),
#   ('"19685389"', 2),
#   ('"28102337"', 2),
#   ('"15793882"', 1),
#   ('"19038309"', 2),
#   ('"32662044"', 1),
#   ('"18571468"', 2),
#   ('"18437909"', 3),
#   ('"10714658"', 4),
#   ('"7556545"', 2),
#   ('"482013"', 1),
#   ('"32662044"', 1)],
#  'ound': [('"1347197"', 4),
#   ('"7719342"', 2),
#   ('"7979224"', 4),
#   ('"34167694"', 1),
#   ('"29418012"', 1),
#   ('"18279642"', 3),
#   ('"19593686"', 1),
#   ('"19834793"', 1),
#   ('"30779476"', 1),
#   ('"26060104"', 1),
#   ('"11834848"', 1),
#   ('"16967287"', 1),
#   ('"32370566"', 1),
#   ('"9039166"', 1),
#   ('"15907240"', 2),
#   ('"33472447"', 1),
#   ('"29561984"', 1),
#   ('"19345148"', 6),
#   ('"19345147"', 3),
#   ('"8684386"', 2),
#   ('"9149944"', 2),
#   ('"10738516"', 8),
#   ('"11523564"', 2),
#   ('"11973627"', 2),
#   ('"12838525"', 2),
#   ('"15111678"', 4),
#   ('"17503336"', 2),
#   ('"19955557"', 1),
#   ('"33638639"', 2),
#   ('"34092466"', 3),
#   ('"34119482"', 5),
#   ('"10994500"', 2),
#   ('"34408078"', 9),
#   ('"33488508"', 3),
#   ('"26087139"', 3),
#   ('"17061185"', 3),
#   ('"14502672"', 4),
#   ('"21839475"', 2),
#   ('"15505159"', 1),
#   ('"9837831"', 2),
#   ('"25209853"', 2),
#   ('"23622412"', 2),
#   ('"23284065"', 4),
#   ('"22345219"', 2),
#   ('"21496608"', 2),
#   ('"20627944"', 2),
#   ('"14872019"', 7),
#   ('"15258227"', 2),
#   ('"21136869"', 2),
#   ('"18827015"', 2),
#   ('"17428918"', 2),
#   ('"31805123"', 2),
#   ('"29739751"', 2),
#   ('"23365103"', 1),
#   ('"25449075"', 1),
#   ('"33832800"', 1),
#   ('"36329866"', 2),
#   ('"33445430"', 4),
#   ('"33799994"', 1),
#   ('"33894367"', 1),
#   ('"34173686"', 6),
#   ('"34398825"', 3),
#   ('"8605706"', 1),
#   ('"7875491"', 1),
#   ('"35074908"', 1),
#   ('"33796112"', 1),
#   ('"35694992"', 1),
#   ('"35611878"', 1),
#   ('"10028024"', 1),
#   ('"10198739"', 1),
#   ('"14517787"', 1),
#   ('"16227563"', 1),
#   ('"1626073"', 1),
#   ('"17006990"', 1),
#   ('"19041429"', 1),
#   ('"19052350"', 1),
#   ('"30444426"', 1),
#   ('"36648081"', 1),
#   ('"16938275"', 2),
#   ('"19284587"', 5),
#   ('"19578124"', 1),
#   ('"23180184"', 1),
#   ('"25203860"', 4),
#   ('"26004199"', 1),
#   ('"26297380"', 3),
#   ('"26940431"', 1),
#   ('"27477622"', 3),
#   ('"28432771"', 2),
#   ('"28756192"', 4),
#   ('"30838317"', 3),
#   ('"32243914"', 2),
#   ('"34949287"', 3),
#   ('"35303767"', 1),
#   ('"9874484"', 2),
#   ('"9749595"', 3),
#   ('"9585364"', 2),
#   ('"9191768"', 6),
#   ('"37267819"', 5),
#   ('"37165749"', 5),
#   ('"20482602"', 1),
#   ('"19651773"', 2),
#   ('"19457118"', 2),
#   ('"19403250"', 2),
#   ('"19260107"', 1),
#   ('"18437909"', 3),
#   ('"18299520"', 2),
#   ('"18224570"', 9),
#   ('"10050893"', 4),
#   ('"10714658"', 6),
#   ('"10720299"', 2),
#   ('"10871631"', 1),
#   ('"10984667"', 4),
#   ('"11104212"', 2),
#   ('"11980065"', 4),
#   ('"14581671"', 4),
#   ('"15342362"', 2),
#   ('"16361107"', 2),
#   ('"16537570"', 4),
#   ('"16631205"', 2),
#   ('"12007841"', 1),
#   ('"11405807"', 4),
#   ('"25674472"', 2),
#   ('"20169475"', 2),
#   ('"15136718"', 6),
#   ('"14690443"', 4),
#   ('"15099679"', 2),
#   ('"15505207"', 2),
#   ('"20639502"', 2),
#   ('"28768697"', 2),
#   ('"2215959"', 2),
#   ('"10980732"', 2),
#   ('"1992364"', 2),
#   ('"11598522"', 1),
#   ('"6234055"', 1),
#   ('"4072505"', 1),
#   ('"21840890"', 1),
#   ('"27477622"', 3),
#   ('"26297380"', 3),
#   ('"28432771"', 2),
#   ('"32243914"', 2),
#   ('"35303767"', 1),
#   ('"34092466"', 3),
#   ('"28768697"', 2),
#   ('"36329866"', 2),
#   ('"33894367"', 1),
#   ('"34119482"', 5),
#   ('"29739751"', 2),
#   ('"34398825"', 3),
#   ('"30838317"', 3),
#   ('"37165749"', 5),
#   ('"28756192"', 4),
#   ('"33445430"', 4),
#   ('"33799994"', 1),
#   ('"33638639"', 2),
#   ('"32037012"', 1)],
#  'osis': [('"7911621"', 4),
#   ('"10737119"', 2),
#   ('"1639411"', 4),
#   ('"12785748"', 2),
#   ('"11912106"', 4),
#   ('"20471632"', 2),
#   ('"30779476"', 1),
#   ('"31867614"', 1),
#   ('"33239013"', 1),
#   ('"11232488"', 1),
#   ('"19345148"', 2),
#   ('"23420606"', 2),
#   ('"24311730"', 2),
#   ('"30244176"', 3),
#   ('"1427899"', 2),
#   ('"14989804"', 7),
#   ('"12691403"', 9),
#   ('"24949445"', 2),
#   ('"23967309"', 2),
#   ('"21136869"', 2),
#   ('"27666935"', 1),
#   ('"28516161"', 1),
#   ('"29053766"', 3),
#   ('"11940688"', 2),
#   ('"36468571"', 2),
#   ('"36096955"', 1),
#   ('"35611878"', 1),
#   ('"19041429"', 1),
#   ('"30444426"', 1),
#   ('"17385355"', 1),
#   ('"36757831"', 3),
#   ('"20301665"', 4),
#   ('"22897341"', 5),
#   ('"35303767"', 2),
#   ('"17713116"', 1),
#   ('"8244374"', 2),
#   ('"21750546"', 2),
#   ('"21496603"', 1),
#   ('"20482602"', 3),
#   ('"10714658"', 2),
#   ('"7205314"', 2),
#   ('"9221523"', 2),
#   ('"8703227"', 1),
#   ('"11701630"', 2),
#   ('"1992364"', 4),
#   ('"7133334"', 1),
#   ('"11598522"', 3),
#   ('"941769"', 1),
#   ('"484133"', 1),
#   ('"20301665"', 4),
#   ('"35303767"', 2),
#   ('"29053766"', 3),
#   ('"30244176"', 3),
#   ('"24311730"', 2),
#   ('"36757831"', 3)],
#  'ase domain': [],
#  'cycle': [('"14989804"', 2), ('"20460154"', 2), ('"35796490"', 1)],
#  'headache': [('"32195978"', 1)],
#  'gene': [('"2317008"', 2),
#   ('"6694180"', 2),
#   ('"2203908"', 2),
#   ('"8079990"', 10),
#   ('"2309703"', 2),
#   ('"1347197"', 14),
#   ('"8513401"', 8),
#   ('"7719342"', 2),
#   ('"7979224"', 4),
#   ('"10435508"', 9),
#   ('"10674821"', 2),
#   ('"1985454"', 4),
#   ('"10737119"', 8),
#   ('"9120448"', 2),
#   ('"9778264"', 4),
#   ('"15897512"', 6),
#   ('"12575458"', 6),
#   ('"1639411"', 4),
#   ('"2666583"', 2),
#   ('"1677923"', 2),
#   ('"9266460"', 4),
#   ('"12785748"', 3),
#   ('"11912106"', 2),
#   ('"8277574"', 2),
#   ('"28943611"', 1),
#   ('"10523017"', 1),
#   ('"16639700"', 1),
#   ('"30779476"', 1),
#   ('"24444577"', 1),
#   ('"21929335"', 1),
#   ('"15137480"', 1),
#   ('"11302971"', 3),
#   ('"31867614"', 1),
#   ('"25925917"', 2),
#   ('"32370566"', 1),
#   ('"9039166"', 1),
#   ('"33472447"', 1),
#   ('"32118025"', 1),
#   ('"30528262"', 1),
#   ('"29561984"', 1),
#   ('"19355902"', 1),
#   ('"16706073"', 1),
#   ('"8365724"', 1),
#   ('"12402271"', 2),
#   ('"34380890"', 3),
#   ('"10541594"', 3),
#   ('"16682692"', 2),
#   ('"10449567"', 6),
#   ('"21956287"', 2),
#   ('"19345147"', 2),
#   ('"20211909"', 2),
#   ('"8004804"', 5),
#   ('"8684386"', 6),
#   ('"9288096"', 7),
#   ('"9149944"', 13),
#   ('"10738516"', 13),
#   ('"11523564"', 8),
#   ('"11973627"', 8),
#   ('"12473770"', 1),
#   ('"15111678"', 2),
#   ('"12975293"', 6),
#   ('"15293281"', 2),
#   ('"15326234"', 4),
#   ('"15455404"', 7),
#   ('"15548549"', 2),
#   ('"17027035"', 5),
#   ('"17503336"', 8),
#   ('"18477710"', 3),
#   ('"18823044"', 2),
#   ('"19528516"', 2),
#   ('"19955557"', 5),
#   ('"16415980"', 7),
#   ('"22132914"', 3),
#   ('"27939583"', 5),
#   ('"27919237"', 2),
#   ('"30879706"', 2),
#   ('"33476878"', 2),
#   ('"33757902"', 10),
#   ('"33706202"', 7),
#   ('"34038798"', 4),
#   ('"34092466"', 5),
#   ('"34119482"', 14),
#   ('"10073176"', 4),
#   ('"10994500"', 6),
#   ('"11984483"', 3),
#   ('"24262166"', 7),
#   ('"25192508"', 5),
#   ('"8255463"', 6),
#   ('"15390042"', 4),
#   ('"19685389"', 10),
#   ('"24311730"', 10),
#   ('"33395620"', 3),
#   ('"12194383"', 5),
#   ('"10919137"', 4),
#   ('"11528394"', 3),
#   ('"12391355"', 2),
#   ('"12151848"', 4),
#   ('"30244176"', 5),
#   ('"34189496"', 7),
#   ('"33476687"', 17),
#   ('"1427899"', 2),
#   ('"16275837"', 4),
#   ('"14989804"', 8),
#   ('"12691403"', 16),
#   ('"12821512"', 6),
#   ('"33468570"', 5),
#   ('"17702041"', 2),
#   ('"17061185"', 6),
#   ('"22151759"', 3),
#   ('"14502672"', 4),
#   ('"15505159"', 4),
#   ('"12652041"', 2),
#   ('"9837831"', 11),
#   ('"28102337"', 2),
#   ('"26790671"', 6),
#   ('"25894231"', 2),
#   ('"25209853"', 2),
#   ('"23622412"', 2),
#   ('"23284065"', 6),
#   ('"22166420"', 8),
#   ('"22345219"', 2),
#   ('"21496608"', 2),
#   ('"20627944"', 7),
#   ('"20841370"', 2),
#   ('"18265016"', 11),
#   ('"19066193"', 4),
#   ('"18267263"', 5),
#   ('"15390016"', 4),
#   ('"14872019"', 9),
#   ('"15258227"', 4),
#   ('"14628853"', 3),
#   ('"12761637"', 2),
#   ('"31618684"', 7),
#   ('"27716431"', 5),
#   ('"24508913"', 2),
#   ('"23967309"', 7),
#   ('"23018676"', 12),
#   ('"22391119"', 12),
#   ('"21995941"', 5),
#   ('"21136869"', 17),
#   ('"21078339"', 8),
#   ('"20584926"', 4),
#   ('"20223934"', 6),
#   ('"20132487"', 6),
#   ('"18299128"', 7),
#   ('"17956903"', 8),
#   ('"17550429"', 4),
#   ('"16934985"', 7),
#   ('"16458269"', 6),
#   ('"15930383"', 5),
#   ('"11730696"', 2),
#   ('"10814722"', 10),
#   ('"36417958"', 9),
#   ('"35955710"', 7),
#   ('"36546658"', 11),
#   ('"31805123"', 4),
#   ('"31320448"', 5),
#   ('"26183317"', 12),
#   ('"24951854"', 4),
#   ('"23840813"', 2),
#   ('"30237473"', 1),
#   ('"33247415"', 2),
#   ('"32516804"', 1),
#   ('"29739751"', 7),
#   ('"31580306"', 2),
#   ('"34298581"', 1),
#   ('"32079672"', 1),
#   ('"34264428"', 1),
#   ('"25347348"', 1),
#   ('"33753289"', 1),
#   ('"27666935"', 5),
#   ('"33502045"', 2),
#   ('"25779878"', 1),
#   ('"33740122"', 1),
#   ('"30643666"', 1),
#   ('"25449075"', 1),
#   ('"18322712"', 6),
#   ('"21322026"', 1),
#   ('"22722545"', 3),
#   ('"32239467"', 1),
#   ('"33175450"', 3),
#   ('"33832800"', 3),
#   ('"33134321"', 2),
#   ('"11940688"', 4),
#   ('"25461922"', 2),
#   ('"37134150"', 4),
#   ('"33991565"', 3),
#   ('"34398157"', 1),
#   ('"33458877"', 2),
#   ('"33529159"', 12),
#   ('"33894367"', 4),
#   ('"27911022"', 5),
#   ('"8813214"', 3),
#   ('"22040906"', 2),
#   ('"22080833"', 2),
#   ('"29325615"', 1),
#   ('"34358617"', 1),
#   ('"7783076"', 1),
#   ('"3458307"', 1),
#   ('"32777581"', 1),
#   ('"3262691"', 1),
#   ('"36355183"', 1),
#   ('"35694992"', 2),
#   ('"36045526"', 1),
#   ('"36415137"', 1),
#   ('"36096955"', 1),
#   ('"35839368"', 1),
#   ('"10644435"', 10),
#   ('"14517787"', 1),
#   ('"15793882"', 1),
#   ('"1626073"', 1),
#   ('"17006990"', 1),
#   ('"18689116"', 1),
#   ('"19052350"', 1),
#   ('"19208776"', 1),
#   ('"20178968"', 1),
#   ('"20359791"', 1),
#   ('"20661732"', 1),
#   ('"21621928"', 1),
#   ('"22465228"', 1),
#   ('"28708086"', 1),
#   ('"20590811"', 4),
#   ('"19182804"', 2),
#   ('"17702011"', 1),
#   ('"2404852"', 1),
#   ('"21907099"', 4),
#   ('"945867"', 1),
#   ('"2426591"', 1),
#   ('"26417535"', 1),
#   ('"12822816"', 6),
#   ('"10979329"', 2),
#   ('"37607452"', 1),
#   ('"36757831"', 5),
#   ('"36648081"', 3),
#   ('"36445406"', 1),
#   ('"35533513"', 9),
#   ('"12609485"', 8),
#   ('"15939081"', 3),
#   ('"16938275"', 5),
#   ('"17290457"', 5),
#   ('"19038309"', 12),
#   ('"19157930"', 3),
#   ('"19284587"', 8),
#   ('"19578124"', 5),
#   ('"20301665"', 11),
#   ('"22639460"', 3),
#   ('"22897341"', 7),
#   ('"23180184"', 5),
#   ('"23196519"', 8),
#   ('"23222958"', 4),
#   ('"24588501"', 4),
#   ('"24757586"', 3),
#   ('"24976531"', 3),
#   ('"25155315"', 3),
#   ('"25203860"', 4),
#   ('"25403864"', 6),
#   ('"26004199"', 1),
#   ('"26297380"', 1),
#   ('"26940431"', 3),
#   ('"27143436"', 1),
#   ('"27477622"', 4),
#   ('"28283962"', 1),
#   ('"28432771"', 3),
#   ('"28756192"', 2),
#   ('"29396398"', 6),
#   ('"30100364"', 1),
#   ('"30838317"', 5),
#   ('"32502938"', 9),
#   ('"32662044"', 1),
#   ('"34949287"', 4),
#   ('"35041927"', 1),
#   ('"35044558"', 1),
#   ('"35303767"', 5),
#   ('"17713116"', 6),
#   ('"9874484"', 9),
#   ('"9749609"', 7),
#   ('"9749595"', 6),
#   ('"9667600"', 3),
#   ('"9618171"', 12),
#   ('"9585364"', 21),
#   ('"9191768"', 2),
#   ('"8871591"', 6),
#   ('"8309575"', 10),
#   ('"8232931"', 2),
#   ('"7845403"', 6),
#   ('"7654519"', 4),
#   ('"7629534"', 14),
#   ('"37352388"', 6),
#   ('"37165749"', 5),
#   ('"32289333"', 3),
#   ('"27093447"', 3),
#   ('"26596547"', 4),
#   ('"25337725"', 4),
#   ('"23436503"', 2),
#   ('"22770546"', 2),
#   ('"22622408"', 3),
#   ('"21800139"', 3),
#   ('"21496603"', 1),
#   ('"21301909"', 1),
#   ('"20687193"', 4),
#   ('"20482602"', 4),
#   ('"20350935"', 2),
#   ('"20066431"', 2),
#   ('"19555827"', 8),
#   ('"19457118"', 7),
#   ('"19403250"', 2),
#   ('"19260107"', 3),
#   ('"19039992"', 5),
#   ('"18685824"', 3),
#   ('"18571468"', 5),
#   ('"18552369"', 11),
#   ('"18437909"', 6),
#   ('"18299520"', 2),
#   ('"18224570"', 10),
#   ('"18176524"', 2),
#   ('"10050893"', 4),
#   ('"10225357"', 5),
#   ('"10448655"', 2),
#   ('"10477437"', 13),
#   ('"10627938"', 10),
#   ('"10714658"', 8),
#   ('"10871631"', 8),
#   ('"10881900"', 5),
#   ('"10984667"', 9),
#   ('"11009204"', 2),
#   ('"11014135"', 2),
#   ('"11104212"', 2),
#   ('"11261511"', 3),
#   ('"11921134"', 3),
#   ('"11980065"', 6),
#   ('"12360559"', 7),
#   ('"12760408"', 6),
#   ('"12821514"', 15),
#   ('"12859412"', 4),
#   ('"12883919"', 2),
#   ('"14581671"', 8),
#   ('"15342362"', 2),
#   ('"15555920"', 7),
#   ('"15593317"', 4),
#   ('"15726581"', 2),
#   ('"16361107"', 4),
#   ('"16537570"', 6),
#   ('"16631205"', 8),
#   ('"16773641"', 5),
#   ('"17129379"', 5),
#   ('"22472189"', 10),
#   ('"15283994"', 7),
#   ('"12671990"', 7),
#   ('"12007841"', 5),
#   ('"33425096"', 2),
#   ('"11405807"', 1),
#   ('"36409706"', 1),
#   ('"25674472"', 7),
#   ('"15136718"', 2),
#   ('"9750906"', 5),
#   ('"11244697"', 4),
#   ('"11584049"', 3),
#   ('"15989773"', 2),
#   ('"15099679"', 2),
#   ('"15147511"', 4),
#   ('"19761814"', 5),
#   ('"20639502"', 2),
#   ('"24627482"', 5),
#   ('"28768697"', 14),
#   ('"32248052"', 1),
#   ('"34062155"', 6),
#   ('"9380054"', 2),
#   ('"8723633"', 4),
#   ('"2215959"', 2),
#   ('"2183913"', 4),
#   ('"1940944"', 2),
#   ('"8723145"', 2),
#   ('"10526391"', 2),
#   ('"12876228"', 2),
#   ('"1623256"', 2),
#   ('"18591071"', 2),
#   ('"3948889"', 2),
#   ('"2245082"', 1),
#   ('"6443743"', 1),
#   ('"8894706"', 2),
#   ('"21840890"', 2),
#   ('"10833562"', 5),
#   ('"18688663"', 3),
#   ('"11714689"', 4),
#   ('"31332180"', 2),
#   ('"6240313"', 1),
#   ('"7791942"', 2),
#   ('"24976531"', 3),
#   ('"27477622"', 4),
#   ('"32662044"', 1),
#   ('"37352388"', 6),
#   ('"26297380"', 1),
#   ('"32502938"', 9),
#   ('"20301665"', 11),
#   ('"28432771"', 3),
#   ('"35303767"', 5),
#   ('"31618684"', 7),
#   ('"36417958"', 9),
#   ('"33476878"', 2),
#   ('"34092466"', 5),
#   ('"33468570"', 5),
#   ('"33753289"', 1),
#   ('"29325615"', 1),
#   ('"32239467"', 1),
#   ('"32516804"', 1),
#   ('"33247415"', 2),
#   ('"33175450"', 3),
#   ('"33502045"', 2),
#   ('"34189496"', 7),
#   ('"30244176"', 5),
#   ('"24627482"', 5),
#   ('"28768697"', 14),
#   ('"35955710"', 7),
#   ('"33134321"', 2),
#   ('"33757902"', 10),
#   ('"33894367"', 4),
#   ('"34062155"', 6),
#   ('"34119482"', 14),
#   ('"24311730"', 10),
#   ('"27911022"', 5),
#   ('"29739751"', 7),
#   ('"34358617"', 1),
#   ('"26183317"', 12),
#   ('"36757831"', 5),
#   ('"24757586"', 3),
#   ('"27716431"', 5),
#   ('"30838317"', 5),
#   ('"32289333"', 3),
#   ('"37165749"', 5),
#   ('"28756192"', 2),
#   ('"33991565"', 3),
#   ('"33395620"', 3),
#   ('"26790671"', 6),
#   ('"32037012"', 1),
#   ('"26596547"', 4),
#   ('"34728955"', 1)],
#  'system development': [('"33616084"', 3)],
#  'e signaling pathway': [('"22391119"', 4),
#   ('"32289333"', 5),
#   ('"32289333"', 5)],
#  'inflammatory response': [],
#  'lymphoma': [('"30302434"', 1)],
#  'protein processing': [('"23967309"', 2), ('"17428918"', 5)],
#  'gents': [('"20301665"', 3),
#   ('"10871631"', 1),
#   ('"14690443"', 2),
#   ('"20301665"', 3)],
#  's simplex': [('"15099679"', 2)],
#  'hesion': [('"16361107"', 4)],
#  'infarction': [],
#  'holine': [('"34323950"', 3),
#   ('"15455404"', 2),
#   ('"33757902"', 4),
#   ('"33638639"', 5),
#   ('"34119482"', 12),
#   ('"34189496"', 7),
#   ('"33468570"', 4),
#   ('"31618684"', 8),
#   ('"21995941"', 5),
#   ('"16934985"', 6),
#   ('"36546658"', 4),
#   ('"31805123"', 6),
#   ('"31320448"', 4),
#   ('"24951854"', 7),
#   ('"36329866"', 2),
#   ('"33894367"', 3),
#   ('"34173686"', 13),
#   ('"27911022"', 1),
#   ('"20301665"', 1),
#   ('"15283994"', 2),
#   ('"35643882"', 3),
#   ('"10349117"', 2),
#   ('"20301665"', 1),
#   ('"31618684"', 8),
#   ('"33468570"', 4),
#   ('"34189496"', 7),
#   ('"36329866"', 2),
#   ('"33757902"', 4),
#   ('"33894367"', 3),
#   ('"34119482"', 12),
#   ('"27911022"', 1),
#   ('"33638639"', 5)],
#  'sulfide': [('"12671990"', 2), ('"34062155"', 4), ('"34062155"', 4)],
#  'cellular phenotype': [('"24931141"', 3), ('"24931141"', 3)],
#  'openia': [],
#  "eimer's disease": [],
#  'synaptic signaling': [('"34398825"', 4), ('"34398825"', 4)],
#  'notch': [],
#  'al disorder': [('"2317008"', 2),
#   ('"7911621"', 2),
#   ('"17142829"', 2),
#   ('"33616084"', 3),
#   ('"10073176"', 1),
#   ('"36757831"', 3),
#   ('"24627482"', 4),
#   ('"650244"', 2),
#   ('"24627482"', 4),
#   ('"36757831"', 3)],
#  'nium': [('"14690443"', 2)],
#  'a secondary': [('"23284065"', 2)],
#  'ogenesis': [('"31867614"', 1),
#   ('"19355902"', 1),
#   ('"34380890"', 3),
#   ('"27939583"', 2),
#   ('"33757902"', 3),
#   ('"34189496"', 3),
#   ('"33476687"', 6),
#   ('"23018676"', 3),
#   ('"16458269"', 2),
#   ('"36417958"', 1),
#   ('"26183317"', 10),
#   ('"23840813"', 2),
#   ('"33753289"', 1),
#   ('"33134321"', 2),
#   ('"11940688"', 2),
#   ('"33529159"', 2),
#   ('"29325615"', 1),
#   ('"34358617"', 1),
#   ('"32777581"', 1),
#   ('"14517787"', 1),
#   ('"19052350"', 1),
#   ('"24588501"', 4),
#   ('"27477622"', 1),
#   ('"32662044"', 1),
#   ('"37352388"', 2),
#   ('"18552369"', 2),
#   ('"14581671"', 4),
#   ('"15283994"', 2),
#   ('"15136718"', 2),
#   ('"15099679"', 2),
#   ('"24627482"', 5),
#   ('"28768697"', 4),
#   ('"34062155"', 6),
#   ('"27477622"', 1),
#   ('"32662044"', 1),
#   ('"37352388"', 2),
#   ('"36417958"', 1),
#   ('"33753289"', 1),
#   ('"29325615"', 1),
#   ('"34189496"', 3),
#   ('"24627482"', 5),
#   ('"28768697"', 4),
#   ('"33134321"', 2),
#   ('"33757902"', 3),
#   ('"34062155"', 6),
#   ('"34358617"', 1),
#   ('"26183317"', 10)],
#  'erone': [('"19955557"', 1),
#   ('"24311730"', 4),
#   ('"17428918"', 2),
#   ('"16458269"', 4),
#   ('"10814722"', 5),
#   ('"31057009"', 1),
#   ('"7231447"', 1),
#   ('"24931141"', 1),
#   ('"25379658"', 2),
#   ('"18258738"', 2),
#   ('"10871631"', 3),
#   ('"16361107"', 4),
#   ('"17129379"', 2),
#   ('"12671990"', 2),
#   ('"20169475"', 19),
#   ('"11438481"', 3),
#   ('"15099679"', 2),
#   ('"15147511"', 2),
#   ('"24627482"', 12),
#   ('"28768697"', 2),
#   ('"27490483"', 2),
#   ('"24931141"', 1),
#   ('"24627482"', 12),
#   ('"28768697"', 2),
#   ('"24311730"', 4)],
#  'rone': [('"19955557"', 1),
#   ('"24311730"', 6),
#   ('"17428918"', 2),
#   ('"16458269"', 4),
#   ('"10814722"', 5),
#   ('"31057009"', 1),
#   ('"18519462"', 1),
#   ('"7231447"', 1),
#   ('"19578124"', 2),
#   ('"24931141"', 1),
#   ('"25379658"', 2),
#   ('"18258738"', 2),
#   ('"10871631"', 3),
#   ('"16361107"', 4),
#   ('"17129379"', 2),
#   ('"12671990"', 2),
#   ('"20169475"', 19),
#   ('"11438481"', 3),
#   ('"15099679"', 2),
#   ('"15147511"', 2),
#   ('"24627482"', 12),
#   ('"28768697"', 2),
#   ('"27490483"', 2),
#   ('"24931141"', 1),
#   ('"24627482"', 12),
#   ('"28768697"', 2),
#   ('"24311730"', 6)],
#  'disorder': [('"8432555"', 2),
#   ('"2317008"', 2),
#   ('"8079990"', 2),
#   ('"8916165"', 2),
#   ('"2309703"', 2),
#   ('"7911621"', 2),
#   ('"17142829"', 2),
#   ('"10737119"', 1),
#   ('"2666583"', 2),
#   ('"15954126"', 2),
#   ('"20672922"', 2),
#   ('"12785748"', 1),
#   ('"11912106"', 2),
#   ('"24210306"', 1),
#   ('"12402271"', 2),
#   ('"9288096"', 3),
#   ('"12975293"', 2),
#   ('"15293281"', 2),
#   ('"15326234"', 2),
#   ('"15548549"', 2),
#   ('"33616084"', 3),
#   ('"33638639"', 6),
#   ('"34038798"', 6),
#   ('"34119482"', 8),
#   ('"10073176"', 1),
#   ('"24262166"', 2),
#   ('"11528394"', 2),
#   ('"30244176"', 1),
#   ('"34189496"', 4),
#   ('"14989804"', 3),
#   ('"33468570"', 3),
#   ('"17702041"', 2),
#   ('"22151759"', 3),
#   ('"15505159"', 3),
#   ('"23622412"', 2),
#   ('"22375360"', 2),
#   ('"20627944"', 5),
#   ('"18265016"', 2),
#   ('"15390016"', 1),
#   ('"14872019"', 2),
#   ('"31618684"', 3),
#   ('"23967309"', 7),
#   ('"23018676"', 4),
#   ('"22391119"', 8),
#   ('"21995941"', 5),
#   ('"21136869"', 5),
#   ('"21078339"', 8),
#   ('"20584926"', 7),
#   ('"20223934"', 4),
#   ('"18827015"', 7),
#   ('"17428918"', 2),
#   ('"15930383"', 5),
#   ('"11730696"', 5),
#   ('"10814722"', 3),
#   ('"36417958"', 3),
#   ('"35955710"', 5),
#   ('"26183317"', 5),
#   ('"24951854"', 4),
#   ('"23840813"', 2),
#   ('"20460154"', 1),
#   ('"31580306"', 2),
#   ('"18322712"', 1),
#   ('"11940688"', 2),
#   ('"25461922"', 5),
#   ('"36329866"', 3),
#   ('"34398157"', 1),
#   ('"33458877"', 2),
#   ('"22080833"', 2),
#   ('"21656045"', 1),
#   ('"2404852"', 1),
#   ('"13597141"', 1),
#   ('"945867"', 1),
#   ('"2426591"', 1),
#   ('"36757831"', 4),
#   ('"35533513"', 3),
#   ('"19284587"', 1),
#   ('"22639460"', 3),
#   ('"22897341"', 5),
#   ('"24757586"', 3),
#   ('"25403864"', 3),
#   ('"26940431"', 3),
#   ('"9874484"', 1),
#   ('"9749595"', 4),
#   ('"9585364"', 2),
#   ('"37165749"', 5),
#   ('"29483592"', 3),
#   ('"26592310"', 2),
#   ('"25149450"', 4),
#   ('"22770546"', 2),
#   ('"21301909"', 1),
#   ('"19651773"', 4),
#   ('"19457118"', 3),
#   ('"18299520"', 2),
#   ('"18258738"', 5),
#   ('"36302970"', 5),
#   ('"35563018"', 4),
#   ('"10627938"', 3),
#   ('"10714658"', 2),
#   ('"10720299"', 2),
#   ('"10871631"', 5),
#   ('"11261511"', 1),
#   ('"12360559"', 3),
#   ('"12760408"', 1),
#   ('"16361107"', 1),
#   ('"17129379"', 2),
#   ('"11405807"', 4),
#   ('"20169475"', 3),
#   ('"15136718"', 5),
#   ('"14690443"', 5),
#   ('"15099679"', 3),
#   ('"15147511"', 3),
#   ('"15269177"', 1),
#   ('"15829632"', 5),
#   ('"24627482"', 4),
#   ('"34062155"', 3),
#   ('"8413963"', 2),
#   ('"8341297"', 2),
#   ('"8723145"', 2),
#   ('"10809944"', 2),
#   ('"650244"', 2),
#   ('"6697632"', 2),
#   ('"7469847"', 2),
#   ('"2966619"', 1),
#   ('"2245082"', 1),
#   ('"7299845"', 1),
#   ('"2868026"', 1),
#   ('"2840407"', 1),
#   ('"2179685"', 1),
#   ('"8894706"', 2),
#   ('"21840890"', 3),
#   ('"27448549"', 1),
#   ('"18688663"', 1),
#   ('"31618684"', 3),
#   ('"36417958"', 3),
#   ('"33468570"', 3),
#   ('"34189496"', 4),
#   ('"30244176"', 1),
#   ('"24627482"', 4),
#   ('"26592310"', 2),
#   ('"35563018"', 4),
#   ('"36329866"', 3),
#   ('"35955710"', 5),
#   ('"34062155"', 3),
#   ('"34119482"', 8),
#   ('"26183317"', 5),
#   ('"36757831"', 4),
#   ('"24757586"', 3),
#   ('"37165749"', 5),
#   ('"33638639"', 6)],
#  'synaptic membrane': [],
#  'oxide': [('"895957"', 1)],
#  'dilated cardiomyopathy': [],
#  'hypertension': [],
#  'synapse': [('"33991565"', 3),
#   ('"19457118"', 2),
#   ('"35643882"', 3),
#   ('"33991565"', 3)],
#  'stiffness': [('"16275837"', 2)],
#  'lide': [('"13605317"', 1), ('"13385097"', 1), ('"13597141"', 1)],
#  'burn': [],
#  'transport': [('"34323950"', 3),
#   ('"15455404"', 5),
#   ('"33638639"', 3),
#   ('"33468570"', 1),
#   ('"20132487"', 2),
#   ('"17550429"', 5),
#   ('"34173686"', 7),
#   ('"34358617"', 2),
#   ('"30444426"', 1),
#   ('"15593317"', 9),
#   ('"15505207"', 2),
#   ('"33468570"', 1),
#   ('"34358617"', 2),
#   ('"33638639"', 3)],
#  't gene': [('"8513401"', 4),
#   ('"10435508"', 1),
#   ('"12575458"', 2),
#   ('"11973627"', 2),
#   ('"17503336"', 2),
#   ('"34092466"', 2),
#   ('"15390042"', 1),
#   ('"19685389"', 4),
#   ('"12194383"', 3),
#   ('"11528394"', 3),
#   ('"34189496"', 4),
#   ('"12821512"', 3),
#   ('"20627944"', 5),
#   ('"18267263"', 5),
#   ('"31618684"', 3),
#   ('"27716431"', 5),
#   ('"23967309"', 7),
#   ('"23018676"', 4),
#   ('"22391119"', 8),
#   ('"21995941"', 5),
#   ('"21136869"', 2),
#   ('"15930383"', 5),
#   ('"36417958"', 8),
#   ('"31805123"', 4),
#   ('"27666935"', 3),
#   ('"25779878"', 1),
#   ('"33175450"', 1),
#   ('"33832800"', 1),
#   ('"8813214"', 3),
#   ('"3458307"', 1),
#   ('"35694992"', 1),
#   ('"19052350"', 1),
#   ('"20590811"', 3),
#   ('"36648081"', 2),
#   ('"12609485"', 2),
# ...
#   ('"15548549"', 5),
#   ('"17027035"', 5),
#   ('"17503336"', 6),
#   ('"18477710"', 6),
#   ('"19528516"', 2),
#   ('"19955557"', 8),
#   ('"16415980"', 5),
#   ('"22132914"', 9),
#   ('"27939583"', 5),
#   ('"27919237"', 2),
#   ('"30879706"', 2),
#   ('"33476878"', 5),
#   ('"33757902"', 8),
#   ('"33616084"', 3),
#   ('"33706202"', 7),
#   ('"33638639"', 9),
#   ('"34038798"', 9),
#   ('"34092466"', 17),
#   ('"34119482"', 18),
#   ('"34438319"', 6),
#   ('"12325076"', 3),
#   ('"10073176"', 4),
#   ('"10994500"', 4),
#   ('"11984483"', 3),
#   ('"23420606"', 2),
#   ('"24262166"', 11),
#   ('"25192508"', 4),
#   ('"8255463"', 4),
#   ('"15390042"', 4),
#   ('"19685389"', 8),
#   ('"28843013"', 3),
#   ('"24311730"', 4),
#   ('"22266882"', 3),
#   ('"16541453"', 2),
#   ('"33395620"', 9),
#   ('"12194383"', 5),
#   ('"10919137"', 6),
#   ('"11528394"', 5),
#   ('"12391355"', 2),
#   ('"12151848"', 4),
#   ('"30244176"', 4),
#   ('"34408078"', 8),
#   ('"34189496"', 14),
#   ('"33476687"', 23),
#   ('"33488508"', 7),
#   ('"1427899"', 2),
#   ('"16275837"', 2),
#   ('"14989804"', 8),
#   ('"12691403"', 16),
#   ('"12821512"', 9),
#   ('"33468570"', 13),
#   ('"17702041"', 4),
#   ('"19349605"', 3),
#   ('"15954129"', 3),
#   ('"26087139"', 3),
#   ('"17061185"', 10),
#   ('"22151759"', 3),
#   ('"14502672"', 4),
#   ('"24949445"', 2),
#   ('"21839475"', 2),
#   ('"15505159"', 5),
#   ('"12652041"', 4),
#   ('"9837831"', 9),
#   ('"30028274"', 2),
#   ('"28102337"', 2),
#   ('"25894231"', 2),
#   ('"23622412"', 4),
#   ('"23284065"', 8),
#   ('"22166420"', 7),
#   ('"22345219"', 4),
#   ('"22375360"', 4),
#   ('"21496608"', 2),
#   ('"20627944"', 14),
#   ('"20841370"', 2),
#   ('"18265016"', 5),
#   ('"18267263"', 5),
#   ('"16227522"', 2),
#   ('"15390016"', 2),
#   ('"14872019"', 5),
#   ('"15258227"', 2),
#   ('"14628853"', 3),
#   ('"12781594"', 2),
#   ('"31618684"', 6),
#   ('"27716431"', 11),
#   ('"23967309"', 15),
#   ('"23018676"', 7),
#   ('"22391119"', 12),
#   ('"21995941"', 8),
#   ('"21136869"', 6),
#   ('"21078339"', 13),
#   ('"20584926"', 10),
#   ('"20223934"', 12),
#   ('"20132487"', 14),
#   ('"18827015"', 7),
#   ('"18299128"', 18),
#   ('"17956903"', 13),
#   ('"17550429"', 19),
#   ('"17428918"', 10),
#   ('"16934985"', 13),
#   ('"16458269"', 4),
#   ('"16364891"', 5),
#   ('"15930383"', 10),
#   ('"11730696"', 5),
#   ('"10814722"', 8),
#   ('"36417958"', 19),
#   ('"35955710"', 5),
#   ('"36546658"', 11),
#   ('"31805123"', 6),
#   ('"31320448"', 7),
#   ('"26183317"', 10),
#   ('"24951854"', 17),
#   ('"23840813"', 2),
#   ('"20460154"', 3),
#   ('"30237473"', 1),
#   ('"33247415"', 1),
#   ('"32516804"', 9),
#   ('"29739751"', 4),
#   ('"31580306"', 2),
#   ('"32079672"', 2),
#   ('"24938147"', 1),
#   ('"34264428"', 1),
#   ('"25347348"', 1),
#   ('"33753289"', 3),
#   ('"27666935"', 4),
#   ('"33502045"', 3),
#   ('"33740122"', 1),
#   ('"30643666"', 1),
#   ('"25449075"', 1),
#   ('"18322712"', 6),
#   ('"21322026"', 1),
#   ('"22722545"', 4),
#   ('"31321303"', 3),
#   ('"31517057"', 3),
#   ('"32239467"', 1),
#   ('"33175450"', 5),
#   ('"29053766"', 4),
#   ('"33134321"', 3),
#   ('"17200151"', 7),
#   ('"25461922"', 5),
#   ('"37134150"', 8),
#   ('"36329866"', 3),
#   ('"33991565"', 3),
#   ('"34398157"', 1),
#   ('"33458877"', 4),
#   ('"33529159"', 18),
#   ('"33445430"', 4),
#   ('"33799994"', 5),
#   ('"33894367"', 8),
#   ('"34173686"', 10),
#   ('"34398825"', 18),
#   ('"27911022"', 12),
#   ('"8813214"', 3),
#   ('"22040906"', 4),
#   ('"22080833"', 9),
#   ('"29325615"', 1),
#   ('"34358617"', 8),
#   ('"10644435"', 11),
#   ('"33724724"', 1),
#   ('"21496605"', 3),
#   ('"20590811"', 5),
#   ('"27171035"', 1),
#   ('"15477576"', 1),
#   ('"15786454"', 1),
#   ('"15159681"', 1),
#   ('"19182804"', 3),
#   ('"21656045"', 3),
#   ('"17702011"', 1),
#   ('"2368812"', 1),
#   ('"2404852"', 2),
#   ('"21907099"', 4),
#   ('"14957878"', 1),
#   ('"6050693"', 1),
#   ('"12978961"', 1),
#   ('"14022841"', 1),
#   ('"13605317"', 1),
#   ('"13739435"', 1),
#   ('"20344681"', 1),
#   ('"13697597"', 1),
#   ('"14779577"', 1),
#   ('"14450922"', 1),
#   ('"10437291"', 1),
#   ('"5529477"', 1),
#   ('"13957880"', 1),
#   ('"13385097"', 1),
#   ('"2315224"', 1),
#   ('"13597141"', 1),
#   ('"13097210"', 1),
#   ('"945867"', 1),
#   ('"6470761"', 2),
#   ('"2426591"', 3),
#   ('"7231447"', 1),
#   ('"3362365"', 1),
#   ('"9146025"', 1),
#   ('"26417535"', 1),
#   ('"17385355"', 1),
#   ('"12822816"', 14),
#   ('"12518301"', 2),
#   ('"10979329"', 2),
#   ('"35312111"', 1),
#   ('"37607452"', 1),
#   ('"36757831"', 3),
#   ('"36648081"', 2),
#   ('"36445406"', 1),
#   ('"35533513"', 7),
#   ('"12609485"', 5),
#   ('"17290457"', 4),
#   ('"19038309"', 14),
#   ('"19157930"', 5),
#   ('"19284587"', 13),
#   ('"19578124"', 14),
#   ('"20301665"', 19),
#   ('"22897341"', 2),
#   ('"23180184"', 4),
#   ('"23196519"', 8),
#   ('"23222958"', 5),
#   ('"23893446"', 5),
#   ('"24092288"', 5),
#   ('"24588501"', 4),
#   ('"24757586"', 3),
#   ('"24931141"', 8),
#   ('"24976531"', 3),
#   ('"25155315"', 3),
#   ('"25203860"', 6),
#   ('"25403864"', 14),
#   ('"26004199"', 2),
#   ('"26297380"', 13),
#   ('"26810727"', 2),
#   ('"26940431"', 7),
#   ('"27477622"', 9),
#   ('"28283962"', 1),
#   ('"28432771"', 4),
#   ('"28756192"', 5),
#   ('"29396398"', 6),
#   ('"30100364"', 1),
#   ('"30838317"', 11),
#   ('"32243914"', 5),
#   ('"32502938"', 7),
#   ('"32662044"', 5),
#   ('"34949287"', 3),
#   ('"35303767"', 3),
#   ('"17713116"', 5),
#   ('"9874484"', 8),
#   ('"9749609"', 7),
#   ('"9749595"', 18),
#   ('"9667600"', 3),
#   ('"9618171"', 15),
#   ('"9585364"', 15),
#   ('"9191768"', 8),
#   ('"8871591"', 4),
#   ('"8309575"', 8),
#   ('"8244374"', 2),
#   ('"8232931"', 6),
#   ('"7845403"', 6),
#   ('"7654519"', 4),
#   ('"7629534"', 16),
#   ('"37352388"', 6),
#   ('"37267819"', 9),
#   ('"37165749"', 11),
#   ('"34645254"', 2),
#   ('"32289333"', 8),
#   ('"29483592"', 12),
#   ('"29396174"', 2),
#   ('"28461905"', 3),
#   ('"27093447"', 3),
#   ('"26596547"', 6),
#   ('"26592310"', 2),
#   ('"26125045"', 6),
#   ('"25653290"', 6),
#   ('"25379658"', 10),
#   ('"25337725"', 4),
#   ('"25149450"', 4),
#   ('"23814535"', 2),
#   ('"23724359"', 3),
#   ('"23436503"', 2),
#   ('"22770546"', 3),
#   ('"22622408"', 8),
#   ('"21800139"', 10),
#   ('"21750546"', 10),
#   ('"21496603"', 5),
#   ('"21301909"', 3),
#   ('"20687193"', 2),
#   ('"20482602"', 7),
#   ('"20066431"', 2),
#   ('"19890997"', 5),
#   ('"19651773"', 10),
#   ('"19555827"', 8),
#   ('"19457118"', 5),
#   ('"19403250"', 2),
#   ('"19260107"', 3),
#   ('"19039992"', 11),
#   ('"18685824"', 3),
#   ('"18571468"', 7),
#   ('"18552369"', 15),
#   ('"18437909"', 10),
#   ('"18299520"', 9),
#   ('"18258738"', 15),
#   ('"18224570"', 13),
#   ('"18176524"', 2),
#   ('"17894340"', 2),
#   ('"36288966"', 2),
#   ('"36302970"', 8),
#   ('"36263189"', 13),
#   ('"35563018"', 10),
#   ('"10050893"', 8),
#   ('"10225357"', 9),
#   ('"10448655"', 3),
#   ('"10477437"', 10),
#   ('"10627938"', 8),
#   ('"10714658"', 11),
#   ('"10720299"', 6),
#   ('"10871631"', 10),
#   ('"10881900"', 5),
#   ('"10984667"', 10),
#   ('"11009204"', 1),
#   ('"11014135"', 2),
#   ('"11104212"', 4),
#   ('"11261511"', 4),
#   ('"11835464"', 8),
#   ('"11921134"', 7),
#   ('"11980065"', 8),
#   ('"12360559"', 5),
#   ('"12760408"', 3),
#   ('"12821514"', 7),
#   ('"12859412"', 4),
#   ('"12883919"', 2),
#   ('"12900733"', 3),
#   ('"14581671"', 4),
#   ('"15555920"', 11),
#   ('"15593317"', 9),
#   ('"15726581"', 2),
#   ('"15895426"', 2),
#   ('"16361107"', 3),
#   ('"16537570"', 8),
#   ('"16631205"', 10),
#   ('"16773641"', 4),
#   ('"16924015"', 2),
#   ('"17097111"', 3),
#   ('"17129379"', 6),
#   ('"22472189"', 14),
#   ('"15283994"', 5),
#   ('"12671990"', 7),
#   ('"12007841"', 3),
#   ('"33425096"', 2),
#   ('"19214438"', 3),
#   ('"11405807"', 4),
#   ('"25674472"', 14),
#   ('"21818381"', 3),
#   ('"20169475"', 13),
#   ('"15136718"', 7),
#   ('"9750906"', 5),
#   ('"10434613"', 5),
#   ('"11244697"', 4),
#   ('"11584049"', 3),
#   ('"15989773"', 2),
#   ('"11438481"', 3),
#   ('"14690443"', 11),
#   ('"15099679"', 7),
#   ('"15147511"', 3),
#   ('"15269177"', 3),
#   ('"15505207"', 11),
#   ('"15829632"', 7),
#   ('"19761814"', 7),
#   ('"20639502"', 2),
#   ('"24627482"', 9),
#   ('"25425325"', 5),
#   ('"28768697"', 9),
#   ('"35643882"', 3),
#   ('"32248052"', 1),
#   ('"26506956"', 1),
#   ('"23107556"', 2),
#   ('"34062155"', 3),
#   ('"9539346"', 4),
#   ('"941774"', 2),
#   ('"9380054"', 4),
#   ('"8723633"', 4),
#   ('"8595478"', 4),
#   ('"8552116"', 2),
#   ('"8413963"', 4),
#   ('"8341297"', 4),
#   ('"7969702"', 4),
#   ('"7897412"', 4),
#   ('"7753056"', 2),
#   ('"7205314"', 2),
#   ('"7057205"', 4),
#   ('"3746330"', 2),
#   ('"3574676"', 2),
#   ('"3400519"', 2),
#   ('"3400502"', 2),
#   ('"2840805"', 2),
#   ('"2456673"', 3),
#   ('"2322135"', 2),
#   ('"2239458"', 2),
#   ('"2215959"', 4),
#   ('"2183913"', 4),
#   ('"2005929"', 4),
#   ('"1940944"', 4),
#   ('"1758449"', 4),
#   ('"1758448"', 4),
#   ('"1756758"', 4),
#   ('"131183"', 2),
#   ('"12030016"', 6),
#   ('"11432664"', 6),
#   ('"10463238"', 2),
#   ('"9918350"', 2),
#   ('"9819835"', 2),
#   ('"9440801"', 4),
#   ('"9335011"', 2),
#   ('"9225692"', 2),
#   ('"9221523"', 2),
#   ('"918463"', 2),
#   ('"9176783"', 2),
#   ('"9153120"', 2),
#   ('"8723145"', 2),
#   ('"8703227"', 4),
#   ('"8353711"', 2),
#   ('"10349117"', 2),
#   ('"10526391"', 2),
#   ('"10809944"', 2),
#   ('"10877155"', 2),
#   ('"10980732"', 2),
#   ('"11685399"', 2),
#   ('"11701630"', 2),
#   ('"12876228"', 2),
#   ('"16024174"', 2),
#   ('"1623256"', 2),
#   ('"17125732"', 2),
#   ('"18591071"', 2),
#   ('"1992364"', 4),
#   ('"2073302"', 2),
#   ('"21048241"', 2),
#   ('"2356013"', 2),
#   ('"2614440"', 2),
#   ('"3941936"', 5),
#   ('"3948889"', 2),
#   ('"3984684"', 2),
#   ('"4065158"', 2),
#   ('"626228"', 2),
#   ('"650244"', 2),
#   ('"6697632"', 7),
#   ('"690631"', 2),
#   ('"7325607"', 2),
#   ('"7469847"', 2),
#   ('"7507398"', 2),
#   ('"7556545"', 2),
#   ('"7695236"', 6),
#   ('"7858177"', 2),
#   ('"8221055"', 2),
#   ('"7133334"', 1),
#   ('"2966619"', 2),
#   ('"2245082"', 2),
#   ('"11598522"', 3),
#   ('"941769"', 1),
#   ('"8511436"', 1),
#   ('"8416347"', 2),
#   ('"8277565"', 1),
#   ('"796956"', 4),
#   ('"7856369"', 1),
#   ('"7299845"', 2),
#   ('"7191439"', 1),
#   ('"7164771"', 1),
#   ('"7092616"', 2),
#   ('"6822602"', 1),
#   ('"6622883"', 2),
#   ('"6612149"', 2),
#   ('"6497558"', 2),
#   ('"6477216"', 1),
#   ('"6443743"', 1),
#   ('"6282513"', 2),
#   ('"6234055"', 2),
#   ('"556814"', 1),
#   ('"482013"', 3),
#   ('"4072505"', 4),
#   ('"3724992"', 1),
#   ('"3178457"', 2),
#   ('"310282"', 1),
#   ('"2977281"', 2),
#   ('"2868026"', 1),
#   ('"2840407"', 2),
#   ('"22604515"', 2),
#   ('"2179685"', 2),
#   ('"2164296"', 2),
#   ('"16602679"', 1),
#   ('"15568498"', 1),
#   ('"10527098"', 2),
#   ('"9399227"', 2),
#   ('"8894706"', 4),
#   ('"24486689"', 2),
#   ('"21840890"', 7),
#   ('"20113647"', 1),
#   ('"21900627"', 1),
#   ('"19353218"', 1),
#   ('"17960812"', 1),
#   ('"10833562"', 5),
#   ('"27448549"', 7),
#   ('"18688663"', 6),
#   ('"941783"', 1),
#   ('"941772"', 1),
#   ('"7908772"', 1),
#   ('"7245665"', 1),
#   ('"7052665"', 1),
#   ('"6731882"', 1),
#   ('"6694320"', 1),
#   ('"484133"', 1),
#   ('"4474046"', 3),
#   ('"4448193"', 1),
#   ('"227178"', 1),
#   ('"22183"', 1),
#   ('"207060"', 1),
#   ('"1614793"', 1),
#   ('"1130730"', 1),
#   ('"11714689"', 4),
#   ('"31332180"', 2),
#   ('"27490483"', 6),
#   ('"19765051"', 1),
#   ('"12074905"', 1),
#   ('"14509659"', 5),
#   ('"3041765"', 2),
#   ('"21965893"', 2),
#   ('"19685597"', 2),
#   ('"1484541"', 2),
#   ('"993556"', 1),
#   ('"895957"', 1),
#   ('"3848614"', 1),
#   ('"3468383"', 1),
#   ('"22166421"', 2),
#   ('"6240313"', 1),
#   ('"7791942"', 2),
#   ('"38214203"', 1),
#   ('"24976531"', 3),
#   ('"27477622"', 9),
#   ('"32662044"', 5),
#   ('"37352388"', 6),
#   ('"26297380"', 13),
#   ('"32502938"', 7),
#   ('"24931141"', 8),
#   ('"29641419"', 1),
#   ('"20301665"', 19),
#   ('"28432771"', 4),
#   ('"32243914"', 5),
#   ('"35303767"', 3),
#   ('"31618684"', 6),
#   ('"36417958"', 19),
#   ('"33476878"', 5),
#   ('"34092466"', 17),
#   ('"33468570"', 13),
#   ('"33753289"', 3),
#   ('"29325615"', 1),
#   ('"32239467"', 1),
#   ('"32516804"', 9),
#   ('"33247415"', 1),
#   ('"33175450"', 5),
#   ('"33502045"', 3),
#   ('"34189496"', 14),
#   ('"29053766"', 4),
#   ('"30244176"', 4),
#   ('"24627482"', 9),
#   ('"26592310"', 2),
#   ('"28768697"', 9),
#   ('"35563018"', 10),
#   ('"36329866"', 3),
#   ('"35955710"', 5),
#   ('"33134321"', 3),
#   ('"33757902"', 8),
#   ('"33894367"', 8),
#   ('"34062155"', 3),
#   ('"34119482"', 18),
#   ('"24311730"', 4),
#   ('"27911022"', 12),
#   ('"29739751"', 4),
#   ('"34358617"', 8),
#   ('"26183317"', 10),
#   ('"36263189"', 13),
#   ('"34398825"', 18),
#   ('"36757831"', 3),
#   ('"24757586"', 3),
#   ('"27716431"', 11),
#   ('"30838317"', 11),
#   ('"32289333"', 8),
#   ('"37165749"', 11),
#   ('"28756192"', 5),
#   ('"33445430"', 4),
#   ('"33799994"', 5),
#   ('"33638639"', 9),
#   ('"33991565"', 3),
#   ('"28843013"', 3),
#   ('"28941827"', 2),
#   ('"33395620"', 9),
#   ('"14957878"', 1),
#   ('"14779577"', 1),
#   ('"14921156"', 3),
#   ('"14022841"', 1),
#   ('"32037012"', 4),
#   ('"26596547"', 6),
#   ('"34728955"', 1)],
#  'o decreased': [('"21750546"', 2)],
#  'disturbance': [('"2426591"', 1), ('"9585364"', 5), ('"6497558"', 1)],
#  'iness': [],
#  'a primary': [('"19345148"', 6),
#   ('"12821512"', 3),
#   ('"17956903"', 8),
#   ('"23196519"', 6)],
#  'noids': [],
#  'toxicity': [('"15793882"', 1)],
#  'netic disease': [('"10833562"', 1), ('"6240313"', 1)],
#  'duced': [('"8432555"', 2),
#   ('"8513401"', 2),
#   ('"15668438"', 4),
#   ('"23032422"', 1),
#   ('"19688081"', 1),
#   ('"34380890"', 3),
#   ('"15293281"', 2),
#   ('"19955557"', 1),
#   ('"33757902"', 2),
#   ('"33706202"', 3),
#   ('"34038798"', 4),
#   ('"19685389"', 2),
#   ('"33476687"', 5),
#   ('"33468570"', 3),
#   ('"23284065"', 2),
#   ('"22166420"', 2),
#   ('"14872019"', 2),
#   ('"27716431"', 12),
#   ('"23967309"', 6),
#   ('"20584926"', 6),
#   ('"20223934"', 6),
#   ('"20132487"', 2),
#   ('"17956903"', 2),
#   ('"17428918"', 4),
#   ('"15930383"', 2),
#   ('"36546658"', 2),
#   ('"32516804"', 1),
#   ('"33753289"', 1),
#   ('"32239467"', 3),
#   ('"36329866"', 2),
#   ('"33458877"', 4),
#   ('"33799994"', 1),
#   ('"33894367"', 1),
#   ('"34398825"', 4),
#   ('"35665810"', 1),
#   ('"11495087"', 1),
#   ('"16981842"', 1),
#   ('"21656045"', 1),
#   ('"36757831"', 3),
#   ('"19038309"', 3),
#   ('"19157930"', 3),
#   ('"20301665"', 3),
#   ('"37267819"', 3),
#   ('"37165749"', 3),
#   ('"18552369"', 2),
#   ('"18258738"', 6),
#   ('"10714658"', 6),
#   ('"11261511"', 1),
#   ('"12360559"', 1),
#   ('"12859412"', 2),
#   ('"16361107"', 1),
#   ('"16537570"', 2),
#   ('"12671990"', 2),
#   ('"25674472"', 2),
#   ('"20169475"', 2),
#   ('"25425325"', 3),
#   ('"28768697"', 2),
#   ('"3746330"', 2),
#   ('"1940944"', 2),
#   ('"690631"', 2),
#   ('"482013"', 1),
#   ('"2164296"', 1),
#   ('"8894706"', 2),
#   ('"21840890"', 1),
#   ('"20301665"', 3),
#   ('"33468570"', 3),
#   ('"33753289"', 1),
#   ('"32239467"', 3),
#   ('"32516804"', 1),
#   ('"28768697"', 2),
#   ('"36329866"', 2),
#   ('"33757902"', 2),
#   ('"33894367"', 1),
#   ('"34398825"', 4),
#   ('"36757831"', 3),
#   ('"27716431"', 12),
#   ('"37165749"', 3),
#   ('"33799994"', 1)],
#  'adhesion': [('"16361107"', 4)],
#  'l disorder': [('"2317008"', 2),
#   ('"7911621"', 2),
#   ('"17142829"', 2),
#   ('"33616084"', 3),
#   ('"10073176"', 1),
#   ('"36757831"', 3),
#   ('"24627482"', 4),
#   ('"650244"', 2),
#   ('"24627482"', 4),
#   ('"36757831"', 3)],
#  'kinesia': [('"2666583"', 2),
#   ('"11912106"', 4),
#   ('"24262166"', 2),
#   ('"22266882"', 3),
#   ('"22151759"', 3),
#   ('"33458877"', 4),
#   ('"941774"', 2),
#   ('"17125732"', 2),
#   ('"7695236"', 2),
#   ('"7164771"', 1)],
#  'cell death': [],
#  'pathway': [('"9146024"', 2),
#   ('"27939583"', 2),
#   ('"33757902"', 3),
#   ('"34038798"', 2),
#   ('"25192508"', 3),
#   ('"18267263"', 2),
#   ('"23967309"', 4),
#   ('"22391119"', 4),
#   ('"21136869"', 2),
#   ('"18299128"', 3),
#   ('"17428918"', 9),
#   ('"24951854"', 3),
#   ('"30643666"', 1),
#   ('"33458877"', 6),
#   ('"33799994"', 1),
#   ('"24931141"', 2),
#   ('"37165749"', 3),
#   ('"32289333"', 5),
#   ('"25379658"', 2),
#   ('"19555827"', 2),
#   ('"19457118"', 2),
#   ('"18552369"', 4),
#   ('"18258738"', 9),
#   ('"10984667"', 2),
#   ('"14581671"', 2),
#   ('"16361107"', 2),
#   ('"28768697"', 2),
#   ('"2179685"', 1),
#   ('"12074905"', 1),
#   ('"24931141"', 2),
#   ('"28768697"', 2),
#   ('"33757902"', 3),
#   ('"32289333"', 5),
#   ('"37165749"', 3),
#   ('"33799994"', 1)],
#  'signaling': [('"27939583"', 5),
#   ('"22391119"', 4),
#   ('"16934985"', 3),
#   ('"33894367"', 1),
#   ('"34398825"', 4),
#   ('"32289333"', 5),
#   ('"25379658"', 4),
#   ('"15269177"', 2),
#   ('"33894367"', 1),
#   ('"34398825"', 4),
#   ('"32289333"', 5)],
#  'ty disorder': [],
#  '6648': [],
#  'cell migration': [('"18827015"', 2)],
#  'autophagy': [('"24931141"', 2), ('"18552369"', 6), ('"24931141"', 2)]}

# %%
find_gene_from_pathways
pheno_count_smae_Sen_update=dict()
for i in pheno_count_smae_Sen:
     pheno_count_smae_Sen_update[(str(i),str(find_gene_from_pathways[i]))]= pheno_count_smae_Sen[i]
pheno_count_smae_Sen_update
# Out:
# {('translation', "['TARDBP']"): [('"21818381"', 2)],
#  ('global', "['CBX1', 'NFE2L2']"): [('"36263189"', 3), ('"36263189"', 3)],
#  ('rhythm', "['TARDBP']"): [('"21496608"', 2)],
#  ('cell death', "['NFE2L2', 'TARDBP']"): [],
#  ('aging', "['NFE2L2']"): [('"18299128"', 3),
#   ('"24951854"', 3),
#   ('"27171035"', 1),
#   ('"19578124"', 1),
#   ('"35044558"', 1),
#   ('"37165749"', 6),
#   ('"10349117"', 2),
#   ('"10980732"', 2),
#   ('"33229589"', 2),
#   ('"37165749"', 6)],
#  ('viral infection', "['TARDBP']"): [('"37627888"', 1)],
#  ('nucleocytoplasmic transport', "['TARDBP']"): [('"33468570"', 1),
#   ('"34358617"', 2),
#   ('"33468570"', 1),
#   ('"34358617"', 2)],
#  ('apoptosis', "['NFE2L2', 'TARDBP']"): [('"22897341"', 5)],
#  ('nuclear import', "['TARDBP']"): [],
#  ('response to oxidative stress', "['NFE2L2']"): [('"12671990"', 2)],
#  ('ageing', "['NFE2L2']"): [],
#  ('necrosis', "['NFE2L2', 'TARDBP']"): [],
#  ('rcd', "['NFE2L2', 'TARDBP']"): [('"11232488"', 1)],
#  ('nuclear translocation', "['TARDBP']"): [('"23018676"', 1)],
#  ('detoxification', "['NFE2L2']"): [],
#  ('endoplasmic reticulum-associated degradation',
#   "['NFE2L2']"): [('"21750546"', 4)],
#  ('response to stress', "['TDP1', 'NFE2L2', 'CBX1']"): [('"18267263"', 2),
#   ('"19555827"', 2),
#   ('"12671990"', 2)],
#  ('isr', "['NFE2L2']"): [('"34323950"', 3),
#   ('"33638639"', 5),
#   ('"33468570"', 1),
#   ('"33894367"', 4),
#   ('"34358617"', 7),
#   ('"32502938"', 11),
#   ('"32502938"', 11),
#   ('"33468570"', 1),
#   ('"33894367"', 4),
#   ('"33229589"', 2),
#   ('"34358617"', 7),
#   ('"33638639"', 5)],
#  ('degradation', "['NFE2L2', 'TARDBP']"): [('"15455404"', 5),
#   ('"24311730"', 2),
#   ('"14502672"', 2),
#   ('"17200151"', 5),
#   ('"24931141"', 1),
#   ('"21750546"', 6),
#   ('"18552369"', 4),
#   ('"11438481"', 3),
#   ('"24627482"', 2),
#   ('"28768697"', 4),
#   ('"24931141"', 1),
#   ('"24627482"', 2),
#   ('"28768697"', 4),
#   ('"24311730"', 2)],
#  ('nuclear morphology', "['TARDBP']"): [('"33468570"', 1), ('"33468570"', 1)],
#  ('breakdown', "['NFE2L2', 'TARDBP']"): [('"7231447"', 1)],
#  ('nucleoside',
#   "['CBX1', 'NFE2L2', 'TARDBPCBX1', 'TARDBPNFE2L2', 'TARDBPTARDBP']"): [],
#  ('transcription', "['CBX1', 'NFE2L2']"): [('"21847143"', 2),
#   ('"30237473"', 1)]}

# %% [markdown]
# Annotation checking: disease

# %%
concatenated_df
# Out:
#           Disease                                       disease_name  \
# 0     OMIM:618573  Hypothyroidism, congenital, nongoitrous, 7, 61...
# 1     OMIM:246200                       Donohue syndrome, 246200 (3)
# 2     OMIM:613011         Lymphoproliferative syndrome 1, 613011 (3)
# 3     OMIM:617062  Okur-Chung neurodevelopmental syndrome, 617062...
# 4     OMIM:602849                        Muenke syndrome, 602849 (3)
# ..            ...                                                ...
# 390    ORPHA:1930        Orphanet: Herpes simplex virus encephalitis
# 391   ORPHA:50943              Orphanet: Keratolytic winter erythema
# 392  ORPHA:464293  Orphanet: NON RARE IN EUROPE: Infantile capill...
# 393   ORPHA:33069                          Orphanet: Dravet syndrome
# 394     ORPHA:794                 Orphanet: Saethre-Chotzen syndrome
#
#                                                    Syn  \
# 0                                          TRHR, CHNG7
# 1                                           INSR, HHF5
# 2                                      ITK, EMT, LPFS1
# 3                                CSNK2A1, CK2A1, OCNDS
# 4                                           FGFR3, ACH
# ..                                                 ...
# 390  HSE, HSV encephalitis, HSVE, Herpes simplex me...
# 391    Erythrokeratolysis hiemalis, Oudtshoorn disease
# 392                                               None
# 393  SMEI, Severe myoclonic epilepsy of infancy, Se...
# 394            ACS3, Acrocephalosyndactyly type 3, SCS
#
#                                        disease_des/def  \
# 0    Nongoitrous congenital hypothyroidism-7 (CHNG7...
# 1                                                 None
# 2    Lymphoproliferative syndrome-1 is an autosomal...
# 3    Okur-Chung neurodevelopmental syndrome (OCNDS)...
# 4    Muenke syndrome is an autosomal dominant disor...
# ..                                                 ...
# 390  A rare disorder caused by infection of the cen...
# 391  Keratolytic winter erythema is a rare epiderma...
# 392                                               None
# 393  A rare, genetic, developmental and epileptic e...
# 394  A syndrome characterized by unilateral or bila...
#
#                          Clinicalfeatures/Clinical_des
# 0    {2:Collu et al. (1997)} studied a 12.5-year-ol...
# 1    Among the children of second cousins once remo...
# 2    {1:Huck et al. (2009)} reported 2 sisters, bor...
# 3    {3:Okur et al. (2016)} reported 5 unrelated gi...
# 4    On the basis of 61 individuals from 20 unrelat...
# ..                                                 ...
# 390  HSVE usually peaks in childhood (between 3 mon...
# 391                                               None
# 392                                               None
# 393  Onset of the first seizure is mainly in the fi...
# 394  SCS has a variable spectrum of manifestations....
#
# [395 rows x 5 columns]

# %%
Genes_= sum(concatenated_df['disease_name+syn'],[])
Genes_=list(set(Genes_))
Genes_= [i[9:].strip().lower()  if i[:9]=='Orphanet:' else i.strip().lower() for i in Genes_]
Genes_
# Out:
# ['minds syndrome',
#  'rochis',
#  'cfd1',
#  'acute myeloblastic leukemia 3',
#  'familial scaphocephaly syndrome',
#  'tbxas1',
#  'gastric cancer, somatic',
#  'syringocystadenoma papilliferum',
#  'besnier-boeck-schaumann disease',
#  'ondine-hirschsprung disease',
#  'fanconi-bickel syndrome',
#  'aiide',
#  'non rare in europe: infantile capillary hemangioma',
#  'dyt18',
#  'cervical cancer, somatic',
#  'rdeb',
#  'hemophilia b',
#  'juvenile rheumatoid factor-negative polyarthritis',
#  'ache',
#  'ar-nsid',
#  'chronic myelogenous leukemia',
#  'boeck sarcoid',
#  'myeloproliferative disorder with eosinophilia',
#  'ptpn11',
#  'coffin-lowry syndrome',
#  'btk',
#  'ctsk',
#  'undetermined early-onset epileptic encephalopathy',
#  'pik3cd',
#  'herpes simplex neuroinvasion',
#  'col7a1',
#  'abcc1',
#  'familial mtc',
#  'gabra1',
#  'metaphyseal anadysplasia',
#  'williams-beuren syndrome',
#  'nak',
#  'jackson-weiss syndrome',
#  'itk',
#  'congenital heart defects, multiple types, 7',
#  'mody',
#  'hyperinsulinemic hypoglycemia, familial, 3',
#  'chronic myeloproliferative disease',
#  'lymphatic malformation 1',
#  'still disease',
#  'congenital heart defects and skeletal malformations syndrome',
#  'craf',
#  'rp38',
#  'buphthalmia',
#  'basal ganglia calcification, idiopathic, 1',
#  'non rare in europe: hypodontia',
#  'undetermined eoee',
#  'premature aging syndrome',
#  'congenital chronic diarrhea with protein-losing enteropathy',
#  'chtd7',
#  'aml with t(15;17)(q22;q12);(pml/raralpha) and variants',
#  'insr',
#  'prkm1',
#  'blood group, yt system',
#  'mild congenital factor ix deficiency',
#  'symptomatic form of coffin-lowry syndrome in female carriers',
#  'polycythemia rubra vera',
#  'agammaglobulinemia, x-linked 1',
#  'cdg syndrome type iia',
#  'donohue syndrome',
#  'fgfr2-related bent bone dysplasia',
#  'hsv encephalitis',
#  'myeloid/lymphoid neoplasm associated with fgfr1 rearrangement',
#  'idiopathic bronchiectasis',
#  'cardiofaciocutaneous syndrome',
#  'imd22',
#  'hereditary chronic pancreatitis',
#  'microphthalmia with colobomatous cyst',
#  'bronchiectasis with or without elevated sweat chloride 1',
#  'hies',
#  'aoms3',
#  'cystic fibrosis',
#  'crouzon syndrome',
#  'bcns1',
#  'glut1 deficiency syndrome 1, infantile onset, severe',
#  'isolated bicoronal craniosynostosis',
#  'mrp1',
#  'medullary thyroid carcinoma',
#  'f11',
#  'oligoarticular juvenile idiopathic arthritis',
#  'cfc syndrome',
#  'htlvr',
#  'pn1',
#  'pndm3',
#  'gabra5',
#  'colchicine resistance',
#  'mucoviscidosis',
#  'classic pfeiffer syndrome',
#  'primary myelofibrosis',
#  'mgat2-cdg',
#  'faah',
#  'follicular lymphoma',
#  'epilepsy, idiopathic generalized, susceptibility to, 15',
#  'acs3',
#  'kiaa0551',
#  'myoclonic-astatic epilepsy',
#  'jmml',
#  'frontotemporal dementia with motor neuron disease',
#  'mplv',
#  'camptodactyly-tall stature-scoliosis-deafness syndrome',
#  'ondine-hirschsprung syndrome',
#  'pafah',
#  'moderate congenital f9 deficiency',
#  'abcg2',
#  'keratolytic winter erythema',
#  'nut midline carcinoma',
#  'rubinstein-taybi syndrome 1',
#  'mapk1',
#  'immunodeficiency 14a, autosomal dominant',
#  'smith-kingsmore syndrome',
#  'alk+ large b-cell lymphoma',
#  'autosomal dominant isolated neurosensory deafness type dfna',
#  'marfanoid habitus-facial dysmorphism-skeletal abnormality-heart defect syndrome',
#  'chronic granulocytic leukemia',
#  'insensitivity to pain, congenital',
#  'spg76',
#  'acquired primary erythrocytosis',
#  'chronic nk lymphocytosis',
#  'regressive metaphyseal dysplasia',
#  'central hypothyroidism due to trh receptor deficiency',
#  'sur1',
#  'myoclonus-dystonia syndrome',
#  'focal dermal hypoplasia',
#  'chronic nk-cell lymphocytosis',
#  'hereditary sensory and autonomic neuropathy type iv',
#  'growth delay due to insulin-like growth factor i resistance',
#  'combined immunodeficiency due to itk deficiency',
#  'mdr1',
#  'ck2a1',
#  'leukemic reticuloendotheliosis',
#  'cml',
#  'nmc',
#  'alk',
#  'steroid 5-alpha-reductase 2 deficiency',
#  '8p11 myeloproliferative syndrome',
#  'sur',
#  'apds',
#  'multiple endocrine neoplasia iib',
#  'trpo',
#  'sfnp',
#  'cnkl',
#  'budd-chiari syndrome, somatic',
#  'bspdc',
#  'non-syndromic bilateral coronal suture synostosis',
#  'amyotrophic lateral sclerosis',
#  'pediatric multiple sclerosis',
#  'cls',
#  'childhood absence epilepsy',
#  'cip',
#  'kdp',
#  'congenital stuart factor deficiency',
#  'epilepsy with myoclonic absences',
#  'mastc',
#  'infantile myofibromatosis',
#  'non rare in europe: melanoma',
#  'mae',
#  'saethre-chotzen syndrome with or without eyelid anomalies',
#  'hes-m',
#  'jak3',
#  'myofibromatosis, infantile, 1',
#  'hirschsprung disease, protection against',
#  'vaquez disease',
#  'leopard syndrome 2',
#  'kosaki overgrowth syndrome',
#  'cdg2a',
#  'muenke syndrome',
#  'clg4b',
#  'developmental and epileptic encephalopathy 19',
#  'papillary syringocystadenoma',
#  'bek',
#  'intellectual developmental disorder with hypotonia and behavioral abnormalities',
#  'rorc',
#  'b-all with t(9;22)(q34.1;q11.2)',
#  'plasma thromboplastin antecedent deficiency',
#  'autosomal dominant non-syndromic neurosensory deafness type dfna',
#  'xla',
#  'familial medullary thyroid carcinoma',
#  'septo-optic dysplasia',
#  'chdskm',
#  'clg',
#  'rheumatoid factor-negative polyarticular juvenile idiopathic arthritis',
#  'smei',
#  'paroxysmal extreme pain disorder',
#  'mandibulofacial dysostosis with alopecia',
#  'cd36l1',
#  'rorb',
#  'microform hpe',
#  'hyperinsulinemic hypoglycemia due to insulin receptor deficiency',
#  'bruton type agammaglobulinemia',
#  'non-specific syndromic intellectual disability',
#  'pfeiffer syndrome type 3',
#  'severe combined immunodeficiency due to ikk2 deficiency',
#  'severe form',
#  'amyotrophic lateral sclerosis 19',
#  'bullous pemphigoid',
#  'akt1',
#  'tnik',
#  'noonan syndrome with multiple lentigines',
#  'mandp2',
#  'ctsb',
#  'cmns',
#  'pentt',
#  'leprechaunism',
#  'lymphatic malformation 8',
#  'gefs+',
#  'aquagenic syringeal acrokeratoderma',
#  'carbohydrate deficient glycoprotein syndrome type iia',
#  'encephalopathy due to glut1 deficiency',
#  'thyroid hormone resistance, autosomal recessive',
#  'severe congenital factor ix deficiency',
#  'cornelia de lange syndrome 6',
#  'braf',
#  'ncms',
#  'cpt1a deficiency',
#  'prostate cancer/brain cancer susceptibility, somatic',
#  'noonan syndrome 1',
#  'pfeiffer syndrome type 2',
#  'ejm5',
#  'hla-drb1',
#  'thrb',
#  'hhf3',
#  'ghosal',
#  'noonan syndrome 13',
#  'systemic sclerosis sine scleroderma',
#  'apert syndrome',
#  'histiocytosis x',
#  'hereditary sensory and autonomic neuropathy type 2',
#  'hypochondroplasia',
#  'giant cell arteritis',
#  'de morsier syndrome',
#  'curry-jones syndrome, somatic mosaic',
#  'hscr1',
#  'autosomal recessive lymphoproliferative disease due to itk deficiency',
#  'tpor',
#  'rosenthal syndrome',
#  'non rare in europe: ulcerative colitis',
#  'admio1',
#  'aquagenic wrinkling of the palms',
#  'charcot disease',
#  'dgat1',
#  'f9',
#  'gsd due to glut2 deficiency',
#  'non rare in europe: multiple sclerosis',
#  'non-syndromic metopic craniosynostosis',
#  'autosomal dominant isolated sensorineural deafness type dfna',
#  'crouzon syndrome-acanthosis nigricans syndrome',
#  'asps',
#  'ghosal hematodiaphyseal dysplasia',
#  'carnitine palmitoyl transferase 1a deficiency',
#  'neonatal inflammatory skin and bowel disease',
#  'neu',
#  'acrofacial dysostosis, cincinnati type',
#  'noonan syndrome 5',
#  'hereditary sensory and autonomic neuropathy type v',
#  'corpus callosum agenesis-polysyndactyly syndrome',
#  'scn9a-related congenital insensitivity to pain',
#  'lmphm1',
#  'limited cutaneous systemic sclerosis',
#  'ibgc4',
#  'ns6',
#  'mfda',
#  'juvenile myoclonic epilepsy',
#  'smoh',
#  'multiple sclerosis, disease progression, modifier of',
#  'ndnc8',
#  'chronic lymphoproliferative disorder of nk-cells',
#  'cmpd-u',
#  'autosomal dominant non-syndromic sensorineural hearing loss type dfna',
#  'skeletal overgrowth-craniofacial dysmorphism-hyperelastic skin-white matter lesions syndrome',
#  'non rare in europe: crohn disease',
#  'sleb2',
#  'mild congenital f9 deficiency',
#  'ret',
#  'cpsb',
#  'congenital glaucoma',
#  'stat3-related early-onset multisystem autoimmune disease',
#  'langerhans cell granulomatosis',
#  'hypochondroplasia',
#  'leopard syndrome 3',
#  'bdplt22',
#  'lennox-gastaut syndrome',
#  'muenke syndrome',
#  'immunodeficiency 15b',
#  't-b+ severe combined immunodeficiency due to jak3 deficiency',
#  'sdchc',
#  'fet1',
#  'primary congenital glaucoma',
#  'myelofibrosis with myeloid metaplasia, somatic',
#  'rare autosomal dominant non-syndromic sensorineural deafness type dfna',
#  'severe myoclonic epilepsy of infancy',
#  'antley-bixler syndrome without genital anomalies or disordered steroidogenesis',
#  'buckley syndrome',
#  'autosomal recessive dystrophic epidermolysis bullosa',
#  'philadelphia chromosome-like b-all',
#  'cebpa',
#  'leukodystrophy, hypomyelinating, 27',
#  'cornelia de lange syndrome',
#  'epidermolysis bullosa dystrophica inversa',
#  'try1',
#  'acrocephalosyndactyly type 1',
#  'doose syndrome',
#  'crouzon-dermoskeletal syndrome',
#  'mtor',
#  'familial or idiopathic dilated cardiomyopathy',
#  'hartsfield syndrome',
#  'lhrhr',
#  'ighd3',
#  'macrocephaly-intellectual disability-neurodevelopmental disorder-small thorax syndrome',
#  'erbb2',
#  'alk+ lbcl',
#  'limited cutaneous systemic scleroderma',
#  'diabetes mellitus, noninsulin-dependent',
#  'brd4',
#  'hereditary pseudocholinesterase deficiency',
#  'sipple syndrome',
#  'penttinen type',
#  'advanced sleep-phase syndrome, familial, 2',
#  'autosomal dominant non-syndromic intellectual disability',
#  'mandibulofacial dysostosis with alopecia',
#  'autosomal recessive non-syndromic intellectual disability',
#  'autosomal recessive primary immunodeficiency due to rorc mutation',
#  'phls',
#  'papillary or follicular thyroid carcinoma',
#  'hsan4',
#  'resistance to thyroid hormone due to a mutation in thyroid hormone receptor beta',
#  'huntington chorea',
#  'besc1',
#  'dyrk1b',
#  'fgfr3',
#  'buphthalmus',
#  'bcr-abl1-like b-all',
#  'transient reactive papulotranslucent acrokeratoderma',
#  'egfr',
#  'basal ganglia calcification, idiopathic, 4',
#  'prkwnk1',
#  'cf',
#  'epilepsy, childhood absence, susceptibility to, 4',
#  'classic glucose transporter type 1 deficiency syndrome',
#  'thcyt2',
#  'eig15',
#  'aprf',
#  'frontotemporal dementia and/or amyotrophic lateral sclerosis 4',
#  'hepatic carnitine palmitoyl transferase i deficiency',
#  'curry-jones syndrome',
#  'hereditary thrombocythemia',
#  'colonic aganglionosis',
#  'ped',
#  'severe generalized rdeb',
#  'imd1',
#  'non-immune hf',
#  'men2a',
#  'cacna1b',
#  'hcl-c',
#  'congenital central alveolar hypoventilation-hirschsprung disease syndrome',
#  'pyknodysostosis',
#  'immunodeficiency 22',
#  'rabson-mendenhall syndrome',
#  'sdchcn',
#  'idiopathic basal ganglia calcification',
#  'pta deficiency',
#  'giant cell glioblastoma',
#  'activated pi3k-delta syndrome',
#  'budd-chiari syndrome',
#  'cerebrovascular ferrocalcinosis',
#  '46',
#  'capb',
#  'ogd',
#  'pfbc',
#  'cardiomyopathic lentiginosis',
#  'non rare in europe: diabetes mellitus type 1',
#  'corticotroph pituitary adenoma',
#  'rdeb generalisata gravis',
#  'aml with t(8;16)(p11;p13) translocation',
#  'neoplastic hypereosinophilic syndrome',
#  'encephalocraniocutaneous lipomatosis, somatic mosaic',
#  'menke-hennekam syndrome 1',
#  'porc',
#  'non rare in europe: hereditary essential tremor',
#  'skap',
#  'gmn',
#  'mmp3',
#  'syringadenoma papilliferum',
#  'l-cpt1 deficiency',
#  'levy-hollister syndrome',
#  'stmy1',
#  'mac',
#  'congenital disorder of glycosylation type iia',
#  'moderate congenital factor ix deficiency',
#  'glut1 deficiency syndrome 2, childhood onset',
#  'dyt18',
#  'imd42',
#  'syk',
#  'distal monosomy 22q11.2',
#  'ns13',
#  'congenital disorder of glycosylation type 2a',
#  'imd14b',
#  'rzrb',
#  'goltz-gorlin syndrome',
#  'resistance to thyroid hormone beta',
#  'pbt',
#  'drt',
#  'hereditary sensory and autonomic neuropathy type 5',
#  'iiae8',
#  'autosomal dominant isolated neurosensory hearing loss type dfna',
#  'basal cell carcinoma, somatic',
#  'osteoglophonic dysplasia',
#  'fpc',
#  'x-linked agammaglobulinemia',
#  'blue rubber bleb nevus',
#  'pdgfr',
#  'hyptrp',
#  'hpe7',
#  't-cell large granular lymphocyte leukemia',
#  'agmx1',
#  'xy dsd due to 5-alpha-reductase 2 deficiency',
#  'pheochromocytoma',
#  'myelofibrosis with myeloid metaplasia',
#  'ovarian cancer, somatic',
#  'high density lipoprotein cholesterol level qtl6',
#  'germ cell tumors, somatic',
#  'hyperinsulinemic hypoglycemia due to insr deficiency',
#  'mfda',
#  'developmental and epileptic encephalopathy 79',
#  'ss1',
#  'scaphocephaly, maxillary retrusion, and impaired intellectual development',
#  'abdominal obesity-metabolic syndrome 3',
#  'autosomal dominant isolated sensorineural hearing loss type dfna',
#  'ptc syndrome',
#  'bbds',
#  'aquagenic keratoderma',
#  'chronic myelomonocytic leukemia',
#  'rthb',
#  'severe hemophilia b',
#  'congenital bilateral agenesis of vas deferens',
#  'gnrhr',
#  'mucocutaneous venous malformations',
#  'bched',
#  'alk-positive large b-cell lymphoma',
#  'alps4',
#  'chronic lymphoproliferative disorder of natural killer cells',
#  'rubinstein-taybi syndrome due to 16p13.3 microdeletion',
#  'multiple endocrine neoplasia type 2a',
#  'autosomal recessive dystrophic epidermolysis bullosa generalisata gravis',
#  'disc2',
#  'thrombophilia 8, x-linked, due to factor ix defect',
#  'alk-positive anaplastic large cell lymphoma',
#  'craniofacial-skeletal-dermatologic dysplasia',
#  'tbk1',
#  'congenital insensitivity to pain-anosmia-neuropathic arthropathy',
#  't-b+ scid due to jak3 deficiency',
#  'primary hes',
#  'pndm1',
#  'tdo2',
#  'thph8',
#  'glioblastoma, somatic',
#  'et',
#  'narcolepsy without cataplexy',
#  'gck',
#  'ibgc2',
#  'warfarin sensitivity',
#  'hereditary essential myoclonus',
#  'classic hairy cell leukemia',
#  'thanatophoric dysplasia type 2',
#  'noonan syndrome 7',
#  'drug addiction, susceptibility to',
#  'thanatophoric dwarfism type 2',
#  'epidermal nevus, somatic',
#  'septo-optic dysplasia spectrum',
#  'td2',
#  'vmcm',
#  't-lgl',
#  'familial rectal pain',
#  'bent bone dysplasia syndrome',
#  'congenital factor xi deficiency',
#  'hpe-l',
#  'stuart-prower factor deficiency',
#  'clonal hypereosinophilic syndrome',
#  'jak1',
#  'erythermalgia, primary',
#  'nihf',
#  'f10',
#  'pik3cg',
#  'schizophrenia',
#  'senescent t-cells-lymphadenopathy-immunodeficiency syndrome due to p110delta-activating mutation',
#  'inflammatory myofibroblastic tumor',
#  'bladder cancer, somatic',
#  'thrombocytopenia 6',
#  'neuroblastoma',
#  'factor xi deficiency, autosomal dominant',
#  'congenital disorder of glycosylation, type iia',
#  'horton disease',
#  'cloverleaf skull-micromelic bone dysplasia syndrome',
#  'cla1',
#  'rsts1',
#  'huntington disease',
#  'diabetes mellitus, permanent neonatal 1',
#  'lpfs1',
#  'porcn',
#  'als',
#  'butyrylcholinesterase deficiency',
#  'meningioma',
#  'fgfr2',
#  'kal2',
#  'apml',
#  'congenital bilateral aplasia of vas deferens',
#  'acrocephalosyndactyly type 3',
#  'hypertryptophanemia',
#  'hhf1',
#  'glycogen storage disease due to glut2 deficiency',
#  'eca4',
#  'myoclonic-astatic epilepsy in early childhood',
#  'glut1',
#  't-cell lgl leukemia',
#  'camptodactyly-tall stature-scoliosis-hearing loss syndrome',
#  'pafad',
#  'perinatal lethal bent bone dysplasia',
#  'mrt54',
#  'tnf',
#  'flt2',
#  'severe achondroplasia-developmental delay-acanthosis nigricans syndrome',
#  'familial thrombocytosis',
#  'fcd type iib',
#  'essential tremor, hereditary, 1',
#  'ftdals4',
#  'sporadic pheochromocytoma/secreting paraganglioma',
#  'isolated pndm',
#  'rheumatoid factor-negative polyarticular jia',
#  'resistance to thyrotropin-releasing hormone syndrome',
#  'asv',
#  'severe myoclonus epilepsy of infancy',
#  'srd5a2',
#  'aganglionic megacolon',
#  'her2',
#  'factor x deficiency',
#  'hypogonadotropic hypogonadism 7 without anosmia',
#  'ladd syndrome 1',
#  'mrp7',
#  'agnogenic myeloid metaplasia',
#  'juvenile myoclonus epilepsy',
#  'holoprosencephaly',
#  'td1',
#  'tnfa',
#  'diaphyseal dysplasia-anemia syndrome',
#  'craniopharyngioma',
#  'crouzon craniofacial dysostosis',
#  'focal dermal hypoplasia',
#  'ns7',
#  'vscn2',
#  'monogenic diabetes of infancy',
#  'nihh',
#  'ghosal syndrome',
#  'congenital hypogonadotropic hypogonadism with anosmia',
#  'thanatophoric dysplasia, type i',
#  'autoimmune pap',
#  'oligoarticular jia',
#  'x-linked non-syndromic intellectual disability',
#  'isolated focal cortical dysplasia type iib',
#  'nena',
#  'imd15b',
#  'myoclonic atonic epilepsy',
#  'isolated trigonocephaly',
#  'retinitis pigmentosa',
#  'paroxysmal dystonic choreathetosis with episodic ataxia and spasticity',
#  'gliosarcoma',
#  'crlr',
#  'hscr',
#  'chds6',
#  'rps6ka3',
#  'hyperinsulinemic hypoglycemia, familial, 5',
#  'hemophilia c',
#  'imd97',
#  'scs',
#  'vegfr3',
#  'yt',
#  'precursor t-cell acute lymphocytic leukemia',
#  'prth',
#  'trhr',
#  'scarb1',
#  'bleeding disorder, platelet-type, 22',
#  'progressive cutaneous systemic scleroderma',
#  'autosomal dominant non-syndromic neurosensory hearing loss type dfna',
#  'thc6',
#  'colon cancer, advanced, somatic',
#  'emt',
#  'focal cortical dysplasia, type ii, somatic',
#  'tndm2',
#  'monosomy 7q11.23',
#  'myeloid/lymphoid neoplasm associated with pdgfrb rearrangement',
#  'ladd syndrome 2',
#  'deletion 7q11.23',
#  'hereditary sodium channelopathy-related small fibers neuropathy',
#  'saethre-chotzen syndrome',
#  'osteoglophonic dwarfism',
#  'narcolepsy-cataplexy',
#  'male infertility with azoospermia or oligozoospermia due to single gene mutation',
#  'src',
#  'moderate hemophilia b',
#  'hyperinsulinism due to insr deficiency',
#  'classic glut1-ds',
#  'ptp2c',
#  'cipa',
#  'pyknolepsy',
#  'btps2',
#  'cushing disease',
#  'holoprosencephaly-ectrodactyly-cleft lip/palate syndrome',
#  'metaphyseal anadysplasia 2',
#  'acs3',
#  'episodic choreoathetosis/spasticity',
#  'cutis gyrata-acanthosis nigricans-craniosynostosis syndrome',
#  'nontropical sprue',
#  'idiopathic myelofibrosis',
#  'non-specific early-onset epileptic encephalopathy',
#  'selective tooth agenesis',
#  'hereditary sensory and autonomic neuropathy type 4',
#  'immunodeficiency 97 with autoinflammation',
#  'abcp',
#  'dravet syndrome',
#  'kit',
#  'coronary heart disease, susceptibility to, 6',
#  'noonan syndrome',
#  'familial isolated dilated cardiomyopathy',
#  'cebp',
#  'job syndrome',
#  'apert syndrome',
#  'isolated brachycephaly',
#  'desmd',
#  'cpt deficiency, hepatic, type ia',
#  'achondroplasia',
#  'genetic epilepsy with febrile seizures-plus',
#  'mertk',
#  'lymphoproliferative syndrome 1',
#  'jws',
#  'leopard syndrome',
#  'severe combined immunodeficiency due to lck deficiency',
#  'mkhk1',
#  'nedneh',
#  'pgy1',
#  'ednra',
#  'asthma, diminished response to antileukotriene treatment in',
#  'drd3',
#  'wagenmann-froboese syndrome',
#  'cutaneous and mucosal venous malformation',
#  'autosomal recessive generalized dystrophic epidermolysis bullosa',
#  'ghosal hematodiaphyseal syndrome',
#  'undifferentiated myeloproliferative disease',
#  'ad-hies due to stat3 deficiency',
#  'autosomal dominant hyperimmunoglobulin e syndrome due to signal transducer and activator of transcription 3 protein deficiency',
#  'dhof',
#  'primary familial brain calcification',
#  'holoprosencephaly-like',
#  'visceral neuropathy, familial, 2, autosomal recessive',
#  'disseminated lupus erythematosus',
#  'thrombocythemia 3',
#  'che1',
#  'spastic paraplegia 76, autosomal recessive',
#  'polr1a',
#  'erk2',
#  'spg76',
#  'crebbp',
#  'twist1',
#  'slc2a1',
#  'ach',
#  'ns5',
#  'mirk',
#  'crouzon syndrome with acanthosis nigricans',
#  'cgrpr',
#  'gluten-induced enteropathy',
#  'scid due to lck deficiency',
#  'pycnodysostosis',
#  'oligodontia',
#  'familial pheochromocytoma-paraganglioma',
#  'diabetes mellitus, insulin-resistant, with acanthosis nigricans',
#  'hdlqtl6',
#  'glvr2',
#  'hereditary cryohydrocytosis with reduced stomatin',
#  'choanal atresia-hearing loss-cardiac defects-craniofacial dysmorphism syndrome',
#  'familial multiple lentigines syndrome',
#  'nblst3',
#  'abcc7',
#  'hemimegalencephaly',
#  'slc20a2',
#  'cdk8',
#  'non-syndromic bicoronal craniosynostosis',
#  'progressive cutaneous systemic sclerosis',
#  'pauciarticular chronic arthritis',
#  'tk14',
#  'mrp',
#  'multiple endocrine neoplasia type 3',
#  'hpe',
#  'smith-kingsmore syndrome',
#  'naevus syringocystadenomatosus papilliferus',
#  'hepatic carnitine palmitoyl transferase 1 deficiency',
#  'l-cpti deficiency',
#  'hereditary cryohydrocytosis type 2',
#  'rosenthal factor deficiency',
#  'hsan5',
#  'severe congenital f9 deficiency',
#  'congenital intestinal aganglionosis',
#  'cdgs2',
#  'ns-arid',
#  'epilepsy with myoclonic-astatic seizures',
#  'men2b',
#  'imf1',
#  'migraine without aura, susceptibility to',
#  'stat3',
#  'thyroid hormone resistance',
#  'differentiated thyroid carcinoma',
#  'knstrn',
#  'giant congenital melanocytic nevus',
#  'osler-vaquez disease',
#  'lobar holoprosencephaly',
#  'clcs',
#  'acroosteolysis-keloid-like lesions-premature aging syndrome',
#  'proliferation of large granular lymphocytes',
#  'precursor t-cell acute lymphoblastic leukemia',
#  'alox5',
#  'jakl',
#  'multiple endocrine neoplasia iia',
#  'familial thrombocythemia',
#  'hhf5',
#  'lck',
#  'menke-hennekam syndrome',
#  'scid due to lymphocyte-specific protein tyrosine kinase deficiency',
#  'eig12',
#  'catshl syndrome',
#  'hrtfds',
#  'venous malformations, multiple cutaneous and mucosal',
#  'hyper-ige syndrome 1, autosomal dominant, with recurrent infections',
#  'lard syndrome',
#  'cws6',
#  'ptch1',
#  'haberland syndrome',
#  'fistulous vegetative verrucous hydradenoma',
#  'lmphm8',
#  'metcds',
#  'epilepsy, idiopathic generalized, susceptibility to, 12',
#  'hereditary sensory and autonomic neuropathy type ii',
#  'nras',
#  'herpetic encephalitis',
#  'isolated metopic craniosynostosis',
#  'osteomyelofibrosis',
#  'gs',
#  'diffuse cutaneous systemic sclerosis',
#  'cardiofaciocutaneous syndrome',
#  'autosomal recessive mendelian susceptibility to mycobacterial diseases due to partial jak1 deficiency',
#  'essential thrombocythemia',
#  'large congenital melanocytic nevus',
#  'non-immune fetal hydrops',
#  'minor form',
#  'frap1',
#  'hypothyroidism, congenital, nongoitrous, 7',
#  'chronic myeloid leukemia',
#  '46',
#  'stomatin-deficient cryohydrocytosis with neurologic defects',
#  'ftd-als',
#  'xlid19',
#  'autosomal dominant charcot-marie-tooth disease type 2 due to dgat2 mutation',
#  'btk-deficiency',
#  'alcohol-responsive dystonia',
#  'immunodeficiency 15a',
#  'erbb4',
#  'pha1b2',
#  'rabson-mendenhall syndrome',
#  'pseudovaginal perineoscrotal hypospadias',
#  'glut1ds',
#  'polycythemia vera, somatic',
#  'sks',
#  'mmp1',
#  'uaqtl1',
#  'xy disorder of sex development due to 5-alpha-reductase 2 deficiency',
#  'stomatin-deficient cryohydrocytosis',
#  'de vivo disease',
#  'thcyt3',
#  'microform holoprosencephaly',
#  'saddan',
#  'congenital factor x deficiency',
#  'non-syndromic metopic suture synostosis',
#  'autosomal recessive sensory radicular neuropathy',
#  'paroxysmal exertion-induced dyskinesia',
#  'dystonia 18',
#  'maroteaux-verloes-stanescu syndrome',
#  'pha2c',
#  'lidls1',
#  'pancreatitis, hereditary',
#  'receup',
#  'congenital bilateral absence of vas deferens',
#  'pdgfrb',
#  'cpt1a',
#  'thyroid hormone resistance, selective pituitary',
#  'bche',
#  'diar7',
#  'microphthalmia-anophthalmia-coloboma syndrome',
#  'trka',
#  'rubinstein-taybi syndrome due to crebbp mutations',
#  'thanatophoric dwarfism-cloverleaf skull syndrome',
#  'scid due to ikk2 deficiency',
#  'cdg-iia',
#  'cf',
#  'frontotemporal dementia with amyotrophic lateral sclerosis',
#  'rorg',
#  'fanconi-bickel syndrome',
#  'jme',
#  'wnk1',
#  'severe combined immunodeficiency due to lymphocyte-specific protein tyrosine kinase deficiency',
#  'mlvar',
#  'congenital glucokinase-related hyperinsulinism',
#  'ulcerative proctosigmoiditis',
#  'distal 22q11.2 microdeletion syndrome',
#  'scaphocephaly-macrocephaly-maxillary retrusion-intellectual disability syndrome',
#  'hh7',
#  'imd14a',
#  'familial advanced sleep-phase syndrome',
#  'isolated focal cortical dysplasia type iia',
#  'cyp5',
#  'apds',
#  'hallopeau-siemens type',
#  'essential thrombocytosis',
#  'polycythemia vera',
#  'limited systemic sclerosis',
#  'eccl',
#  'herpes simplex meningo-encephalitis',
#  'lacrimoauriculodentodigital syndrome',
#  'jackson-weiss syndrome',
#  'congenital chronic diarrhea with exudative enteropathy',
#  'pla2g7',
#  'afdcin',
#  'rpa194',
#  'cbp',
#  'thanatophoric dysplasia, type ii',
#  'roifman-chitayat syndrome',
#  'hereditary pheochromocytoma-paraganglioma',
#  'slc2a2',
#  'cystic fibrosis',
#  'kallmann syndrome',
#  'hes-n',
#  'abcc8',
#  'systemic lupus erythematosus',
#  'autoimmune pulmonary alveolar proteinosis',
#  'trigonocephaly 1',
#  'isolated growth hormone deficiency, type iii, with agammaglobulinemia',
#  'imd82',
#  'pycnodysostosis',
#  'glaucoma 3, primary congenital, e',
#  'neuroblastoma, susceptibility to, 3',
#  'keratolytic winter erythema',
#  'classic glut1 deficiency syndrome',
#  'diffuse cutaneous systemic scleroderma',
#  'burn-mckeown syndrome',
#  'olfacto-genital pathological sequence',
#  'giant pigmented hairy nevus',
#  'epht3',
#  'non rare in europe: celiac disease',
#  'shp2',
#  'congenital insensitivity to pain with anhidrosis',
#  'junior blood group system',
#  'dee79',
#  'uric acid concentration, serum, qtl1',
#  'unilateral megalencephaly',
#  'langerhans cell histiocytosis',
#  'juvenile polyarthritis without rheumatoid factor',
#  'epilepsy with myoclonic-atonic seizures',
#  'adenocarcinoma of lung, response to tyrosine kinase inhibitor in',
#  'her4',
#  'aml m3',
#  'coffin-lowry syndrome',
#  'pseudovaginal perineoscrotal hypospadias',
#  'nbccs',
#  'pallister-hall-like syndrome',
#  'normosmic idiopathic hypogonadotropic hypogonadism',
#  't-all',
#  'intellectual developmental disorder, autosomal recessive 54',
#  'roifman-chitayat syndrome, digenic',
#  'idiopathic steatorrhea',
#  'crouzon syndrome',
#  'pilomyxoid astrocytoma',
#  'buphthalmos',
#  'beare-stevenson cutis gyrata syndrome',
#  'systemic-onset jia',
#  'nk-cell lineage granular lymphocyte proliferative disorder',
#  'carnitine palmitoyl transferase ia deficiency',
#  'raf1',
#  'platelet-activating factor acetylhydrolase deficiency',
#  'als19',
#  'melanoma, malignant, somatic',
#  'tie2',
#  'leukemia, acute myeloid',
#  'stem cell leukemia/lymphoma',
#  'bilateral striopallidodentate calcinosis',
#  'bean syndrome',
#  'lou gehrig disease',
#  'cap',
#  'men2a',
#  'ibd13',
#  'milroy disease',
#  'tooth agenesis',
#  'acs1',
#  'neurodevelopmental disorder with seizures and nonepileptic hyperkinetic movements',
#  'b-lymphoblastic leukemia/lymphoma with t(9;22)(q34.1;q11.2)',
#  'dyt9',
#  'scap',
#  'smo',
#  'hirschsprung disease',
#  'immunodeficiency 14b, autosomal recessive',
#  'apc',
#  'calcrl',
#  'chc type 2',
#  'dfna77',
#  'tph2',
#  'herpes simplex virus encephalitis',
#  'phhi',
#  'autoinflammation, immune dysregulation, and eosinophilia',
#  'non-immune fetal edema',
#  'gluten intolerance',
#  'pfeiffer syndrome type 1',
#  'igf1r',
#  'renal agenesis',
#  'retinitis pigmentosa 38',
#  'cftr',
#  'hsve',
#  'narcolepsy type 2',
#  'fgfr1',
#  'cardiomyopathy, dilated, 1nn',
#  'aquagenic palmoplantar keratoderma',
#  'cacnl1a5',
#  'hh2',
#  'fasps',
#  'imd15a',
#  'ladd syndrome',
#  'fasps2',
#  'autoimmune disease, multisystem, infantile-onset, 1',
#  'autosomal recessive spastic paraplegia type 76',
#  'autosomal dominant hyper-ige syndrome due to stat3 deficiency',
#  'lam',
#  'immunodeficiency 42',
#  'autosomal recessive msmd due to complete rorgamma receptor defiency',
#  'ikbkb',
#  'hemangioma, capillary infantile, somatic',
#  'ulcerative proctitis',
#  'ocnds',
#  'tsc2',
#  'generalized epilepsy with febrile seizures-plus',
#  'hse',
#  'familial prostate cancer',
#  'etm1',
#  'cmd1nn',
#  'csnk1d',
#  'coeliac disease',
#  'primary erythermalgia',
#  'pcbc',
#  'autosomal dominant hies due to stat3 deficiency',
#  'hypertryptophanemia',
#  'deafness, autosomal dominant 77',
#  'acute myeloid leukemia with t(8;16)(p11;p13) translocation',
#  'brbn',
#  'hypogonadotropic hypogonadism 2 with or without anosmia',
#  'jak2',
#  'gout1',
#  'glut2',
#  'neuropathy, hereditary sensory and autonomic, type ii',
#  'colobomatous microphthalmia',
#  'primary erythromelalgia',
#  'distal del(22)(q11.2)',
#  'antley-bixler syndrome without genital anomaly or disorder of steroidogenesis',
#  'craniosynostosis-midfacial hypoplasia-foot abnormalities syndrome',
#  'bleeding disorder in hemophilia b carriers',
#  'autosomal recessive mendelian susceptibility to mycobacterial diseases due to complete rorgamma receptor deficiency',
#  'capn1',
#  'leukemia, philadelphia chromosome-positive, resistant to imatinib',
#  'kosaki overgrowth syndrome',
#  'dyt9',
#  'non rare in europe: rheumatoid arthritis',
#  'isolated permanent neonatal diabetes mellitus',
#  'n-acetylglucosaminyltransferase 2 deficiency',
#  'src1',
#  'hsan2',
#  'non-immune hydrops fetalis',
#  'clpd-nk',
#  'primary hypereosinophilic syndrome',
#  'semilobar holoprosencephaly',
#  'acute promyelocytic leukemia',
#  'premature aging syndrome, penttinen type',
#  'ntrk1',
#  'emas',
#  'osteoglosphonic dysplasia',
#  'diarrhea 7, protein-losing enteropathy type',
#  'scn9a',
#  'mgat2',
#  'abcb1',
#  'hereditary butyrylcholinesterase deficiency',
#  'precursor t-cell acute lymphoblastic leukemia/lymphoma',
#  'erk',
#  'pcl',
#  'hereditary lymphedema type i',
#  'fodh',
#  'preeclampsia',
#  ...]

# %%
Genes_= sum(concatenated_df['disease_name+syn'],[])
Genes_=list(set(Genes_))
Genes_= [i[9:].strip().lower()  if i[:9]=='Orphanet:' else i.strip().lower() for i in Genes_]
Genes_annotation= dict()
pathways_for_concurency=set()
papers_pathways=set()

for i in Genes_:
     for j in dyt1.index:
         if i in dyt1['related_gene'][j]:
              dis=Find_dis_dict[ i.lower() ]
              if dis in Genes_annotation:
                if dyt1['p.pubmed_id'][j] not in   [i[0] for i in Genes_annotation[dis]]:
                     Genes_annotation[dis].append((dyt1['p.pubmed_id'][j],i))
              else:
                                Genes_annotation[dis]=[(dyt1['p.pubmed_id'][j],i)]
              pathways_for_concurency.add(i)
              papers_pathways.add(dyt1['p.pubmed_id'][j])
Genes_annotation
# Out:
# {'ORPHA:98811': [('"24262166"', 'dyt18'),
#   ('"19685389"', 'dyt18'),
#   ('"22166420"', 'dyt18'),
#   ('"19578124"', 'dyt18'),
#   ('"23893446"', 'dyt18'),
#   ('"24092288"', 'dyt18')],
#  'OMIM:112100': [('"34173686"', 'ache')],
#  'ORPHA:586': [('"11701630"', 'cystic fibrosis')],
#  'ORPHA:36899': [('"11528394"', 'myoclonus-dystonia syndrome'),
#   ('"30028274"', 'myoclonus-dystonia syndrome'),
#   ('"28102337"', 'myoclonus-dystonia syndrome'),
#   ('"26790671"', 'myoclonus-dystonia syndrome'),
#   ('"21496608"', 'myoclonus-dystonia syndrome'),
#   ('"12761637"', 'myoclonus-dystonia syndrome'),
#   ('"17200151"', 'myoclonus-dystonia syndrome'),
#   ('"6683367"', 'myoclonic dystonia'),
#   ('"2666583"', 'myoclonic dystonia'),
#   ('"1677923"', 'myoclonic dystonia'),
#   ('"9266460"', 'myoclonic dystonia'),
#   ('"12652041"', 'myoclonic dystonia'),
#   ('"22166420"', 'myoclonic dystonia'),
#   ('"19117362"', 'myoclonic dystonia'),
#   ('"16227522"', 'myoclonic dystonia'),
#   ('"8813214"', 'myoclonic dystonia')],
#  'OMIM:181000': [('"10523017"', 'hla-drb1'),
#   ('"9039166"', 'hla-drb1'),
#   ('"9486405"', 'hla-drb1'),
#   ('"24265781"', 'hla-drb1'),
#   ('"29516402"', 'hla-drb1'),
#   ('"29858799"', 'hla-drb1')],
#  'OMIM:616638': [('"33425096"', 'mtor')],
#  'OMIM:618497': [('"35041927"', 'cacna1b')],
#  'OMIM:166250': [('"28387648"', 'ogd')],
#  'OMIM:171300': [('"12671990"', 'pheochromocytoma')],
#  'ORPHA:3318': [('"8232931"', 'et')],
#  'OMIM:606176': [('"28387648"', 'gck')],
#  'OMIM:181500': [('"20471632"', 'schizophrenia'),
#   ('"21965893"', 'schizophrenia')],
#  'ORPHA:635': [('"15593317"', 'neuroblastoma'),
#   ('"16361107"', 'neuroblastoma'),
#   ('"19761814"', 'neuroblastoma')],
#  'ORPHA:803': [('"24311730"', 'als')],
#  'OMIM:157300': [('"10583169"', 'tnf'), ('"16981842"', 'tnf')],
#  'OMIM:606777': [('"24262166"', 'slc2a1'),
#   ('"19685389"', 'slc2a1'),
#   ('"22166420"', 'slc2a1'),
#   ('"19578124"', 'slc2a1'),
#   ('"23893446"', 'slc2a1'),
#   ('"24092288"', 'slc2a1'),
#   ('"20301334"', 'slc2a1')],
#  'OMIM:100800': [('"34173686"', 'ach')],
#  'OMIM:213600': [('"20301334"', 'slc20a2'), ('"16924015"', 'ibgc1')],
#  'OMIM:615007': [('"20301334"', 'pdgfrb')],
#  'OMIM:256800': [('"31618684"', 'trka')],
#  'ORPHA:536': [('"7783076"', 'systemic lupus erythematosus'),
#   ('"1626073"', 'systemic lupus erythematosus'),
#   ('"16639700"', 'sle')],
#  'ORPHA:53583': [('"12194383"', 'dyt9'),
#   ('"22166420"', 'dyt9'),
#   ('"19578124"', 'dyt9')],
#  'OMIM:277180': [('"30981209"', 'cftr'), ('"21750546"', 'cftr')],
#  'OMIM:190300': [('"12575458"', 'etm1')],
#  'ORPHA:555': [('"17190764"', 'coeliac disease'),
#   ('"19593686"', 'coeliac disease'),
#   ('"30779476"', 'coeliac disease'),
#   ('"26060104"', 'coeliac disease'),
#   ('"15137480"', 'coeliac disease'),
#   ('"11302971"', 'coeliac disease'),
#   ('"19244266"', 'coeliac disease'),
#   ('"33239013"', 'coeliac disease'),
#   ('"32044834"', 'coeliac disease'),
#   ('"9098455"', 'coeliac disease'),
#   ('"8858285"', 'coeliac disease'),
#   ('"37627888"', 'coeliac disease'),
#   ('"35074908"', 'coeliac disease'),
#   ('"36468571"', 'coeliac disease'),
#   ('"35611878"', 'coeliac disease'),
#   ('"12169991"', 'coeliac disease'),
#   ('"17706474"', 'coeliac disease'),
#   ('"19208776"', 'coeliac disease')],
#  'OMIM:618462': [('"33458877"', 'erk')],
#  'ORPHA:904': [('"19688081"', 'williams syndrome')],
#  'ORPHA:797': [('"26001889"', 'sarcoidosis')],
#  'OMIM:608232': [('"1427899"', 'abl1'), ('"22639460"', 'abl1')],
#  'ORPHA:243377': [('"8450297"', 'insulin-dependent diabetes mellitus')]}

# %%
concatenated_df['disease_name1']= concatenated_df.apply(lambda x: [x['disease_name']] ,axis=1)
Genes_= sum(concatenated_df['disease_name1'],[])
Genes_=list(set(Genes_))
Genes_= [i[9:].strip().lower()  if i[:9]=='Orphanet:' else i.strip().lower() for i in Genes_]
dyt1['title+abstract']=  dyt1['p.title']+dyt1['p.abstractText']
Genes_annotation= dict()


for i in Genes_:
     for j in dyt1.index:
         if i in dyt1['title+abstract'][j]:
              dis=Find_dis_dict[ i.lower() ]
              if dis in Genes_annotation:  Genes_annotation[dis].append((dyt1['p.pubmed_id'][j],i))
              else:                      Genes_annotation[dis]=[(dyt1['p.pubmed_id'][j],i)]
Genes_annotation
# Out:
# {'ORPHA:803': [('"24311730"', 'amyotrophic lateral sclerosis'),
#   ('"24311730"', 'amyotrophic lateral sclerosis')]}

# %%
pheno_count_smae_Sen=dict()
dyt1['title_abstract'] = dyt1['p.title'].astype(str) + '. ' + dyt1['p.abstractText'].astype(str)

for i in list(pathways_for_concurency):
    pheno_count_smae_Sen[i]=[]

for i in  dyt1.index:
  pubid=dyt1['p.pubmed_id'][i]
  if pubid in papers_pathways:
        tetx=dyt1['title_abstract'][i]
        words_to_chcek=   pathways_for_concurency
        for j in words_to_chcek:
            num=chcek_in_one_sen(j,tetx)
            if num >0:
               if (pubid,num) not in pheno_count_smae_Sen[j.lower()]:
                pheno_count_smae_Sen[j.lower()].append((pubid,num))
pheno_count_smae_Sen
# Out:
# {'cftr': [('"21750546"', 7)],
#  'neuroblastoma': [('"15593317"', 2), ('"16361107"', 2), ('"19761814"', 2)],
#  'ogd': [],
#  'trka': [('"31618684"', 4)],
#  'coeliac disease': [('"30779476"', 2),
#   ('"36468571"', 2),
#   ('"35611878"', 1),
#   ('"17706474"', 2)],
#  'etm1': [('"12575458"', 4)],
#  'erk': [('"6683367"', 2),
#   ('"24262166"', 2),
#   ('"11528394"', 2),
#   ('"21496608"', 2),
#   ('"19117362"', 2),
#   ('"33458877"', 2)],
#  'et': [('"12575458"', 6),
#   ('"2666583"', 2),
#   ('"1677923"', 2),
#   ('"10523017"', 1),
#   ('"10583169"', 1),
#   ('"20471632"', 2),
#   ('"16639700"', 4),
#   ('"17190764"', 2),
#   ('"19593686"', 1),
#   ('"28387648"', 1),
#   ('"15137480"', 1),
#   ('"11302971"', 3),
#   ('"19244266"', 1),
#   ('"19688081"', 1),
#   ('"9039166"', 1),
#   ('"24262166"', 6),
#   ('"19685389"', 8),
#   ('"24311730"', 8),
#   ('"12194383"', 5),
#   ('"11528394"', 3),
#   ('"1427899"', 2),
#   ('"12652041"', 2),
#   ('"28102337"', 2),
#   ('"26790671"', 4),
#   ('"22166420"', 8),
#   ('"21496608"', 2),
#   ('"31618684"', 16),
#   ('"33458877"', 6),
#   ('"34173686"', 13),
#   ('"8813214"', 3),
#   ('"30981209"', 1),
#   ('"9486405"', 1),
#   ('"8858285"', 1),
#   ('"35074908"', 1),
#   ('"36468571"', 1),
#   ('"1626073"', 1),
#   ('"16981842"', 1),
#   ('"24265781"', 1),
#   ('"29516402"', 1),
#   ('"29858799"', 1),
#   ('"19578124"', 3),
#   ('"22639460"', 3),
#   ('"24092288"', 2),
#   ('"35041927"', 1),
#   ('"8232931"', 6),
#   ('"21750546"', 20),
#   ('"15593317"', 11),
#   ('"16361107"', 7),
#   ('"12671990"', 13),
#   ('"8450297"', 1),
#   ('"19761814"', 7),
#   ('"11701630"', 2)],
#  'myoclonic dystonia': [('"1677923"', 2),
#   ('"22166420"', 2),
#   ('"16227522"', 2)],
#  'hla-drb1': [('"9039166"', 1), ('"29516402"', 1), ('"29858799"', 1)],
#  'als': [('"20471632"', 2),
#   ('"16639700"', 1),
#   ('"17190764"', 1),
#   ('"19688081"', 1),
#   ('"24311730"', 8),
#   ('"12652041"', 2),
#   ('"30028274"', 2),
#   ('"16227522"', 2),
#   ('"31618684"', 2),
#   ('"33458877"', 2),
#   ('"9098455"', 1),
#   ('"36468571"', 1),
#   ('"19578124"', 2),
#   ('"21750546"', 2)],
#  'abl1': [('"22639460"', 3)],
#  'ibgc1': [('"16924015"', 2)],
#  'dyt9': [('"12194383"', 2), ('"22166420"', 2), ('"19578124"', 2)],
#  'insulin-dependent diabetes mellitus': [('"8450297"', 1)],
#  'ach': [('"16639700"', 2),
#   ('"33239013"', 1),
#   ('"12652041"', 2),
#   ('"12761637"', 2),
#   ('"34173686"', 8),
#   ('"19578124"', 1)],
#  'pdgfrb': [],
#  'ache': [('"16639700"', 1), ('"34173686"', 1)],
#  'myoclonus-dystonia syndrome': [('"11528394"', 2),
#   ('"30028274"', 2),
#   ('"28102337"', 2),
#   ('"17200151"', 2)],
#  'systemic lupus erythematosus': [('"16639700"', 1)],
#  'schizophrenia': [('"20471632"', 1), ('"21965893"', 2)],
#  'cacna1b': [],
#  'sarcoidosis': [],
#  'cystic fibrosis': [('"21750546"', 2), ('"11701630"', 2)],
#  'gck': [],
#  'tnf': [('"16981842"', 1)],
#  'sle': [('"16639700"', 1), ('"28387648"', 1)],
#  'slc20a2': [],
#  'mtor': [],
#  'pheochromocytoma': [],
#  'dyt18': [('"24262166"', 2),
#   ('"19685389"', 2),
#   ('"22166420"', 2),
#   ('"19578124"', 6),
#   ('"23893446"', 2),
#   ('"24092288"', 2)],
#  'slc2a1': [('"24262166"', 2),
#   ('"19685389"', 2),
#   ('"22166420"', 2),
#   ('"19578124"', 4),
#   ('"23893446"', 2),
#   ('"24092288"', 2)],
#  'williams syndrome': []}

# %% [markdown]
# Annotation checking: phenotype

# %%
pheno=[]
n=0
for cc in ['phenotype_0','phenotype_1',	'phenotype_2']:
   shared_gene_phenotype_table['annot_phenotype'+str(n)] =None
   shared_gene_phenotype_table['annot_phenotype'+str(n)] = shared_gene_phenotype_table['annot_phenotype'+str(n)].astype(object)
   for i in shared_gene_phenotype_table.index:
     for j in shared_gene_phenotype_table[cc][i]:
         for k in dyt1.index:
               if j.lower() in dyt1['related_gene'][k]:
                   pheno.append(j.lower() )
                   if   shared_gene_phenotype_table['annot_phenotype'+str(n)][i]==None:
                         shared_gene_phenotype_table.at[i,'annot_phenotype'+str(n)]=[(dyt1['p.pubmed_id'][k],j)]
                   else: shared_gene_phenotype_table.at[i,'annot_phenotype'+str(n)]=shared_gene_phenotype_table['annot_phenotype'+str(n)][i]+ [(dyt1['p.pubmed_id'][k],j)]
   n+=1

# %%
shared_gene_phenotype_table['annot_phenotype0_count'] = shared_gene_phenotype_table.apply(
    lambda x: len(x['annot_phenotype0']) if isinstance(x['annot_phenotype0'], list) else 0, axis=1
)
shared_gene_phenotype_table['annot_phenotype1_count'] = shared_gene_phenotype_table.apply(
    lambda x: len(x['annot_phenotype1']) if isinstance(x['annot_phenotype1'], list) else 0, axis=1
)
shared_gene_phenotype_table['annot_phenotype2_count'] = shared_gene_phenotype_table.apply(
    lambda x: len(x['annot_phenotype2']) if isinstance(x['annot_phenotype2'], list) else 0, axis=1
)
shared_gene_phenotype_table
# Out:
#              shared_gene_0 shared_gene_1 shared_gene_2  \
# 0                    MGAT2        SLC8A1         DGAT1
# 1                    DGAT2          PTK2         PDE4B
# 2                     FASN         SCN9A         MAPK8
# 3                    DGAT1         PTAFR         FGFR3
# 4                      SYK         ABCB1         FGFR1
# ..                     ...           ...           ...
# 95                    BRD2        PLA2G7           TEK
# 96                    BRD3           ITK          IDO1
# 97             CDK5R1 CDK5    CCNA2 CDK2          BRAF
# 98  CCNB3 CDK1 CCNB1 CCNB2          BRAF          RORC
# 99            CALCRL RAMP1            F9         NAMPT
#
#                                           phenotype_0  \
# 0   [Osteopenia, Aggressive behavior, Dental crowd...
# 1                                                  []
# 2                                                  []
# 3   [Neonatal onset, Hyperlipidemia, Diarrhea, Aut...
# 4   [Lymphadenopathy, Hepatitis, Splenomegaly, Ele...
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
#                                           phenotype_1  \
# 0                                                  []
# 1                                                  []
# 2   [Generalized cerebral atrophy/hypoplasia, Inte...
# 3                                                  []
# 4               [Inflammation of the large intestine]
# ..                                                ...
# 95  [Autosomal recessive inheritance, Increased le...
# 96  [Pleural effusion, Lymphadenopathy, Decreased ...
# 97                                                 []
# 98  [Osteopenia, EEG abnormality, Abnormal heart v...
# 99  [X-linked recessive inheritance, Abnormal blee...
#
#                                           phenotype_2  \
# 0   [Neonatal onset, Hyperlipidemia, Diarrhea, Aut...
# 1                                                  []
# 2                                                  []
# 3   [Hypoplastic ilia, Nail dysplasia, Tibial bowi...
# 4   [Osteopenia, Inguinal hernia, Renal agenesis, ...
# ..                                                ...
# 95  [Increased cup-to-disc ratio, Ocular hypertens...
# 96                                                 []
# 97  [Osteopenia, EEG abnormality, Abnormal heart v...
# 98  [Hypoplasia of the thymus, Autosomal recessive...
# 99                                                 []
#
#                                    shared_gene_0_phen  \
# 0   [Scoliosis, Global developmental delay, Microc...
# 1                                                  []
# 2                                                  []
# 3   [Neonatal onset, Autosomal recessive inheritance]
# 4                    [Autosomal dominant inheritance]
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
#                                    shared_gene_1_phen  \
# 0                                                  []
# 1                                                  []
# 2   [Myoclonus, Neonatal onset, Generalized hypoto...
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 95                  [Autosomal recessive inheritance]
# 96                  [Autosomal recessive inheritance]
# 97                                                 []
# 98  [Neonatal onset, Dysphagia, Polyhydramnios, Lo...
# 99                                                 []
#
#                                    shared_gene_2_phen  \
# 0   [Neonatal onset, Autosomal recessive inheritance]
# 1                                                  []
# 2                                                  []
# 3   [Motor delay, Dysphagia, Polyhydramnios, Autos...
# 4   [Inguinal hernia, Dysphagia, Long philtrum, Wi...
# ..                                                ...
# 95  [Autosomal recessive inheritance, Autosomal do...
# 96                                                 []
# 97  [Neonatal onset, Dysphagia, Polyhydramnios, Lo...
# 98                  [Autosomal recessive inheritance]
# 99                                                 []
#
#                           dis_0  \
# 0    [OMIM:212066, ORPHA:79329]
# 1                [ORPHA:487814]
# 2                            []
# 3   [OMIM:615863, ORPHA:329242]
# 4                 [OMIM:619381]
# ..                          ...
# 95                           []
# 96                           []
# 97                           []
# 98                           []
# 99                           []
#
#                                                 dis_1  \
# 0                                                  []
# 1                                                  []
# 2   [OMIM:201300, OMIM:243000, OMIM:133020, OMIM:1...
# 3                                                  []
# 4               [OMIM:120080, OMIM:612244, ORPHA:771]
# ..                                                ...
# 95                                      [OMIM:614278]
# 96                        [OMIM:613011, ORPHA:538963]
# 97                                                 []
# 98  [OMIM:115150, OMIM:114500, OMIM:211980, OMIM:6...
# 99  [OMIM:301052, OMIM:306900, OMIM:300807, ORPHA:...
#
#                                                 dis_2  \
# 0                         [OMIM:615863, ORPHA:329242]
# 1                                                  []
# 2                                                  []
# 3   [OMIM:146000, OMIM:162900, OMIM:616482, OMIM:1...
# 4   [OMIM:613001, OMIM:190440, OMIM:147950, OMIM:6...
# ..                                                ...
# 95  [OMIM:600975, OMIM:600195, OMIM:617272, ORPHA:...
# 96                                                 []
# 97  [OMIM:115150, OMIM:114500, OMIM:211980, OMIM:6...
# 98                        [OMIM:616622, ORPHA:477857]
# 99                                                 []
#
#                                      annot_phenotype0  \
# 0   [("18689116", Osteopenia), ("20359791", Osteop...
# 1                                                None
# 2                                                None
# 3   [("24444577", Diarrhea), ("25925917", Diarrhea...
# 4   [("9186828", Hepatitis), ("16456406", Villous ...
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99                                               None
#
#                                      annot_phenotype1  \
# 0                                                None
# 1                                                None
# 2   [("6683367", Myoclonus), ("9266460", Myoclonus...
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96  [("22604515", Thrombocytopenia), ("30528262", ...
# 97                                               None
# 98  [("18689116", Osteopenia), ("20359791", Osteop...
# 99                                               None
#
#                                      annot_phenotype2  annot_phenotype0_count  \
# 0   [("24444577", Diarrhea), ("25925917", Diarrhea...                      15
# 1                                                None                       0
# 2                                                None                       0
# 3   [("22639460", Short stature), ("17142829", Dys...                      25
# 4   [("18689116", Osteopenia), ("20359791", Osteop...                      43
# ..                                                ...                     ...
# 95                                               None                       0
# 96                                               None                       0
# 97  [("18689116", Osteopenia), ("20359791", Osteop...                       0
# 98                                               None                       0
# 99                                               None                       0
#
#     annot_phenotype1_count  annot_phenotype2_count
# 0                        0                      25
# 1                        0                       0
# 2                      129                       0
# 3                        0                      35
# 4                        0                     102
# ..                     ...                     ...
# 95                       0                       0
# 96                       9                       0
# 97                       0                      63
# 98                      63                       0
# 99                       0                       0
#
# [100 rows x 18 columns]

# %%
find_gene_from_pheno=dict()
for cc in ['phenotype_0','phenotype_1',	'phenotype_2']:
     for i in shared_gene_phenotype_table.index:
                 wordss=shared_gene_phenotype_table[cc][i]
                 if wordss != None:
                    for k in wordss:
                        k=k.lower()
                        if  k not in  find_gene_from_pheno:
                           if cc==   'phenotype_0'     :  find_gene_from_pheno[k] =[shared_gene_phenotype_table['shared_gene_0'][i] ]
                           if cc==   'phenotype_1'     :  find_gene_from_pheno[k] =[shared_gene_phenotype_table['shared_gene_1'][i] ]
                           if cc==   'phenotype_2'     :  find_gene_from_pheno[k] =[shared_gene_phenotype_table['shared_gene_2'][i] ]
                        else:
                            if cc==   'phenotype_0'     :
                               if shared_gene_phenotype_table['shared_gene_0'][i]  not in find_gene_from_pheno[k]:
                                      find_gene_from_pheno[k].append( shared_gene_phenotype_table['shared_gene_0'][i] )
                            if cc==   'phenotype_1'     :
                               if shared_gene_phenotype_table['shared_gene_1'][i]  not in find_gene_from_pheno[k]:
                                      find_gene_from_pheno[k].append( shared_gene_phenotype_table['shared_gene_1'][i] )
                            if cc==   'phenotype_2'     :
                               if shared_gene_phenotype_table['shared_gene_2'][i]  not in find_gene_from_pheno[k]:
                                      find_gene_from_pheno[k].append( shared_gene_phenotype_table['shared_gene_2'][i] )

# %%
def count_unique_values(input_list):
    # Create a pandas Series from the input list
    series = pd.Series(input_list)
    # Count the occurrences of each unique value
    value_counts = series.value_counts()
    # Create a DataFrame with the unique values in the first column and their counts in the second column
    result_df = pd.DataFrame({'Value': value_counts.index, 'Count': value_counts.values})
    return result_df


# Example usage
result_df = count_unique_values(pheno)
result_df['gene']= result_df.apply(lambda x:  find_gene_from_pheno[x['Value']]  ,axis=1)

result_df
# Out:
#                       Value  Count  \
# 0                  dystonia   2856
# 1                    tremor    350
# 2                 myoclonus    264
# 3                  diarrhea    243
# 4                depression    186
# ..                      ...    ...
# 112                 allergy      1
# 113  hyperkinetic movements      1
# 114        pheochromocytoma      1
# 115      nephrotic syndrome      1
# 116  membranous nephropathy      1
#
#                                                   gene
# 0              [CACNA1B, SLC2A1, SLC2A3, DRD2, PDGFRB]
# 1    [GABRA5, CACNA1B, SLC2A1, SCN9A, PDGFRB, FGFR1...
# 2    [RORB, MTOR, GABRA5, ALK, CACNA1B, SLC2A1, SLC...
# 3    [DGAT1, SYK, PIK3CD, PIK3CG, CFTR, LCK, SMO, B...
# 4    [GNRHR, CFTR, MMP1, RPS6KA3, HLA-DRB1, BRAF, T...
# ..                                                 ...
# 112                                             [MTOR]
# 113                                          [CACNA1B]
# 114                                              [RET]
# 115                                             [JAK1]
# 116                                             [JAK1]
#
# [117 rows x 3 columns]

# %% [markdown]
#  mentioned in the same sentense

# %%
paprs_pheno=dict()

CC = ['annot_phenotype0','annot_phenotype1','annot_phenotype2']
for i in CC:
  for j in shared_gene_phenotype_table.index:
    XX=shared_gene_phenotype_table[i][j]
    if XX != None:
       for k in XX:
            if k[0] not in paprs_pheno: paprs_pheno[k[0]]=[k[1] ]
            else:                       paprs_pheno[k[0]].append( k[1] )

# %%
# !pip install nltk

import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def chcek_in_one_sen_help(word0, word1, text):
    sentences = sent_tokenize(text)
    count = 0
    for sentence in sentences:
        sentence=sentence.lower()
        if word0.lower() in sentence and word1.lower() in sentence:
            count += 1
    return count

# Example usage
text = """
This is a sample text. It contains several sentences.
Some sentences contain the word apple and some sentences contain the word banana.
This sentence contains both apple and banana. This one does not?
Another apple and banana sentence is here.
"""
word0 = "apple"
word1 = "banana"
result = check_in_one_sen_help(word0, word1, text)
print(result)

def chcek_in_one_sen(word, text):
   dyt1_words=['early-onset generalized torsion dystonia', 'tor1a dystonia', 'idiopathic dystonia dyt1', 'primary torsion dystonia', 'early-onset torsion dystonia', "oppenheim's dystonia", 'torsin a', 'early onset torsion dystonia', 'dyt1 dystonia', 'torsina', 'oppenheim dystonia', 'early-onset generalized dystonia', 'torsin-1a', 'tor1a', 'dyt1', 'dystonia 1', 'torsion (autosomal dominant; torsin a)', "oppenheim's dystonia", 'dyt1 early-onset isolated dystonia', 'early-onset torsion dystonia', 'dyt1', 'torsin family 1', 'dystonia musculorum deformans 1', 'dystonia musculorum deformans', 'dystonia 1, torsion, autosomal dominant', 'idiopathic torsion dystonia', 'early-onset generalized limb-onset dystonia', 'idiopathic torsion dystonia', 'dq2', 'early-onset primary dystonia', 'member a (torsin a)', 'dyt-tor1a dystonia', 'torsina', 'primary dystonias', 'early-onset torsion dystonia', 'eotd', 'dystonia 1', 'early-onset isolated dystonia']
   num=0
   for i in dyt1_words:
       num+=  chcek_in_one_sen_help(i,word, text)
   return num

pheno_count_smae_Sen=dict()
for i in list(result_df['Value']):
    pheno_count_smae_Sen[i]=[]

dyt1['title_abstract'] = dyt1['p.title'].astype(str) + '. ' + dyt1['p.abstractText'].astype(str)


for i in  dyt1.index:
  pubid=dyt1['p.pubmed_id'][i]
  if pubid in paprs_pheno:
        tetx=dyt1['title_abstract'][i]
        words_to_chcek=   paprs_pheno[pubid]
        for j in words_to_chcek:
            num=chcek_in_one_sen(j,tetx)
            if num >0:
                pheno_count_smae_Sen[j.lower()].append((pubid,num))
pheno_count_smae_Sen
# Out:
# 3
# {'dystonia': [('"2317008"', 2),
#   ('"2317008"', 2),
#   ('"2317008"', 2),
#   ('"2317008"', 2),
#   ('"2317008"', 2),
#   ('"2317008"', 2),
#   ('"1867195"', 2),
#   ('"1867195"', 2),
#   ('"1867195"', 2),
#   ('"1867195"', 2),
#   ('"1867195"', 2),
#   ('"1867195"', 2),
#   ('"8079990"', 8),
#   ('"8079990"', 8),
#   ('"8079990"', 8),
#   ('"8079990"', 8),
#   ('"8079990"', 8),
#   ('"8079990"', 8),
#   ('"941766"', 2),
#   ('"941766"', 2),
#   ('"941766"', 2),
#   ('"941766"', 2),
#   ('"941766"', 2),
#   ('"941766"', 2),
#   ('"8916165"', 2),
#   ('"8916165"', 2),
#   ('"8916165"', 2),
#   ('"8916165"', 2),
#   ('"8916165"', 2),
#   ('"8916165"', 2),
#   ('"1121020"', 2),
#   ('"1121020"', 2),
#   ('"1121020"', 2),
#   ('"1121020"', 2),
#   ('"1121020"', 2),
#   ('"1121020"', 2),
#   ('"2817837"', 2),
#   ('"2817837"', 2),
#   ('"2817837"', 2),
#   ('"2817837"', 2),
#   ('"2817837"', 2),
#   ('"2817837"', 2),
#   ('"1347197"', 6),
#   ('"1347197"', 6),
#   ('"1347197"', 6),
#   ('"1347197"', 6),
#   ('"1347197"', 6),
#   ('"1347197"', 6),
#   ('"8513401"', 14),
#   ('"8513401"', 14),
#   ('"8513401"', 14),
#   ('"8513401"', 14),
#   ('"8513401"', 14),
#   ('"8513401"', 14),
#   ('"7979224"', 14),
#   ('"7979224"', 14),
#   ('"7979224"', 14),
#   ('"7979224"', 14),
#   ('"7979224"', 14),
#   ('"7979224"', 14),
#   ('"10435508"', 9),
#   ('"10435508"', 9),
#   ('"10435508"', 9),
#   ('"10435508"', 9),
#   ('"10435508"', 9),
#   ('"10435508"', 9),
#   ('"15668438"', 7),
#   ('"15668438"', 7),
#   ('"15668438"', 7),
#   ('"15668438"', 7),
#   ('"15668438"', 7),
#   ('"15668438"', 7),
#   ('"17142829"', 2),
#   ('"17142829"', 2),
#   ('"17142829"', 2),
#   ('"17142829"', 2),
#   ('"17142829"', 2),
#   ('"17142829"', 2),
#   ('"1985454"', 6),
#   ('"1985454"', 6),
#   ('"1985454"', 6),
#   ('"1985454"', 6),
#   ('"1985454"', 6),
#   ('"1985454"', 6),
#   ('"1449240"', 2),
#   ('"1449240"', 2),
#   ('"1449240"', 2),
#   ('"1449240"', 2),
#   ('"1449240"', 2),
#   ('"1449240"', 2),
#   ('"10737119"', 9),
#   ('"10737119"', 9),
#   ('"10737119"', 9),
#   ('"10737119"', 9),
#   ('"10737119"', 9),
#   ('"10737119"', 9),
#   ('"9120448"', 15),
#   ('"9120448"', 15),
#   ('"9120448"', 15),
#   ('"9120448"', 15),
#   ('"9120448"', 15),
#   ('"9120448"', 15),
#   ('"9778264"', 4),
#   ('"9778264"', 4),
#   ('"9778264"', 4),
#   ('"9778264"', 4),
#   ('"9778264"', 4),
#   ('"9778264"', 4),
#   ('"9779659"', 2),
#   ('"9779659"', 2),
#   ('"9779659"', 2),
#   ('"9779659"', 2),
#   ('"9779659"', 2),
#   ('"9779659"', 2),
#   ('"15897512"', 5),
#   ('"15897512"', 5),
#   ('"15897512"', 5),
#   ('"15897512"', 5),
#   ('"15897512"', 5),
#   ('"15897512"', 5),
#   ('"6683367"', 2),
#   ('"6683367"', 2),
#   ('"6683367"', 2),
#   ('"6683367"', 2),
#   ('"6683367"', 2),
#   ('"6683367"', 2),
#   ('"2666583"', 6),
#   ('"2666583"', 6),
#   ('"2666583"', 6),
#   ('"2666583"', 6),
#   ('"2666583"', 6),
#   ('"2666583"', 6),
#   ('"1677923"', 2),
#   ('"1677923"', 2),
#   ('"1677923"', 2),
#   ('"1677923"', 2),
#   ('"1677923"', 2),
#   ('"1677923"', 2),
#   ('"9266460"', 4),
#   ('"9266460"', 4),
#   ('"9266460"', 4),
#   ('"9266460"', 4),
#   ('"9266460"', 4),
#   ('"9266460"', 4),
#   ('"15954126"', 2),
#   ('"15954126"', 2),
#   ('"15954126"', 2),
#   ('"15954126"', 2),
#   ('"15954126"', 2),
#   ('"15954126"', 2),
#   ('"20672922"', 2),
#   ('"20672922"', 2),
#   ('"20672922"', 2),
#   ('"20672922"', 2),
#   ('"20672922"', 2),
#   ('"20672922"', 2),
#   ('"9146024"', 2),
#   ('"9146024"', 2),
#   ('"9146024"', 2),
#   ('"9146024"', 2),
#   ('"9146024"', 2),
#   ('"9146024"', 2),
#   ('"12785748"', 3),
#   ('"12785748"', 3),
#   ('"12785748"', 3),
#   ('"12785748"', 3),
#   ('"12785748"', 3),
#   ('"12785748"', 3),
#   ('"12402271"', 2),
#   ('"12402271"', 2),
#   ('"12402271"', 2),
#   ('"12402271"', 2),
#   ('"12402271"', 2),
#   ('"12402271"', 2),
#   ('"34380890"', 3),
#   ('"34380890"', 3),
#   ('"34380890"', 3),
#   ('"34380890"', 3),
#   ('"34380890"', 3),
#   ('"34380890"', 3),
#   ('"27672781"', 3),
#   ('"27672781"', 3),
#   ('"27672781"', 3),
#   ('"27672781"', 3),
#   ('"27672781"', 3),
#   ('"27672781"', 3),
#   ('"34323950"', 3),
#   ('"34323950"', 3),
#   ('"34323950"', 3),
#   ('"34323950"', 3),
#   ('"34323950"', 3),
#   ('"34323950"', 3),
#   ('"18519876"', 3),
#   ('"18519876"', 3),
#   ('"18519876"', 3),
#   ('"18519876"', 3),
#   ('"18519876"', 3),
#   ('"18519876"', 3),
#   ('"10449567"', 6),
#   ('"10449567"', 6),
#   ('"10449567"', 6),
#   ('"10449567"', 6),
#   ('"10449567"', 6),
#   ('"10449567"', 6),
#   ('"19345148"', 8),
#   ('"19345148"', 8),
#   ('"19345148"', 8),
#   ('"19345148"', 8),
#   ('"19345148"', 8),
#   ('"19345148"', 8),
#   ('"19345147"', 5),
#   ('"19345147"', 5),
#   ('"19345147"', 5),
#   ('"19345147"', 5),
#   ('"19345147"', 5),
#   ('"19345147"', 5),
#   ('"20211909"', 2),
#   ('"20211909"', 2),
#   ('"20211909"', 2),
#   ('"20211909"', 2),
#   ('"20211909"', 2),
#   ('"20211909"', 2),
#   ('"8684386"', 8),
#   ('"8684386"', 8),
#   ('"8684386"', 8),
#   ('"8684386"', 8),
#   ('"8684386"', 8),
#   ('"8684386"', 8),
#   ('"9288096"', 8),
#   ('"9288096"', 8),
#   ('"9288096"', 8),
#   ('"9288096"', 8),
#   ('"9288096"', 8),
#   ('"9288096"', 8),
#   ('"11523564"', 8),
#   ('"11523564"', 8),
#   ('"11523564"', 8),
#   ('"11523564"', 8),
#   ('"11523564"', 8),
#   ('"11523564"', 8),
#   ('"11973627"', 11),
#   ('"11973627"', 11),
#   ('"11973627"', 11),
#   ('"11973627"', 11),
#   ('"11973627"', 11),
#   ('"11973627"', 11),
#   ('"12473770"', 3),
#   ('"12473770"', 3),
#   ('"12473770"', 3),
#   ('"12473770"', 3),
#   ('"12473770"', 3),
#   ('"12473770"', 3),
#   ('"12838525"', 6),
#   ('"12838525"', 6),
#   ('"12838525"', 6),
#   ('"12838525"', 6),
#   ('"12838525"', 6),
#   ('"12838525"', 6),
#   ('"15111678"', 3),
#   ('"15111678"', 3),
#   ('"15111678"', 3),
#   ('"15111678"', 3),
#   ('"15111678"', 3),
#   ('"15111678"', 3),
#   ('"12975293"', 8),
#   ('"12975293"', 8),
#   ('"12975293"', 8),
#   ('"12975293"', 8),
#   ('"12975293"', 8),
#   ('"12975293"', 8),
#   ('"15293281"', 2),
#   ('"15293281"', 2),
#   ('"15293281"', 2),
#   ('"15293281"', 2),
#   ('"15293281"', 2),
#   ('"15293281"', 2),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15455404"', 17),
#   ('"15455404"', 17),
#   ('"15455404"', 17),
#   ('"15455404"', 17),
#   ('"15455404"', 17),
#   ('"15455404"', 17),
#   ('"15548549"', 5),
#   ('"15548549"', 5),
#   ('"15548549"', 5),
#   ('"15548549"', 5),
#   ('"15548549"', 5),
#   ('"15548549"', 5),
#   ('"17027035"', 5),
#   ('"17027035"', 5),
#   ('"17027035"', 5),
#   ('"17027035"', 5),
#   ('"17027035"', 5),
#   ('"17027035"', 5),
#   ('"17503336"', 6),
#   ('"17503336"', 6),
#   ('"17503336"', 6),
#   ('"17503336"', 6),
#   ('"17503336"', 6),
#   ('"17503336"', 6),
#   ('"18477710"', 6),
#   ('"18477710"', 6),
#   ('"18477710"', 6),
#   ('"18477710"', 6),
#   ('"18477710"', 6),
#   ('"18477710"', 6),
#   ('"19528516"', 2),
#   ('"19528516"', 2),
#   ('"19528516"', 2),
#   ('"19528516"', 2),
#   ('"19528516"', 2),
#   ('"19528516"', 2),
#   ('"19955557"', 8),
#   ('"19955557"', 8),
#   ('"19955557"', 8),
#   ('"19955557"', 8),
#   ('"19955557"', 8),
#   ('"19955557"', 8),
#   ('"16415980"', 5),
#   ('"16415980"', 5),
#   ('"16415980"', 5),
#   ('"16415980"', 5),
#   ('"16415980"', 5),
#   ('"16415980"', 5),
#   ('"22132914"', 9),
#   ('"22132914"', 9),
#   ('"22132914"', 9),
#   ('"22132914"', 9),
#   ('"22132914"', 9),
#   ('"22132914"', 9),
#   ('"27939583"', 5),
#   ('"27939583"', 5),
#   ('"27939583"', 5),
#   ('"27939583"', 5),
#   ('"27939583"', 5),
#   ('"27939583"', 5),
#   ('"27919237"', 2),
#   ('"27919237"', 2),
#   ('"27919237"', 2),
#   ('"27919237"', 2),
#   ('"27919237"', 2),
#   ('"27919237"', 2),
#   ('"30879706"', 2),
#   ('"30879706"', 2),
#   ('"30879706"', 2),
#   ('"30879706"', 2),
#   ('"30879706"', 2),
#   ('"30879706"', 2),
#   ('"33476878"', 5),
#   ('"33476878"', 5),
#   ('"33476878"', 5),
#   ('"33476878"', 5),
#   ('"33476878"', 5),
#   ('"33476878"', 5),
#   ('"33757902"', 8),
#   ('"33757902"', 8),
#   ('"33757902"', 8),
#   ('"33757902"', 8),
#   ('"33757902"', 8),
#   ('"33757902"', 8),
#   ('"33757902"', 8),
#   ('"33757902"', 8),
#   ('"33757902"', 8),
#   ('"33757902"', 8),
#   ('"33757902"', 8),
#   ('"33757902"', 8),
#   ('"33616084"', 3),
#   ('"33616084"', 3),
#   ('"33616084"', 3),
#   ('"33616084"', 3),
#   ('"33616084"', 3),
#   ('"33616084"', 3),
#   ('"33706202"', 7),
#   ('"33706202"', 7),
#   ('"33706202"', 7),
#   ('"33706202"', 7),
#   ('"33706202"', 7),
#   ('"33706202"', 7),
#   ('"33638639"', 9),
#   ('"33638639"', 9),
#   ('"33638639"', 9),
#   ('"33638639"', 9),
#   ('"33638639"', 9),
#   ('"33638639"', 9),
#   ('"33638639"', 9),
#   ('"33638639"', 9),
#   ('"33638639"', 9),
#   ('"33638639"', 9),
#   ('"33638639"', 9),
#   ('"33638639"', 9),
#   ('"34038798"', 9),
#   ('"34038798"', 9),
#   ('"34038798"', 9),
#   ('"34038798"', 9),
#   ('"34038798"', 9),
#   ('"34038798"', 9),
#   ('"34092466"', 17),
#   ('"34092466"', 17),
#   ('"34092466"', 17),
#   ('"34092466"', 17),
#   ('"34092466"', 17),
#   ('"34092466"', 17),
#   ('"34119482"', 18),
#   ('"34119482"', 18),
#   ('"34119482"', 18),
#   ('"34119482"', 18),
#   ('"34119482"', 18),
#   ('"34119482"', 18),
#   ('"34119482"', 18),
#   ('"34119482"', 18),
#   ('"34119482"', 18),
#   ('"34119482"', 18),
#   ('"34119482"', 18),
#   ('"34119482"', 18),
#   ('"34438319"', 6),
#   ('"34438319"', 6),
#   ('"34438319"', 6),
#   ('"34438319"', 6),
#   ('"34438319"', 6),
#   ('"34438319"', 6),
#   ('"12325076"', 3),
#   ('"12325076"', 3),
#   ('"12325076"', 3),
#   ('"12325076"', 3),
#   ('"12325076"', 3),
#   ('"12325076"', 3),
#   ('"10073176"', 4),
#   ('"10073176"', 4),
#   ('"10073176"', 4),
#   ('"10073176"', 4),
#   ('"10073176"', 4),
#   ('"10073176"', 4),
#   ('"10994500"', 4),
#   ('"10994500"', 4),
#   ('"10994500"', 4),
#   ('"10994500"', 4),
#   ('"10994500"', 4),
#   ('"10994500"', 4),
#   ('"11984483"', 3),
#   ('"11984483"', 3),
#   ('"11984483"', 3),
#   ('"11984483"', 3),
#   ('"11984483"', 3),
#   ('"11984483"', 3),
#   ('"23420606"', 2),
#   ('"23420606"', 2),
#   ('"23420606"', 2),
#   ('"23420606"', 2),
#   ('"23420606"', 2),
#   ('"23420606"', 2),
#   ('"24262166"', 11),
#   ('"24262166"', 11),
#   ('"24262166"', 11),
#   ('"24262166"', 11),
#   ('"24262166"', 11),
#   ('"24262166"', 11),
#   ('"25192508"', 4),
#   ('"25192508"', 4),
#   ('"25192508"', 4),
#   ('"25192508"', 4),
#   ('"25192508"', 4),
#   ('"25192508"', 4),
#   ('"8255463"', 4),
#   ('"8255463"', 4),
#   ('"8255463"', 4),
#   ('"8255463"', 4),
#   ('"8255463"', 4),
#   ('"8255463"', 4),
#   ('"15390042"', 4),
#   ('"15390042"', 4),
#   ('"15390042"', 4),
#   ('"15390042"', 4),
#   ('"15390042"', 4),
#   ('"15390042"', 4),
#   ('"19685389"', 8),
#   ('"19685389"', 8),
#   ('"19685389"', 8),
#   ('"19685389"', 8),
#   ('"19685389"', 8),
#   ('"19685389"', 8),
#   ('"28843013"', 3),
#   ('"28843013"', 3),
#   ('"28843013"', 3),
#   ('"28843013"', 3),
#   ('"28843013"', 3),
#   ('"28843013"', 3),
#   ('"28843013"', 3),
#   ('"28843013"', 3),
#   ('"28843013"', 3),
#   ('"28843013"', 3),
#   ('"28843013"', 3),
#   ('"28843013"', 3),
#   ('"24311730"', 4),
#   ('"24311730"', 4),
#   ('"24311730"', 4),
#   ('"24311730"', 4),
#   ('"24311730"', 4),
#   ('"24311730"', 4),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"16541453"', 2),
#   ('"16541453"', 2),
#   ('"16541453"', 2),
#   ('"16541453"', 2),
#   ('"16541453"', 2),
#   ('"16541453"', 2),
#   ('"33395620"', 9),
#   ('"33395620"', 9),
#   ('"33395620"', 9),
#   ('"33395620"', 9),
#   ('"33395620"', 9),
#   ('"33395620"', 9),
#   ('"12194383"', 5),
#   ('"12194383"', 5),
#   ('"12194383"', 5),
#   ('"12194383"', 5),
#   ('"12194383"', 5),
#   ('"12194383"', 5),
#   ('"10919137"', 6),
#   ('"10919137"', 6),
#   ('"10919137"', 6),
#   ('"10919137"', 6),
#   ('"10919137"', 6),
#   ('"10919137"', 6),
#   ('"11528394"', 5),
#   ('"11528394"', 5),
#   ('"11528394"', 5),
#   ('"11528394"', 5),
#   ('"11528394"', 5),
#   ('"11528394"', 5),
#   ('"12391355"', 2),
#   ('"12391355"', 2),
#   ('"12391355"', 2),
#   ('"12391355"', 2),
#   ('"12391355"', 2),
#   ('"12391355"', 2),
#   ('"12151848"', 4),
#   ('"12151848"', 4),
#   ('"12151848"', 4),
#   ('"12151848"', 4),
#   ('"12151848"', 4),
#   ('"12151848"', 4),
#   ('"30244176"', 4),
#   ('"30244176"', 4),
#   ('"30244176"', 4),
#   ('"30244176"', 4),
#   ('"30244176"', 4),
#   ('"30244176"', 4),
#   ('"34408078"', 8),
#   ('"34408078"', 8),
#   ('"34408078"', 8),
#   ('"34408078"', 8),
#   ('"34408078"', 8),
#   ('"34408078"', 8),
#   ('"34189496"', 14),
#   ('"34189496"', 14),
#   ('"34189496"', 14),
#   ('"34189496"', 14),
#   ('"34189496"', 14),
#   ('"34189496"', 14),
#   ('"34189496"', 14),
#   ('"34189496"', 14),
#   ('"34189496"', 14),
#   ('"34189496"', 14),
#   ('"34189496"', 14),
#   ('"34189496"', 14),
#   ('"33476687"', 23),
#   ('"33476687"', 23),
#   ('"33476687"', 23),
#   ('"33476687"', 23),
#   ('"33476687"', 23),
#   ('"33476687"', 23),
#   ('"33488508"', 7),
#   ('"33488508"', 7),
#   ('"33488508"', 7),
#   ('"33488508"', 7),
#   ('"33488508"', 7),
#   ('"33488508"', 7),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"12691403"', 16),
#   ('"12691403"', 16),
#   ('"12691403"', 16),
#   ('"12691403"', 16),
#   ('"12691403"', 16),
#   ('"12691403"', 16),
#   ('"12821512"', 9),
#   ('"12821512"', 9),
#   ('"12821512"', 9),
#   ('"12821512"', 9),
#   ('"12821512"', 9),
#   ('"12821512"', 9),
#   ('"33468570"', 13),
#   ('"33468570"', 13),
#   ('"33468570"', 13),
#   ('"33468570"', 13),
#   ('"33468570"', 13),
#   ('"33468570"', 13),
#   ('"33468570"', 13),
#   ('"33468570"', 13),
#   ('"33468570"', 13),
#   ('"33468570"', 13),
#   ('"33468570"', 13),
#   ('"33468570"', 13),
#   ('"17702041"', 4),
#   ('"17702041"', 4),
#   ('"17702041"', 4),
#   ('"17702041"', 4),
#   ('"17702041"', 4),
#   ('"17702041"', 4),
#   ('"19349605"', 3),
#   ('"19349605"', 3),
#   ('"19349605"', 3),
#   ('"19349605"', 3),
#   ('"19349605"', 3),
#   ('"19349605"', 3),
#   ('"15954129"', 3),
#   ('"15954129"', 3),
#   ('"15954129"', 3),
#   ('"15954129"', 3),
#   ('"15954129"', 3),
#   ('"15954129"', 3),
#   ('"26087139"', 3),
#   ('"26087139"', 3),
#   ('"26087139"', 3),
#   ('"26087139"', 3),
#   ('"26087139"', 3),
#   ('"26087139"', 3),
#   ('"17061185"', 10),
#   ('"17061185"', 10),
#   ('"17061185"', 10),
#   ('"17061185"', 10),
#   ('"17061185"', 10),
#   ('"17061185"', 10),
#   ('"22151759"', 3),
#   ('"22151759"', 3),
#   ('"22151759"', 3),
#   ('"22151759"', 3),
#   ('"22151759"', 3),
#   ('"22151759"', 3),
#   ('"24949445"', 2),
#   ('"24949445"', 2),
#   ('"24949445"', 2),
#   ('"24949445"', 2),
#   ('"24949445"', 2),
#   ('"24949445"', 2),
#   ('"21839475"', 2),
#   ('"21839475"', 2),
#   ('"21839475"', 2),
#   ('"21839475"', 2),
#   ('"21839475"', 2),
#   ('"21839475"', 2),
#   ('"15505159"', 5),
#   ('"15505159"', 5),
#   ('"15505159"', 5),
#   ('"15505159"', 5),
#   ('"15505159"', 5),
#   ('"15505159"', 5),
#   ('"12652041"', 4),
#   ('"12652041"', 4),
#   ('"12652041"', 4),
#   ('"12652041"', 4),
#   ('"12652041"', 4),
#   ('"12652041"', 4),
#   ('"9837831"', 9),
#   ('"9837831"', 9),
#   ('"9837831"', 9),
#   ('"9837831"', 9),
#   ('"9837831"', 9),
#   ('"9837831"', 9),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"28102337"', 2),
#   ('"28102337"', 2),
#   ('"28102337"', 2),
#   ('"28102337"', 2),
#   ('"28102337"', 2),
#   ('"28102337"', 2),
#   ('"25894231"', 2),
#   ('"25894231"', 2),
#   ('"25894231"', 2),
#   ('"25894231"', 2),
#   ('"25894231"', 2),
#   ('"25894231"', 2),
#   ('"23622412"', 4),
#   ('"23622412"', 4),
#   ('"23622412"', 4),
#   ('"23622412"', 4),
#   ('"23622412"', 4),
#   ('"23622412"', 4),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"22166420"', 7),
#   ('"22166420"', 7),
#   ('"22166420"', 7),
#   ('"22166420"', 7),
#   ('"22166420"', 7),
#   ('"22166420"', 7),
#   ('"22345219"', 4),
#   ('"22345219"', 4),
#   ('"22345219"', 4),
#   ('"22345219"', 4),
#   ('"22345219"', 4),
#   ('"22345219"', 4),
#   ('"21496608"', 2),
#   ('"21496608"', 2),
#   ('"21496608"', 2),
#   ('"21496608"', 2),
#   ('"21496608"', 2),
#   ('"21496608"', 2),
#   ('"20627944"', 14),
#   ('"20627944"', 14),
#   ('"20627944"', 14),
#   ('"20627944"', 14),
#   ('"20627944"', 14),
#   ('"20627944"', 14),
#   ('"20841370"', 2),
#   ('"20841370"', 2),
#   ('"20841370"', 2),
#   ('"20841370"', 2),
#   ('"20841370"', 2),
#   ('"20841370"', 2),
#   ('"18265016"', 5),
#   ('"18265016"', 5),
#   ('"18265016"', 5),
#   ('"18265016"', 5),
#   ('"18265016"', 5),
#   ('"18265016"', 5),
#   ('"18267263"', 5),
#   ('"18267263"', 5),
#   ('"18267263"', 5),
#   ('"18267263"', 5),
#   ('"18267263"', 5),
#   ('"18267263"', 5),
#   ('"16227522"', 2),
#   ('"16227522"', 2),
#   ('"16227522"', 2),
#   ('"16227522"', 2),
#   ('"16227522"', 2),
#   ('"16227522"', 2),
#   ('"15390016"', 2),
#   ('"15390016"', 2),
#   ('"15390016"', 2),
#   ('"15390016"', 2),
#   ('"15390016"', 2),
#   ('"15390016"', 2),
#   ('"14872019"', 5),
#   ('"14872019"', 5),
#   ('"14872019"', 5),
#   ('"14872019"', 5),
#   ('"14872019"', 5),
#   ('"14872019"', 5),
#   ('"14628853"', 3),
#   ('"14628853"', 3),
#   ('"14628853"', 3),
#   ('"14628853"', 3),
#   ('"14628853"', 3),
#   ('"14628853"', 3),
#   ('"31618684"', 6),
#   ('"31618684"', 6),
#   ('"31618684"', 6),
#   ('"31618684"', 6),
#   ('"31618684"', 6),
#   ('"31618684"', 6),
#   ('"31618684"', 6),
#   ('"31618684"', 6),
#   ('"31618684"', 6),
#   ('"31618684"', 6),
#   ('"31618684"', 6),
#   ('"31618684"', 6),
#   ('"27716431"', 11),
#   ('"27716431"', 11),
#   ('"27716431"', 11),
#   ('"27716431"', 11),
#   ('"27716431"', 11),
#   ('"27716431"', 11),
#   ('"27716431"', 11),
#   ('"27716431"', 11),
#   ('"27716431"', 11),
#   ('"27716431"', 11),
#   ('"27716431"', 11),
#   ('"27716431"', 11),
#   ('"23967309"', 15),
#   ('"23967309"', 15),
#   ('"23967309"', 15),
#   ('"23967309"', 15),
#   ('"23967309"', 15),
#   ('"23967309"', 15),
#   ('"23018676"', 7),
#   ('"23018676"', 7),
#   ('"23018676"', 7),
#   ('"23018676"', 7),
#   ('"23018676"', 7),
#   ('"23018676"', 7),
#   ('"22391119"', 12),
#   ('"22391119"', 12),
#   ('"22391119"', 12),
#   ('"22391119"', 12),
#   ('"22391119"', 12),
#   ('"22391119"', 12),
#   ('"21995941"', 8),
#   ('"21995941"', 8),
#   ('"21995941"', 8),
#   ('"21995941"', 8),
#   ('"21995941"', 8),
#   ('"21995941"', 8),
#   ('"21078339"', 13),
#   ('"21078339"', 13),
#   ('"21078339"', 13),
#   ('"21078339"', 13),
#   ('"21078339"', 13),
#   ('"21078339"', 13),
#   ('"20584926"', 10),
#   ('"20584926"', 10),
#   ('"20584926"', 10),
#   ('"20584926"', 10),
#   ('"20584926"', 10),
#   ('"20584926"', 10),
#   ('"20223934"', 12),
#   ('"20223934"', 12),
#   ('"20223934"', 12),
#   ('"20223934"', 12),
#   ('"20223934"', 12),
#   ('"20223934"', 12),
#   ('"20132487"', 14),
#   ('"20132487"', 14),
#   ('"20132487"', 14),
#   ('"20132487"', 14),
#   ('"20132487"', 14),
#   ('"20132487"', 14),
#   ('"18299128"', 18),
#   ('"18299128"', 18),
#   ('"18299128"', 18),
#   ('"18299128"', 18),
#   ('"18299128"', 18),
#   ('"18299128"', 18),
#   ('"17956903"', 13),
#   ('"17956903"', 13),
#   ('"17956903"', 13),
#   ('"17956903"', 13),
#   ('"17956903"', 13),
#   ('"17956903"', 13),
#   ('"17550429"', 19),
#   ('"17550429"', 19),
#   ('"17550429"', 19),
#   ('"17550429"', 19),
#   ('"17550429"', 19),
#   ('"17550429"', 19),
#   ('"17428918"', 10),
#   ('"17428918"', 10),
#   ('"17428918"', 10),
#   ('"17428918"', 10),
#   ('"17428918"', 10),
#   ('"17428918"', 10),
#   ('"16934985"', 13),
#   ('"16934985"', 13),
#   ('"16934985"', 13),
#   ('"16934985"', 13),
#   ('"16934985"', 13),
#   ('"16934985"', 13),
#   ('"16364891"', 5),
#   ('"16364891"', 5),
#   ('"16364891"', 5),
#   ('"16364891"', 5),
#   ('"16364891"', 5),
#   ('"16364891"', 5),
#   ('"15930383"', 10),
#   ('"15930383"', 10),
#   ('"15930383"', 10),
#   ('"15930383"', 10),
#   ('"15930383"', 10),
#   ('"15930383"', 10),
#   ('"36417958"', 19),
#   ('"36417958"', 19),
#   ('"36417958"', 19),
#   ('"36417958"', 19),
#   ('"36417958"', 19),
#   ('"36417958"', 19),
#   ('"36417958"', 19),
#   ('"36417958"', 19),
#   ('"36417958"', 19),
#   ('"36417958"', 19),
#   ('"36417958"', 19),
#   ('"36417958"', 19),
#   ('"35955710"', 5),
#   ('"35955710"', 5),
#   ('"35955710"', 5),
#   ('"35955710"', 5),
#   ('"35955710"', 5),
#   ('"35955710"', 5),
#   ('"35955710"', 5),
#   ('"35955710"', 5),
#   ('"35955710"', 5),
#   ('"35955710"', 5),
#   ('"35955710"', 5),
#   ('"35955710"', 5),
#   ('"36546658"', 11),
#   ('"36546658"', 11),
#   ('"36546658"', 11),
#   ('"36546658"', 11),
#   ('"36546658"', 11),
#   ('"36546658"', 11),
#   ('"31805123"', 6),
#   ('"31805123"', 6),
#   ('"31805123"', 6),
#   ('"31805123"', 6),
#   ('"31805123"', 6),
#   ('"31805123"', 6),
#   ('"31320448"', 7),
#   ('"31320448"', 7),
#   ('"31320448"', 7),
#   ('"31320448"', 7),
#   ('"31320448"', 7),
#   ('"31320448"', 7),
#   ('"26183317"', 10),
#   ('"26183317"', 10),
#   ('"26183317"', 10),
#   ('"26183317"', 10),
#   ('"26183317"', 10),
#   ('"26183317"', 10),
#   ('"24951854"', 17),
#   ('"24951854"', 17),
#   ('"24951854"', 17),
#   ('"24951854"', 17),
#   ('"24951854"', 17),
#   ('"24951854"', 17),
#   ('"20460154"', 3),
#   ('"20460154"', 3),
#   ('"20460154"', 3),
#   ('"20460154"', 3),
#   ('"20460154"', 3),
#   ('"20460154"', 3),
#   ('"30237473"', 1),
#   ('"30237473"', 1),
#   ('"30237473"', 1),
#   ('"30237473"', 1),
#   ('"30237473"', 1),
#   ('"30237473"', 1),
#   ('"33247415"', 1),
#   ('"33247415"', 1),
#   ('"33247415"', 1),
#   ('"33247415"', 1),
#   ('"33247415"', 1),
#   ('"33247415"', 1),
#   ('"33247415"', 1),
#   ('"33247415"', 1),
#   ('"33247415"', 1),
#   ('"33247415"', 1),
#   ('"33247415"', 1),
#   ('"33247415"', 1),
#   ('"32516804"', 9),
#   ('"32516804"', 9),
#   ('"32516804"', 9),
#   ('"32516804"', 9),
#   ('"32516804"', 9),
#   ('"32516804"', 9),
#   ('"32516804"', 9),
#   ('"32516804"', 9),
#   ('"32516804"', 9),
#   ('"32516804"', 9),
#   ('"32516804"', 9),
#   ('"32516804"', 9),
#   ('"29739751"', 4),
#   ('"29739751"', 4),
#   ('"29739751"', 4),
#   ('"29739751"', 4),
#   ('"29739751"', 4),
#   ('"29739751"', 4),
#   ('"32079672"', 2),
#   ('"32079672"', 2),
#   ('"32079672"', 2),
#   ('"32079672"', 2),
#   ('"32079672"', 2),
#   ('"32079672"', 2),
#   ('"24938147"', 1),
#   ('"24938147"', 1),
#   ('"24938147"', 1),
#   ('"24938147"', 1),
#   ...],
#  'tremor': [('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"34264428"', 1),
#   ('"34264428"', 1),
#   ('"34264428"', 1),
#   ('"34264428"', 1),
#   ('"34264428"', 1),
#   ('"34264428"', 1),
#   ('"34264428"', 1),
#   ('"34264428"', 1),
#   ('"34264428"', 1),
#   ('"34264428"', 1),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"21907099"', 4),
#   ('"21907099"', 4),
#   ('"21907099"', 4),
#   ('"21907099"', 4),
#   ('"21907099"', 4),
#   ('"21907099"', 4),
#   ('"21907099"', 4),
#   ('"21907099"', 4),
#   ('"21907099"', 4),
#   ('"21907099"', 4),
#   ('"8232931"', 2),
#   ('"8232931"', 2),
#   ('"8232931"', 2),
#   ('"8232931"', 2),
#   ('"8232931"', 2),
#   ('"8232931"', 2),
#   ('"8232931"', 2),
#   ('"8232931"', 2),
#   ('"8232931"', 2),
#   ('"8232931"', 2),
#   ('"10477437"', 1),
#   ('"10477437"', 1),
#   ('"10477437"', 1),
#   ('"10477437"', 1),
#   ('"10477437"', 1),
#   ('"10477437"', 1),
#   ('"10477437"', 1),
#   ('"10477437"', 1),
#   ('"10477437"', 1),
#   ('"10477437"', 1),
#   ('"9440801"', 2),
#   ('"9440801"', 2),
#   ('"9440801"', 2),
#   ('"9440801"', 2),
#   ('"9440801"', 2),
#   ('"9440801"', 2),
#   ('"9440801"', 2),
#   ('"9440801"', 2),
#   ('"9440801"', 2),
#   ('"9440801"', 2),
#   ('"650244"', 2),
#   ('"650244"', 2),
#   ('"650244"', 2),
#   ('"650244"', 2),
#   ('"650244"', 2),
#   ('"650244"', 2),
#   ('"650244"', 2),
#   ('"650244"', 2),
#   ('"650244"', 2),
#   ('"650244"', 2),
#   ('"7164771"', 1),
#   ('"7164771"', 1),
#   ('"7164771"', 1),
#   ('"7164771"', 1),
#   ('"7164771"', 1),
#   ('"7164771"', 1),
#   ('"7164771"', 1),
#   ('"7164771"', 1),
#   ('"7164771"', 1),
#   ('"7164771"', 1),
#   ('"16602679"', 1),
#   ('"16602679"', 1),
#   ('"16602679"', 1),
#   ('"16602679"', 1),
#   ('"16602679"', 1),
#   ('"16602679"', 1),
#   ('"16602679"', 1),
#   ('"16602679"', 1),
#   ('"16602679"', 1),
#   ('"16602679"', 1),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"29053766"', 2),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1),
#   ('"30244176"', 1)],
#  'myoclonus': [('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"30028274"', 2),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"23284065"', 8),
#   ('"33832800"', 1),
#   ('"33832800"', 1),
#   ('"33832800"', 1),
#   ('"33832800"', 1),
#   ('"33832800"', 1),
#   ('"33832800"', 1),
#   ('"33832800"', 1),
#   ('"33832800"', 1),
#   ('"33832800"', 1),
#   ('"33832800"', 1),
#   ('"33832800"', 1),
#   ('"33832800"', 1),
#   ('"22040906"', 4),
#   ('"22040906"', 4),
#   ('"22040906"', 4),
#   ('"22040906"', 4),
#   ('"22040906"', 4),
#   ('"22040906"', 4),
#   ('"22040906"', 4),
#   ('"22040906"', 4),
#   ('"22040906"', 4),
#   ('"22040906"', 4),
#   ('"22040906"', 4),
#   ('"22040906"', 4),
#   ('"22080833"', 4),
#   ('"22080833"', 4),
#   ('"22080833"', 4),
#   ('"22080833"', 4),
#   ('"22080833"', 4),
#   ('"22080833"', 4),
#   ('"22080833"', 4),
#   ('"22080833"', 4),
#   ('"22080833"', 4),
#   ('"22080833"', 4),
#   ('"22080833"', 4),
#   ('"22080833"', 4),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"20482602"', 2),
#   ('"20482602"', 2),
#   ('"20482602"', 2),
#   ('"20482602"', 2),
#   ('"20482602"', 2),
#   ('"20482602"', 2),
#   ('"20482602"', 2),
#   ('"20482602"', 2),
#   ('"20482602"', 2),
#   ('"20482602"', 2),
#   ('"20482602"', 2),
#   ('"20482602"', 2)],
#  'diarrhea': [],
#  'depression': [('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"15326234"', 7),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"34398825"', 4),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3),
#   ('"33991565"', 3)],
#  'abdominal pain': [],
#  'weight loss': [],
#  'ataxia': [('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"22345219"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1),
#   ('"16227563"', 1)],
#  'dysarthria': [],
#  'anemia': [],
#  'parkinsonism': [('"1985454"', 2),
#   ('"1985454"', 2),
#   ('"1985454"', 2),
#   ('"1985454"', 2),
#   ('"1985454"', 2),
#   ('"1985454"', 2),
#   ('"11523564"', 6),
#   ('"11523564"', 6),
#   ('"11523564"', 6),
#   ('"11523564"', 6),
#   ('"11523564"', 6),
#   ('"11523564"', 6),
#   ('"22132914"', 3),
#   ('"22132914"', 3),
#   ('"22132914"', 3),
#   ('"22132914"', 3),
#   ('"22132914"', 3),
#   ('"22132914"', 3),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"24262166"', 2),
#   ('"15390042"', 3),
#   ('"15390042"', 3),
#   ('"15390042"', 3),
#   ('"15390042"', 3),
#   ('"15390042"', 3),
#   ('"15390042"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"22266882"', 3),
#   ('"10979329"', 2),
#   ('"10979329"', 2),
#   ('"10979329"', 2),
#   ('"10979329"', 2),
#   ('"10979329"', 2),
#   ('"10979329"', 2),
#   ('"19578124"', 1),
#   ('"19578124"', 1),
#   ('"19578124"', 1),
#   ('"19578124"', 1),
#   ('"19578124"', 1),
#   ('"19578124"', 1),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"24092288"', 2),
#   ('"10720299"', 2),
#   ('"10720299"', 2),
#   ('"10720299"', 2),
#   ('"10720299"', 2),
#   ('"10720299"', 2),
#   ('"10720299"', 2),
#   ('"2164296"', 2),
#   ('"2164296"', 2),
#   ('"2164296"', 2),
#   ('"2164296"', 2),
#   ('"2164296"', 2),
#   ('"2164296"', 2)],
#  'torsion dystonia': [('"1867195"', 2),
#   ('"941766"', 2),
#   ('"7436383"', 2),
#   ('"1121020"', 2),
#   ('"1347197"', 6),
#   ('"12575458"', 6),
#   ('"10541594"', 3),
#   ('"19345148"', 6),
#   ('"8004804"', 5),
#   ('"9288096"', 8),
#   ('"9149944"', 7),
#   ('"11973627"', 1),
#   ('"15111678"', 1),
#   ('"15455404"', 3),
#   ('"17503336"', 2),
#   ('"33638639"', 6),
#   ('"10994500"', 2),
#   ('"8255463"', 4),
#   ('"22266882"', 3),
#   ('"1427899"', 2),
#   ('"14989804"', 8),
#   ('"24949445"', 2),
#   ('"15505159"', 2),
#   ('"9837831"', 5),
#   ('"14628853"', 1),
#   ('"21078339"', 11),
#   ('"20584926"', 8),
#   ('"20223934"', 6),
#   ('"20132487"', 6),
#   ('"18827015"', 7),
#   ('"17956903"', 8),
#   ('"17550429"', 4),
#   ('"17428918"', 5),
#   ('"16934985"', 7),
#   ('"16458269"', 4),
#   ('"16364891"', 5),
#   ('"11730696"', 5),
#   ('"10814722"', 8),
#   ('"36546658"', 6),
#   ('"26183317"', 5),
#   ('"24951854"', 4),
#   ('"23840813"', 2),
#   ('"20460154"', 1),
#   ('"18322712"', 6),
#   ('"33134321"', 3),
#   ('"22040906"', 2),
#   ('"10644435"', 10),
#   ('"19182804"', 3),
#   ('"2404852"', 2),
#   ('"12609485"', 1),
#   ('"19038309"', 9),
#   ('"23196519"', 6),
#   ('"23222958"', 5),
#   ('"24931141"', 8),
#   ('"29396398"', 6),
#   ('"9874484"', 4),
#   ('"9749609"', 5),
#   ('"9618171"', 13),
#   ('"9585364"', 15),
#   ('"7654519"', 4),
#   ('"21750546"', 5),
#   ('"19651773"', 4),
#   ('"19039992"', 11),
#   ('"18552369"', 7),
#   ('"18258738"', 10),
#   ('"10477437"', 9),
#   ('"10627938"', 6),
#   ('"10714658"', 9),
#   ('"10871631"', 10),
#   ('"10984667"', 10),
#   ('"11835464"', 4),
#   ('"15555920"', 7),
#   ('"16361107"', 1),
#   ('"16537570"', 3),
#   ('"17129379"', 5),
#   ('"22472189"', 6),
#   ('"12671990"', 7),
#   ('"19214438"', 3),
#   ('"11405807"', 4),
#   ('"25674472"', 10),
#   ('"21818381"', 3),
#   ('"20169475"', 13),
#   ('"15136718"', 5),
#   ('"9750906"', 5),
#   ('"10434613"', 5),
#   ('"11584049"', 3),
#   ('"11438481"', 3),
#   ('"14690443"', 7),
#   ('"15099679"', 3),
#   ('"15147511"', 3),
#   ('"15269177"', 3),
#   ('"15505207"', 6),
#   ('"15829632"', 5),
#   ('"19761814"', 5),
#   ('"24627482"', 9),
#   ('"28768697"', 9),
#   ('"34062155"', 3),
#   ('"2073302"', 2),
#   ('"3984684"', 2),
#   ('"690631"', 2),
#   ('"2164296"', 1),
#   ('"10833562"', 3),
#   ('"11714689"', 4),
#   ('"14509659"', 5),
#   ('"21965893"', 2),
#   ('"24931141"', 8),
#   ('"29641419"', 1),
#   ('"24627482"', 9),
#   ('"28768697"', 9),
#   ('"33134321"', 3),
#   ('"34062155"', 3),
#   ('"26183317"', 5),
#   ('"33638639"', 6)],
#  'anxiety': [],
#  'microcephaly': [],
#  'celiac disease': [('"33885207"', 1),
#   ('"33885207"', 1),
#   ('"24444577"', 1),
#   ('"24444577"', 1),
#   ('"19688081"', 1),
#   ('"19688081"', 1),
#   ('"16552828"', 1),
#   ('"16552828"', 1),
#   ('"32118025"', 1),
#   ('"32118025"', 1),
#   ('"29561984"', 3),
#   ('"29561984"', 3),
#   ('"30981209"', 1),
#   ('"30981209"', 1),
#   ('"37554750"', 1),
#   ('"37554750"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"35694992"', 3),
#   ('"35694992"', 3),
#   ('"10201480"', 1),
#   ('"10201480"', 1),
#   ('"18689116"', 1),
#   ('"18689116"', 1),
#   ('"20178968"', 1),
#   ('"20178968"', 1),
#   ('"20359791"', 1),
#   ('"20359791"', 1),
#   ('"20661732"', 1),
#   ('"20661732"', 1),
#   ('"21621928"', 1),
#   ('"21621928"', 1),
#   ('"29516402"', 1),
#   ('"29516402"', 1),
#   ('"29858799"', 1),
#   ('"29858799"', 1)],
#  'diabetes mellitus': [('"28387648"', 1),
#   ('"28387648"', 1),
#   ('"28387648"', 1),
#   ('"28387648"', 1),
#   ('"28387648"', 1),
#   ('"28387648"', 1),
#   ('"28387648"', 1),
#   ('"28387648"', 1),
#   ('"28387648"', 1),
#   ('"28387648"', 1),
#   ('"33725967"', 1),
#   ('"33725967"', 1),
#   ('"33725967"', 1),
#   ('"33725967"', 1),
#   ('"33725967"', 1),
#   ('"33725967"', 1),
#   ('"33725967"', 1),
#   ('"33725967"', 1),
#   ('"33725967"', 1),
#   ('"33725967"', 1),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2),
#   ('"16275837"', 2)],
#  'osteoporosis': [],
#  'blepharospasm': [('"15505159"', 3),
#   ('"15505159"', 3),
#   ('"15505159"', 3),
#   ('"15505159"', 3),
#   ('"15159681"', 1),
#   ('"15159681"', 1),
#   ('"15159681"', 1),
#   ('"15159681"', 1),
#   ('"19284587"', 1),
#   ('"19284587"', 1),
#   ('"19284587"', 1),
#   ('"19284587"', 1),
#   ('"941774"', 2),
#   ('"941774"', 2),
#   ('"941774"', 2),
#   ('"941774"', 2),
#   ('"12030016"', 2),
#   ('"12030016"', 2),
#   ('"12030016"', 2),
#   ('"12030016"', 2),
#   ('"650244"', 2),
#   ('"650244"', 2),
#   ('"650244"', 2),
#   ('"650244"', 2),
#   ('"19765051"', 1),
#   ('"19765051"', 1),
#   ('"19765051"', 1),
#   ('"19765051"', 1)],
#  'vomiting': [],
#  'pain': [('"35955710"', 7),
#   ('"35955710"', 7),
#   ('"35955710"', 7),
#   ('"35955710"', 7),
#   ('"35955710"', 7),
#   ('"35955710"', 7),
#   ('"35955710"', 7),
#   ('"35955710"', 7),
#   ('"33445430"', 1),
#   ('"33445430"', 1),
#   ('"33445430"', 1),
#   ('"33445430"', 1),
#   ('"17706474"', 1),
#   ('"17706474"', 1),
#   ('"17706474"', 1),
#   ('"17706474"', 1),
#   ('"2868026"', 1),
#   ('"2868026"', 1),
#   ('"2868026"', 1),
#   ('"2868026"', 1),
#   ('"35955710"', 7),
#   ('"35955710"', 7),
#   ('"35955710"', 7),
#   ('"35955710"', 7),
#   ('"35955710"', 7),
#   ('"35955710"', 7),
#   ('"35955710"', 7),
#   ('"35955710"', 7),
#   ('"33445430"', 1),
#   ('"33445430"', 1),
#   ('"33445430"', 1),
#   ('"33445430"', 1)],
#  'fever': [],
#  'immunodeficiency': [('"23609110"', 1),
#   ('"23609110"', 1),
#   ('"23609110"', 1),
#   ('"23609110"', 1),
#   ('"23609110"', 1),
#   ('"23609110"', 1),
#   ('"23609110"', 1),
#   ('"23609110"', 1),
#   ('"23609110"', 1),
#   ('"23609110"', 1),
#   ('"23609110"', 1),
#   ('"23609110"', 1),
#   ('"23609110"', 1),
#   ('"23609110"', 1),
#   ('"23609110"', 1),
#   ('"23609110"', 1)],
#  'hypertension': [],
#  'malabsorption': [],
#  'villous atrophy': [('"32118025"', 1),
#   ('"32118025"', 1),
#   ('"32118025"', 1),
#   ('"32118025"', 1),
#   ('"32118025"', 1),
#   ('"32044834"', 1),
#   ('"32044834"', 1),
#   ('"32044834"', 1),
#   ('"32044834"', 1),
#   ('"32044834"', 1)],
#  'chorea': [('"9146024"', 2),
#   ('"9146024"', 2),
#   ('"9146024"', 2),
#   ('"9146024"', 2),
#   ('"9146024"', 2),
#   ('"23420606"', 2),
#   ('"23420606"', 2),
#   ('"23420606"', 2),
#   ('"23420606"', 2),
#   ('"23420606"', 2),
#   ('"11940688"', 2),
#   ('"11940688"', 2),
#   ('"11940688"', 2),
#   ('"11940688"', 2),
#   ('"11940688"', 2),
#   ('"16602679"', 1),
#   ('"16602679"', 1),
#   ('"16602679"', 1),
#   ('"16602679"', 1),
#   ('"16602679"', 1)],
#  'osteopenia': [],
#  'short stature': [],
#  'autoimmunity': [],
#  'peripheral neuropathy': [],
#  'dyskinesia': [('"33458877"', 4),
#   ('"33458877"', 4),
#   ('"33458877"', 4),
#   ('"33458877"', 4),
#   ('"33458877"', 4),
#   ('"33458877"', 4),
#   ('"7164771"', 1),
#   ('"7164771"', 1),
#   ('"7164771"', 1),
#   ('"7164771"', 1),
#   ('"7164771"', 1),
#   ('"7164771"', 1)],
#  'headache': [('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1),
#   ('"32195978"', 1)],
#  'scoliosis': [],
#  'dysphagia': [],
#  'hypotonia': [],
#  'neuroblastoma': [('"15593317"', 2),
#   ('"15593317"', 2),
#   ('"15593317"', 2),
#   ('"15593317"', 2),
#   ('"15593317"', 2),
#   ('"15593317"', 2),
#   ('"15593317"', 2),
#   ('"15593317"', 2),
#   ('"15593317"', 2),
#   ('"15593317"', 2),
#   ('"16361107"', 2),
#   ('"16361107"', 2),
#   ('"16361107"', 2),
#   ('"16361107"', 2),
#   ('"16361107"', 2),
#   ('"16361107"', 2),
#   ('"16361107"', 2),
#   ('"16361107"', 2),
#   ('"16361107"', 2),
#   ('"16361107"', 2),
#   ('"19761814"', 2),
#   ('"19761814"', 2),
#   ('"19761814"', 2),
#   ('"19761814"', 2),
#   ('"19761814"', 2),
#   ('"19761814"', 2),
#   ('"19761814"', 2),
#   ('"19761814"', 2),
#   ('"19761814"', 2),
#   ('"19761814"', 2)],
#  'spasticity': [],
#  'fatigue': [],
#  'thrombocytopenia': [],
#  'rigidity': [('"6234055"', 1),
#   ('"6234055"', 1),
#   ('"6234055"', 1),
#   ('"6234055"', 1),
#   ('"6234055"', 1),
#   ('"6234055"', 1),
#   ('"6234055"', 1),
#   ('"6234055"', 1),
#   ('"6234055"', 1)],
#  'neurodegeneration': [('"12785748"', 2),
#   ('"12785748"', 2),
#   ('"12785748"', 2),
#   ('"22132914"', 3),
#   ('"22132914"', 3),
#   ('"22132914"', 3),
#   ('"32516804"', 1),
#   ('"32516804"', 1),
#   ('"32516804"', 1),
#   ('"19457118"', 2),
#   ('"19457118"', 2),
#   ('"19457118"', 2),
#   ('"32516804"', 1),
#   ('"32516804"', 1),
#   ('"32516804"', 1)],
#  'lymphoma': [('"30302434"', 1),
#   ('"30302434"', 1),
#   ('"30302434"', 1),
#   ('"30302434"', 1),
#   ('"30302434"', 1),
#   ('"30302434"', 1)],
#  'encephalopathy': [('"25449075"', 1),
#   ('"25449075"', 1),
#   ('"25449075"', 1),
#   ('"25449075"', 1)],
#  'ventriculomegaly': [],
#  'hyperactivity': [('"17956903"', 4),
#   ('"17956903"', 4),
#   ('"17956903"', 4),
#   ('"17956903"', 4),
#   ('"17956903"', 4),
#   ('"690631"', 2),
#   ('"690631"', 2),
#   ('"690631"', 2),
#   ('"690631"', 2),
#   ('"690631"', 2)],
#  'nystagmus': [],
#  'optic atrophy': [],
#  'respiratory failure': [],
#  'hemiparesis': [],
#  'amenorrhea': [],
#  'hypothyroidism': [],
#  'sepsis': [],
#  'cognitive impairment': [],
#  'visual impairment': [],
#  'hydrocephalus': [],
#  'stroke': [],
#  'involuntary movements': [],
#  'hypertonia': [],
#  'pruritus': [],
#  'infantile spasms': [('"25449075"', 1),
#   ('"25449075"', 1),
#   ('"25449075"', 1),
#   ('"25449075"', 1)],
#  'dilated cardiomyopathy': [],
#  'dysphonia': [('"19284587"', 1),
#   ('"19284587"', 1),
#   ('"650244"', 2),
#   ('"650244"', 2)],
#  'psychosis': [('"20471632"', 2),
#   ('"20471632"', 2),
#   ('"20471632"', 2),
#   ('"20471632"', 2),
#   ('"20471632"', 2),
#   ('"20471632"', 2),
#   ('"20471632"', 2),
#   ('"20471632"', 2),
#   ('"20471632"', 2),
#   ('"20471632"', 2)],
#  'bradykinesia': [('"7695236"', 2),
#   ('"7695236"', 2),
#   ('"7695236"', 2),
#   ('"7695236"', 2),
#   ('"7695236"', 2)],
#  'arthrogryposis multiplex congenita': [('"36757831"', 3),
#   ('"36757831"', 3),
#   ('"36757831"', 3),
#   ('"35303767"', 2),
#   ('"35303767"', 2),
#   ('"35303767"', 2),
#   ('"35303767"', 2),
#   ('"35303767"', 2),
#   ('"35303767"', 2),
#   ('"35303767"', 2),
#   ('"35303767"', 2),
#   ('"35303767"', 2),
#   ('"35303767"', 2),
#   ('"35303767"', 2),
#   ('"35303767"', 2),
#   ('"36757831"', 3),
#   ('"36757831"', 3),
#   ('"36757831"', 3)],
#  'malnutrition': [],
#  'epileptic encephalopathy': [('"31580306"', 2),
#   ('"31580306"', 2),
#   ('"31580306"', 2)],
#  'retinopathy': [],
#  'dehydration': [],
#  'autism': [],
#  'limb dystonia': [('"34092466"', 3),
#   ('"34092466"', 3),
#   ('"34092466"', 3),
#   ('"34092466"', 3)],
#  'athetosis': [],
#  'paralysis': [('"24627482"', 4),
#   ('"24627482"', 4),
#   ('"24627482"', 4),
#   ('"24627482"', 4),
#   ('"24627482"', 4),
#   ('"24627482"', 4),
#   ('"24627482"', 4),
#   ('"24627482"', 4),
#   ('"24627482"', 4),
#   ('"24627482"', 4),
#   ('"24627482"', 4),
#   ('"24627482"', 4),
#   ('"24627482"', 4),
#   ('"24627482"', 4)],
#  'impulsivity': [],
#  'kyphoscoliosis': [],
#  'iron deficiency anemia': [],
#  'arthralgia': [],
#  'dementia': [],
#  'paroxysmal dystonia': [('"12194383"', 2), ('"10919137"', 2)],
#  'insomnia': [],
#  'hyperglycemia': [],
#  'cirrhosis': [],
#  'astrocytoma': [],
#  'hepatitis': [],
#  'chronic pain': [],
#  'tachycardia': [],
#  'myopathy': [],
#  'nausea': [],
#  'systemic lupus erythematosus': [],
#  'lower limb spasticity': [],
#  'hypoglycemia': [],
#  'choreoathetosis': [('"12691403"', 9), ('"12691403"', 9)],
#  'cardiomyopathy': [('"25425325"', 2), ('"25425325"', 2)],
#  'talipes equinovarus': [],
#  'gait ataxia': [],
#  'glomerulonephritis': [],
#  'photophobia': [],
#  'torticollis': [],
#  'myalgia': [],
#  'muscle spasm': [('"16275837"', 2), ('"16275837"', 2), ('"16275837"', 2)],
#  'hyponatremia': [],
#  'heart block': [],
#  'hyperthyroidism': [],
#  'paraplegia': [],
#  'hand tremor': [('"27919237"', 2), ('"27919237"', 2)],
#  'schizophrenia': [('"20471632"', 1), ('"21965893"', 2)],
#  "writer's cramp": [],
#  'vasculitis': [('"22465228"', 1), ('"22465228"', 1)],
#  'nephropathy': [],
#  'paroxysmal dyskinesia': [],
#  'rheumatoid arthritis': [('"29516402"', 1), ('"29858799"', 1)],
#  'bone fracture': [],
#  'allergy': [],
#  'hyperkinetic movements': [],
#  'pheochromocytoma': [],
#  'nephrotic syndrome': [('"16967287"', 1)],
#  'membranous nephropathy': []}

# %%
result_df['paper_']= result_df.apply(lambda x: pheno_count_smae_Sen[x['Value']]  , axis=1)
def counting_(x):
  num=0
  for i in x:
   num+=i[1]
  return num
result_df['count_paper_']= result_df.apply(lambda x: counting_(x['paper_'])  , axis=1)
result_df
# Out:
#                       Value  Count  \
# 0                  dystonia   2856
# 1                    tremor    350
# 2                 myoclonus    264
# 3                  diarrhea    243
# 4                depression    186
# ..                      ...    ...
# 112                 allergy      1
# 113  hyperkinetic movements      1
# 114        pheochromocytoma      1
# 115      nephrotic syndrome      1
# 116  membranous nephropathy      1
#
#                                                   gene  \
# 0              [CACNA1B, SLC2A1, SLC2A3, DRD2, PDGFRB]
# 1    [GABRA5, CACNA1B, SLC2A1, SCN9A, PDGFRB, FGFR1...
# 2    [RORB, MTOR, GABRA5, ALK, CACNA1B, SLC2A1, SLC...
# 3    [DGAT1, SYK, PIK3CD, PIK3CG, CFTR, LCK, SMO, B...
# 4    [GNRHR, CFTR, MMP1, RPS6KA3, HLA-DRB1, BRAF, T...
# ..                                                 ...
# 112                                             [MTOR]
# 113                                          [CACNA1B]
# 114                                              [RET]
# 115                                             [JAK1]
# 116                                             [JAK1]
#
#                                                 paper_  count_paper_
# 0    [("2317008", 2), ("2317008", 2), ("2317008", 2...         19266
# 1    [("22266882", 3), ("22266882", 3), ("22266882"...           230
# 2    [("24262166", 2), ("24262166", 2), ("24262166"...           360
# 3                                                   []             0
# 4    [("15326234", 7), ("15326234", 7), ("15326234"...           651
# ..                                                 ...           ...
# 112                                                 []             0
# 113                                                 []             0
# 114                                                 []             0
# 115                                  [("16967287", 1)]             1
# 116                                                 []             0
#
# [117 rows x 5 columns]

# %%
result_df['paper_'][5]
# Out:
# [('"12785748"', 2),
#  ('"22132914"', 3),
#  ('"32516804"', 1),
#  ('"19457118"', 2),
#  ('"32516804"', 1)]
